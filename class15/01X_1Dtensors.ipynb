# %% [markdown]
# # Torch tensors

# %%
# These are the libraries will be used for this lab.

import torch 
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 1. Convert a 1D tensor to a 1X5 tensor.

# %%
# Convert the following tensor to a tensor object with 1 row and 5 columns
t = torch.tensor([1, 2, 3, 4, 5])

## YOUR CODE HERE ##

# %%
t.reshape(1, 5)
# Out:
# tensor([[1, 2, 3, 4, 5]])

# %% [markdown]
# #### 2. Change the values on index 3, 4, 7 of the following tensor to 0.

# %%
# Change the values on index 3, 4, 7 to 0
t = torch.tensor([2, 7, 3, 4, 6, 2, 3, 1, 2])

## YOUR CODE HERE ##

# %%
t[3] = 0
t[4] = 0
t[7] = 0
print(t)
# Out:
# tensor([2, 7, 3, 0, 0, 2, 3, 0, 2])
