# %% [markdown]
# # Exercises "Lecture 7: Preprocessing Text"
#
# In this session, you will learn to apply some of the pre-processing steps discussed in the lecture.
#
# * Segmenting a file into sentences and sentences into words (tokenization)
# * Removing punctuation and lowercasing
# * Removing function words
# * Lemmatizing
# * POS tagging
# * Named Entity Recognition
#
# As we'll see in the next lectures, all or some of these pre-processing steps are applied when performing statistical analysis on a text collection or when applying machine learning techniques (classification, clustering, regression).
#
# There are many exercises. Some are marked as OPTIONAL. These are usually complemented with some code showing how to do the task using Spacy, which means that if you haven't done the exercise, you can still implement the task by using the provided (Spacy) code.  In a first pass, I would advise skipping them. In the last exercise, we ask you to use the code and functions developed  during the exercises to preprocess a file containing Wikipedia text.
#
# Python libraries used: SpaCy
# Datafile: webnlg-test.txt
# Cheatsheet: spacy_cheat_sheet.ipynb

# %% [markdown]
# ### Loading a SpaCy model and reading 'webnlg-test.txt' into a string
#
# **Exercice 1**
#
# - Install SpaCy and download English models. Use the en_core_web_sm Model
# - Read "data/webnlg-test.txt" into a string
# - Apply your SpaCy model  to this string

# %%
import spacy
# Load English Model
nlp = spacy.load('en_core_web_sm')

# %%
rawtext=open("webnlg-test.txt").read()
rawtext
# Out:
# 'Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca. Agremiação Sportiva Arapiraquense, nicknamed "Alvinegro", lay in the Campeonato Brasileiro Série C league from Brazil.Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca. Alvinegro, the nickname of Agremiação Sportiva Arapiraquense, play in the Campeonato Brasileiro Série C league from Brazil.Nie Haisheng, born on October 13, 1964, worked as a fighter pilot.Nie Haisheng is a former fighter pilot who was born on October 13, 1964.Nie Haisheng born on 10/13/1964 is a fighter pilot.MotorSport Vision is located in the city of Fawkham.MotorSport Vision is located in the city of Fawkham, UK.MotorSport Vision is located in Fawkham.185 centimetre tall Aleksandr Prudnikov played for the Otkrytiye Arena based FC Spartak, Moscow.The 185 cm tall Aleksandr Prudnikov plays for FC Spartak Moscow who call their home ground Otkrytiye Arena.Aleksandr Prudnikov who is 185 cm tall, plays for FC Spartak Moscow whose ground is the Otkrytiye Arena.Ciudad Ayala is a city with population density and population of 1604 and 1777539 respectively, where the leader is called the City Manager. The government type in the city of Ciudad Ayala is council-manager.The city of Ciudad Ayala, with a population of 1,777,539, is led by a City Manager on a council-manager government system. It has a population density of 1604.Ciudad Ayala, a city with population density and population of 1604.0 and 1,777,539 respectively, uses a type of government called council-manager government. One of the leaders of Ciudad Ayala is the City Manager.The album 1969: The Velvet Underground Live is preceded by the Velvet Underground album Squeeze, which was followed by The Quine Tapes.The Velvet Underground album Bootleg Series Volume 1: The Quine Tapes was preceded by the album Squeeze, which was followed by the live album 1969: The Velvet Underground Live.The Bootleg Series Volume I: The Quine Tapes is preceded by the Velvet Underground album Squeeze which was itself followed by the album 1969: The Velvet Underground Live.Ciudad Ayala in Mexico with population density of 1604.0 and elevated 1147.0 above sea level is in the PDT time zone. The leader here is called the governator.Ciudad Ayala is a country in Mexico that is located 1147 above sea level and is in the Pacific Daylight time zone. The population density is 1604 and the leader of Ciudad Ayala is called the governator.Ciudad Ayala is located in Mexico and has a population density of 1604. The city stands 1147 m above sea level. The Governator is the leader of Ciudad Ayala located in the Pacific Daylight time zone.Olga Bondareva died on December 9, 1991.Olga Bondareva died on the 9th of December, 1991.The date of Olga Bondareva\'s death was the ninth of December 1991.Saint Petersburg was founded on May 27, 1703 and has a total area of 1439.0, Olga Bondareva passed away at Saint Petersburg.Saint Petersburg, where Olga Bondareva died, was founded on the 27th of May, 1703 and has a total area of approximately 1439 km2.Saint Petersburg, where Olga Bondareva died, was founded on May 27, 1703 and consists of a total area of 1439.0 sq/km.The population density of Ciudad Ayala is 1604.0.Ciudad Ayala city has a population density of 1604.0.The population density in Ciudad Ayala is 1604.Piotr Hallmann was born on August 25, 1987.Piotr Hallmann\'s birthday is August 25th 1987.Piotr Hallmann was born on the 25th of August 1987.The Darlington town has an area code of 01325.The telephone area code for Darlington is 01325.The area code in Darlington is 01325.Pennsylvania\'s Franklin County is found to the west of Adams County, Pennsylvania and Pennsylvania\'s Cumberland County is to the north. A monument to the 11th Mississippi Infantry was erected in Adams County in the year 2000 in the municipality of Gettysburg and this monument is categorised as a contrib ...

# %%
import nltk
nltk.download('punkt')  # Downloads the Punkt tokenizer models
nltk.download('punkt_tab')# Downloads additional tokenizer models
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /home/tacit/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/tacit/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/tacit/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.sent_tokenize(rawtext)
# Out:
# ['Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca.',
#  'Agremiação Sportiva Arapiraquense, nicknamed "Alvinegro", lay in the Campeonato Brasileiro Série C league from Brazil.Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca.',
#  'Alvinegro, the nickname of Agremiação Sportiva Arapiraquense, play in the Campeonato Brasileiro Série C league from Brazil.Nie Haisheng, born on October 13, 1964, worked as a fighter pilot.Nie Haisheng is a former fighter pilot who was born on October 13, 1964.Nie Haisheng born on 10/13/1964 is a fighter pilot.MotorSport Vision is located in the city of Fawkham.MotorSport Vision is located in the city of Fawkham, UK.MotorSport Vision is located in Fawkham.185 centimetre tall Aleksandr Prudnikov played for the Otkrytiye Arena based FC Spartak, Moscow.The 185 cm tall Aleksandr Prudnikov plays for FC Spartak Moscow who call their home ground Otkrytiye Arena.Aleksandr Prudnikov who is 185 cm tall, plays for FC Spartak Moscow whose ground is the Otkrytiye Arena.Ciudad Ayala is a city with population density and population of 1604 and 1777539 respectively, where the leader is called the City Manager.',
#  'The government type in the city of Ciudad Ayala is council-manager.The city of Ciudad Ayala, with a population of 1,777,539, is led by a City Manager on a council-manager government system.',
#  'It has a population density of 1604.Ciudad Ayala, a city with population density and population of 1604.0 and 1,777,539 respectively, uses a type of government called council-manager government.',
#  'One of the leaders of Ciudad Ayala is the City Manager.The album 1969: The Velvet Underground Live is preceded by the Velvet Underground album Squeeze, which was followed by The Quine Tapes.The Velvet Underground album Bootleg Series Volume 1: The Quine Tapes was preceded by the album Squeeze, which was followed by the live album 1969: The Velvet Underground Live.The Bootleg Series Volume I: The Quine Tapes is preceded by the Velvet Underground album Squeeze which was itself followed by the album 1969: The Velvet Underground Live.Ciudad Ayala in Mexico with population density of 1604.0 and elevated 1147.0 above sea level is in the PDT time zone.',
#  'The leader here is called the governator.Ciudad Ayala is a country in Mexico that is located 1147 above sea level and is in the Pacific Daylight time zone.',
#  'The population density is 1604 and the leader of Ciudad Ayala is called the governator.Ciudad Ayala is located in Mexico and has a population density of 1604.',
#  'The city stands 1147 m above sea level.',
#  "The Governator is the leader of Ciudad Ayala located in the Pacific Daylight time zone.Olga Bondareva died on December 9, 1991.Olga Bondareva died on the 9th of December, 1991.The date of Olga Bondareva's death was the ninth of December 1991.Saint Petersburg was founded on May 27, 1703 and has a total area of 1439.0, Olga Bondareva passed away at Saint Petersburg.Saint Petersburg, where Olga Bondareva died, was founded on the 27th of May, 1703 and has a total area of approximately 1439 km2.Saint Petersburg, where Olga Bondareva died, was founded on May 27, 1703 and consists of a total area of 1439.0 sq/km.The population density of Ciudad Ayala is 1604.0.Ciudad Ayala city has a population density of 1604.0.The population density in Ciudad Ayala is 1604.Piotr Hallmann was born on August 25, 1987.Piotr Hallmann's birthday is August 25th 1987.Piotr Hallmann was born on the 25th of August 1987.The Darlington town has an area code of 01325.The telephone area code for Darlington is 01325.The area code in Darlington is 01325.Pennsylvania's Franklin County is found to the west of Adams County, Pennsylvania and Pennsylvania's Cumberland County is to the north.",
#  'A monument to the 11th Mississippi Infantry was erected in Adams County in the year 2000 in the municipality of Gettysburg and this monument is categorised as a contributing property.The 11th Mississippi Infantry Monument, a Contributing property established in the year 2000 in Adams County, Pennsylvania falls in the municipality of Gettysburg, Pennsylvania.',
#  'Adams County Pennsylvania is East of Franklin County, Pennsylvania and has Cumberland County, Pennsylvania to its north.The official language of Israel is modern Hebrew.Israel’s official language is Modern Hebrew.Modern Hebrew is the official language of Israel.ENAIRE is the operating organisation for Adolfo Suarez Madrid-Barajas airport.',
#  'This airport is situated 610 meters above sea level in Alcobendas.GMA New Media, a company founded on 01-01-2000 are manufacturers of mobile applications.GMA New Media, which was founded on January 1, 2000, is a company that offers products such as mobile applications.GMA New Media makes mobile apps and was founded on 01/01/2000.Hypermarcas is a pharmaceutical company located in Sao Paulo, Brazil.',
#  "Brazil is 8514837.14 square kilometers in size.Hypermarcas, a pharmaceutical company, is located in Sao Paulo within the 8514837.14 square kilometres that make up the country of Brazil.Hypermarcas, a company in the pharmaceuticals industry, is located in Sao Paulo, Brazil, a country with a total area of 8514837.14 square kilometres.The Quine Tapes are Rock music genre preceded by the album Squeeze, and Squeeze was preceded by the album Andy Warhol's Velvet Underground Featuring Nico.Bootleg Series Volume 1: The Quine Tapes's genre is rock, and is preceded by the Velvet Underground album Squeeze, which was preceded by the compilation album Andy Warhol's Velvet Underground Featuring Nico.The album Bootleg Series Volume 1: The Quine Tapes fits into the Rock music genre and was preceded by Squeeze by The Velvet Underground, which in turn was preceded by Andy Warhol's Velvet Underground Featuring Nico.Dr.",
#  'G. P. Prabhukumar is the director of the Acharya Institute of Technology which is located at Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090 in India and is affiliated with Visvesvaraya Technological University.The Acharya Institute of Technology campus is located in Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090, India.',
#  'Its director is Dr.G.P.',
#  'Prabhukumar and it is affiliated to Visvesvaraya Technological University.The campus of the Acharya Institute of Technology is located at Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090, India and it is affiliated with the Visvesvaraya Technological University.',
#  'Its director is Dr.G.P.Prabhukumar.Abraham A. Ribicoff was born and died in the United States where African Americans are an ethnic group.Abraham A.Ribicoff died in the United States.',
#  'It was also his birthplace.',
#  'African Americans are an ethnic group in the U.S.A.Abraham A Ribicoff was born and died in the United States where African Americans are an ethnic group.Music group the Velvet Underground produced and released rock music album Bootleg Series Volume 1: The Quine Tapes under the Polydor Records record label.',
#  'The album was recorded in St. Louis, Missouri, USA and has a run time of 230:05.Bootleg Series Volume 1: The Quine Tapes created and produced by The Velvet Underground with runtime of 230.05 minutes was recorded in was St. Louis Missouri, United States.',
#  'The Rock genre album was recorded through Polydor Records.The Bootleg Series Volume I: The Quine Tapes created and produced by The Velvet Underground with runtime of 230.05 minutes was recorded in St. Louis, Missouri, United States.',
#  "The Rock music genre album was released by the record label Polydor Records.The fellowship of the Ring belongs to the fantasy genre.George Allen &amp; Unwin published it.The Fellowship of the Ring was published in the Fantasy genre by George Allen &amp; Unwin.The Fellowship of the Ring, from the fantasy genre, was published by George Allen &amp; Unwin.Distinguished Service Medal (US Navy) recipient Alan Shepard was born in New Hampshire but died in California.Awarded the Distinguished Service Medal by The United States Navy, Alan Shepard, was born in New Hampshire, and died in California.Alan Shepard, born in New Hampshire while having died in California, was awarded the Distinguished Service Medal by the United States Navy.Imagine is a song that Train followed Mermaid with, which was a song produced by the production team Espionage, and was on their album California 37.Train followed its song Mermaid, from its California 37 album, which was was produced by the production team Espionage, with a song titled Imagine.From the production team Espionage, Train's song Mermaid (on the California 37 album) was followed by Train's performance of Imagine by John Lennon.The Train song Mermaid, which belongs to the California 37 Train album and was produced by Espionage, is followed by the John Lennon song Imagine.Train's song Imagine came after a song from their California 37 album, titled Mermaid, which was produced by the production team Espionage.The Fellowship of the Ring was written by J.R.R.",
#  'Tolkien and was released on July 29, 1954.',
#  'The Fellowship of the Ring is considered fantasy and was published by George Allen &amp; Unwin.',
#  'The sequel to The Fellowship of the Ring was The Two Towers.J.R.R.',
#  'Tolkien is the author of The Fellowship of the Ring released on July 29, 1954.',
#  'It is a fantasy book published by George Allen &amp; Unwin.',
#  'The novel was followed by The Two Towers.The Fellowship of the Ring belongs to the fantasy genre.',
#  'Its author is J.R.R.',
#  'Tolkien.',
#  'It was published on July 29, 1954 by George Allen &amp; Unwin.',
#  'It was followed by The Two Towers.GMA New Media lies in the Philippines where applications are offered in the entertainment industry.Located in the Philippines, GMA New Media is an entertainment industry.GMA New Media is an entertainment company located in the Philippines.English Without Tears, written by Terence Rattigan, runs 89 minutes.',
#  'The cinematography for the film was done by Bernard Knowles.English Without Tears, an 89 minute film written by Terence Rattigan, features the cinematography of Bernard Knowles.Terence Rattigan is the writer of the 89 minute movie ´English Without Tears´ and Bernard Knowles is the cinematographer.George Monson was married to Lady Anne Monson, a botanist, who died on February 18, 1776.Lady Anne Monson, a professional botanist who was married to George Monson, died on February 18th, 1776.Lady Anne Monson is the spouse of George Monson.',
#  'Her professional field of study was botany, and she died on 18 February 1776.Abdul Taib Mahmud, member of the Parti Pesaka Bumiputera Bersatu party, resides in Demak Jaya, Jalan Bako, Kuching, Sarawak.Abdul Taib Mahmud, a member of the Parti Pesaka Bumiputera Bersatu party, resides in Demak Jaya, Jalan Bako, Kuching, Sarawak.Liselotte Grschebina was an Israeli who attended the school of Applied Arts in Stuttgart.',
#  'She was born in Karlsruhe, Germany.',
#  "Israel's national language is Modern Hebrew.Liselotte Grschebina is an Israeli national who did her studies at the School of Applied Arts in Stuttgart and was born in Karlsruhe, which is in Germany unlike Israel whose language is Modern Hebrew.Liselotte Grschebina was born in Karlsruhe which is located in Germany, has Israeli nationality (the language in Israel is Modern Hebrew), and studied at the School of Applied Arts in Stuttgart.Chinabank's location is the Philippines.Chinabank is located in the Philippines.The Train song Mermaid, which is an example of the reggae genre, was released under the record labels of Columbia Records and Sony Music Entertainment.",
#  'It was written by Espen Lind and Amund Bjørklund and has a total runtime of 3 minutes and 16 seconds.Amund Bjorklund and Espen Lind are writers of the 3.16 minute reggae song Mermaid by Train that was released under Sony Music Entertainment and Columbia Records.The song Mermaid was written In the reggae music genre by Espen Lind and Amund Bjorklund The song was performed by Train and released by Columbia Records and Sony Music Entertainment records.',
#  "It has a total runtime of three minutes and sixteen seconds.It's Great to be Young,a 1956 film starring Cecil Parker was composed by Louis Levy and written by Ted Willis.“It's Great to Be Young” (1956) was written by Ted Willis and features music by Louis Levy.",
#  "A main role in the movie was given to Cecil Parker.Louis Levy is the composer of the 1956 film It's Great to Be Young, which is written by Ted Willis and stars Cecil Parker.Aaron Turner is a post-metal musician from Massachusetts who plays the electric guitar.",
#  "He started performing in 1995 and is a musician in the Lotus Eaters band.Aaron Turner is a post-metal musician born in Massachusetts who plays electric guitar, started performing in 1995 and is in the Lotus Eaters band.Aaron Turner is a post metal performer from Massachusetts who plays the electric guitar, started performing in 1995 and is in the Lotus Eaters band.Pennsylvania's Franklin County is found to the west of Adams County, Pennsylvania and Carroll County, Maryland is to the southeast.",
#  'A monument to the 11th Mississippi Infantry was erected in 2000 in Adams County and this monument is classed as a contributing property.The 11th Mississippi Infantry Monument was established in 2000 in Adams County, Pennsylvania which has Carroll County, Maryland to its southeast and Franklin County, Pennsylvania to its west.',
#  'The 11th Mississippi Infantry Monument is in the category of contributing property.The 11th Mississippi Infantry Monument, established in 2000, falls under the category of Contributing property and is located in Adams County, Pennsylvania, which has Carroll County, Maryland to the southeast and Franklin County, Pennsylvania to the east.The band Nord is a sludge metal band that releases post-metal.',
#  'They have an album called the Year of No light that was released on June 9th 2006, and was under Crucial Blast Label.Year of No Light self-produced their album Nord.',
#  'The album was released under the label Crucial Blast on September 6th, 2006.',
#  'Nord falls into the sludge metal and post-metal genres.Ciudad Ayala is a metropolitan city which has population of 1,777,539 with its population density of 1604.0 and it falls into UTC offset -6 time zone.',
#  'One of the leaders of Ciudad Ayala is the City Manager which uses council-manager government.The city Ciudad Ayala has population 1,777,539 making the density 1604.0.',
#  'One of the leaders in the council-manager government is the City Manager.',
#  'It is in UTC offset -6.The city Ciudad Ayala has population 1777539 making the density 1604.',
#  'It is a council-managed government led by a City Manager.',
#  'It is in UTC offset -6.Super Capers is a 98 minute film with a $2000000.0 budget.',
#  'It stars Tom Sizemore and Michael Rooker, and was written and directed by Ray Griggs.Super Capers is a 98 minute movie starring Michael Rooker and Tom Sizemore.',
#  'It was written and directed by Ray Griggs.',
#  'It had a budget of $2,000,000.The 98 minute film Super Capers had a budget of 2 million dollars.',
#  'It was written and directed by Ray Griggs.',
#  'It starred Tom Sizemore and also featured Michael Rooker.Darinka Dentcheva developed a theory influenced by Andrzej Piotr Ruszczyński.Darinka Dentcheva was influenced by Andrzej Piotr Ruszczyński.Darinka Dentcheva was influenced by Andrzej Piotr Ruszczynski.Born in 1878, Harry Carey later grew up to write and star in the movie McVeagh of the South Seas.Harry Carey, born in 1878, wrote and appeared in the movie McVeagh of the South Seas.Harry Carey, who was born in 1878, wrote and starred the film of McVeagh of the South Seas.Mexicans, the inhabitants of Mexico, can use their peso currency to purchase a dessert called Bionico.',
#  'Bionico can be found in Guadalajara, Mexico, and is made from sour cream, chopped fruits, condensed milk, granola, coconut and raisins.',
#  'They can also buy cookies, another dessert.Much like a cookie, Bionico is a dessert food whose ingredients include chopped fruits, sour cream, condensed milk, granola, shredded coconut and raisins.',
#  'Bionico is found in the Guadalajara region of Mexico, which uses pesos are their currency and is home to Mexican people.Mexico inhabited by Mexicans has peso as its currency.',
#  'Bionico, a dessert food found in Guadalajara, Mexico, has sour cream, chopped fruits, condensed milk, granola, raisins and shredded coconut as its main ingredients.',
#  'Cookie is a type of dessert.One of the leader of Ciudad Ayala (a city) is called City Manager.',
#  'With a population density of 1604.0.Ciudad Ayala is a city with a population density of 1,604.',
#  'One of the leaders is called the City Manager.One of the leaders of Ciudad Ayala, a city with a population density of 1604.0, is the City Manager.ENAIRE, based in Madrid, Spain, is the operating organisation for Adolfo Suarez Madrid-Barajas airport which is in Alcobendas.',
#  'The runway length at the airport is 3500.Located in Madrid, Spain, ENAIRE operates the Adolfo Suarez Madrid-Barajas Airport in Alcobendas which reports a runway length of 3,500.Adolfo Suarez Madrid-Barajas Airport, operated by ENAIRE, is located in Alcobendas while ENAIRE is located in Madrid, Spain.',
#  "The Airport's runway length is 3500.Bionico is a dish served for dessert in Mexico, where the currency is the peso, the dish contains granola.Bionico, a food that requires granola as one of its ingredients and served at the dessert is found in Mexico.",
#  'The currency is the Peso.Bionico is a food found in Mexico (currency: peso).',
#  "Bionico (dessert) requires granola as one of its ingredients.With a periapsis of 260855000000.0, the 1147 Stavropolis has a epoch of 31 July 2016 (JD2457600.5).1147 Stavropolis epoch is 31 July 2016 (Julian Day 2457600.5) and the periapsis of 1147 Stavropolis is 260855000000.1147 Stavropolis has an epoch on 31 July 2016 and a periapsis of 260855000000.0.Ciudad Ayala which is in the Pacific Daylight time zone has the population density of 1604.Ciudad Ayala city which has a PDT time zone has a population density of 1604.0.Ciudad Ayala's time zone is Pacific Daylight Time and its population density is 1604.0.The net income of Chinabank is 15,100,000,000, and they have 5594 workers total.Chinabank currently brings in a net income of 15100000000 thanks to the efforts of its 5594 employees.Chinabank brings in a net income of 15,100,000,000 with its 5594 employees.Steve Bright is the creator of Bananaman which was last broadcast on April 15th 1986 by the BBC.Bananaman was created by Steve Bright and last aired on April 15th 1986.",
#  'It was broadcast by the BBC.Bananaman, the TV show, was created by Steve Bright and was last aired on 15th April 1986.',
#  'Bananaman was broadcast on the BBC.Bionico (a dish served for dessert) is a food found in Guadalajara in Mexico.',
#  'The currency in Mexico is the Mexican peso inhabited by Mexicans.Bionico (a dessert) is a food found in Guadalajara in Mexico.',
#  'The currency in Mexico is the Mexican peso inhabited by the Mexicans.Bionico is a food found in Mexico and served at the dessert course.',
#  'The dessert can be found in Guadalajara.',
#  'The currency of Mexico (inhabited by Mexicans) is Peso.The Year of No Light album Live at Roadburn 2008 was followed by their album Nord.Live at Roadburn 2008 was preceded by the album Nord played by Year of No Light.Year of No Light, who released the album Nord, followed this up with the album Live at Roadburn 2008.Alan Shepard was a crew member of Apollo 14 who was born November 18th, 1923, in New Hampshire and died in California.Alan Shepard was born in New Hampshire on November 18, 1923.',
#  'He was a crew member of Apollo 14, and died later on in California.Alan Shepard was born on Nov 18, 1923 in New Hampshire, was a member of the Apollo 14 crew and died in California.The ALCO RS-3, with a four-stroke engine and 12 cylinders, has a length of 17068.8 millimetres.The four-stroke 12 cylinder ALCO RS-3 is 17068.8 millimetres long.The ALCO RS-3 has a four-stroke engine and a cylinder count of 12 which is 17068.8 mm in length.Olga Nikolaevna Bondareva, (born April 27, 1937) died in Saint Petersburg.',
#  'She was best known for the "Bondareva-Shapley theorem..Olga Nikolaevna Bondareva, known for the Bondareva-Shapley theorem, was born on April 27, 1937 and died in Saint Petersburg.Olga Bondareva, born "Olga Nikolaevna Bondareva" on April 27th, 1937 and known for the Bondareva-Shapley theorem, died in Saint Petersburg.Fellowship of the Ring, a fantasy novel created by J.R.R.',
#  'Tolkien was released on July 29, 1954; the Hobbit came before The Fellowship of the Ring.J.R.R.',
#  'Tolkien is the author of The Fellowship of the Ring published on July 29, 1954.',
#  "This book belongs to the fantasy genre and came after The Hobbit.Fantasy is The Fellowship of the Ring's genre, and it was released on July 29, 1954.",
#  'The Fellowship of the Ring was written by J.R.R.',
#  "Tolkien and was preceded by the Hobbit.Train's hit Mermaid was put out by the Sony Music Entertainment record label, was written by Amund Bjørklund with the producer Stargate.",
#  'Train followed Mermaid with Imagine, a song by John Lennon where Mermaid was produced by the Espionage production team.The song Mermaid, by Train, is a Sony Music Entertainment release produced by Stargate along with the production team Espionage.',
#  "Mermaid, written by Amund Bjorklund, is followed by John Lennon's Imagine.The Train song Mermaid written by Amund Bjørklund and production team Stargate was produced by the production team Espionage and released under the record label Sony Music Entertainment.",
#  'It was followed by the release of Imagine by John Lennon performed by Train.Year of No Light produced an album called Nord on 6/9/2006 which is 58.41 minutes long.',
#  'They came out with the Demo 2004 album first, followed by Nord, and then the album Live at Roadburn in 2008.The Year of No Light album Nord with runtime of 58.41 minutes was released by the artist on the date 2006-09-06.',
#  "It was preceded by Year of No Light's album Demo 2004 and followed by Year of No Light's album Live at Roadburn 2008.The album Nord by Year of No Light with runtime of 58 minutes and 41 seconds was released on September 6, 2006.The album Nord was preceded by the album Demo 2004 and followed by Live at Roadburn 2008 .The 11th Mississippi Infantry Monument is placed in the municipality of Gettysburg in Pennsylvania, in Adams County, USA.",
#  'Adams County has Carroll County, Maryland to its southeast and the 11th Mississippi Infantry Monument is categorized as a Contributing Property.The 11th Mississippi Infantry Monument is categorised as a contributing property and stands in Adams County, Pennsylvania in the municipality of Gettysburg in the USA.',
#  "Carroll County Maryland is southeast of Adams County.The 11th Mississippi Infantry Monument's location is Adams County, Pennsylvania, USA, in the municipality of Gettysburg.",
#  'To the southeast of Adams County, lies Carroll County, Maryland.',
#  'The 11th Mississippi Infantry Monument is a contributing property.Israeli national Liselotte Grschebina was born in the German Empire and died in Israel on June 14, 1994.Liselotte Grschebina died in Israel on June 14, 1994.',
#  'Though she had Israeli nationality, she was born in the German Empire.Liselotte Grschebina was an Israeli national born in the German Empire.',
#  'She died on June 14, 1994 in Israel.Located in King of Prussia, Pennsylvania, AmeriGas is an energy company that serves the United States.',
#  'AmeriGas has an operating income of $380,700,000 and net income of $211,200,000.Currently serving all regions of the United States, AmeriGas is headquartered in the King of Prussia, Pennsylvania in the United States.',
#  'An established company in the energy industry, AmeriGas has an operating income of $380,700,000 and a net income of $211,200,000.A US provider in the energy industry, AmeriGas is located in the King of Prussia, Pennsylvania in the United States, and has an operating income of $380,700,000 with a net income of $211,200,000.Discovered in 1927 by Grigory Neujmin, 1147 Stavropolis has an apoapsis of 418476000000 and an orbital period of 1249.6 days.The asteroid 1147 Stavropolis was discovered by Grigory Neujmin on the 11th of June 1929.',
#  'It has an orbital period of 1249.6 days and an apoapsis of 418476000000.0.1147 Stavropolis is an asteroid, discovered on 11 June 1929 by Grigory Neujmin.',
#  'Its apoapsis is 418476000000.0 AU and the orbital period is 1249.6.Ciudad Ayala is a city which is located 1147m above sea level and has a UTC offset of -6.',
#  'Ciudad Ayala is located in Mexico and has a leader called the Governator.Ciudad Ayala ruled by governator is in the country of Mexico with offset of -6 as well as sea level of 1147.0.Ciudad Ayala is located in Mexico, with a UTC offset -6.',
#  "The city has an elevation of 1147.0 above sea level and its leader is called the governator.Morelos, in Ciudad Ayala, is in the UTC offset -6 timezone.Ciudad Ayala, which has a UTC offset of -6, is part of Morelos.The UTC offset of Ciudad Ayala which is part of Morelos is -6.Lady Anne Monson's spouse was George Monson.The spouse of George Monson is Lady Anne Monson.Lady Anne Monson is the spouse of George Monson.With 17000 members, Agremiação Sportiva Arapiraquense play in the Campeonato Brasileiro Série C league, of which Vila Nova Futebol Clube have been champions.Agremiação Sportiva Arapiraquense is a club of 17000 members in the Campeonato Brasileiro Série C league along with the Vila Nova Futebol Clube.Agremiação Sportiva Arapiraquense play in the Campeonato Brasileiro Série C league.",
#  'The club currently has 17000 members.',
#  "The Vila Nova Futebol Clube were champions of the league.In the region of Jalisco, Mexico, is a food dish served for dessert called Bionico.Bionico, a food found in the Jalisco region of Mexico, is served at the dessert course.Bionico (a dessert) is a food found in the region of Jalisco in Mexico.The Quine Tapes was produced by The Velvet Underground in St. Louis, Missouri, United States; its genre is rock.The rock album Bootleg Series Volume 1: The Quine Tapes was produced and recorded by the Velvet Underground in St. Louis, Missouri, USA.The Velvet Underground recorded Rock album The Bootleg Series Volume I: The Quine Tapes in St. Louis, Missouri, USA.Gdynia city in Poland has time zone of UTC +2 .Gdynia in Poland has a UTC (Coordinate Universal Time) offset of +2.Gdynia, Poland has a UTC of +02:00.Year of No Light is a band whose members include a former guitarist for Monarch has created an album called Nord.Nord is an album by Year of No Light, which is associated with the band Monarch.Born in Zaoyang city, Hubei, Nie Haisheng participated in the Shenzhou 6 mission.Shenzhou 6 crew member Nie Haisheng was born in Zaoyang in Hubei province.Born in Zaoyang, Hubei, Nie Haisheng participated in Shenzhou 6.Aleksandr Prudnikov, 185cm tall played for FC Spartak Moscow's youth team.",
#  'FC Spartak Moscow is based in the Otkrytiye Arena.Aleksandr Prudnikov who is 185 cm tall is a member of the youth side of FC Spartak Moscow.',
#  'The home ground of FC Spartak Moscow is Otkrytiye Arena.Aleksandr Prudnikov is 185.0 cm tall and played for the FC Spartak Moscow at the Otkrytiye Arena.The Pontiac Rageous assembled in Michigan with assembly line in Detroit was last produced in 1997.Ending its production in 1997, the Pontiac Rageous was assembled in Detroit, Michigan.Ending in 1997, the Pontiac Rageous was assembled in Detroit, Michigan.The total area of the city of Detroit is 370.03 square kilometers.Detroit has a total area of 370.03 square kilometers.English Without Tears, a film directed by Harold French and composed by Nicholas Brodszky, was released on 07-28-1944.',
#  'The film length is 89 minutes.The 89 minute movie ´English Without Tears´ was directed by Harold French, and released on 7-28-1944.',
#  'The songs used throughout the movie were composed by Nicholas Brodszky.English Without Tears is a movie directed by Harold French and musically composed by Nicholas Brodszky.',
#  "It runs for 89 minutes and was released on July 7th, 1944.GMA New Media is located in the GMA Network Center.GMA New Media headquarters are located in the GMA Network Center.GMA New Media is located inside GMA Network Center.Olga Bondareva's professional field is Economics.Olga Bondareva is an economist.Olga Bondareva currently works in the field of Economics.The music of the film English Without Tears is composed by Nicholas Brodszky.Nicholas Brodszky composed music of the movie English Without Tears.Nicholas Brodszky was a composer of the songs that were used in English Without Tears.The BBC (located in Broadcasting House in London) last aired creator Steve Bright's Bananaman, starring Bill Oddie, on April 15th, 1986.The BBC (Broadcasting House) is based in London.",
#  'The show Bananaman that starred Bill Oddie was broadcasted by BBC and last aired on April 15th, 1986.',
#  'The creator of Bananaman was Steve Bright.Broadcasting House is also known as the Headquarters of the BBC.',
#  'One of the BBC television shows, Bananaman was created by Steve Bright and starred Bill Oddie.',
#  "Bananaman's last episode was broadcast on April 15, 1986.Montreal Locomotive Works built the ALCO RS-3 between May 1950 and August 1956.The ALCO RS-3, built by Montreal Locomotive Works, was produced between May 1950 and August 1956.The ALCO RS-3 was built by the Montreal Locomotive Works and was produced between May 1950 and August 1956.Agremiacao Sportiva Arapiraquense has 17000 members and play in the Campeonato Brasileiro Serie C league.",
#  'The champions of the league have been Vila Nova Futebol Clube.Agremiação Sportiva Arapiraquense has 17000 members and play in the Campeonato Brasileiro Série C league, which Vila Nova Futebol Clube are the champions of.Agremiacao Sportiva Arapiraquense has 17000 members and plays in the Campeonato Brasileiro Serie C league of which the Vila Nova Futebol Clube were champions.Cecil Parker had a main role in It\'s Great to Be Young.Cecil Parker starred in the 1956 movie It\'s Great to Be Young.It\'s Great to be Young is a 1956 film starring Cecil Parker.The movie "Super Capers" was directed by Ray Griggs.Super Capers is directed by Ray Griggs.Ray Griggs is the director of Super Capers.The sludge metal and post metal album Nord was produced and created by the artist Year of No Light and was released by the record label Crucial blast on 06-09-2006.',
#  'It was followed by the album Live at Roadburn 2008.The Year of No Light self produced album Nord, a sludge and post-metal genre was released on September 6, 2006.',
#  'Its record label is Crucial Blast and was followed by Live at Roadburn 2008.The self-produced Year of No Light post metal and sludge metal album Nord was released on 2006-09-06 and was followed by the album Live at Roadburn 2008.',
#  'Nord was released on the Crucial Blast record label.Train followed Mermaid with Imagine is a song by musical artist John Lennon, which has a FIMI certification.',
#  "It was produced by the production team Espionage.Train released Mermaid, produced by the Espionage team, shortly before covering John Lennon's Imagine.",
#  'Imagine by John Lennon earned the FIMI certification.The Train song Mermaid, produced by the Espionage production team, was followed by the band’s cover of the John Lennon song Imagine.',
#  'Musician John Lennon wrote and also originally performed the song Imagine which is certified by FIMI.The Adolfo Suárez Madrid–Barajas Airport is located 610 metres above sea level.',
#  'This airport is operated by ENAIRE and has a runway named 14L/32R, which has a length of 3500.Adolfo Suárez Madrid–Barajas Airport, operated by ENAIRE organisation, is elevated 610 metres above sea level and has the runway length of 3500.0.',
#  "The Adolfo Suárez Madrid–Barajas Airport runway name is 14L/32R.Expect a Miracle's genre is easy listening.Expect a Miracle is an easy listening album.Expect a Miracle is of the easy listening genre.Liselotte Grschebina's nationality is Israeli where one of the ethnic groups is Arab.Liselotte Grschebina has the nationality of Israel where one of the ethnicities is Arab people.Israel has different ethnic groups like Arabs, and Israeli nationals such as Liselotte Grschebina.Squeeze was followed by the album 1969: The Velvet Underground Live.The Velvet Underground album Squeeze was followed by the live album 1969: The Velvet Underground Live.The Velvet Underground album Squeeze is followed by the album 1969: The Velvet Underground Live.Alan B. Miller Hall which is owned by the College of William and Mary was completed on 1st June 2009.Completed on June 1st, 2009, Alan B. Miller Hall is owned by the College of William and Mary.The Alan B. Miller Hall, which is owned by The College of William and Mary, was completed on 1st June 2009.The Bootleg Series Volume I: The Quine Tapes, a rock music genre,with runtime of 230:05 was produced and released by Velvet Underground.",
#  'It was recorded in the United States.The Bootleg Series Volume I: The Quine Tapes, produced and created by The Velvet Underground with run time of 230.05 minutes was recorded in the United States.',
#  'It belongs to rock genre.The album Bootleg Series Volume 1: The Quine Tapes by The Velvet Underground in the Rock music genre, was produced by The Velvet Underground and recorded in the United States.',
#  'It lasts 230.05 minutes.Bionico (served at the dessert course) is a food found in Mexico.',
#  'The currency in Mexico is the Mexican peso inhabited by the Mexicans.',
#  'Honey can be added to bionico.Bionico is a dessert food that can be made with honey and is found in Mexico.',
#  'Mexico is inhabited by Mexicans and their currency is the peso.Bionico (served at the dessert course) is a food found in Mexico.',
#  'Honey can be used as a variation in the dish Bionico, the currency in Mexico is the peso inhabited by Mexicans.Gdynia, Poland follows the Central European Summer Time timezone.Gdynia, Poland is in the Central European Summer Time zone.The time zone for Gdynia, Poland is Central European summer time.Super Capers was distributed by the public company Lionsgate.',
#  "It was also distributed by Roadside Attractions.Roadside Attractions distributed Super Capers which was also distributed by the public company Lionsgate.The movie Super Capers is distributed by Roadside Attractions and Lionsgate, a public company.In terms of nationality, Nurhan Atasoy is a Turkish person.Nurhan Atasoy is of Turkish nationality.Nurhan Atasoy's nationality is that of Turkish people.The 11th Mississippi Infantry Monument was established in 2000 and is categorized as a Contributing Property.",
#  'The monument is situated in Adams County, Pennsylvania which has Frederick County, Maryland to its southwest.The 11th Mississippi Infantry Monument, which was built in the year 2000, falls under the category of contributing property.',
#  'The monument is located in Adams County, Pennsylvania which has Frederick County, Maryland to the southwest.A monument to the 11th Mississippi Infantry was erected in Adams County, Pennsylvania in the year 2000.',
#  'Frederick County, Maryland is southwest of Adams County Pennsylvania.',
#  "The 11th Mississippi Infantry Monument is in the category of a contributing property.The train song Mermaid, released on Dec. 27th, 2012 and written by Amund Bjorklund and Espen Lind, was preceded by the song This'll Be My Year.",
#  'Mermaid lasts 3.16 minutes.Train released their song Mermaid on December 27th, 2012.',
#  'The song was written by Amund Bjorklund and Espen Lind, and runs three minutes and sixteen seconds long.',
#  "Train's most recent song before Mermaid was This'll Be My Year.Mermaid by Train was written by Espen Lind and Amund Bjorklund.",
#  'The song, which runs 3 minutes and 16 seconds long, was released on December 27th, 2012.',
#  "Train's most recent song before Mermaid was This'll Be My Year.Graco Ramirez leads Ciudad Ayala in Morelos.Ciudad Ayala is part of Morelos and Graco Ramírez is a leader.Ciudad Ayala is a part of Morelos, which Graco Ramírez is a leading official of.Sour cream, chopped fruits, condensed milk, granola, raisins and shredded coconut are the main ingredients in Bionico which is a dessert served in Mexico where the local currency is the peso.Bionico is a dessert food found in Mexico.",
#  'Chopped fruits, sour cream, condensed milk, granola, shredded coconut and raisins are the main ingredients in Bionico.',
#  'The currency of Mexico is the Peso.Bionico is a dish served for dessert in Mexico where the currency is the peso.',
#  'The main ingredients of Bionico are chopped fruits, sour cream, condensed milk, granola, shredded coconut and raisins.Brandon Carter is a professional in the field of general relativity.General Relativity is Brandon Carter\'s professional field.Brandon Carter is a physicist whose professional field was on General Relativity.The University of Burgundy is located in France, where one of the leaders is Claude Bartolone.The University of Burgundy is in France which is led by Claude Bartolone.Claude Bartolone is the leader of France, the location of the University of Burgundy.Nie Haisheng was born in Hubei.Nie Haisheng was born in Hubei Province.The birthplace of Nie Haisheng is Hubei.Olga Bondareva, born "Olga Nikolaevna Bondareva" and a student of Leningrad State University, was known for the Bondareva-Shapley theorem.Olga Bondareva is known for the Bondareva-Shapley theorem, described by Olga Nikolaevna Bondareva in Leningrad State University.Olga Bondareva, birth name Olga Nikolaevna Bondareva, graduated from Leningrad State University.',
#  'She is known for the Bondareva-Shapley theorem.Darinka Dentcheva, a Humboldt University graduate, is a mathematician working in the field of mathematical optimization.Darinka Dentcheva is a professional in the field of mathematical optimization who went to Humboldt University.Humboldt University is the alma mater of Darinka Dentcheva, whose professional field is Mathematical optimization.',
#  '"English Without Tears" was produced by Anatole de Grunwald.Anatole de Grunwald was the producer of \'English Without Tears\'.Anatole de Grunwald is the producer of English Without Tears.Andrew Rayel\'s genre is trance music and it is associated with artists such as Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin, and Alexandra Badoi.Andrew Rayel, who is active in the trance musical genre, is associated with the following musical artists: Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin and Alexandra Badoi.Andrew Rayel is a Trance music performer associated with other artists like Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin and Alexandra Badoi.US born Aaron Turner plays electric guitar for the post metal band Twilight.American guitarist Aaron Turner is a post-metal musician who played electric guitar with the band Twilight.Aaron Turner (from United States) who is a performer of post metal plays the electric guitar in the band Twilight.BBC broadcast Bananaman, a show created by John Geering and starring Bill Oddie.',
#  'Broadcasting House is a location owned by the BBC, the channel that broadcasts this show which first aired on 10/03/83.The show Bananaman, starring Bill Oddie, was first broadcast on 10/03/83 by the BBC, whose headquarters are Broadcasting House.',
#  'The character Bananaman was created by John Geering.Created by John Geering and first broadcast in 1983, Bananaman starred the actor Bill Oddie.',
#  'It was broadcast by the London based Broadcasting House, known as the BBC.Construction on Alan B Miller Hall began on March 30th, 2007.',
#  'The building was designed by Robert A. M. Stern.',
#  'Alan B Miller Hall is located on 101 Ukrop Way in Williamsburg, Virginia, United States.',
#  'The current tenant is the Mason School of Business.The construction of Alan B. Miller Hall began on March 30th, 2007.',
#  'Robert A. M. Stern designed the building.',
#  'Alan B. Miller Hall is located at 101 Ukrop Way, Williamsburg, Virginia, United States and the current tenant is the Mason School of Business/.The Alan B. Miller Hall, which is located at 101 Ukrop Way in Williamsburg, Virginia, USA, was designed by Robert A.M. Stern and began construction on the 30th of March 2007.',
#  'The Mason School of Business are the current residents of the Hall.The Native name of the Baku Turkish Martyrs\' Memorial is "Türk Sehitleri Aniti" which is located in Azerbaijan.The native name of the Baku Turkish Martyrs\' Memorial is Turk Sehitleri Aniti located in Azerbaijan.The native name for the Baku Turkish Martyrs\' Memorial is Turk Sehitleri Aniti, which is located in Baku, Azerbaijan.Sludge metal has a variety called southern sludge.Southern sludge is a subgenre of sludge metal.Southern sludge is a musical subgenre of sludge metal.Olga Bondareva (born Olga Nikolaevna Bondareva, on April 27, 1937, in Leningrad, USSR) graduated from Leningrad State University and is known for Bondareva-Shapley theorem.Olga Bondareva, born in Leningrad, USSR on the date April 27, 1937 as "Olga Nikolaevna Bondareva", is alumni of Leningrad State University and known for the Bondareva-Shapley theorem.Olga Bondareva with birth name "Olga Nikolaevna Bondareva" was born in Leningrad, USSR on April 27, 1937.',
#  "A Leningrad State University graduate, she is known for Bondareva-Shapley theorem.John Mills had a main role in the movie It's Great to Be Young which has taken 282,838 pounds at the box office.It's Great to Be Young is a 1956 film which received £282,838 and featured John Mills in the lead role.It's Great to Be Young is a 1956 film starring John Mills,and it cost £282,838.Located in Adams Country, Pennsylvania in the United States, the monument to the 11th Mississippi Infantry was erected in 2000.",
#  'It is described as a contributing property.',
#  "Cumberland County is to the north of Adams County.The 11th Mississippi Infantry Monument's located in the United States near Adams County, Pennsylvania.",
#  'It falls under the category of Contributing property and was established in the year 2000.',
#  'Adams County, Pennsylvania has Cumberland County, Pennsylvania to its north.The 11th Mississippi Infantry Monument was established in 2000 and is categorized as a Contributing Property.',
#  'The monument is located in Adams County, Pennsylvania, USA and has Cumberland county, Pennsylvania to the north.Bananaman had as one of its stars Bill Oddie and was last aired on the 15/04/1986 on the BBC who are based at their headquarters, Broadcasting House in London.Bill Oddie starred in Bananaman which last aired on April 15th, 1986.',
#  'The show was broadcast by the BBC which is based at Broadcasting House in London.The BBC, based at their home in Broadcasting House in London, broadcast Bananaman which last aired on 15/04/1986.',
#  'Bill Oddie was a star of the show.Terence Rattigan, who died in 1977, wrote the film English Without Tears in co-authorship with Anatole de Grunwald.',
#  'The film was directed by Harold French, an actor whose career began in 1920.The movie English Without Tears was written by Anatole de Grunwald and Terence Rattigan, who died in 1977, and directed by Harold French, who has been acting since 1920.English Without Tears is a movie directed by Harold French who became an active actor in 1920.',
#  'The movie was written by Anatole de Grunwald and Terence Rattigan.',
#  "Rattigan passed away in 1977.The BBC broadcasted Bananaman, which was created by Steve Bright.Steve Bright is the creator of Bananaman which is broadcast by the BBC.Bananaman, the TV series created by Steve Bright, was shown on the BBC.The leader of Gdynia, Poland is called the Mayor.Gdynia is the city in Poland under the leadership of Mayor.One of the leaders of Gdynia, Poland is the Mayor.The zip code areas in Darlington are DL1, DL2, DL3.The postal codes within Darlington are DL1, DL2, and DL3.Darlington's postal codes are as followed: DL1, DL2, and DL3.Hypermarcas is a drug maker in the pharmaceutical industry.",
#  'They were founded in Brazil on January 1, 2001, and employ 10252 people.',
#  'They are an S.A. corporation, and are managed by a CEO.Hypermarcas was founded in 2001-01-01, it is a type of S.A corporation which has 10252 employees.',
#  'It is a pharmaceutical company located in Brazil that make drugs.',
#  'It is managed by a CEO.Hypermarcas is a pharmaceutical drug company located in Brazil.',
#  'They were founded on January 1, 2001, and employ 10,252 people.',
#  "They are an S.A. corporation, headed up by their CEO.Aleksandr Prudnikov was born on 1989-02-24 and played for FC Spartak Moscow's youth team.",
#  'Its team grounds are the Otkrytiye Arena.Aleksandr Prudnikov was born on February 24, 1989 and is a member of the youth side of FC Spartak Moscow which plays out of Otkrytiye Arena.Aleksandr Prudnikov who was born on 24th February 1989, played youth football for FC Spartak Moscow who play at the Otkrytiye Arena.Nie Haisheng from the People\'s Republic of China was born in Hubei October 13, 1964.Nie Haisheng was born on the 13th of October, 1964 in Hubei in the People\'s Republic of China.Nie Haisheng, born in Hubei Province on 10/13/1964, is a citizen of the People\'s Republic of China.Turk is the demonym for residents of Turkey.An inhabitant of Turkey is called a Turk.The demonym for people who live in Turkey is "Turk".Super Capers, a film written by Ray Griggs, is 98 minutes long.',
#  'Danielle Harris was one of the stars of the movie.The film Super Capers is written by Ray Griggs and stars Danielle Harris.',
#  'The film\'s running time is 98 minutes.The 98.0 minute film,Super Capers starring Danielle Harris was written by the director Ray Griggs.The film "English Without Tears" was written by Terence Rattigan, who died on 30/11/1977.',
#  "The film's director, Harold French, was born in 1897.Harold French who was born in 1897 directed the film, English Without tears.",
#  'Terence Rattigan wrote the movie and died on November 30th, 1977.English Without Tears was directed by Harold French who was born in 1897.',
# ...
#  "and is categorized as sludge metal.The album entitled Nord, followed by Year of No Light's album Live at Roadburn 2008, was released by the artist Year of No Light on the Crucial Blast label on the date 2006-09-06 and produced by Year of No Light.The album Nord by Year of No Light was produced by the band and released by the record label Crucial blast on 06-09-2006.",
#  'The album Nord was followed with the album Live at Roadburn 2008.The album Nord by the Year of No Light, who also produced it was released on September 6, 2006 on record label Crucial Blast.',
#  'Live at Roadburn 2008 was preceded by the album Nord.Sandesh is a dessert, as is Bionico which contains granola and is from the Guadalajara region of Mexico.',
#  'Mexico uses pesos as their currency and the people that live there are Mexicans.Sandesh and Bionico are desserts, the latter one found in Guadalajara, Mexico, and requires granola as an ingredient.',
#  'Mexico is a country where Mexicans live and where that dessert can be purchased using the country currency, the peso.The people in Mexico are called Mexicans and the currency is the peso.',
#  'Bionico is a dessert food found in Mexico in the Guadalajara area.',
#  'This dish requires granola as one of its ingredients.',
#  'Another types of dessert is Sandesh.Liselotte Grschebina was born on May 2,1908 in Karlsruhe, German Empire and belongs to the Israeli nation.',
#  'Liselotte Grschebina died on June 14, 1994 in Petah Tikva, Israel.Liselotte Grschebina, an Israeli national, born in Karlsruhe in the German Empire on 1908-05-02, died in Petah Tikva, Israel on 14th of June, 1994.Liselotte Grschebina was born in Karlsruhe, in the German Empire, on May 2nd, 1908.',
#  'She died in Petah Tikva, in Israel, on June 14th, 1994.',
#  'She was an Israeli national.George Allen &amp; Unwin published The Fellowship of the Ring, a fantasy, on July 29th, 1954.',
#  'The Fellowship of the Ring is preceded by the Hobbit and followed by The Two Towers.The Fellowship of the Ring belongs to the fantasy literary genre, released on July 29, 1954, followed by The Two Towers and published by George Allen &amp; Unwin.',
#  'The Hobbit came before it.The Fellowship of the Ring belongs to the fantasy genre, published on July 29, 1954, by George Allen &amp; Unwin.',
#  'The Hobbit came before it, followed by The Two Towers.The Agremiação Sportiva Arapiraquense club are managed by Vica.',
#  'They have 17000 members and played in the Campeonato Brasileiro Série C league based in Brazil on their ground the Estadio Municipal Coaracy da Mata Fonseca located in Arapiraca.',
#  'The Vila Nova Futebol Clube are the champions.The Estadio Municipal Coaracy da Mata Fonseca is in Arapiraca &amp; is the name of the ground of Agremiação Sportiva Arapiraquense (plays in the Campeonato Brasileiro Série C league managed by Vica with 17000 members).',
#  'The Vila Nova Futebol Clube from Brazil were champions at the Campeonato Brasileiro Série C.Agremiação Sportiva Arapiraquense has 17000 members and played in the Campeonato Brasileiro Série C league from Brazil, whose champions are Vila Nova Futebol Clube.',
#  'They are managed by Vica.',
#  'The Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense located in Arapiraca.A monument to the 11th Mississippi Infantry was erected in 2000 categorised as a contributing property and stands in the state of Pennsylvania in the municipality of Gettysburg in Pennsylvania located in Adams County, Pennsylvania.',
#  "Carroll County Maryland is southeast and Pennsylvania's Cumberland County is to the north of the Adams County.Categorised as a contributing Property, the 11th Mississippi Infantry Monument was established in 2000.",
#  'It is located in Adams County in the municipality of Gettysburg in Pennsylvania.',
#  "This county has Carroll County, Maryland to its southeast, and Cumberland county to its north.The 11th Mississippi Infantry Monument, located in the municipality of Gettysburg in Adams County, Pennsylvania, which sits north of Carroll County, Maryland, and south of Cumberland County, was established in the year 2000 and falls under the category of Contributing property.The 1956 movie , It's Great to be Young, was edited by Max Benedict who later died in 1986.",
#  'The director was Cyril Frankel and the music composer was Louis Levy.The film "It’s Great to Be Young" was edited by Max Benedict, who died in 1986.',
#  'The director of the 1958 film is Cyril Frankel, while the music was composed by Louis Levy.Great to Be Young is a 1956 film directed by Cyril Frankel, composed music by Louis Levy, and edited by Max Benedict, who died in 1986.Year of No Light produced the album Nord, which was released on June 9th, 2006.',
#  'Nord falls into the sludge metal genre.',
#  "Year of No Light's next album was Live at Roadburn 2008.The Year of No Light album Nord was released on September 6, 2006 and was followed by Year of No Light's album Live at Roadburn 2008.",
#  'The album was produced by the band and is in the genre of sludge metal.Prior to his death in California, Alan Shepard was born on November 18, 1923 in New Hampshire, United States.',
#  'He served as Chief of the Astronaut Office in 1963 and was awarded the Distinguished Service Medal by the United States Navy.American Alan Shepard was born in New Hampshire on November 18th 1923.',
#  'Shepard was awarded the Distinguished Service Medal from the Navy, he was the chief of the astronaut office in 1963 and he recently passed away in California.Alan Shepard (nationality: United States) was born November 18th, 1923 in New Hampshire.',
#  'He was the chief of the Astronaut office in 1963.',
#  'The United States Navy awarded the Distinguished service medal to him.',
#  'He died in California.GMA New Media, which is located in the GMA Network Center, makes mobile apps.GMA New Media is a company located inside GMA Network Center that offers products such as mobile applications.GMA New Media makes mobile applications.',
#  'Their headquarters are located in the GMA Network Center.Darlington is in the North East England region.Darlington is in the North East of England.Darlington is located in the North East of England.The album Turn Me On (which has run time of 35.1 minutes) was preceded by the album Let It Breed; Let It Breed is preceded by the release of the album Love American Style.Preceded by the Love American Style album and the Let it Breed album, the album Turn Me On has a runtime of just over 35 minutes.Following the albums, Let it Breed and Love American Style, Turn me on was released at a length of 35 minutes and 10 seconds.Turkish citizen Nurhan Atasoy, resident of Istanbul, won the State Award for Superior Achievement.Nurhan Atasoy, of Turkish citizenship and nationality, resides in Istanbul, Turkey.',
#  'Nurhan won the State Award for Superior Achievement.Nurhan Atasoy, a Turkish citizen of Turkish nationality, is a resident of Istanbul.',
#  "He was awarded the State Award for Superior Achievement.It's Great to Be Young is a 1956 film that stars Cecil Parker and John Mills.",
#  'The length of the movie is 94 minutes and written by Ted Willis.',
#  "It’s edited by Max Benedict and the score is composed by Louis Levy.John Mills and Cecil Parker play the lead in the 94 minute movie It's Great to Be Young (released in 1956 and edited by Max Benedict), while Louis Levy is the music composer and Ted Willis is the writer.Ted Willis wrote the 1956 movie It's Great to Be Young starring John Mills and Cecil Parker.",
#  'Louis Levy composed music for the 94 minute movie which was edited by Max Benedict.Bedford Aerodrome is located in Thurleigh.',
#  'This airport serves the Bedford Autodrome and is operated by MotorSport Vision.',
#  'The runway is 1095 meters long and is made of concrete.',
#  'The ICAO location identifier for Bedford Aerodrome is EGBF.Bedford Aerodrome is located in Thurleigh.',
#  'This airport serves the Bedford Autodrome and is operated by MotorSport Vision.',
#  'The runway is 1095 meters long and made of concrete.',
#  "The ICAO location identifier for Bedford Aerodrome is EGBF.Born in Zaoyang, Hubei, Nie Haisheng participated in the Shenzhou 10 mission.Nie Haisheng born in Zaoyang, Hubei Province took part in the Shenzhou 10 mission.Nie Haisheng was born in Zaoyang, Hubei and he was part of Shenzhou 10 mission.The religion of some Turkish people could be defined as irreligion.Some Turkish people are irreligious.Agremiação Sportiva Arapiraquense played in the 2015 season and play in the Campeonato Brasileiro Série C league, which Vila Nova Futebol Clube have been the champions of.Agremiação Sportiva Arapiraquense played in the 2015 season and play in the Campeonato Brasileiro Série C league, which The Vila Nova Futebol Clube were champions of.Agremiação Sportiva Arapiraquense play in the Campeonato Brasileiro Série C league in 2015 where Vila Nova Futebol Clube are the champions.The record labels of the Year of No Light album Nord's in post-metal genre are Crucial Blast and E-Vinyl.The album entitled Nord in the post-metal genre by the group Year of No Light was released on the Crucial Blast label recorded by label E-Vinyl.Nord is an album in the post metal genre by Year of No Light called Nord which was released by the record label Crucial blast and it was released on the E-Vinyl record label.Liselotte Grschebina died in Petah Tikva, Israel.Liselotte Grschebina died in Petah Tikva, a city in Israel.The album Turn Me On is by the American band The Honeymoon Killers.The album by the Honeymoon Killers is titled Turn Me On.The artist of the Turn Me On album is the Honeymoon Killers.Harry Carey (actor, born in 1878) was the writer of the film McVeagh of the South Seas, directed by Cyril Bruce.Originally written by Harry Carey, the movie McVeagh of the South Seas was directed by Cyril Bruce.Cyril Bruce directed the movie McVeagh of the South Seas written by Harry Carey who was born in 1878.The 11th Mississippi Infantry Monument is in the United States in a place called the municipality of Gettysburg in Adams County, Pennsylvania.",
#  "This place has to its southeast Carroll County, Maryland and to its north Pennsylvania's Cumberland County.",
#  'The 11th Mississippi Infantry Monument is classified as a contributing property.The 11th Mississippi Infantry Monument is located in the United States in the municipality of Gettysburg which is in Adams County, Pennsylvania.',
#  'To the southeast of Adams County, Pennsylvania lies Carroll County, Maryland while to its north is Cumberland County, Pennsylvania.',
#  'The monument falls under the category of Contributing property.The 11th Mississippi Infantry Monument is categorized as a Contributing Property and is located in the municipality of Gettysburg, Adams County, Pennsylvania, USA.',
#  'Adams County has Carroll County, Maryland to its southeast and Cumberland County, Pennsylvania to its north.Owned by The College of William and Mary, Alan B. Miller Hall was completed on June 1st, 2009 and hosts tenants including the Mason School of Business.The Mason school of business is currently located at Alan B Miller hall which was completed on June 1,2009 and is owned by The College of William and Mary.The Mason School of Business is in the Alan B. Miller Hall, which was completed on June 1, 2009 and is owned by The College of William and Mary.Liselotte Grschebina was born in the German Empire and lived from May 2nd, 1908 to June 14th, 1994.Liselotte Grschebina was born on May 2, 1908 in the German Empire and died on June 14, 1994.Liselotte Grschebina was born on the 2nd of May, 1908, in the German Empire and died on the 14th of June, 1994.Michael Rooker was born in the year 1955.Michael Rooker was born in 1955.The Bedford Aerodrome is located in Thurleigh, postal code MK44, United Kingdom.',
#  'The place served by the Bedford Aerodrome is the Bedford Autodrome.The Bedford Aerodrome is located in Thurleigh (which has the postal code MK44), in the United Kingdom.',
#  'The Bedford Aerodrome serves the Bedford Autodrome.Mexico is inhabited by Mexican people and the currency is the peso.',
#  'Bionico is a dessert containing raisins from the Mexican region of Guadalajara, which is served as a dessert course much like cookies.Mexico has people called Mexicans and uses the Mexican peso as its currency.',
#  'Bionico, served as a dessert, is from the Guadalajara region in Mexico and contains raisins.',
#  'A cookie is a dessert as well.Bionico is a type of dessert food, containing raisins, found in Guadalajara, Mexico.',
#  'Mexico is inhabited by Mexicans, and the peso is its currency.',
#  'Cookie is also a dessert.The cinematography of English Without Tears was done by Bernard Knowles.Bernard Knowles was the cinematographer of the film English Without Tears.The cinematographer of the movie English Without Tears is Bernard Knowles.English Without Tears is an 89 minute movie that was released on July 7th, 1944.',
#  'The music was composed by Nicholas Brodszky.',
#  'Anatole de Grunwald was the producer of the film.English Without Tears is a movie produced by Anatole de Grunwald and runs for 89 minutes.',
#  'The music was made by Nicholas Brodszky and it was released to theaters on July 28th, 1944.´English Without Tears´, produced by Anatole de Grunwald and released on 28 July 1944, runs for 89 minutes.',
#  'The songs used in ´English Without Tears´ were composed by Nicholas Brodszky.Ciudad Ayala is a city which is part of Morelos in Mexico and the metropolitan area has a population of 1777539.',
#  'Its government is council-manager and the city has a UTC offset of -6.Ciudad Ayala is a part of Morelos and is in the country of Mexico.',
#  'The population of the metropolitan area is 1,777,539 and is governed by a council-manager government.',
#  'Their UTC offset is -6.Ciudad Ayala part of Morelos in Mexico with population of 1,777,539 falls into UTC offset -6 time zone.',
#  'The type of government here is called the council-manager government.1147 Stavropolis epoch is 31 July 2016 (Julian Day 2457600.5).',
#  'It was discovered by Grigory Neujmin.',
#  'Its orbital period of the asteroid is 1249.6 days and the periapsis is 260855000000.1147 Stavropolis epoch is 31 July 2016 (Julian Day 2457600.5).',
#  'It was discovered by Grigory Neujmin.',
#  'It has a periapsis of 260855000000.0 and the orbital period of the asteroid 1147 Stavropolis is 1249.6 days.The periapsis of 1147 Stavropolis, discovered by Grigory Neujmin, is 260855000000.0.',
#  'The epoch of 1147 Stavropolis is 31 July 2016 (JD2457600.5) and the orbital period of 1147 Stavropolis is 1249.6.',
#  '"Imagine" is a song by musical artist, John Lennon.Musician John Lennon wrote and performed the song Imagine.The song Imagine belongs to the musician John Lennon.The leader\'s title in India is "President..The leader of India is given the title of President.The leader of India is called the President.Tom Sizemore began his career in 1989.Tom Sizemore active years as an actor started in 1989.Tom Sizemore started performing in 1989.Bananaman last aired on April 15th 1986, on BBC.Broadcasted by the BBC, Bananaman was last aired on the 15th April 1986.Bananaman, the TV series, was last shown on the BBC, 15th April 1986.The BBC broadcasted Bananaman on April 15th 1986 for a last time.Israeli national Liselotte Grschebina was born in the German Empire, which was founded on January 1, 1871, and later became a professional photographer.Photographer Liselotte Grschebina was born in the German Empire, founded on January 1, 1871.',
#  'However, Grschebina is an Israeli national.Photographer Liselotte Grschebina was a photographer with Israeli nationality.',
#  'However, she was born in the German Empire, founded on January 1, 1871.The Acharya Institute of Technology which is in India, is affiliated with Visvesvaraya Technological University and was given the Technical Campus status by The All India Council for Technical Education which is in Mumbai.',
#  ...]

# %%
sp_tok = nlp(rawtext)
sp_tok
# Out:
# Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca. Agremiação Sportiva Arapiraquense, nicknamed "Alvinegro", lay in the Campeonato Brasileiro Série C league from Brazil.Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca. Alvinegro, the nickname of Agremiação Sportiva Arapiraquense, play in the Campeonato Brasileiro Série C league from Brazil.Nie Haisheng, born on October 13, 1964, worked as a fighter pilot.Nie Haisheng is a former fighter pilot who was born on October 13, 1964.Nie Haisheng born on 10/13/1964 is a fighter pilot.MotorSport Vision is located in the city of Fawkham.MotorSport Vision is located in the city of Fawkham, UK.MotorSport Vision is located in Fawkham.185 centimetre tall Aleksandr Prudnikov played for the Otkrytiye Arena based FC Spartak, Moscow.The 185 cm tall Aleksandr Prudnikov plays for FC Spartak Moscow who call their home ground Otkrytiye Arena.Aleksandr Prudnikov who is 185 cm tall, plays for FC Spartak Moscow whose ground is the Otkrytiye Arena.Ciudad Ayala is a city with population density and population of 1604 and 1777539 respectively, where the leader is called the City Manager. The government type in the city of Ciudad Ayala is council-manager.The city of Ciudad Ayala, with a population of 1,777,539, is led by a City Manager on a council-manager government system. It has a population density of 1604.Ciudad Ayala, a city with population density and population of 1604.0 and 1,777,539 respectively, uses a type of government called council-manager government. One of the leaders of Ciudad Ayala is the City Manager.The album 1969: The Velvet Underground Live is preceded by the Velvet Underground album Squeeze, which was followed by The Quine Tapes.The Velvet Underground album Bootleg Series Volume 1: The Quine Tapes was preceded by the album Squeeze, which was followed by the live album 1969: The Velvet Underground Live.The Bootleg Series Volume I: The Quine Tapes is preceded by the Velvet Underground album Squeeze which was itself followed by the album 1969: The Velvet Underground Live.Ciudad Ayala in Mexico with population density of 1604.0 and elevated 1147.0 above sea level is in the PDT time zone. The leader here is called the governator.Ciudad Ayala is a country in Mexico that is located 1147 above sea level and is in the Pacific Daylight time zone. The population density is 1604 and the leader of Ciudad Ayala is called the governator.Ciudad Ayala is located in Mexico and has a population density of 1604. The city stands 1147 m above sea level. The Governator is the leader of Ciudad Ayala located in the Pacific Daylight time zone.Olga Bondareva died on December 9, 1991.Olga Bondareva died on the 9th of December, 1991.The date of Olga Bondareva's death was the ninth of December 1991.Saint Petersburg was founded on May 27, 1703 and has a total area of 1439.0, Olga Bondareva passed away at Saint Petersburg.Saint Petersburg, where Olga Bondareva died, was founded on the 27th of May, 1703 and has a total area of approximately 1439 km2.Saint Petersburg, where Olga Bondareva died, was founded on May 27, 1703 and consists of a total area of 1439.0 sq/km.The population density of Ciudad Ayala is 1604.0.Ciudad Ayala city has a population density of 1604.0.The population density in Ciudad Ayala is 1604.Piotr Hallmann was born on August 25, 1987.Piotr Hallmann's birthday is August 25th 1987.Piotr Hallmann was born on the 25th of August 1987.The Darlington town has an area code of 01325.The telephone area code for Darlington is 01325.The area code in Darlington is 01325.Pennsylvania's Franklin County is found to the west of Adams County, Pennsylvania and Pennsylvania's Cumberland County is to the north. A monument to the 11th Mississippi Infantry was erected in Adams County in the year 2000 in the municipality of Gettysburg and this monument is categorised as a contributing ...

# %%
for sentence in sp_tok.sents:
   print("\n",sentence)
# Out:
#  Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca.
#
#  Agremiação Sportiva Arapiraquense, nicknamed "Alvinegro", lay in the Campeonato Brasileiro Série C league from Brazil.
#
#  Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca.
#
#  Alvinegro, the nickname of Agremiação Sportiva Arapiraquense, play in the Campeonato Brasileiro Série C league from Brazil.
#
#  Nie Haisheng, born on October 13, 1964, worked as a fighter pilot.
#
#  Nie Haisheng is a former fighter pilot who was born on October 13, 1964.Nie
#
#  Haisheng born on 10/13/1964 is a fighter pilot.
#
#  MotorSport Vision is located in the city of Fawkham.
#
#  MotorSport Vision is located in the city of Fawkham, UK.MotorSport Vision is located in Fawkham.185 centimetre tall Aleksandr Prudnikov played for the Otkrytiye Arena based FC Spartak, Moscow.
#
#  The 185 cm tall Aleksandr Prudnikov plays for FC Spartak Moscow who call their home ground Otkrytiye Arena.
#
#  Aleksandr Prudnikov who is 185 cm tall, plays for FC Spartak Moscow whose ground is the Otkrytiye Arena.
#
#  Ciudad Ayala is a city with population density and population of 1604 and 1777539 respectively, where the leader is called the City Manager.
#
#  The government type in the city of Ciudad Ayala is council-manager.
#
#  The city of Ciudad Ayala, with a population of 1,777,539, is led by a City Manager on a council-manager government system.
#
#  It has a population density of 1604.Ciudad Ayala, a city with population density and population of 1604.0 and 1,777,539 respectively, uses a type of government called council-manager government.
#
#  One of the leaders of Ciudad Ayala is the City Manager.
#
#  The album 1969: The Velvet Underground Live is preceded by the Velvet Underground album Squeeze, which was followed by The Quine Tapes.
#
#  The Velvet Underground album Bootleg Series Volume 1: The Quine Tapes was preceded by the album Squeeze, which was followed by the live album 1969: The Velvet Underground Live.
#
#  The Bootleg Series Volume I: The Quine Tapes is preceded by the Velvet Underground album Squeeze which was itself followed by the album 1969:
#
#  The Velvet Underground Live.
#
#  Ciudad Ayala in Mexico with population density of 1604.0 and elevated 1147.0 above sea level is in the PDT time zone.
#
#  The leader here is called the governator.
#
#  Ciudad Ayala is a country in Mexico that is located 1147 above sea level and is in the Pacific Daylight time zone.
#
#  The population density is 1604 and the leader of Ciudad Ayala is called the governator.
#
#  Ciudad Ayala is located in Mexico and has a population density of 1604.
#
#  The city stands 1147 m above sea level.
#
#  The Governator is the leader of Ciudad Ayala located in the Pacific Daylight time zone.
#
#  Olga Bondareva died on December 9, 1991.Olga Bondareva died on the 9th of December, 1991.The date of Olga Bondareva's death was the ninth of December 1991.Saint Petersburg was founded on May 27, 1703 and has a total area of 1439.0, Olga Bondareva passed away at Saint Petersburg.
#
#  Saint Petersburg, where Olga Bondareva died, was founded on the 27th of May, 1703 and has a total area of approximately 1439 km2.Saint Petersburg, where Olga Bondareva died, was founded on May 27, 1703 and consists of a total area of 1439.0 sq/km.
#
#  The population density of Ciudad Ayala is 1604.0.Ciudad Ayala city has a population density of 1604.0.The population density in Ciudad Ayala is 1604.Piotr Hallmann was born on August 25, 1987.Piotr Hallmann's birthday is August 25th
#
#  1987.Piotr Hallmann was born on the 25th of August 1987.The
#
#  Darlington town has an area code of 01325.The telephone area code for Darlington is 01325.The area code in Darlington is 01325.Pennsylvania's Franklin County is found to the west of Adams County, Pennsylvania and Pennsylvania's Cumberland County is to the north.
#
#  A monument to the 11th Mississippi Infantry was erected in Adams County in the year 2000 in the municipality of Gettysburg and this monument is categorised as a contributing property.
#
#  The 11th Mississippi Infantry Monument, a Contributing property established in the year 2000 in Adams County, Pennsylvania falls in the municipality of Gettysburg, Pennsylvania.
#
#  Adams County Pennsylvania is East of Franklin County, Pennsylvania and has Cumberland County, Pennsylvania to its north.
#
#  The official language of Israel is modern Hebrew.
#
#  Israel’s official language is Modern Hebrew.
#
#  Modern Hebrew is the official language of Israel.
#
#  ENAIRE is the operating organisation for Adolfo Suarez Madrid-Barajas airport.
#
#  This airport is situated 610 meters above sea level in Alcobendas.
#
#  GMA New Media, a company founded on 01-01-2000 are manufacturers of mobile applications.
#
#  GMA New Media, which was founded on January 1, 2000, is a company that offers products such as mobile applications.
#
#  GMA New Media makes mobile apps and was founded on 01/01/2000.Hypermarcas is a pharmaceutical company located in Sao Paulo, Brazil.
#
#  Brazil is 8514837.14 square kilometers in size.
#
#  Hypermarcas, a pharmaceutical company, is located in Sao Paulo within the 8514837.14 square kilometres that make up the country of Brazil.
#
#  Hypermarcas, a company in the pharmaceuticals industry, is located in Sao Paulo, Brazil, a country with a total area of 8514837.14 square kilometres.
#
#  The Quine Tapes are Rock music genre preceded by the album Squeeze, and Squeeze was preceded by the album Andy Warhol's Velvet Underground Featuring Nico.
#
#  Bootleg Series Volume 1: The Quine Tapes's genre is rock, and is preceded by the Velvet Underground album Squeeze, which was preceded by the compilation album Andy Warhol's Velvet Underground Featuring Nico.
#
#  The album Bootleg Series Volume 1: The Quine Tapes fits into the Rock music genre and was preceded by Squeeze by The Velvet Underground, which in turn was preceded by Andy Warhol's Velvet Underground Featuring Nico.
#
#  Dr. G. P. Prabhukumar is the director of the Acharya Institute of Technology which is located at Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090 in India and is affiliated with Visvesvaraya Technological University.
#
#  The Acharya Institute of Technology campus is located in Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090, India.
#
#  Its director is Dr.G.P. Prabhukumar and it is affiliated to Visvesvaraya Technological University.
#
#  The campus of the Acharya Institute of Technology is located at Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090, India and it is affiliated with the Visvesvaraya Technological University.
#
#  Its director is Dr.G.P.Prabhukumar.
#
#  Abraham A. Ribicoff was born and died in the United States where African Americans are an ethnic group.
#
#  Abraham A.Ribicoff died in the United States.
#
#  It was also his birthplace.
#
#  African Americans are an ethnic group in the U.S.A.Abraham A Ribicoff was born and died in the United States where African Americans are an ethnic group.
#
#  Music group the Velvet Underground produced and released rock music album Bootleg Series Volume 1: The Quine Tapes under the Polydor Records record label.
#
#  The album was recorded in St. Louis, Missouri, USA and has a run time of 230:05.Bootleg Series Volume 1: The Quine Tapes created and produced by The Velvet Underground with runtime of 230.05 minutes was recorded in was St. Louis Missouri, United States.
#
#  The Rock genre album was recorded through Polydor Records.
#
#  The Bootleg Series Volume I: The Quine Tapes created and produced by The Velvet Underground with runtime of 230.05 minutes was recorded in St. Louis, Missouri, United States.
#
#  The Rock music genre album was released by the record label Polydor Records.
#
#  The fellowship of the Ring belongs to the fantasy genre.
#
#  George Allen &amp; Unwin published it.
#
#  The Fellowship of the Ring was published in the Fantasy genre by George Allen &amp; Unwin.
#
#  The Fellowship of the Ring, from the fantasy genre, was published by George Allen &amp; Unwin.
#
#  Distinguished Service Medal (US Navy) recipient Alan Shepard was born in New Hampshire but died in California.
#
#  Awarded the Distinguished Service Medal by The United States Navy, Alan Shepard, was born in New Hampshire, and died in California.
#
#  Alan Shepard, born in New Hampshire while having died in California, was awarded the Distinguished Service Medal by the United States Navy.
#
#  Imagine is a song that Train followed Mermaid with, which was a song produced by the production team Espionage, and was on their album California 37.Train followed its song Mermaid, from its California 37 album, which was was produced by the production team Espionage, with a song titled Imagine.
#
#  From the production team Espionage, Train's song Mermaid (on the California 37 album) was followed by Train's performance of Imagine by John Lennon.
#
#  The Train song Mermaid, which belongs to the California 37 Train album and was produced by Espionage, is followed by the John Lennon song Imagine.
#
#  Train's song Imagine came after a song from their California 37 album, titled Mermaid, which was produced by the production team Espionage.
#
#  The Fellowship of the Ring was written by J.R.R. Tolkien and was released on July 29, 1954.
#
#  The Fellowship of the Ring is considered fantasy and was published by George Allen &amp; Unwin.
#
#  The sequel to The Fellowship of the Ring was The Two Towers.
#
#  J.R.R. Tolkien is the author of The Fellowship of the Ring released on July 29, 1954.
#
#  It is a fantasy book published by George Allen &amp; Unwin.
#
#  The novel was followed by The Two Towers.
#
#  The Fellowship of the Ring belongs to the fantasy genre.
#
#  Its author is J.R.R. Tolkien.
#
#  It was published on July 29, 1954 by George Allen &amp; Unwin.
#
#  It was followed by The Two Towers.
#
#  GMA
#
#  New Media lies in the Philippines where applications are offered in the entertainment industry.
#
#  Located in the Philippines, GMA New Media is an entertainment industry.
#
#  GMA
#
#  New Media is an entertainment company located in the Philippines.
#
#  English Without Tears, written by Terence Rattigan, runs 89 minutes.
#
#  The cinematography for the film was done by Bernard Knowles.
#
#  English Without Tears, an 89 minute film written by Terence Rattigan, features the cinematography of Bernard Knowles.
#
#  Terence Rattigan is the writer of the 89 minute movie ´English Without Tears´ and Bernard Knowles is the cinematographer.
#
#  George Monson was married to Lady Anne Monson, a botanist, who died on February 18, 1776.Lady Anne Monson, a professional botanist who was married to George Monson, died on February 18th,
#
#  1776.Lady Anne Monson is the spouse of George Monson.
#
#  Her professional field of study was botany, and she died on 18 February 1776.Abdul Taib Mahmud, member of the Parti Pesaka Bumiputera Bersatu party, resides in Demak Jaya, Jalan Bako, Kuching, Sarawak.
#
#  Abdul Taib Mahmud, a member of the Parti Pesaka Bumiputera Bersatu party, resides in Demak Jaya, Jalan Bako, Kuching, Sarawak.
#
#  Liselotte Grschebina was an Israeli who attended the school of Applied Arts in Stuttgart.
#
#  She was born in Karlsruhe, Germany.
#
#  Israel's national language is Modern Hebrew.
#
#  Liselotte Grschebina is an Israeli national who did her studies at the School of Applied Arts in Stuttgart and was born in Karlsruhe, which is in Germany unlike Israel whose language is Modern Hebrew.
#
#  Liselotte Grschebina was born in Karlsruhe which is located in Germany, has Israeli nationality (the language in Israel is Modern Hebrew), and studied at the School of Applied Arts in Stuttgart.
#
#  Chinabank's location is the Philippines.
#
#  Chinabank is located in the Philippines.
#
#  The Train song Mermaid, which is an example of the reggae genre, was released under the record labels of Columbia Records and Sony Music Entertainment.
#
#  It was written by Espen Lind and Amund Bjørklund and has a total runtime of 3 minutes and 16 seconds.
#
#  Amund Bjorklund and Espen Lind are writers of the 3.16 minute reggae song Mermaid by Train that was released under Sony Music Entertainment and Columbia Records.
#
#  The song Mermaid was written In the reggae music genre by Espen Lind and Amund Bjorklund The song was performed by Train and released by Columbia Records and Sony Music Entertainment records.
#
#  It has a total runtime of three minutes and sixteen seconds.
#
#  It's Great to be Young,a 1956 film starring Cecil Parker was composed by Louis Levy and written by Ted Willis.
#
#  “It's Great to Be Young” (1956) was written by Ted Willis and features music by Louis Levy.
#
#  A main role in the movie was given to Cecil Parker.
#
#  Louis Levy is the composer of the 1956 film It's Great to Be Young, which is written by Ted Willis and stars Cecil Parker.
#
#  Aaron Turner is a post-metal musician from Massachusetts who plays the electric guitar.
#
#  He started performing in 1995 and is a musician in the Lotus Eaters band.
#
#  Aaron Turner is a post-metal musician born in Massachusetts who plays electric guitar, started performing in 1995 and is in the Lotus Eaters band.
#
#  Aaron Turner is a post metal performer from Massachusetts who plays the electric guitar, started performing in 1995 and is in the Lotus Eaters band.
#
#  Pennsylvania's Franklin County is found to the west of Adams County, Pennsylvania and Carroll County, Maryland is to the southeast.
#
#  A monument to the 11th Mississippi Infantry was erected in 2000 in Adams County and this monument is classed as a contributing property.
#
#  The 11th Mississippi Infantry Monument was established in 2000 in Adams County, Pennsylvania which has Carroll County, Maryland to its southeast and Franklin County, Pennsylvania to its west.
#
#  The 11th Mississippi Infantry Monument is in the category of contributing property.
#
#  The 11th Mississippi Infantry Monument, established in 2000, falls under the category of Contributing property and is located in Adams County, Pennsylvania, which has Carroll County, Maryland to the southeast and Franklin County, Pennsylvania to the east.
#
#  The band Nord is a sludge metal band that releases post-metal.
#
#  They have an album called the Year of No light that was released on June 9th 2006, and was under Crucial Blast Label.
#
#  Year of No Light self-produced their album Nord.
#
#  The album was released under the label Crucial Blast on September 6th, 2006.
#
#  Nord falls into the sludge metal and post-metal genres.
#
#  Ciudad Ayala is a metropolitan city which has population of 1,777,539 with its population density of 1604.0 and it falls into UTC offset -6 time zone.
#
#  One of the leaders of Ciudad Ayala is the City Manager which uses council-manager government.
#
#  The city Ciudad Ayala has population 1,777,539 making the density 1604.0.
#
#  One of the leaders in the council-manager government is the City Manager.
#
#  It is in UTC offset -6.The city Ciudad Ayala has population 1777539 making the density 1604.
#
#  It is a council-managed government led by a City Manager.
#
#  It is in UTC offset -6.Super
#
#  Capers is a 98 minute film with a $2000000.0 budget.
#
#  It stars Tom Sizemore and Michael Rooker, and was written and directed by Ray Griggs.
#
#  Super Capers is a 98 minute movie starring Michael Rooker and Tom Sizemore.
#
#  It was written and directed by Ray Griggs.
#
#  It had a budget of $2,000,000.The 98 minute film Super Capers had a budget of 2 million dollars.
#
#  It was written and directed by Ray Griggs.
#
#  It starred Tom Sizemore and also featured Michael Rooker.
#
#  Darinka Dentcheva developed a theory influenced by Andrzej Piotr Ruszczyński.
#
#  Darinka Dentcheva was influenced by Andrzej Piotr Ruszczyński.
#
#  Darinka Dentcheva was influenced by Andrzej Piotr Ruszczynski.
#
#  Born in 1878, Harry Carey later grew up to write and star in the movie McVeagh of the South Seas.
#
#  Harry Carey, born in 1878, wrote and appeared in the movie McVeagh of the South Seas.
#
#  Harry Carey, who was born in 1878, wrote and starred the film of McVeagh of the South Seas.
#
#  Mexicans, the inhabitants of Mexico, can use their peso currency to purchase a dessert called Bionico.
#
#  Bionico can be found in Guadalajara, Mexico, and is made from sour cream, chopped fruits, condensed milk, granola, coconut and raisins.
#
#  They can also buy cookies, another dessert.
#
#  Much like a cookie, Bionico is a dessert food whose ingredients include chopped fruits, sour cream, condensed milk, granola, shredded coconut and raisins.
#
#  Bionico is found in the Guadalajara region of Mexico, which uses pesos are their currency and is home to Mexican people.
#
#  Mexico inhabited by Mexicans has peso as its currency.
#
#  Bionico, a dessert food found in Guadalajara, Mexico, has sour cream, chopped fruits, condensed milk, granola, raisins and shredded coconut as its main ingredients.
#
#  Cookie is a type of dessert.
#
#  One of the leader of Ciudad Ayala (a city) is called City Manager.
#
#  With a population density of 1604.0.Ciudad Ayala is a city with a population density of 1,604.
#
#  One of the leaders is called the City Manager.
#
#  One of the leaders of Ciudad Ayala, a city with a population density of 1604.0, is the City Manager.
#
#  ENAIRE, based in Madrid, Spain, is the operating organisation for Adolfo Suarez Madrid-Barajas airport which is in Alcobendas.
#
#  The runway length at the airport is 3500.Located in Madrid, Spain, ENAIRE operates the Adolfo Suarez Madrid-Barajas Airport in Alcobendas which reports a runway length of 3,500.Adolfo Suarez Madrid-Barajas Airport, operated by ENAIRE, is located in Alcobendas while ENAIRE is located in Madrid, Spain.
#
#  The Airport's runway length is 3500.Bionico is a dish served for dessert in Mexico, where the currency is the peso, the dish contains granola.
#
#  Bionico, a food that requires granola as one of its ingredients and served at the dessert is found in Mexico.
#
#  The currency is the Peso.
#
#  Bionico is a food found in Mexico (currency: peso).
#
#  Bionico (dessert) requires granola as one of its ingredients.
#
#  With a periapsis of 260855000000.0, the 1147 Stavropolis has a epoch of 31 July 2016 (JD2457600.5).1147 Stavropolis epoch is 31 July 2016 (Julian Day 2457600.5) and the periapsis of 1147 Stavropolis is 260855000000.1147
#
#  Stavropolis has an epoch on 31 July 2016 and a periapsis of 260855000000.0.Ciudad Ayala which is in the Pacific Daylight time zone has the population density of 1604.Ciudad Ayala city which has a PDT time zone has a population density of 1604.0.Ciudad Ayala's time zone is Pacific Daylight Time and its population density is 1604.0.The net income of Chinabank is 15,100,000,000, and they have 5594 workers total.
#
#  Chinabank currently brings in a net income of 15100000000 thanks to the efforts of its 5594 employees.
#
#  Chinabank brings in a net income of 15,100,000,000 with its 5594 employees.
#
#  Steve Bright is the creator of Bananaman which was last broadcast on April 15th 1986 by the BBC.Bananaman was created by Steve Bright and last aired on April 15th 1986.
#
#  It was broadcast by the BBC.Bananaman, the TV show, was created by Steve Bright and was last aired on 15th April 1986.
#
#  Bananaman was broadcast on the BBC.Bionico (a dish served for dessert) is a food found in Guadalajara in Mexico.
#
#  The currency in Mexico is the Mexican peso inhabited by Mexicans.
#
#  Bionico (a dessert) is a food found in Guadalajara in Mexico.
#
#  The currency in Mexico is the Mexican peso inhabited by the Mexicans.
#
#  Bionico is a food found in Mexico and served at the dessert course.
#
#  The dessert can be found in Guadalajara.
#
#  The currency of Mexico (inhabited by Mexicans) is Peso.
#
#  The Year of No Light album Live at Roadburn 2008 was followed by their album Nord.
#
#  Live at Roadburn 2008 was preceded by the album Nord played by Year of No Light.
#
#  Year of No Light, who released the album Nord, followed this up with the album Live at Roadburn 2008.Alan
#
#  Shepard was a crew member of Apollo 14 who was born November 18th, 1923, in New Hampshire and died in California.
#
#  Alan Shepard was born in New Hampshire on November 18, 1923.
#
#  He was a crew member of Apollo 14, and died later on in California.
#
#  Alan Shepard was born on Nov 18, 1923 in New Hampshire, was a member of the Apollo 14 crew and died in California.
#
#  The ALCO RS-3, with a four-stroke engine and 12 cylinders, has a length of 17068.8 millimetres.
#
#  The four-stroke 12 cylinder ALCO RS-3 is 17068.8 millimetres long.
#
#  The ALCO RS-3 has a four-stroke engine and a cylinder count of 12 which is 17068.8 mm in length.
#
#  Olga Nikolaevna Bondareva, (born April 27, 1937) died in Saint Petersburg.
#
#  She was best known for the "Bondareva-Shapley theorem..
#
#  Olga Nikolaevna Bondareva, known for the Bondareva-Shapley theorem, was born on April 27, 1937 and died in Saint Petersburg.
#
#  Olga Bondareva, born "Olga Nikolaevna Bondareva" on April 27th, 1937 and known for the Bondareva-Shapley theorem, died in Saint Petersburg.
#
#  Fellowship of the Ring, a fantasy novel created by J.R.R. Tolkien was released on July 29, 1954; the Hobbit came before The Fellowship of the Ring.
#
#  J.R.R. Tolkien is the author of The Fellowship of the Ring published on July 29, 1954.
#
#  This book belongs to the fantasy genre and came after The Hobbit.
#
#  Fantasy is The Fellowship of the Ring's genre, and it was released on July 29, 1954.
#
#  The Fellowship of the Ring was written by J.R.R. Tolkien and was preceded by the Hobbit.
#
#  Train's hit Mermaid was put out by the Sony Music Entertainment record label, was written by Amund Bjørklund with the producer Stargate.
#
#  Train followed Mermaid with Imagine, a song by John Lennon where Mermaid was produced by the Espionage production team.
#
#  The song Mermaid, by Train, is a Sony Music Entertainment release produced by Stargate along with the production team Espionage.
#
#  Mermaid, written by Amund Bjorklund, is followed by John Lennon's Imagine.
#
#  The Train song Mermaid written by Amund Bjørklund and production team Stargate was produced by the production team Espionage and released under the record label Sony Music Entertainment.
#
#  It was followed by the release of Imagine by John Lennon performed by Train.
#
#  Year of No Light produced an album called Nord on 6/9/2006 which is 58.41 minutes long.
#
#  They came out with the Demo 2004 album first, followed by Nord, and then the album Live at Roadburn in 2008.The Year of No Light album Nord with runtime of 58.41 minutes was released by the artist on the date 2006-09-06.
#
#  It was preceded by Year of No Light's album Demo 2004 and followed by Year of No Light's album Live at Roadburn 2008.The album Nord by Year of No Light with runtime of 58 minutes and 41 seconds was released on September 6, 2006.The album Nord was preceded by the album Demo 2004 and followed by Live at Roadburn 2008 .The
#
#  11th Mississippi Infantry Monument is placed in the municipality of Gettysburg in Pennsylvania, in Adams County, USA.
#
#  Adams County has Carroll County, Maryland to its southeast and the 11th Mississippi Infantry Monument is categorized as a Contributing Property.
#
#  The 11th Mississippi Infantry Monument is categorised as a contributing property and stands in Adams County, Pennsylvania in the municipality of Gettysburg in the USA.
#
#  Carroll County Maryland is southeast of Adams County.
#
#  The 11th Mississippi Infantry Monument's location is Adams County, Pennsylvania, USA, in the municipality of Gettysburg.
#
#  To the southeast of Adams County, lies Carroll County, Maryland.
#
#  The 11th Mississippi Infantry Monument is a contributing property.
#
#  Israeli national Liselotte Grschebina was born in the German Empire and died in Israel on June 14, 1994.Liselotte Grschebina died in Israel on June 14, 1994.
#
#  Though she had Israeli nationality, she was born in the German Empire.
#
#  Liselotte Grschebina was an Israeli national born in the German Empire.
#
#  She died on June 14, 1994 in Israel.
#
#  Located in King of Prussia, Pennsylvania, AmeriGas is an energy company that serves the United States.
#
#  AmeriGas has an operating income of $380,700,000 and net income of $211,200,000.Currently serving all regions of the United States, AmeriGas is headquartered in the King of Prussia, Pennsylvania in the United States.
#
#  An established company in the energy industry, AmeriGas has an operating income of $380,700,000 and a net income of $211,200,000.A US provider in the energy industry, AmeriGas is located in the King of Prussia, Pennsylvania in the United States, and has an operating income of $380,700,000 with a net income of $211,200,000.Discovered in 1927 by Grigory Neujmin, 1147 Stavropolis has an apoapsis of 418476000000 and an orbital period of 1249.6 days.
#
#  The asteroid 1147 Stavropolis was discovered by Grigory Neujmin on the 11th of June 1929.
#
#  It has an orbital period of 1249.6 days and an apoapsis of 418476000000.0.1147 Stavropolis is an asteroid, discovered on 11 June 1929 by Grigory Neujmin.
#
#  Its apoapsis is 418476000000.0 AU and the orbital period is
#
#  1249.6.Ciudad Ayala is a city which is located 1147m above sea level and has a UTC offset of -6.
#
#  Ciudad Ayala is located in Mexico and has a leader called the Governator.
#
#  Ciudad Ayala ruled by governator is in the country of Mexico with offset of -6 as well as sea level of 1147.0.Ciudad Ayala is located in Mexico, with a UTC offset
#
#  -6.
#
#  The city has an elevation of 1147.0 above sea level and its leader is called the governator.
#
#  Morelos, in Ciudad Ayala, is in the UTC offset -6 timezone.
#
#  Ciudad Ayala, which has a UTC offset of -6, is part of Morelos.
#
#  The UTC offset of Ciudad Ayala which is part of Morelos is -6.Lady
#
#  Anne Monson's spouse was George Monson.
#
#  The spouse of George Monson is Lady Anne Monson.
#
#  Lady Anne Monson is the spouse of George Monson.
#
#  With 17000 members, Agremiação Sportiva Arapiraquense play in the Campeonato Brasileiro Série C league, of which Vila Nova Futebol Clube have been champions.
#
#  Agremiação Sportiva Arapiraquense is a club of 17000 members in the Campeonato Brasileiro Série C league along with the Vila Nova Futebol Clube.
#
#  Agremiação Sportiva Arapiraquense play in the Campeonato Brasileiro Série C league.
#
#  The club currently has 17000 members.
#
#  The Vila Nova Futebol Clube were champions of the league.
#
#  In the region of Jalisco, Mexico, is a food dish served for dessert called Bionico.
#
#  Bionico, a food found in the Jalisco region of Mexico, is served at the dessert course.
#
#  Bionico (a dessert) is a food found in the region of Jalisco in Mexico.
#
#  The Quine Tapes was produced by The Velvet Underground in St. Louis, Missouri, United States; its genre is rock.
#
#  The rock album Bootleg Series Volume 1: The Quine Tapes was produced and recorded by the Velvet Underground in St. Louis, Missouri, USA.The Velvet Underground recorded Rock album The Bootleg Series Volume
#
#  I: The Quine Tapes in St. Louis, Missouri, USA.Gdynia city in Poland has time zone of UTC +2 .Gdynia
#
#  in Poland has a UTC (Coordinate Universal Time) offset of +2.Gdynia, Poland has a UTC of +02:00.Year of No Light is a band whose members include a former guitarist for Monarch has created an album called Nord.
#
#  Nord is an album by Year of No Light, which is associated with the band Monarch.
#
#  Born in Zaoyang city, Hubei, Nie Haisheng participated in the Shenzhou 6 mission.
#
#  Shenzhou 6 crew member Nie Haisheng was born in Zaoyang in Hubei province.
#
#  Born in Zaoyang, Hubei, Nie Haisheng participated in Shenzhou 6.Aleksandr Prudnikov, 185cm tall played for FC Spartak Moscow's youth team.
#
#  FC Spartak Moscow is based in the Otkrytiye Arena.
#
#  Aleksandr Prudnikov who is 185 cm tall is a member of the youth side of FC Spartak Moscow.
#
#  The home ground of FC Spartak Moscow is Otkrytiye Arena.
#
#  Aleksandr Prudnikov is 185.0 cm tall and played for the FC Spartak Moscow at the Otkrytiye Arena.
#
#  The Pontiac Rageous assembled in Michigan with assembly line in Detroit was last produced in 1997.Ending its production in 1997, the Pontiac Rageous was assembled in Detroit, Michigan.
#
#  Ending in 1997, the Pontiac Rageous was assembled in Detroit, Michigan.
#
#  The total area of the city of Detroit is 370.03 square kilometers.
#
#  Detroit has a total area of 370.03 square kilometers.
#
#  English Without Tears, a film directed by Harold French and composed by Nicholas Brodszky, was released on 07-28-1944.
#
#  The film length is 89 minutes.
#
#  The 89 minute movie ´English Without Tears´ was directed by Harold French, and released on 7-28-1944.
#
#  The songs used throughout the movie were composed by Nicholas Brodszky.
#
#  English Without Tears is a movie directed by Harold French and musically composed by Nicholas Brodszky.
#
#  It runs for 89 minutes and was released on July 7th, 1944.GMA New Media is located in the GMA Network Center.
#
#  GMA New Media headquarters are located in the GMA Network Center.
#
#  GMA
#
#  New Media is located inside GMA Network Center.
#
#  Olga Bondareva's professional field is Economics.
#
#  Olga Bondareva is an economist.
#
#  Olga Bondareva currently works in the field of Economics.
#
#  The music of the film English Without Tears is composed by Nicholas Brodszky.
#
#  Nicholas Brodszky composed music of the movie English Without Tears.
#
#  Nicholas Brodszky was a composer of the songs that were used in English Without Tears.
#
#  The BBC (located in Broadcasting House in London) last aired creator Steve Bright's Bananaman, starring Bill Oddie, on April 15th, 1986.The BBC (Broadcasting House) is based in London.
#
#  The show Bananaman that starred Bill Oddie was broadcasted by BBC and last aired on April 15th, 1986.
#
#  The creator of Bananaman was Steve Bright.
#
#  Broadcasting House is also known as the Headquarters of the BBC.
#
#  One of the BBC television shows, Bananaman was created by Steve Bright and starred Bill Oddie.
#
#  Bananaman's last episode was broadcast on April 15, 1986.Montreal Locomotive Works built the ALCO RS-3 between May 1950 and August 1956.The
#
#  ALCO RS-3, built by Montreal Locomotive Works, was produced between May 1950 and August 1956.The
#
#  ALCO RS-3 was built by the Montreal Locomotive Works and was produced between May 1950 and August 1956.Agremiacao
#
#  Sportiva Arapiraquense has 17000 members and play in the Campeonato Brasileiro Serie C league.
#
#  The champions of the league have been Vila Nova Futebol Clube.
#
#  Agremiação Sportiva Arapiraquense has 17000 members and play in the Campeonato Brasileiro Série C league, which Vila Nova Futebol Clube are the champions of.
#
#  Agremiacao Sportiva Arapiraquense has 17000 members and plays in the Campeonato Brasileiro Serie C league of which the Vila Nova Futebol Clube were champions.
#
#  Cecil Parker had a main role in It's Great to Be Young.
#
#  Cecil Parker starred in the 1956 movie It's Great to Be Young.
#
#  It's Great to be Young is a 1956 film starring Cecil Parker.
#
#  The movie "Super Capers" was directed by Ray Griggs.
#
#  Super Capers is directed by Ray Griggs.
#
#  Ray Griggs is the director of Super Capers.
#
#  The sludge metal and post metal album Nord was produced and created by the artist Year of No Light and was released by the record label Crucial blast on 06-09-2006.
#
#  It was followed by the album Live at Roadburn 2008.The Year of No Light self produced album Nord, a sludge and post-metal genre was released on September 6, 2006.
#
#  Its record label is Crucial Blast and was followed by Live at Roadburn 2008.The self-produced Year of No Light post metal and sludge metal album Nord was released on 2006-09-06 and was followed by the album Live at Roadburn 2008.
#
#  Nord was released on the Crucial Blast record label.
#
#  Train followed Mermaid with Imagine is a song by musical artist John Lennon, which has a FIMI certification.
#
#  It was produced by the production team Espionage.
#
#  Train released Mermaid, produced by the Espionage team, shortly before covering John Lennon's Imagine.
#
#  Imagine by John Lennon earned the FIMI certification.
#
#  The Train song Mermaid, produced by the Espionage production team, was followed by the band’s cover of the John Lennon song Imagine.
#
#  Musician John Lennon wrote and also originally performed the song Imagine which is certified by FIMI.The
#
#  Adolfo Suárez Madrid–Barajas Airport is located 610 metres above sea level.
#
#  This airport is operated by ENAIRE and has a runway named 14L/32R, which has a length of 3500.Adolfo Suárez Madrid–Barajas Airport, operated by ENAIRE organisation, is elevated 610 metres above sea level and has the runway length of 3500.0.
#
#  The Adolfo Suárez Madrid–Barajas Airport runway name is 14L/32R.Expect a Miracle's genre is easy listening.
#
#  Expect a Miracle is an easy listening album.
#
#  Expect a Miracle is of the easy listening genre.
#
#  Liselotte Grschebina's nationality is Israeli where one of the ethnic groups is Arab.
#
#  Liselotte Grschebina has the nationality of Israel where one of the ethnicities is Arab people.
#
#  Israel has different ethnic groups like Arabs, and Israeli nationals such as Liselotte Grschebina.
#
#  Squeeze was followed by the album 1969:
#
#  The Velvet Underground Live.
#
#  The Velvet Underground album Squeeze was followed by the live album 1969:
#
#  The Velvet Underground Live.
#
#  The Velvet Underground album Squeeze is followed by the album 1969:
#
#  The Velvet Underground Live.
#
#  Alan B. Miller Hall which is owned by the College of William and Mary was completed on 1st June 2009.Completed on June 1st, 2009, Alan B. Miller Hall is owned by the College of William and Mary.
#
#  The Alan B. Miller Hall, which is owned by The College of William and Mary, was completed on 1st June 2009.The Bootleg Series Volume I: The Quine Tapes, a rock music genre,with runtime of 230:05 was produced and released by Velvet Underground.
#
#  It was recorded in the United States.
#
#  The Bootleg Series Volume I: The Quine Tapes, produced and created by The Velvet Underground with run time of 230.05 minutes was recorded in the United States.
#
#  It belongs to rock genre.
#
#  The album Bootleg Series Volume 1: The Quine Tapes by The Velvet Underground in the Rock music genre, was produced by The Velvet Underground and recorded in the United States.
#
#  It lasts 230.05 minutes.
#
#  Bionico (served at the dessert course) is a food found in Mexico.
#
#  The currency in Mexico is the Mexican peso inhabited by the Mexicans.
#
#  Honey can be added to bionico.
#
#  Bionico is a dessert food that can be made with honey and is found in Mexico.
#
#  Mexico is inhabited by Mexicans and their currency is the peso.
#
#  Bionico (served at the dessert course) is a food found in Mexico.
#
#  Honey can be used as a variation in the dish Bionico, the currency in Mexico is the peso inhabited by Mexicans.
#
#  Gdynia, Poland follows the Central European Summer Time timezone.
#
#  Gdynia, Poland is in the Central European Summer Time zone.
#
#  The time zone for Gdynia, Poland is Central European summer time.
#
#  Super Capers was distributed by the public company Lionsgate.
#
#  It was also distributed by Roadside Attractions.
#
#  Roadside Attractions distributed Super Capers which was also distributed by the public company Lionsgate.
#
#  The movie Super Capers is distributed by Roadside Attractions and Lionsgate, a public company.
#
#  In terms of nationality, Nurhan Atasoy is a Turkish person.
#
#  Nurhan Atasoy is of Turkish nationality.
#
#  Nurhan Atasoy's nationality is that of Turkish people.
#
#  The 11th Mississippi Infantry Monument was established in 2000 and is categorized as a Contributing Property.
#
#  The monument is situated in Adams County, Pennsylvania which has Frederick County, Maryland to its southwest.
#
#  The 11th Mississippi Infantry Monument, which was built in the year 2000, falls under the category of contributing property.
#
#  The monument is located in Adams County, Pennsylvania which has Frederick County, Maryland to the southwest.
#
#  A monument to the 11th Mississippi Infantry was erected in Adams County, Pennsylvania in the year 2000.
#
#  Frederick County, Maryland is southwest of Adams County Pennsylvania.
#
#  The 11th Mississippi Infantry Monument is in the category of a contributing property.
#
#  The train song Mermaid, released on Dec. 27th, 2012 and written by Amund Bjorklund and Espen Lind, was preceded by the song This'll Be My Year.
#
#  Mermaid lasts 3.16 minutes.
#
#  Train released their song Mermaid on December 27th, 2012.
#
#  The song was written by Amund Bjorklund and Espen Lind, and runs three minutes and sixteen seconds long.
#
#  Train's most recent song before Mermaid was This'll Be My Year.
#
#  Mermaid by Train was written by Espen Lind and Amund Bjorklund.
#
#  The song, which runs 3 minutes and 16 seconds long, was released on December 27th, 2012.
#
#  Train's most recent song before Mermaid was This'll Be My Year.
#
#  Graco Ramirez leads Ciudad Ayala in Morelos.
#
#  Ciudad Ayala is part of Morelos and Graco Ramírez is a leader.
#
#  Ciudad Ayala is a part of Morelos, which Graco Ramírez is a leading official of.
#
#  Sour cream, chopped fruits, condensed milk, granola, raisins and shredded coconut are the main ingredients in Bionico which is a dessert served in Mexico where the local currency is the peso.
#
#  Bionico is a dessert food found in Mexico.
#
#  Chopped fruits, sour cream, condensed milk, granola, shredded coconut and raisins are the main ingredients in Bionico.
#
#  The currency of Mexico is the Peso.
#
#  Bionico is a dish served for dessert in Mexico where the currency is the peso.
#
#  The main ingredients of Bionico are chopped fruits, sour cream, condensed milk, granola, shredded coconut and raisins.
#
#  Brandon Carter is a professional in the field of general relativity.
#
#  General Relativity is Brandon Carter's professional field.
#
#  Brandon Carter is a physicist whose professional field was on General Relativity.
#
#  The University of Burgundy is located in France, where one of the leaders is Claude Bartolone.
#
#  The University of Burgundy is in France which is led by Claude Bartolone.
#
#  Claude Bartolone is the leader of France, the location of the University of Burgundy.
#
#  Nie Haisheng was born in Hubei.
#
#  Nie Haisheng was born in Hubei Province.
#
#  The birthplace of Nie Haisheng is Hubei.
#
#  Olga Bondareva, born "Olga Nikolaevna Bondareva" and a student of Leningrad State University, was known for the Bondareva-Shapley theorem.
#
#  Olga Bondareva is known for the Bondareva-Shapley theorem, described by Olga Nikolaevna Bondareva in Leningrad State University.
#
#  Olga Bondareva, birth name Olga Nikolaevna Bondareva, graduated from Leningrad State University.
#
#  She is known for the Bondareva-Shapley theorem.
#
#  Darinka Dentcheva, a Humboldt University graduate, is a mathematician working in the field of mathematical optimization.
#
#  Darinka Dentcheva is a professional in the field of mathematical optimization who went to Humboldt University.
#
#  Humboldt University is the alma mater of Darinka Dentcheva, whose professional field is Mathematical optimization.
#
#  "English
#
#  Without Tears" was produced by Anatole de Grunwald.
#
#  Anatole de Grunwald was the producer of 'English Without Tears'.
#
#  Anatole de Grunwald is the producer of English Without Tears.
#
#  Andrew Rayel's genre is trance music and it is associated with artists such as Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin, and Alexandra Badoi.
#
#  Andrew Rayel, who is active in the trance musical genre, is associated with the following musical artists: Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin and Alexandra Badoi.
#
#  Andrew Rayel is a Trance music performer associated with other artists like Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin and Alexandra Badoi.
#
#  US born Aaron Turner plays electric guitar for the post metal band Twilight.
#
#  American guitarist Aaron Turner is a post-metal musician who played electric guitar with the band Twilight.
#
#  Aaron Turner (from United States) who is a performer of post metal plays the electric guitar in the band Twilight.
#
#  BBC broadcast Bananaman, a show created by John Geering and starring Bill Oddie.
#
#  Broadcasting House is a location owned by the BBC, the channel that broadcasts this show which first aired on 10/03/83.The show Bananaman, starring Bill Oddie, was first broadcast on 10/03/83 by the BBC, whose headquarters are Broadcasting House.
#
#  The character Bananaman was created by John Geering.
#
#  Created by John Geering and first broadcast in 1983, Bananaman starred the actor Bill Oddie.
#
#  It was broadcast by the London based Broadcasting House, known as the BBC.Construction on Alan B Miller Hall began on March 30th, 2007.
#
#  The building was designed by Robert A. M. Stern.
#
#  Alan B Miller Hall is located on 101 Ukrop Way in Williamsburg, Virginia, United States.
#
#  The current tenant is the Mason School of Business.
#
#  The construction of Alan B. Miller Hall began on March 30th, 2007.
#
#  Robert A. M. Stern designed the building.
#
#  Alan B. Miller Hall is located at 101 Ukrop Way, Williamsburg, Virginia, United States and the current tenant is the Mason School of Business/.The Alan B. Miller Hall, which is located at 101 Ukrop Way in Williamsburg, Virginia, USA, was designed by Robert A.M. Stern and began construction on the 30th of March 2007.
#
#  The Mason School of Business are the current residents of the Hall.
#
#  The Native name of the Baku Turkish Martyrs' Memorial is "Türk Sehitleri Aniti" which is located in Azerbaijan.
#
#  The native name of the Baku Turkish Martyrs' Memorial is Turk Sehitleri Aniti located in Azerbaijan.
#
#  The native name for the Baku Turkish Martyrs' Memorial is Turk Sehitleri Aniti, which is located in Baku, Azerbaijan.
#
#  Sludge metal has a variety called southern sludge.
#
#  Southern sludge is a subgenre of sludge metal.
#
#  Southern sludge is a musical subgenre of sludge metal.
#
#  Olga Bondareva (born Olga Nikolaevna Bondareva, on April 27, 1937, in Leningrad, USSR) graduated from Leningrad State University and is known for Bondareva-Shapley theorem.
#
#  Olga Bondareva, born in Leningrad, USSR on the date April 27, 1937 as "Olga Nikolaevna Bondareva", is alumni of Leningrad State University and known for the Bondareva-Shapley theorem.
#
#  Olga Bondareva with birth name "Olga Nikolaevna Bondareva" was born in Leningrad, USSR on April 27, 1937.
#
#  A Leningrad State University graduate, she is known for Bondareva-Shapley theorem.
#
#  John Mills had a main role in the movie It's Great to Be Young which has taken 282,838 pounds at the box office.
#
#  It's Great to Be Young is a 1956 film which received £282,838 and featured John Mills in the lead role.
#
#  It's Great to Be Young is a 1956 film starring John Mills,and it cost £282,838.Located in Adams Country, Pennsylvania in the United States, the monument to the 11th Mississippi Infantry was erected in 2000.
#
#  It is described as a contributing property.
#
#  Cumberland County is to the north of Adams County.
#
#  The 11th Mississippi Infantry Monument's located in the United States near Adams County, Pennsylvania.
#
#  It falls under the category of Contributing property and was established in the year 2000.
#
#  Adams County, Pennsylvania has Cumberland County, Pennsylvania to its north.
#
#  The 11th Mississippi Infantry Monument was established in 2000 and is categorized as a Contributing Property.
#
#  The monument is located in Adams County, Pennsylvania, USA and has Cumberland county, Pennsylvania to the north.
#
#  Bananaman had as one of its stars Bill Oddie and was last aired on the 15/04/1986 on the BBC who are based at their headquarters, Broadcasting House in London.
#
#  Bill Oddie starred in Bananaman which last aired on April 15th, 1986.
#
#  The show was broadcast by the BBC which is based at Broadcasting House in London.
#
#  The BBC, based at their home in Broadcasting House in London, broadcast Bananaman which last aired on 15/04/1986.
#
#  Bill Oddie was a star of the show.
#
#  Terence Rattigan, who died in 1977, wrote the film English Without Tears in co-authorship with Anatole de Grunwald.
#
#  The film was directed by Harold French, an actor whose career began in 1920.The movie English Without Tears was written by Anatole de Grunwald and Terence Rattigan, who died in 1977, and directed by Harold French, who has been acting since 1920.English Without Tears is a movie directed by Harold French who became an active actor in 1920.
#
#  The movie was written by Anatole de Grunwald and Terence Rattigan.
#
#  Rattigan passed away in 1977.The BBC broadcasted Bananaman, which was created by Steve Bright.
#
#  Steve Bright is the creator of Bananaman which is broadcast by the BBC.Bananaman, the TV series created by Steve Bright, was shown on the BBC.The leader of Gdynia, Poland is called the Mayor.
#
#  Gdynia is the city in Poland under the leadership of Mayor.
#
#  One of the leaders of Gdynia, Poland is the Mayor.
#
#  The zip code areas in Darlington are DL1, DL2, DL3.The postal codes within Darlington are DL1, DL2, and DL3.Darlington's postal codes are as followed: DL1, DL2, and DL3.Hypermarcas is a drug maker in the pharmaceutical industry.
#
#  They were founded in Brazil on January 1, 2001, and employ 10252 people.
#
#  They are an S.A. corporation, and are managed by a CEO.Hypermarcas was founded in 2001-01-01, it is a type of S.A corporation which has 10252 employees.
#
#  It is a pharmaceutical company located in Brazil that make drugs.
#
#  It is managed by a CEO.Hypermarcas is a pharmaceutical drug company located in Brazil.
#
#  They were founded on January 1, 2001, and employ 10,252 people.
#
#  They are an S.A. corporation, headed up by their CEO.Aleksandr Prudnikov was born on 1989-02-24 and played for FC Spartak Moscow's youth team.
#
#  Its team grounds are the Otkrytiye Arena.
#
#  Aleksandr Prudnikov was born on February 24, 1989 and is a member of the youth side of FC Spartak Moscow which plays out of Otkrytiye Arena.
#
#  Aleksandr Prudnikov who was born on 24th February 1989, played youth football for FC Spartak Moscow who play at the Otkrytiye Arena.
#
#  Nie Haisheng from the People's Republic of China was born in Hubei October 13, 1964.Nie
#
#  Haisheng was born on the 13th of October, 1964 in Hubei in the People's Republic of China.
#
#  Nie Haisheng, born in Hubei Province on 10/13/1964, is a citizen of the People's Republic of China.
#
#  Turk is the demonym for residents of Turkey.
#
#  An inhabitant of Turkey is called a Turk.
#
#  The demonym for people who live in Turkey is "Turk".
#
#  Super Capers, a film written by Ray Griggs, is 98 minutes long.
#
#  Danielle Harris was one of the stars of the movie.
#
#  The film Super Capers is written by Ray Griggs and stars Danielle Harris.
#
#  The film's running time is 98 minutes.
#
#  The 98.0 minute film,Super Capers starring Danielle Harris was written by the director Ray Griggs.
#
#  The film "English Without Tears" was written by Terence Rattigan, who died on 30/11/1977.
#
#  The film's director, Harold French, was born in 1897.Harold French who was born in 1897 directed the film, English Without tears.
#
#  Terence Rattigan wrote the movie and died on November 30th, 1977.English Without Tears was directed by Harold French who was born in 1897.
#
#  It was written by Terence Rattigan who died on November 30th, 1977.John Mills starred in the 1956 film It’s Great to Be Young which featured cinematography by Gilbert Taylor.
#
#  John Mills played the leading role in the 1956 movie It's Great to be Young which had Gilbert Taylor as cinematographer.
#
#  John Mills had a main role in the movie It's Great to Be Young, which had its cinematography done by Gilbert Taylor.
#
#  Olga Bondareva, who lived from April 27th, 1937 to December 9th, 1991, was a student at Leningrad State University.
#
#  Olga Bondareva (born on April 27, 1937) graduated from Leningrad State University, and died on the ninth of December 1991.Olga
#
# ...
#
#  Estádio Municipal Coaracy da Mata Fonseca in Arapiraca is the name of the ground of Agremiação Sportiva Arapiraquense.
#
#  Agremiação Sportiva Arapiraquense (full name "Agremiação Sportiva Arapiraquense") play in the Campeonato Brasileiro Série C league from Brazil.
#
#  The Arapiraca based Estádio Municipal Coaracy da Mata Fonseca is the training ground of Agremiacao Sportiva Arapiraquense.
#
#  With a full name of Agremiação Sportiva Arapiraquense, this team play in the Brazilian based Campeonato Brasileiro Série C league.
#
#  AmeriGas serves all regions of the United States, which is also its home country.
#
#  The American company AmeriGas serves the United States.
#
#  AmeriGas works in the United States, providing services there too.
#
#  The Mason School of Business is located in the United States at the College of William and Mary owned Alan B. Miller Hall, which was designed by architect Robert A.M. Stern.
#
#  The hall, which was completed on the 1st of June, 2009, can be found at 101 Ukrop Way and began construction on the 30th of March, 2007.The architect of the Alan B Miller Hall, which is at 101 Ukrop Way, USA, is Robert A M Stern.
#
#  They started to build the Alan B Miller Hall on the 30th of March, 2007 and it was finished on the 1st of June 2009.The Mason School of Business are the current tenants of the building which is owned by The College of William and Mary.
#
#  The College of William and Mary own the Alan B. Miller Hall situated at 101 Ukrop Way, USA.
#
#  The building, which was designed by architect Robert A.M. Stern, currently houses The Mason School of Business and was constructed between the 30th of March 2007 and the 1st of June 2009.Sarah Teale directed and produced the 83-minute movie Death on a Factory Farm which had Jamie Lawrence as the music composer.
#
#  Tom Simon was also a producer of the movie.
#
#  Tom Simon and Sarah Teale produced the film named Death on a Factory Farm.
#
#  Music was composed by Jamie Lawrence; it was directed by Sarah Teale, and it has a running time of 83 minutes.
#
#  Death on a Factory Farm was directed by Sarah Teale, produced by Sarah Teale and Tom Simon, composed by Jamie Lawrence, and had a running time of 83 minutes.
#
#  Philippine Entertainment Portal is a subsidiary of GMA New Media, whose headquarters are in Quezon City, who makes web sites.
#
#  Philippine Entertainment Portal, Inc is a subsidiary of GMA New Media which produces web services in the city of Quezon.
#
#  GMA New Media, offering World Wide Web services and located in Quezon City, also has Philippine Entertainment Portal as their subsidiary.
#
#  The Hobbit's genre is high fantasy.
#
#  The Hobbit literary genre is high fantasy.
#
#  Aaron Turner is a singer who was born in Boston.
#
#  His music is post-metal, and he played with the band twilight.
#
#  Aaron Turner, originally from Boston, sings for a living as a post-metal music performer with the band Twilight.
#
#  Aaron Turner (originally from Boston) sings post-metal music for a living and played with the band Twilight.
#
#  Featuring Cecil Parker as a main role, It's Great to Be Young was edited by Max Benedict.
#
#  The composer of music for the film was Louis Levy.
#
#  “It's Great to Be Young” is a 1956 movie edited by Max Benedict.
#
#  The movie stars Cecil Parker, and includes music by Louis Levy.
#
#  Cecil Parker starred in the 1956 movie It's Great to Be Young, which was edited by Max Benedict, with Louis Levy as the music composer.
#
#  J.R.R. Tolkien wrote The Fellowship of the Ring which was released on July 29, 1954.
#
#  The Hobbit was released first, followed by The Fellowship of the Ring, and then The Two Towers.
#
#  The author of the Fellowship of the Ring is J.R.R. Tolkien.
#
#  It was released on July 29, 1954.
#
#  The Hobbit came before it, and it was followed by The Two Towers.
#
#  The Fellowship of the Ring was published on July 29, 1954, and J.R.R. Tolkien was the author.
#
#  The Fellowship of the Ring was followed by The Two Towers and the Hobbit came before The Fellowship of the Ring.
#
#  Death of a Factory Farm was produced and directed by Tom Simon.
#
#  It was released by HBO and is 83 minutes long.
#
#  The film Death on a Factory Farm (83 minutes), broadcasted by HBO, is both directed and produced by Tom Simon.
#
#  "Death on a Factory Farm" is an 83 minute HBO film that was produced and directed by Tom Simon.
#
#  The Velvet Underground created the album Bootleg Series Volume 1: The Quine Tapes produced by The Velvet Underground which is 230.05 minutes long.
#
#  Music group the Velvet Underground both produced and released The Bootleg Series Volume I: The Quine Tapes, which have a runtime of 230.05 minutes.
#
#  The album Bootleg Series Volume 1: The Quine Tapes is produced by The Velvet underground and has a run time of 230:05.Hypermarcas is a CEO led pharmaceutical company founded on January 1, 2001.Hypermarcas, founded on 2001-01-01, is in the pharmaceutical industry; its key person is their CEO.Hypermarcas, a company in the pharmaceuticals industry, founded on January 1, 2001, is managed by the CEO.Agremiação Sportiva Arapiraquense played in the Campeonato Brasileiro Série C league during the 2015 season.
#
#  Agremiação Sportiva Arapiraquense from the Campeonato Brasileiro Série C league played in the 2015 season.
#
#  Agremiação Sportiva Arapiraquense play in the Campeonato Brasileiro Série C league in 2015.Kingdom of England is a unitary state form of government which is also Lady Anne Monson's nationality.
#
#  Lady Anne Monson is an English national from the unitary Kingdom of England.
#
#  Lady Anne Monson held British nationality; she lived in the kingdom of England where there was a unitary state form of government.
#
#  The orbital period of the asteroid 1147 Stavropolis is 1249.6 days.
#
#  The orbital period of 1147 Stavropolis is 1249.6.Anatole de Grunwald is the writer and producer of 'English Without Tears'.
#
#  "English Without Tears" was produced and written by Anatole de Grunwald.
#
#  'English Without Tears' was written by and produced by Anatole de Grunwald.
#
#  The nationality of Abraham A. Ribicoff was American and he was married to Ruth Ribicoff.
#
#  He was born and died in the United States and during his life he was in office while John F. Kennedy was president.
#
#  Abraham A. Ribicoff was married to Ruth Ribicoff and he was born and died in the USA.
#
#  Mr Ribicoff was in office at the same time as John F. Kennedy was president and was an American citizen.
#
#  The United States is the birthplace of American citizen Abraham A. Ribicoff who was in office while John F. Kennedy was president.
#
#  He was married to Ruth Ribicoff and died in the United States.
#
#  Mexicans inhabit Mexico, where the currency is the peso.
#
#  Bionico is a food found in Mexico that requires granola as one of its ingredients, and is a dessert like Sandesh.
#
#  Sandesh is a confectionary dessert item, much like Bionico, which contains granola and is found in Mexico.
#
#  Mexico uses the peso as its currency and is inhabited by Mexicans.
#
#  Ciudad Ayala is in Morelos and has a population density of 1604.The population density of Ciudad Ayala which is part of Morelos is 1604.0.Being a part of Morelos, Ciudad Ayala has a population density of 1604.0.Cuernavaca is part of Morelos.
#
#  Cuernavaca is a part of Morelos.Liselotte Grschebina, an Israeli national, was born in Karlsruhe.
#
#  Liselotte Grschebina is an Israeli who was born in Karlsruhe.
#
#  Liselotte Grschebina died on June 14, 1994.Liselotte Grschebina died on the 14th of June, 1994.India has a total area of 3287590000000.0.The total area of India is 3,287,590 square kilometers.
#
#  The total area of India is 32875900000000.The University of Cambridge is a research university.
#
#  Cumberland county, Pennsylvania is north of Adams County, Pennsylvania, the location of the 11th Mississippi Infantry Monument in Gettysburg.
#
#  The 11th Mississippi Infantry Monument is in the municipality of Gettysburg, Adams County, Pennsylvania which is south to the Pennsylvania's Cumberland County.11th
#
#  Mississippi Infantry Monument is situated in Adams County, Pennsylvania, in the municipality of Gettysburg.
#
#  Adams County, Pennsylvania has Cumberland County, Pennsylvania to its north.
#
#  It's Great to Be Young (a 1956 film directed by Cyril Frankel) is 94 minutes long.
#
#  Louis Levy is the music composer for the film, while Cecil Parker had a main role in the film and Ted Willis is the writer.
#
#  The running time of the movie It's Great to Be Young directed by Cyril Frankel, starring Cecil Parker in 1956 is 94 minutes.
#
#  Ted Willis is the writer of the film and Louis Levy is the music composer.
#
#  The 1956 film "It's Great to Be Young" was written by Ted Willis, starred Cecil Parker, and was directed by Cyril Frankel.
#
#  "It's Great to Be Young" has a length of 94 minutes and its music was composed by Louis Levy.
#
#  Aaron Turner a Post metal genre performer, started playing electric guitar in 1995 in the Lotus Eaters band .Electric
#
#  guitarist Aaron Turner began performing in 1995.
#
#  Turner is a post-metal musician in the band Lotus Eaters.
#
#  Nicholas Brodszky composed music of the movie English Without Tears with a running time of 89 minutes and release date was 07-28-1944.The 89 minute film, English Without Tears, released on July 1944, was composed by Nicholas Brodszky.
#
#  The music of the 89 minute long film, English Without Tears (released 1944-07-28) is composed by Nicholas Brodszky.
#
#  Punk blues is the genre of the album Turn Me
#
#  On that was self-produced by the American band Honeymoon Killers.
#
#  Noise rock is the genre of the album Turn Me On as well that has run time of 35.1 minutes which was preceded by the album Let It Breed.
#
#  Turn Me On, a punk blues/noise rock album, was produced by The Honeymoon Killers, who also produced the album Let It Breed.
#
#  Turn Me On is 35 minutes 10 seconds in length.
#
#  'English Without Tears' was written by Terence Rattigan and Anatole de Grunwald, who was born in Saint Petersburg.
#
#  'English Without Tears' is the screenplay of writers Terence Rattigan and Anatole de Grunwald.
#
#  The latter was born in Saint Petersburg.
#
#  The writer of English Without Tears was Anatole de Grunwald, born in Saint Petersburg.
#
#  "English Without Tears" was authored by Terence Rattigan.
#
#  The absolute magnitude of 1147 Stavropolis is 11.5.1147 Stavropolis absolute magnitude is 11.5 .1147
#
#  Stavropolis has an absolute magnitude of 11.5.Super Capers is a film starring Michael Rooker and Tom Sizemore.
#
#  The film was edited by Stacy Katzman, and the language is English.
#
#  Roadside Attractions is the distributor of the movie.
#
#  The English film Super Capers, distributed by Roadside Attractions, stars Michael Rooker and Tom Sizemore.
#
#  Stacy Katzman was the editor of Super Capers.
#
#  Michael Rooker and Tom Sizemore starred in the English language movie Super Capers which was edited by Stacy Katzman and distributed by Roadside Attractions.
#
#  The three minute sixteen seconds Mermaid song written by the band Train is on Columbia Records.
#
#  The song Mermaid by the musical group Train is 3 minutes and 16 seconds long and was released on the Columbia Records record label.
#
#  The Train song Mermaid was released under the record label Columbia Records, by the musical band Train which lasts 3.16 minutes.
#
#  A leader of Mexico is called the President of the Chamber of Deputies.
#
#  Mexico's government has a leader position titled the President of the Chamber of Deputies.
#
#  President of the Chamber of Deputies is a leader title in Mexico.
#
#  MotorSport Vision operates the Bedford Aerodrome located in Thurleigh with a runway length of 1095 and serves the Bedford Autodrome.
#
#  The Bedford Aerodrome elevation is 83.2104 meters above sea level with a runway name of 08/26 and its ICAO location identifier of EGBF.MotorSport
#
#  Vision is the operating organisation for Bedford Aerodrome, which has a runway called 08/26 with the length of 1095.0.
#
#  This aerodrome is at an elevation of 83.2104 above sea level and is located in Thurleigh.
#
#  It serves the Bedford Autodrome.
#
#  Bedford Aerodrome's International Civil Aviation Organization (ICAO) identifier is EGBF.The Bedford Aerodrome has an operating organization called the MotorSport Vision, and it has a runway named 08/26.
#
#  The runway length is 1,095, and this aerodrome is 83.2 meters above the sea level.
#
#  The location of Bedford Aerodrome is Thurleigh, and its ICAO id is EGBF.
#
#  The aerodromes serves the Bedford Autodrome.
#
#  American citizen Darinka Dentcheva was born on January 1st, 1958.
#
#  After graduating from her alma mater Humboldt University, she began to work professionally in the field of Mathematical Optimization.
#
#  This New Jersey resident is known for her work with stochastic programming, being heavily influenced by Andrzej Piotr Ruszczynski.
#
#  American mathematician Darinka Dentcheva was born on January 1, 1958.
#
#  Dentcheva graduated from Humboldt University in Berlin, Germany.
#
#  Influenced by fellow mathematician, Andrzej Piotr Ruszczyński, Dentcheva made contributions to the field of mathematical optimization, in particular, Stochastic programming.
#
#  She resides in New Jersey.
#
#  Darinka Dentcheva, a United States citizen with birth date January 1, 1958 is a mathematician influenced by Andrzej Piotr Ruszczyński in the field of mathematical optimization and stochastic programming.
#
#  She graduated from Humboldt University and resides in New Jersey.
#
#  John Mills is playing the lead in the movie It's Great to Be Young, which was released in 1956.It's Great to Be Young is a 1956 film starring John Mills.
#
#  John Mills had a main role in the movie It's Great to Be Young.
#
#  The Pontiac Rageous was produced in Michigan in 1997.The Pontiac Rageous went into production in Michigan in 1997 and ended the same year.
#
#  Pontiac Rageous was first made in Michigan in 1997 and was last produced in 1997.Super Capers was distributed by Roadside Attractions and Lionsgate (founded by Frank Giustra).Roadside Attractions distributed the film of Super Capers which was also distributed by Lionsgate founded by Frank Giustra.
#
#  Super Capers is distributed by Roadside Attractions and by Lionsgate, which was founded by Frank Giustra.
#
#  Darinka Dentcheva is a citizen of the United States who works in the field of Mathematical optimization.
#
#  Darinka Dentcheva is a US citizen and a mathematician working in the field of mathematical optimization.
#
#  Darinka Dentcheva, a citizen of the United States, is a professional in the field of mathematical optimization.
#
#  The University of Burgundy is located in the city of Dijon and has 9400 postgraduate students.
#
#  The University of Burgundy is located in the city of Dijon and has 9400 post-graduate students.
#
#  The University of Burgundy in Dijon has 9400 postgraduate students.
#
#  English Without Tears is written by Anatole de Grunwald.
#
#  The writer of English Without Tears was Anatole de Grunwald.
#
#  "English Without Tears" was written by Anatole de Grunwald.
#
#  Nurhan Atasoy's birthplace is Turkey.
#
#  The place where Nurhan Atasoy was born is Turkey.
#
#  Nurhan Atasoy was born in Turkey.
#
#  GMA
#
#  New Media is a company in the entertainment industry that is located inside the GMA Network Center, which is in the Philippines,.
#
#  Member of the entertainment industry, The GMA New Media, is located in the GMA Network Center in the Philippines.
#
#  GMA
#
#  New Media is located in the GMA Network Center in the Philippines and offers applications in the entertainment industry.
#
#  The Honeymoon killers produced a punk blues album titled Turn Me On.
#
#  The Honeymoon Killers is the producer of the punk-blues album ‘Turn Me On’.
#
#  The American Band, the Honeymoon Killers, self-produced its album called Turn Me On of the punk blues genre.
#
#  Ciudad Ayala is in the country of Mexico and is in the Pacific Daylight time which is in the Pacific Standard Time Zone.
#
#  Ciudad Ayala is a Mexican city located in the Pacific Standard Daylight time zone.
#
#  Ciudad Ayala located in the country of Mexico uses the Pacific Standard Time Zone and Pacific Daylight Time.

# %% [markdown]
# ### Sentence Segmentation
#
# **Exercise 2:** Breaking the text into Sentences
#
# * Use spaCy to segment the text into sentences.
# * Print out the results

# %% [markdown]
# **Exercise 3:** Define a function which takes a SpaCy processed text and segments it into Sentences
#
# * Define a function which takes as input a file processed by spaCy and outputs the sequence of sentences
# identified by spaCy.
# * Print out the results

# %%
def SentSpilt(sp_text):
    return [sentence for sentence in sp_text.sents]

# %%
sp_sent_list = SentSpilt(sp_tok)
sp_sent_list
# Out:
# [Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca.,
#  Agremiação Sportiva Arapiraquense, nicknamed "Alvinegro", lay in the Campeonato Brasileiro Série C league from Brazil.,
#  Estádio Municipal Coaracy da Mata Fonseca is the name of the ground of Agremiação Sportiva Arapiraquense in Arapiraca.,
#  Alvinegro, the nickname of Agremiação Sportiva Arapiraquense, play in the Campeonato Brasileiro Série C league from Brazil.,
#  Nie Haisheng, born on October 13, 1964, worked as a fighter pilot.,
#  Nie Haisheng is a former fighter pilot who was born on October 13, 1964.Nie,
#  Haisheng born on 10/13/1964 is a fighter pilot.,
#  MotorSport Vision is located in the city of Fawkham.,
#  MotorSport Vision is located in the city of Fawkham, UK.MotorSport Vision is located in Fawkham.185 centimetre tall Aleksandr Prudnikov played for the Otkrytiye Arena based FC Spartak, Moscow.,
#  The 185 cm tall Aleksandr Prudnikov plays for FC Spartak Moscow who call their home ground Otkrytiye Arena.,
#  Aleksandr Prudnikov who is 185 cm tall, plays for FC Spartak Moscow whose ground is the Otkrytiye Arena.,
#  Ciudad Ayala is a city with population density and population of 1604 and 1777539 respectively, where the leader is called the City Manager.,
#  The government type in the city of Ciudad Ayala is council-manager.,
#  The city of Ciudad Ayala, with a population of 1,777,539, is led by a City Manager on a council-manager government system.,
#  It has a population density of 1604.Ciudad Ayala, a city with population density and population of 1604.0 and 1,777,539 respectively, uses a type of government called council-manager government.,
#  One of the leaders of Ciudad Ayala is the City Manager.,
#  The album 1969: The Velvet Underground Live is preceded by the Velvet Underground album Squeeze, which was followed by The Quine Tapes.,
#  The Velvet Underground album Bootleg Series Volume 1: The Quine Tapes was preceded by the album Squeeze, which was followed by the live album 1969: The Velvet Underground Live.,
#  The Bootleg Series Volume I: The Quine Tapes is preceded by the Velvet Underground album Squeeze which was itself followed by the album 1969:,
#  The Velvet Underground Live.,
#  Ciudad Ayala in Mexico with population density of 1604.0 and elevated 1147.0 above sea level is in the PDT time zone.,
#  The leader here is called the governator.,
#  Ciudad Ayala is a country in Mexico that is located 1147 above sea level and is in the Pacific Daylight time zone.,
#  The population density is 1604 and the leader of Ciudad Ayala is called the governator.,
#  Ciudad Ayala is located in Mexico and has a population density of 1604.,
#  The city stands 1147 m above sea level.,
#  The Governator is the leader of Ciudad Ayala located in the Pacific Daylight time zone.,
#  Olga Bondareva died on December 9, 1991.Olga Bondareva died on the 9th of December, 1991.The date of Olga Bondareva's death was the ninth of December 1991.Saint Petersburg was founded on May 27, 1703 and has a total area of 1439.0, Olga Bondareva passed away at Saint Petersburg.,
#  Saint Petersburg, where Olga Bondareva died, was founded on the 27th of May, 1703 and has a total area of approximately 1439 km2.Saint Petersburg, where Olga Bondareva died, was founded on May 27, 1703 and consists of a total area of 1439.0 sq/km.,
#  The population density of Ciudad Ayala is 1604.0.Ciudad Ayala city has a population density of 1604.0.The population density in Ciudad Ayala is 1604.Piotr Hallmann was born on August 25, 1987.Piotr Hallmann's birthday is August 25th,
#  1987.Piotr Hallmann was born on the 25th of August 1987.The,
#  Darlington town has an area code of 01325.The telephone area code for Darlington is 01325.The area code in Darlington is 01325.Pennsylvania's Franklin County is found to the west of Adams County, Pennsylvania and Pennsylvania's Cumberland County is to the north.,
#  A monument to the 11th Mississippi Infantry was erected in Adams County in the year 2000 in the municipality of Gettysburg and this monument is categorised as a contributing property.,
#  The 11th Mississippi Infantry Monument, a Contributing property established in the year 2000 in Adams County, Pennsylvania falls in the municipality of Gettysburg, Pennsylvania.,
#  Adams County Pennsylvania is East of Franklin County, Pennsylvania and has Cumberland County, Pennsylvania to its north.,
#  The official language of Israel is modern Hebrew.,
#  Israel’s official language is Modern Hebrew.,
#  Modern Hebrew is the official language of Israel.,
#  ENAIRE is the operating organisation for Adolfo Suarez Madrid-Barajas airport.,
#  This airport is situated 610 meters above sea level in Alcobendas.,
#  GMA New Media, a company founded on 01-01-2000 are manufacturers of mobile applications.,
#  GMA New Media, which was founded on January 1, 2000, is a company that offers products such as mobile applications.,
#  GMA New Media makes mobile apps and was founded on 01/01/2000.Hypermarcas is a pharmaceutical company located in Sao Paulo, Brazil.,
#  Brazil is 8514837.14 square kilometers in size.,
#  Hypermarcas, a pharmaceutical company, is located in Sao Paulo within the 8514837.14 square kilometres that make up the country of Brazil.,
#  Hypermarcas, a company in the pharmaceuticals industry, is located in Sao Paulo, Brazil, a country with a total area of 8514837.14 square kilometres.,
#  The Quine Tapes are Rock music genre preceded by the album Squeeze, and Squeeze was preceded by the album Andy Warhol's Velvet Underground Featuring Nico.,
#  Bootleg Series Volume 1: The Quine Tapes's genre is rock, and is preceded by the Velvet Underground album Squeeze, which was preceded by the compilation album Andy Warhol's Velvet Underground Featuring Nico.,
#  The album Bootleg Series Volume 1: The Quine Tapes fits into the Rock music genre and was preceded by Squeeze by The Velvet Underground, which in turn was preceded by Andy Warhol's Velvet Underground Featuring Nico.,
#  Dr. G. P. Prabhukumar is the director of the Acharya Institute of Technology which is located at Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090 in India and is affiliated with Visvesvaraya Technological University.,
#  The Acharya Institute of Technology campus is located in Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090, India.,
#  Its director is Dr.G.P. Prabhukumar and it is affiliated to Visvesvaraya Technological University.,
#  The campus of the Acharya Institute of Technology is located at Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090, India and it is affiliated with the Visvesvaraya Technological University.,
#  Its director is Dr.G.P.Prabhukumar.,
#  Abraham A. Ribicoff was born and died in the United States where African Americans are an ethnic group.,
#  Abraham A.Ribicoff died in the United States.,
#  It was also his birthplace.,
#  African Americans are an ethnic group in the U.S.A.Abraham A Ribicoff was born and died in the United States where African Americans are an ethnic group.,
#  Music group the Velvet Underground produced and released rock music album Bootleg Series Volume 1: The Quine Tapes under the Polydor Records record label.,
#  The album was recorded in St. Louis, Missouri, USA and has a run time of 230:05.Bootleg Series Volume 1: The Quine Tapes created and produced by The Velvet Underground with runtime of 230.05 minutes was recorded in was St. Louis Missouri, United States.,
#  The Rock genre album was recorded through Polydor Records.,
#  The Bootleg Series Volume I: The Quine Tapes created and produced by The Velvet Underground with runtime of 230.05 minutes was recorded in St. Louis, Missouri, United States.,
#  The Rock music genre album was released by the record label Polydor Records.,
#  The fellowship of the Ring belongs to the fantasy genre.,
#  George Allen &amp; Unwin published it.,
#  The Fellowship of the Ring was published in the Fantasy genre by George Allen &amp; Unwin.,
#  The Fellowship of the Ring, from the fantasy genre, was published by George Allen &amp; Unwin.,
#  Distinguished Service Medal (US Navy) recipient Alan Shepard was born in New Hampshire but died in California.,
#  Awarded the Distinguished Service Medal by The United States Navy, Alan Shepard, was born in New Hampshire, and died in California.,
#  Alan Shepard, born in New Hampshire while having died in California, was awarded the Distinguished Service Medal by the United States Navy.,
#  Imagine is a song that Train followed Mermaid with, which was a song produced by the production team Espionage, and was on their album California 37.Train followed its song Mermaid, from its California 37 album, which was was produced by the production team Espionage, with a song titled Imagine.,
#  From the production team Espionage, Train's song Mermaid (on the California 37 album) was followed by Train's performance of Imagine by John Lennon.,
#  The Train song Mermaid, which belongs to the California 37 Train album and was produced by Espionage, is followed by the John Lennon song Imagine.,
#  Train's song Imagine came after a song from their California 37 album, titled Mermaid, which was produced by the production team Espionage.,
#  The Fellowship of the Ring was written by J.R.R. Tolkien and was released on July 29, 1954.,
#  The Fellowship of the Ring is considered fantasy and was published by George Allen &amp; Unwin.,
#  The sequel to The Fellowship of the Ring was The Two Towers.,
#  J.R.R. Tolkien is the author of The Fellowship of the Ring released on July 29, 1954.,
#  It is a fantasy book published by George Allen &amp; Unwin.,
#  The novel was followed by The Two Towers.,
#  The Fellowship of the Ring belongs to the fantasy genre.,
#  Its author is J.R.R. Tolkien.,
#  It was published on July 29, 1954 by George Allen &amp; Unwin.,
#  It was followed by The Two Towers.,
#  GMA,
#  New Media lies in the Philippines where applications are offered in the entertainment industry.,
#  Located in the Philippines, GMA New Media is an entertainment industry.,
#  GMA,
#  New Media is an entertainment company located in the Philippines.,
#  English Without Tears, written by Terence Rattigan, runs 89 minutes.,
#  The cinematography for the film was done by Bernard Knowles.,
#  English Without Tears, an 89 minute film written by Terence Rattigan, features the cinematography of Bernard Knowles.,
#  Terence Rattigan is the writer of the 89 minute movie ´English Without Tears´ and Bernard Knowles is the cinematographer.,
#  George Monson was married to Lady Anne Monson, a botanist, who died on February 18, 1776.Lady Anne Monson, a professional botanist who was married to George Monson, died on February 18th,,
#  1776.Lady Anne Monson is the spouse of George Monson.,
#  Her professional field of study was botany, and she died on 18 February 1776.Abdul Taib Mahmud, member of the Parti Pesaka Bumiputera Bersatu party, resides in Demak Jaya, Jalan Bako, Kuching, Sarawak.,
#  Abdul Taib Mahmud, a member of the Parti Pesaka Bumiputera Bersatu party, resides in Demak Jaya, Jalan Bako, Kuching, Sarawak.,
#  Liselotte Grschebina was an Israeli who attended the school of Applied Arts in Stuttgart.,
#  She was born in Karlsruhe, Germany.,
#  Israel's national language is Modern Hebrew.,
#  Liselotte Grschebina is an Israeli national who did her studies at the School of Applied Arts in Stuttgart and was born in Karlsruhe, which is in Germany unlike Israel whose language is Modern Hebrew.,
#  Liselotte Grschebina was born in Karlsruhe which is located in Germany, has Israeli nationality (the language in Israel is Modern Hebrew), and studied at the School of Applied Arts in Stuttgart.,
#  Chinabank's location is the Philippines.,
#  Chinabank is located in the Philippines.,
#  The Train song Mermaid, which is an example of the reggae genre, was released under the record labels of Columbia Records and Sony Music Entertainment.,
#  It was written by Espen Lind and Amund Bjørklund and has a total runtime of 3 minutes and 16 seconds.,
#  Amund Bjorklund and Espen Lind are writers of the 3.16 minute reggae song Mermaid by Train that was released under Sony Music Entertainment and Columbia Records.,
#  The song Mermaid was written In the reggae music genre by Espen Lind and Amund Bjorklund The song was performed by Train and released by Columbia Records and Sony Music Entertainment records.,
#  It has a total runtime of three minutes and sixteen seconds.,
#  It's Great to be Young,a 1956 film starring Cecil Parker was composed by Louis Levy and written by Ted Willis.,
#  “It's Great to Be Young” (1956) was written by Ted Willis and features music by Louis Levy.,
#  A main role in the movie was given to Cecil Parker.,
#  Louis Levy is the composer of the 1956 film It's Great to Be Young, which is written by Ted Willis and stars Cecil Parker.,
#  Aaron Turner is a post-metal musician from Massachusetts who plays the electric guitar.,
#  He started performing in 1995 and is a musician in the Lotus Eaters band.,
#  Aaron Turner is a post-metal musician born in Massachusetts who plays electric guitar, started performing in 1995 and is in the Lotus Eaters band.,
#  Aaron Turner is a post metal performer from Massachusetts who plays the electric guitar, started performing in 1995 and is in the Lotus Eaters band.,
#  Pennsylvania's Franklin County is found to the west of Adams County, Pennsylvania and Carroll County, Maryland is to the southeast.,
#  A monument to the 11th Mississippi Infantry was erected in 2000 in Adams County and this monument is classed as a contributing property.,
#  The 11th Mississippi Infantry Monument was established in 2000 in Adams County, Pennsylvania which has Carroll County, Maryland to its southeast and Franklin County, Pennsylvania to its west.,
#  The 11th Mississippi Infantry Monument is in the category of contributing property.,
#  The 11th Mississippi Infantry Monument, established in 2000, falls under the category of Contributing property and is located in Adams County, Pennsylvania, which has Carroll County, Maryland to the southeast and Franklin County, Pennsylvania to the east.,
#  The band Nord is a sludge metal band that releases post-metal.,
#  They have an album called the Year of No light that was released on June 9th 2006, and was under Crucial Blast Label.,
#  Year of No Light self-produced their album Nord.,
#  The album was released under the label Crucial Blast on September 6th, 2006.,
#  Nord falls into the sludge metal and post-metal genres.,
#  Ciudad Ayala is a metropolitan city which has population of 1,777,539 with its population density of 1604.0 and it falls into UTC offset -6 time zone.,
#  One of the leaders of Ciudad Ayala is the City Manager which uses council-manager government.,
#  The city Ciudad Ayala has population 1,777,539 making the density 1604.0.,
#  One of the leaders in the council-manager government is the City Manager.,
#  It is in UTC offset -6.The city Ciudad Ayala has population 1777539 making the density 1604.,
#  It is a council-managed government led by a City Manager.,
#  It is in UTC offset -6.Super,
#  Capers is a 98 minute film with a $2000000.0 budget.,
#  It stars Tom Sizemore and Michael Rooker, and was written and directed by Ray Griggs.,
#  Super Capers is a 98 minute movie starring Michael Rooker and Tom Sizemore.,
#  It was written and directed by Ray Griggs.,
#  It had a budget of $2,000,000.The 98 minute film Super Capers had a budget of 2 million dollars.,
#  It was written and directed by Ray Griggs.,
#  It starred Tom Sizemore and also featured Michael Rooker.,
#  Darinka Dentcheva developed a theory influenced by Andrzej Piotr Ruszczyński.,
#  Darinka Dentcheva was influenced by Andrzej Piotr Ruszczyński.,
#  Darinka Dentcheva was influenced by Andrzej Piotr Ruszczynski.,
#  Born in 1878, Harry Carey later grew up to write and star in the movie McVeagh of the South Seas.,
#  Harry Carey, born in 1878, wrote and appeared in the movie McVeagh of the South Seas.,
#  Harry Carey, who was born in 1878, wrote and starred the film of McVeagh of the South Seas.,
#  Mexicans, the inhabitants of Mexico, can use their peso currency to purchase a dessert called Bionico.,
#  Bionico can be found in Guadalajara, Mexico, and is made from sour cream, chopped fruits, condensed milk, granola, coconut and raisins.,
#  They can also buy cookies, another dessert.,
#  Much like a cookie, Bionico is a dessert food whose ingredients include chopped fruits, sour cream, condensed milk, granola, shredded coconut and raisins.,
#  Bionico is found in the Guadalajara region of Mexico, which uses pesos are their currency and is home to Mexican people.,
#  Mexico inhabited by Mexicans has peso as its currency.,
#  Bionico, a dessert food found in Guadalajara, Mexico, has sour cream, chopped fruits, condensed milk, granola, raisins and shredded coconut as its main ingredients.,
#  Cookie is a type of dessert.,
#  One of the leader of Ciudad Ayala (a city) is called City Manager.,
#  With a population density of 1604.0.Ciudad Ayala is a city with a population density of 1,604.,
#  One of the leaders is called the City Manager.,
#  One of the leaders of Ciudad Ayala, a city with a population density of 1604.0, is the City Manager.,
#  ENAIRE, based in Madrid, Spain, is the operating organisation for Adolfo Suarez Madrid-Barajas airport which is in Alcobendas.,
#  The runway length at the airport is 3500.Located in Madrid, Spain, ENAIRE operates the Adolfo Suarez Madrid-Barajas Airport in Alcobendas which reports a runway length of 3,500.Adolfo Suarez Madrid-Barajas Airport, operated by ENAIRE, is located in Alcobendas while ENAIRE is located in Madrid, Spain.,
#  The Airport's runway length is 3500.Bionico is a dish served for dessert in Mexico, where the currency is the peso, the dish contains granola.,
#  Bionico, a food that requires granola as one of its ingredients and served at the dessert is found in Mexico.,
#  The currency is the Peso.,
#  Bionico is a food found in Mexico (currency: peso).,
#  Bionico (dessert) requires granola as one of its ingredients.,
#  With a periapsis of 260855000000.0, the 1147 Stavropolis has a epoch of 31 July 2016 (JD2457600.5).1147 Stavropolis epoch is 31 July 2016 (Julian Day 2457600.5) and the periapsis of 1147 Stavropolis is 260855000000.1147,
#  Stavropolis has an epoch on 31 July 2016 and a periapsis of 260855000000.0.Ciudad Ayala which is in the Pacific Daylight time zone has the population density of 1604.Ciudad Ayala city which has a PDT time zone has a population density of 1604.0.Ciudad Ayala's time zone is Pacific Daylight Time and its population density is 1604.0.The net income of Chinabank is 15,100,000,000, and they have 5594 workers total.,
#  Chinabank currently brings in a net income of 15100000000 thanks to the efforts of its 5594 employees.,
#  Chinabank brings in a net income of 15,100,000,000 with its 5594 employees.,
#  Steve Bright is the creator of Bananaman which was last broadcast on April 15th 1986 by the BBC.Bananaman was created by Steve Bright and last aired on April 15th 1986.,
#  It was broadcast by the BBC.Bananaman, the TV show, was created by Steve Bright and was last aired on 15th April 1986.,
#  Bananaman was broadcast on the BBC.Bionico (a dish served for dessert) is a food found in Guadalajara in Mexico.,
#  The currency in Mexico is the Mexican peso inhabited by Mexicans.,
#  Bionico (a dessert) is a food found in Guadalajara in Mexico.,
#  The currency in Mexico is the Mexican peso inhabited by the Mexicans.,
#  Bionico is a food found in Mexico and served at the dessert course.,
#  The dessert can be found in Guadalajara.,
#  The currency of Mexico (inhabited by Mexicans) is Peso.,
#  The Year of No Light album Live at Roadburn 2008 was followed by their album Nord.,
#  Live at Roadburn 2008 was preceded by the album Nord played by Year of No Light.,
#  Year of No Light, who released the album Nord, followed this up with the album Live at Roadburn 2008.Alan,
#  Shepard was a crew member of Apollo 14 who was born November 18th, 1923, in New Hampshire and died in California.,
#  Alan Shepard was born in New Hampshire on November 18, 1923.,
#  He was a crew member of Apollo 14, and died later on in California.,
#  Alan Shepard was born on Nov 18, 1923 in New Hampshire, was a member of the Apollo 14 crew and died in California.,
#  The ALCO RS-3, with a four-stroke engine and 12 cylinders, has a length of 17068.8 millimetres.,
#  The four-stroke 12 cylinder ALCO RS-3 is 17068.8 millimetres long.,
#  The ALCO RS-3 has a four-stroke engine and a cylinder count of 12 which is 17068.8 mm in length.,
#  Olga Nikolaevna Bondareva, (born April 27, 1937) died in Saint Petersburg.,
#  She was best known for the "Bondareva-Shapley theorem..,
#  Olga Nikolaevna Bondareva, known for the Bondareva-Shapley theorem, was born on April 27, 1937 and died in Saint Petersburg.,
#  Olga Bondareva, born "Olga Nikolaevna Bondareva" on April 27th, 1937 and known for the Bondareva-Shapley theorem, died in Saint Petersburg.,
#  Fellowship of the Ring, a fantasy novel created by J.R.R. Tolkien was released on July 29, 1954; the Hobbit came before The Fellowship of the Ring.,
#  J.R.R. Tolkien is the author of The Fellowship of the Ring published on July 29, 1954.,
#  This book belongs to the fantasy genre and came after The Hobbit.,
#  Fantasy is The Fellowship of the Ring's genre, and it was released on July 29, 1954.,
#  The Fellowship of the Ring was written by J.R.R. Tolkien and was preceded by the Hobbit.,
#  Train's hit Mermaid was put out by the Sony Music Entertainment record label, was written by Amund Bjørklund with the producer Stargate.,
#  Train followed Mermaid with Imagine, a song by John Lennon where Mermaid was produced by the Espionage production team.,
#  The song Mermaid, by Train, is a Sony Music Entertainment release produced by Stargate along with the production team Espionage.,
#  Mermaid, written by Amund Bjorklund, is followed by John Lennon's Imagine.,
#  The Train song Mermaid written by Amund Bjørklund and production team Stargate was produced by the production team Espionage and released under the record label Sony Music Entertainment.,
#  It was followed by the release of Imagine by John Lennon performed by Train.,
#  Year of No Light produced an album called Nord on 6/9/2006 which is 58.41 minutes long.,
#  They came out with the Demo 2004 album first, followed by Nord, and then the album Live at Roadburn in 2008.The Year of No Light album Nord with runtime of 58.41 minutes was released by the artist on the date 2006-09-06.,
#  It was preceded by Year of No Light's album Demo 2004 and followed by Year of No Light's album Live at Roadburn 2008.The album Nord by Year of No Light with runtime of 58 minutes and 41 seconds was released on September 6, 2006.The album Nord was preceded by the album Demo 2004 and followed by Live at Roadburn 2008 .The,
#  11th Mississippi Infantry Monument is placed in the municipality of Gettysburg in Pennsylvania, in Adams County, USA.,
#  Adams County has Carroll County, Maryland to its southeast and the 11th Mississippi Infantry Monument is categorized as a Contributing Property.,
#  The 11th Mississippi Infantry Monument is categorised as a contributing property and stands in Adams County, Pennsylvania in the municipality of Gettysburg in the USA.,
#  Carroll County Maryland is southeast of Adams County.,
#  The 11th Mississippi Infantry Monument's location is Adams County, Pennsylvania, USA, in the municipality of Gettysburg.,
#  To the southeast of Adams County, lies Carroll County, Maryland.,
#  The 11th Mississippi Infantry Monument is a contributing property.,
#  Israeli national Liselotte Grschebina was born in the German Empire and died in Israel on June 14, 1994.Liselotte Grschebina died in Israel on June 14, 1994.,
#  Though she had Israeli nationality, she was born in the German Empire.,
#  Liselotte Grschebina was an Israeli national born in the German Empire.,
#  She died on June 14, 1994 in Israel.,
#  Located in King of Prussia, Pennsylvania, AmeriGas is an energy company that serves the United States.,
#  AmeriGas has an operating income of $380,700,000 and net income of $211,200,000.Currently serving all regions of the United States, AmeriGas is headquartered in the King of Prussia, Pennsylvania in the United States.,
#  An established company in the energy industry, AmeriGas has an operating income of $380,700,000 and a net income of $211,200,000.A US provider in the energy industry, AmeriGas is located in the King of Prussia, Pennsylvania in the United States, and has an operating income of $380,700,000 with a net income of $211,200,000.Discovered in 1927 by Grigory Neujmin, 1147 Stavropolis has an apoapsis of 418476000000 and an orbital period of 1249.6 days.,
#  The asteroid 1147 Stavropolis was discovered by Grigory Neujmin on the 11th of June 1929.,
#  It has an orbital period of 1249.6 days and an apoapsis of 418476000000.0.1147 Stavropolis is an asteroid, discovered on 11 June 1929 by Grigory Neujmin.,
#  Its apoapsis is 418476000000.0 AU and the orbital period is,
#  1249.6.Ciudad Ayala is a city which is located 1147m above sea level and has a UTC offset of -6.,
#  Ciudad Ayala is located in Mexico and has a leader called the Governator.,
#  Ciudad Ayala ruled by governator is in the country of Mexico with offset of -6 as well as sea level of 1147.0.Ciudad Ayala is located in Mexico, with a UTC offset,
#  -6.,
#  The city has an elevation of 1147.0 above sea level and its leader is called the governator.,
#  Morelos, in Ciudad Ayala, is in the UTC offset -6 timezone.,
#  Ciudad Ayala, which has a UTC offset of -6, is part of Morelos.,
#  The UTC offset of Ciudad Ayala which is part of Morelos is -6.Lady,
#  Anne Monson's spouse was George Monson.,
#  The spouse of George Monson is Lady Anne Monson.,
#  Lady Anne Monson is the spouse of George Monson.,
#  With 17000 members, Agremiação Sportiva Arapiraquense play in the Campeonato Brasileiro Série C league, of which Vila Nova Futebol Clube have been champions.,
#  Agremiação Sportiva Arapiraquense is a club of 17000 members in the Campeonato Brasileiro Série C league along with the Vila Nova Futebol Clube.,
#  Agremiação Sportiva Arapiraquense play in the Campeonato Brasileiro Série C league.,
#  The club currently has 17000 members.,
#  The Vila Nova Futebol Clube were champions of the league.,
#  In the region of Jalisco, Mexico, is a food dish served for dessert called Bionico.,
#  Bionico, a food found in the Jalisco region of Mexico, is served at the dessert course.,
#  Bionico (a dessert) is a food found in the region of Jalisco in Mexico.,
#  The Quine Tapes was produced by The Velvet Underground in St. Louis, Missouri, United States; its genre is rock.,
#  The rock album Bootleg Series Volume 1: The Quine Tapes was produced and recorded by the Velvet Underground in St. Louis, Missouri, USA.The Velvet Underground recorded Rock album The Bootleg Series Volume,
#  I: The Quine Tapes in St. Louis, Missouri, USA.Gdynia city in Poland has time zone of UTC +2 .Gdynia,
#  in Poland has a UTC (Coordinate Universal Time) offset of +2.Gdynia, Poland has a UTC of +02:00.Year of No Light is a band whose members include a former guitarist for Monarch has created an album called Nord.,
#  Nord is an album by Year of No Light, which is associated with the band Monarch.,
#  Born in Zaoyang city, Hubei, Nie Haisheng participated in the Shenzhou 6 mission.,
#  Shenzhou 6 crew member Nie Haisheng was born in Zaoyang in Hubei province.,
#  Born in Zaoyang, Hubei, Nie Haisheng participated in Shenzhou 6.Aleksandr Prudnikov, 185cm tall played for FC Spartak Moscow's youth team.,
#  FC Spartak Moscow is based in the Otkrytiye Arena.,
#  Aleksandr Prudnikov who is 185 cm tall is a member of the youth side of FC Spartak Moscow.,
#  The home ground of FC Spartak Moscow is Otkrytiye Arena.,
#  Aleksandr Prudnikov is 185.0 cm tall and played for the FC Spartak Moscow at the Otkrytiye Arena.,
#  The Pontiac Rageous assembled in Michigan with assembly line in Detroit was last produced in 1997.Ending its production in 1997, the Pontiac Rageous was assembled in Detroit, Michigan.,
#  Ending in 1997, the Pontiac Rageous was assembled in Detroit, Michigan.,
#  The total area of the city of Detroit is 370.03 square kilometers.,
#  Detroit has a total area of 370.03 square kilometers.,
#  English Without Tears, a film directed by Harold French and composed by Nicholas Brodszky, was released on 07-28-1944.,
#  The film length is 89 minutes.,
#  The 89 minute movie ´English Without Tears´ was directed by Harold French, and released on 7-28-1944.,
#  The songs used throughout the movie were composed by Nicholas Brodszky.,
#  English Without Tears is a movie directed by Harold French and musically composed by Nicholas Brodszky.,
#  It runs for 89 minutes and was released on July 7th, 1944.GMA New Media is located in the GMA Network Center.,
#  GMA New Media headquarters are located in the GMA Network Center.,
#  GMA,
#  New Media is located inside GMA Network Center.,
#  Olga Bondareva's professional field is Economics.,
#  Olga Bondareva is an economist.,
#  Olga Bondareva currently works in the field of Economics.,
#  The music of the film English Without Tears is composed by Nicholas Brodszky.,
#  Nicholas Brodszky composed music of the movie English Without Tears.,
#  Nicholas Brodszky was a composer of the songs that were used in English Without Tears.,
#  The BBC (located in Broadcasting House in London) last aired creator Steve Bright's Bananaman, starring Bill Oddie, on April 15th, 1986.The BBC (Broadcasting House) is based in London.,
#  The show Bananaman that starred Bill Oddie was broadcasted by BBC and last aired on April 15th, 1986.,
#  The creator of Bananaman was Steve Bright.,
#  Broadcasting House is also known as the Headquarters of the BBC.,
#  One of the BBC television shows, Bananaman was created by Steve Bright and starred Bill Oddie.,
#  Bananaman's last episode was broadcast on April 15, 1986.Montreal Locomotive Works built the ALCO RS-3 between May 1950 and August 1956.The,
#  ALCO RS-3, built by Montreal Locomotive Works, was produced between May 1950 and August 1956.The,
#  ALCO RS-3 was built by the Montreal Locomotive Works and was produced between May 1950 and August 1956.Agremiacao,
#  Sportiva Arapiraquense has 17000 members and play in the Campeonato Brasileiro Serie C league.,
#  The champions of the league have been Vila Nova Futebol Clube.,
#  Agremiação Sportiva Arapiraquense has 17000 members and play in the Campeonato Brasileiro Série C league, which Vila Nova Futebol Clube are the champions of.,
#  Agremiacao Sportiva Arapiraquense has 17000 members and plays in the Campeonato Brasileiro Serie C league of which the Vila Nova Futebol Clube were champions.,
#  Cecil Parker had a main role in It's Great to Be Young.,
#  Cecil Parker starred in the 1956 movie It's Great to Be Young.,
#  It's Great to be Young is a 1956 film starring Cecil Parker.,
#  The movie "Super Capers" was directed by Ray Griggs.,
#  Super Capers is directed by Ray Griggs.,
#  Ray Griggs is the director of Super Capers.,
#  The sludge metal and post metal album Nord was produced and created by the artist Year of No Light and was released by the record label Crucial blast on 06-09-2006.,
#  It was followed by the album Live at Roadburn 2008.The Year of No Light self produced album Nord, a sludge and post-metal genre was released on September 6, 2006.,
#  Its record label is Crucial Blast and was followed by Live at Roadburn 2008.The self-produced Year of No Light post metal and sludge metal album Nord was released on 2006-09-06 and was followed by the album Live at Roadburn 2008.,
#  Nord was released on the Crucial Blast record label.,
#  Train followed Mermaid with Imagine is a song by musical artist John Lennon, which has a FIMI certification.,
#  It was produced by the production team Espionage.,
#  Train released Mermaid, produced by the Espionage team, shortly before covering John Lennon's Imagine.,
#  Imagine by John Lennon earned the FIMI certification.,
#  The Train song Mermaid, produced by the Espionage production team, was followed by the band’s cover of the John Lennon song Imagine.,
#  Musician John Lennon wrote and also originally performed the song Imagine which is certified by FIMI.The,
#  Adolfo Suárez Madrid–Barajas Airport is located 610 metres above sea level.,
#  This airport is operated by ENAIRE and has a runway named 14L/32R, which has a length of 3500.Adolfo Suárez Madrid–Barajas Airport, operated by ENAIRE organisation, is elevated 610 metres above sea level and has the runway length of 3500.0.,
#  The Adolfo Suárez Madrid–Barajas Airport runway name is 14L/32R.Expect a Miracle's genre is easy listening.,
#  Expect a Miracle is an easy listening album.,
#  Expect a Miracle is of the easy listening genre.,
#  Liselotte Grschebina's nationality is Israeli where one of the ethnic groups is Arab.,
#  Liselotte Grschebina has the nationality of Israel where one of the ethnicities is Arab people.,
#  Israel has different ethnic groups like Arabs, and Israeli nationals such as Liselotte Grschebina.,
#  Squeeze was followed by the album 1969:,
#  The Velvet Underground Live.,
#  The Velvet Underground album Squeeze was followed by the live album 1969:,
#  The Velvet Underground Live.,
#  The Velvet Underground album Squeeze is followed by the album 1969:,
#  The Velvet Underground Live.,
#  Alan B. Miller Hall which is owned by the College of William and Mary was completed on 1st June 2009.Completed on June 1st, 2009, Alan B. Miller Hall is owned by the College of William and Mary.,
#  The Alan B. Miller Hall, which is owned by The College of William and Mary, was completed on 1st June 2009.The Bootleg Series Volume I: The Quine Tapes, a rock music genre,with runtime of 230:05 was produced and released by Velvet Underground.,
#  It was recorded in the United States.,
#  The Bootleg Series Volume I: The Quine Tapes, produced and created by The Velvet Underground with run time of 230.05 minutes was recorded in the United States.,
#  It belongs to rock genre.,
#  The album Bootleg Series Volume 1: The Quine Tapes by The Velvet Underground in the Rock music genre, was produced by The Velvet Underground and recorded in the United States.,
#  It lasts 230.05 minutes.,
#  Bionico (served at the dessert course) is a food found in Mexico.,
#  The currency in Mexico is the Mexican peso inhabited by the Mexicans.,
#  Honey can be added to bionico.,
#  Bionico is a dessert food that can be made with honey and is found in Mexico.,
#  Mexico is inhabited by Mexicans and their currency is the peso.,
#  Bionico (served at the dessert course) is a food found in Mexico.,
#  Honey can be used as a variation in the dish Bionico, the currency in Mexico is the peso inhabited by Mexicans.,
#  Gdynia, Poland follows the Central European Summer Time timezone.,
#  Gdynia, Poland is in the Central European Summer Time zone.,
#  The time zone for Gdynia, Poland is Central European summer time.,
#  Super Capers was distributed by the public company Lionsgate.,
#  It was also distributed by Roadside Attractions.,
#  Roadside Attractions distributed Super Capers which was also distributed by the public company Lionsgate.,
#  The movie Super Capers is distributed by Roadside Attractions and Lionsgate, a public company.,
#  In terms of nationality, Nurhan Atasoy is a Turkish person.,
#  Nurhan Atasoy is of Turkish nationality.,
#  Nurhan Atasoy's nationality is that of Turkish people.,
#  The 11th Mississippi Infantry Monument was established in 2000 and is categorized as a Contributing Property.,
#  The monument is situated in Adams County, Pennsylvania which has Frederick County, Maryland to its southwest.,
#  The 11th Mississippi Infantry Monument, which was built in the year 2000, falls under the category of contributing property.,
#  The monument is located in Adams County, Pennsylvania which has Frederick County, Maryland to the southwest.,
#  A monument to the 11th Mississippi Infantry was erected in Adams County, Pennsylvania in the year 2000.,
#  Frederick County, Maryland is southwest of Adams County Pennsylvania.,
#  The 11th Mississippi Infantry Monument is in the category of a contributing property.,
#  The train song Mermaid, released on Dec. 27th, 2012 and written by Amund Bjorklund and Espen Lind, was preceded by the song This'll Be My Year.,
#  Mermaid lasts 3.16 minutes.,
#  Train released their song Mermaid on December 27th, 2012.,
#  The song was written by Amund Bjorklund and Espen Lind, and runs three minutes and sixteen seconds long.,
#  Train's most recent song before Mermaid was This'll Be My Year.,
#  Mermaid by Train was written by Espen Lind and Amund Bjorklund.,
#  The song, which runs 3 minutes and 16 seconds long, was released on December 27th, 2012.,
#  Train's most recent song before Mermaid was This'll Be My Year.,
#  Graco Ramirez leads Ciudad Ayala in Morelos.,
#  Ciudad Ayala is part of Morelos and Graco Ramírez is a leader.,
#  Ciudad Ayala is a part of Morelos, which Graco Ramírez is a leading official of.,
#  Sour cream, chopped fruits, condensed milk, granola, raisins and shredded coconut are the main ingredients in Bionico which is a dessert served in Mexico where the local currency is the peso.,
#  Bionico is a dessert food found in Mexico.,
#  Chopped fruits, sour cream, condensed milk, granola, shredded coconut and raisins are the main ingredients in Bionico.,
#  The currency of Mexico is the Peso.,
#  Bionico is a dish served for dessert in Mexico where the currency is the peso.,
#  The main ingredients of Bionico are chopped fruits, sour cream, condensed milk, granola, shredded coconut and raisins.,
#  Brandon Carter is a professional in the field of general relativity.,
#  General Relativity is Brandon Carter's professional field.,
#  Brandon Carter is a physicist whose professional field was on General Relativity.,
#  The University of Burgundy is located in France, where one of the leaders is Claude Bartolone.,
#  The University of Burgundy is in France which is led by Claude Bartolone.,
#  Claude Bartolone is the leader of France, the location of the University of Burgundy.,
#  Nie Haisheng was born in Hubei.,
#  Nie Haisheng was born in Hubei Province.,
#  The birthplace of Nie Haisheng is Hubei.,
#  Olga Bondareva, born "Olga Nikolaevna Bondareva" and a student of Leningrad State University, was known for the Bondareva-Shapley theorem.,
#  Olga Bondareva is known for the Bondareva-Shapley theorem, described by Olga Nikolaevna Bondareva in Leningrad State University.,
#  Olga Bondareva, birth name Olga Nikolaevna Bondareva, graduated from Leningrad State University.,
#  She is known for the Bondareva-Shapley theorem.,
#  Darinka Dentcheva, a Humboldt University graduate, is a mathematician working in the field of mathematical optimization.,
#  Darinka Dentcheva is a professional in the field of mathematical optimization who went to Humboldt University.,
#  Humboldt University is the alma mater of Darinka Dentcheva, whose professional field is Mathematical optimization.,
#  "English,
#  Without Tears" was produced by Anatole de Grunwald.,
#  Anatole de Grunwald was the producer of 'English Without Tears'.,
#  Anatole de Grunwald is the producer of English Without Tears.,
#  Andrew Rayel's genre is trance music and it is associated with artists such as Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin, and Alexandra Badoi.,
#  Andrew Rayel, who is active in the trance musical genre, is associated with the following musical artists: Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin and Alexandra Badoi.,
#  Andrew Rayel is a Trance music performer associated with other artists like Armin Van Buuren, Bobina, Mark Sixma, Jonathan Mendelsohn, Christian Burns, Jwaydan, Alexander Popov, Jano, Alexandre Bergheau, Jonny Rose, Sylvia Tosun, Lira Yin and Alexandra Badoi.,
#  US born Aaron Turner plays electric guitar for the post metal band Twilight.,
#  American guitarist Aaron Turner is a post-metal musician who played electric guitar with the band Twilight.,
#  Aaron Turner (from United States) who is a performer of post metal plays the electric guitar in the band Twilight.,
#  BBC broadcast Bananaman, a show created by John Geering and starring Bill Oddie.,
#  Broadcasting House is a location owned by the BBC, the channel that broadcasts this show which first aired on 10/03/83.The show Bananaman, starring Bill Oddie, was first broadcast on 10/03/83 by the BBC, whose headquarters are Broadcasting House.,
#  The character Bananaman was created by John Geering.,
#  Created by John Geering and first broadcast in 1983, Bananaman starred the actor Bill Oddie.,
#  It was broadcast by the London based Broadcasting House, known as the BBC.Construction on Alan B Miller Hall began on March 30th, 2007.,
#  The building was designed by Robert A. M. Stern.,
#  Alan B Miller Hall is located on 101 Ukrop Way in Williamsburg, Virginia, United States.,
#  The current tenant is the Mason School of Business.,
#  The construction of Alan B. Miller Hall began on March 30th, 2007.,
#  Robert A. M. Stern designed the building.,
#  Alan B. Miller Hall is located at 101 Ukrop Way, Williamsburg, Virginia, United States and the current tenant is the Mason School of Business/.The Alan B. Miller Hall, which is located at 101 Ukrop Way in Williamsburg, Virginia, USA, was designed by Robert A.M. Stern and began construction on the 30th of March 2007.,
#  The Mason School of Business are the current residents of the Hall.,
#  The Native name of the Baku Turkish Martyrs' Memorial is "Türk Sehitleri Aniti" which is located in Azerbaijan.,
#  The native name of the Baku Turkish Martyrs' Memorial is Turk Sehitleri Aniti located in Azerbaijan.,
#  The native name for the Baku Turkish Martyrs' Memorial is Turk Sehitleri Aniti, which is located in Baku, Azerbaijan.,
#  Sludge metal has a variety called southern sludge.,
#  Southern sludge is a subgenre of sludge metal.,
#  Southern sludge is a musical subgenre of sludge metal.,
#  Olga Bondareva (born Olga Nikolaevna Bondareva, on April 27, 1937, in Leningrad, USSR) graduated from Leningrad State University and is known for Bondareva-Shapley theorem.,
#  Olga Bondareva, born in Leningrad, USSR on the date April 27, 1937 as "Olga Nikolaevna Bondareva", is alumni of Leningrad State University and known for the Bondareva-Shapley theorem.,
#  Olga Bondareva with birth name "Olga Nikolaevna Bondareva" was born in Leningrad, USSR on April 27, 1937.,
#  A Leningrad State University graduate, she is known for Bondareva-Shapley theorem.,
#  John Mills had a main role in the movie It's Great to Be Young which has taken 282,838 pounds at the box office.,
#  It's Great to Be Young is a 1956 film which received £282,838 and featured John Mills in the lead role.,
#  It's Great to Be Young is a 1956 film starring John Mills,and it cost £282,838.Located in Adams Country, Pennsylvania in the United States, the monument to the 11th Mississippi Infantry was erected in 2000.,
#  It is described as a contributing property.,
#  Cumberland County is to the north of Adams County.,
#  The 11th Mississippi Infantry Monument's located in the United States near Adams County, Pennsylvania.,
#  It falls under the category of Contributing property and was established in the year 2000.,
#  Adams County, Pennsylvania has Cumberland County, Pennsylvania to its north.,
#  The 11th Mississippi Infantry Monument was established in 2000 and is categorized as a Contributing Property.,
#  The monument is located in Adams County, Pennsylvania, USA and has Cumberland county, Pennsylvania to the north.,
#  Bananaman had as one of its stars Bill Oddie and was last aired on the 15/04/1986 on the BBC who are based at their headquarters, Broadcasting House in London.,
#  Bill Oddie starred in Bananaman which last aired on April 15th, 1986.,
#  The show was broadcast by the BBC which is based at Broadcasting House in London.,
#  The BBC, based at their home in Broadcasting House in London, broadcast Bananaman which last aired on 15/04/1986.,
#  Bill Oddie was a star of the show.,
#  Terence Rattigan, who died in 1977, wrote the film English Without Tears in co-authorship with Anatole de Grunwald.,
#  The film was directed by Harold French, an actor whose career began in 1920.The movie English Without Tears was written by Anatole de Grunwald and Terence Rattigan, who died in 1977, and directed by Harold French, who has been acting since 1920.English Without Tears is a movie directed by Harold French who became an active actor in 1920.,
#  The movie was written by Anatole de Grunwald and Terence Rattigan.,
#  Rattigan passed away in 1977.The BBC broadcasted Bananaman, which was created by Steve Bright.,
#  Steve Bright is the creator of Bananaman which is broadcast by the BBC.Bananaman, the TV series created by Steve Bright, was shown on the BBC.The leader of Gdynia, Poland is called the Mayor.,
#  Gdynia is the city in Poland under the leadership of Mayor.,
#  One of the leaders of Gdynia, Poland is the Mayor.,
#  The zip code areas in Darlington are DL1, DL2, DL3.The postal codes within Darlington are DL1, DL2, and DL3.Darlington's postal codes are as followed: DL1, DL2, and DL3.Hypermarcas is a drug maker in the pharmaceutical industry.,
#  They were founded in Brazil on January 1, 2001, and employ 10252 people.,
#  They are an S.A. corporation, and are managed by a CEO.Hypermarcas was founded in 2001-01-01, it is a type of S.A corporation which has 10252 employees.,
#  It is a pharmaceutical company located in Brazil that make drugs.,
#  It is managed by a CEO.Hypermarcas is a pharmaceutical drug company located in Brazil.,
#  They were founded on January 1, 2001, and employ 10,252 people.,
#  They are an S.A. corporation, headed up by their CEO.Aleksandr Prudnikov was born on 1989-02-24 and played for FC Spartak Moscow's youth team.,
#  Its team grounds are the Otkrytiye Arena.,
#  Aleksandr Prudnikov was born on February 24, 1989 and is a member of the youth side of FC Spartak Moscow which plays out of Otkrytiye Arena.,
#  Aleksandr Prudnikov who was born on 24th February 1989, played youth football for FC Spartak Moscow who play at the Otkrytiye Arena.,
#  Nie Haisheng from the People's Republic of China was born in Hubei October 13, 1964.Nie,
#  Haisheng was born on the 13th of October, 1964 in Hubei in the People's Republic of China.,
#  Nie Haisheng, born in Hubei Province on 10/13/1964, is a citizen of the People's Republic of China.,
#  Turk is the demonym for residents of Turkey.,
#  An inhabitant of Turkey is called a Turk.,
#  The demonym for people who live in Turkey is "Turk".,
#  Super Capers, a film written by Ray Griggs, is 98 minutes long.,
#  Danielle Harris was one of the stars of the movie.,
#  The film Super Capers is written by Ray Griggs and stars Danielle Harris.,
#  The film's running time is 98 minutes.,
#  The 98.0 minute film,Super Capers starring Danielle Harris was written by the director Ray Griggs.,
#  The film "English Without Tears" was written by Terence Rattigan, who died on 30/11/1977.,
#  The film's director, Harold French, was born in 1897.Harold French who was born in 1897 directed the film, English Without tears.,
#  Terence Rattigan wrote the movie and died on November 30th, 1977.English Without Tears was directed by Harold French who was born in 1897.,
#  It was written by Terence Rattigan who died on November 30th, 1977.John Mills starred in the 1956 film It’s Great to Be Young which featured cinematography by Gilbert Taylor.,
#  John Mills played the leading role in the 1956 movie It's Great to be Young which had Gilbert Taylor as cinematographer.,
#  John Mills had a main role in the movie It's Great to Be Young, which had its cinematography done by Gilbert Taylor.,
#  Olga Bondareva, who lived from April 27th, 1937 to December 9th, 1991, was a student at Leningrad State University.,
#  Olga Bondareva (born on April 27, 1937) graduated from Leningrad State University, and died on the ninth of December 1991.Olga,
# ...
#  The team’s home ground, Estádio Municipal Coaracy da Mata Fonseca, is in Arapiraca.,
#  The Alan B Miller Hall, which is built in a Georgian style, is located in Virginia and is owned by The College of William and Mary.,
#  The building is currently occupied by The Mason School of Business and can be found at 101 Ukrop Way.,
#  It was designed by Robert A.M. Stern and began construction on the 30th of March 2007.The address of the Robert A M Stern designed building, the Alan B. Miller Hall, is 101 Ukrop Way in Virginia.,
#  They started to build the Georgian style hall on 30/03/2007 and it is now owned by The College of William and Mary with the current tenants being The Mason School of Business.,
#  The Alan B. Miller Hall at 101 Ukrop Way, Virginia, was designed in the Georgian style by Robert A.M. Stern.,
#  The College of William and Mary is the owner of the building which started construction on 30/03/2007.,
#  It currently houses The Mason School of Business.1147 Stavropolis is an asteroid that was discovered by Grigory Neujmin.,
#  It has a rotational period of 20378.5 and an orbital period of 1249.6 days.,
#  1147,
#  Stavropolis epoch is July 31, 2016, the apoapsis is 418476000000.0 and the periapsis is 260855000000.0.The asteroid 1147 Stavropolis, first discovered by Grigory Neujmin, has an orbital period and rotation period of 1249.6 days and 20378.5, respectively.,
#  It has an apoapsis of 418476000000.0 and a periapsis of 260855000000, reckoned by the epoch 31 July 2016 (Julian Day 2457600.5).1147 Stavropolis discovered by Grigory Neujmin with epoch of 31 July 2016 (JD2457600.5) has periapsis and apoapsis of 260855000000.0 and 418476000000.0 AU respectively.,
#  With rotation period of 20378.5 the orbital period of 1147 Stavropolis is 1249.6.While pop rock can trace its stylistic roots back to rock music, Reggae music evolved out of different musical genre, known as ska.,
#  Interestingly, the Train song, Mermaid, belongs to the genre of pop rock, but is also considered to be of the reggae genre as well.,
#  Mermaid is a pop rock song by the band Train, the origins of pop rock is in rock music but the song is also in the reggae genre whose origin is ska.,
#  The Train song by Mermaid is from the pop rock and reggae music genre.,
#  Stylistic origins of reggae and pop rock are Ska and rock music respectively.,
#  Darinka Dentcheva is a resident of New Jersey, a state in the United States, which uses federalism as its type of governing system.,
#  Darinka Dentcheva resides in New Jersey, a small state in the federalist country of the United States.,
#  Darinka Dentcheva lives in New Jersey which is located in the United States and has a federalist type of government.,
#  Liselotte Grschebina died in Petah Tikva, which is led by Itzik Braverman.,
#  Liselotte Grschebina died in Petah Tikva, where one of the leaders was called Itzik Braverman.,
#  One of the leaders of Petah Tikva, where Liselotte Grschebina died, is Itzik Braverman.,
#  Darinka Dentcheva, a United States citizen, developed a theory in Mathematical Optimization, influenced by Andrzej Piotr Ruszczyński .,
#  "In God We Trust" is the motto of the United States.,
#  The United States's motto is "In God We Trust.",
#  Darinka Dentcheva, a United States citizen, was influenced by Andrzej Piotr Ruszczynski, who is a professional in the field of mathematical optimization.,
#  Darinka Dentcheva was influenced by Andrzej Piotr Ruszczynski, who works in the field of mathematical optimization.,
#  Darinka is a citizen of the United States, whose motto is “In God we Trust.”.,
#  Ciudad Ayala city has a population density of 1604.0 and its population in metropolitan area is 1,777,539.,
#  The city has an elevation of 1147.0 above sea level and uses the UTC offset -6 time zone.,
#  Ciudad Ayala uses a type of government called council-manager government and one of the leaders is called City Manager.,
#  Ciudad Ayala is a city; its government type is council manager and the leader title is city manager.,
#  The population in the Ciudad Ayala metropolitan area is 1777539, and the population density is 1604.,
#  It is 1147m above sea level and has a UTC offset of -6.Ciudad Ayala is a city.,
#  The population of its metropolitan area is 1,777,539 and the density is 1604.0.,
#  The government type is council-manager government and one of the leaders is the city manager.,
#  The UTC offset of the city is -6,
#  and the elevation above the sea level is 1147.0.Adolfo Suárez Madrid–Barajas Airport is in Alcobendas and is operated by ENAIRE in which is in Madrid.,
#  The runway length of Adolfo Suárez Madrid–Barajas Airport is 4,349 and is named 14R/32L, Adolfo Suárez Madrid-Barajas Airport also has an elevation of 610.0 metres above sea level and a runway length of 4,349.Adolfo Suárez Madrid–Barajas Airport in Alcobendas (operated by ENAIRE in Madrid), located 610 metres above sea level has a runway called 14R/32L that is 4,349 metres long.,
#  Adolfo Suárez Madrid–Barajas Airport is located in Alcobendas, 610 meters above sea level.,
#  This airport is operated by ENAIRE, which is located in Madrid.,
#  The runway is named 14R/32L and has a length of 4,349 meters.,
#  Aleksandr Prudnikov plays for FC Amkar Perm, which is managed by Gadzhi Gadzhiyev.,
#  Prudnikov also played for FC Spartak Moscow's youth team.,
#  He is 185 cm.,
#  tall.,
#  Aleksandr Prudnikov, who is 185 cm, plays for FC Amkar Perm, which is managed by Gadzhi Gadzhiyev.,
#  Aleksandr Prudnikov is also a member of the youth side of FC Spartak Moscow.,
#  The Adolfo Suárez Madrid–Barajas Airport in Alcobendas , Madrid, Spain operated by ENAIRE has a runway called 14R/32L with the length of 4,349.Adolfo Suárez Madrid–Barajas Airport is located in Alcobendas.,
#  This airport is operated by ENAIRE, which is located in Madrid, Spain.,
#  The runway is named 14R/32L and has a length of 4,349 meters.,
#  Adolfo Suarez Madrid-Barajas Airport is operated by ENAIRE which is located in Alcobendas in Madrid,Spain.,
#  The runway length and the name of the runway of the airport is 4349.0.,
#  and 14R/32L.The drum kit is an instrument used in the punk blues genre.,
#  The drum kit is an instrument of punk blues.,
#  Punk blues usually uses a drum kit.,
#  Liselotte Grschebina was born in Karlsruhe and died in Israel on June 14th, 1994.Liselotte Grschebina was born in Karlsruhe and died on June 14th, 1994 in Israel.,
#  One of the official languages of Israel Is Modern Standard Arabic.,
#  The official language of Israel is Modern Standard Arabic.,
#  Liselotte Grschebina was born in Karlsruhe which is known for having Oberbürgermeister as a leader.,
#  Liselotte Grschebina was born in Karlsruhe, which has Oberbürgermeister as its leader.,
#  Karlsruhe, the birthplace of Liselotte Grschebina, has a leader named Oberburgermeister.,
#  The Acharya Institute of Technology is affiliated to Visvesvaraya Technological University, and offers Tennis as a sport.,
#  The All India Council for Technical Education which is located in Mumbai gave the institute Technical Campus status.,
#  The address for the campus is: Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090.Tennis is one of the sports offered at the Acharya Institute of Technology which is affiliated to Visvesvaraya Technological University.,
#  The All India Council for Technical Education which is located in Mumbai gave the institute Technical Campus status.,
#  The address for the campus is: Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore - 560090.Acharya Institute of Technology was given the 'Technical Campus' status by All India Council for Technical Education, has tennis as one of their sports offered and is affiliated with the Visvesvaraya Technological University.,
#  All India Council for Technical Education is located in Mumbai and the campus of the Acharya Institute of Technology is located at Soldevanahalli, Acharya Dr. Sarvapalli Radhakrishnan Road, Hessarghatta Main Road, Bangalore – 560090.Tom Sizemore stars in Super Capers which starred Michael Rooker.,
#  The film Super Capers stars both Michael Rooker and Tom Sizemore.,
#  Tom Sizemore stars in Super Capers, a film in which Michael Rooker also plays in.,
#  Super Capers starred Michael Rooker, who was born in Jasper, Alabama.,
#  Super Capers is a film starring Michael Rooker, who was born in Jasper, Alabama.,
#  Michael Rooker, who played in Super Capers, was born in Jasper, Alabama.,
#  Grigory Neujmin discovered 1147 Stavropolis on June 11th, 1929.,
#  It has an apoapsis of 418476000000.0 and an absolute magnitude of 11.5.On June 11, 1929, Grigory Neujmin discovered the asteroid 1147 Stavropolis.,
#  It has an apoapsis of 418476000000.0 and an absolute magnitude of 11.5.Grigory Neujmin discovered the asteroid 1147 Stavropolis on June 11, 1929.,
#  It has an absolute magnitude of 11.5 with 418476000000.0 AU.After releasing their album Squeeze, music group the Velvet Underground produced and released rock music album Bootleg Series Volume 1: The Quine Tapes, which they recorded in St Louis Missouri, USA,
#  The album was released on 2001-10-16 under the Polydor and Universal Music Group record labels and has a total run time of 230:05 minutes.,
#  Bootleg Series Volume 1: The Quine Tapes with run time of 230:05 was recorded under the Polydor Records and Universal Music Group record label in St. Louis, Missouri, United States and released on October, 16, 2001.,
#  It was preceded by Squeeze by The Velvet Underground.,
#  The Bootleg Series Volume I: The Quine Tapes with runtime of 230.05 minutes was recorded in St. Louis Missouri,United States and released on 10-16-2001.,
#  Recorded through Polydor Records and Universal Music Group record label the album was preceded by the album Squeeze.1147 Stavropolis discovered on June 11, 1929 with rotation period of 20378.5 has a periapsis of 260855000000.0 and apoapsis of 418476000000.0.,
#  The orbital period of the asteroid is 1249.6 days.1147 Stavropolis is an asteroid, discovered on June 1929.,
#  It has a rotation period of 20378.5.,
#  Its periapsis is 260855000000.0, the apoapsis of the asteroid is 418476000000 AU and the orbital period is 1249.6.The asteroid 1147 Stavropolis discovered on the 11th of June 1929 with a rotation period of 20378.5 has a periapsis of 260855000000 and apoapsis of 418476000000.0.,
#  The orbital period of this asteroid is 1249.6 days.,
#  John Mills died in 2005.Nurhan Atasoy who was born in Reşadiye , has his residence in Istanbul.,
#  Istanbul metro area is 5,343 square kilometers and its time zone is Eastern European Summer Time.,
#  Nurhan Atasoy whose birth place is Resadiye, also had his residence in Istanbul with a metropolitan area of 5,343 km².,
#  Istanbul is in the Eastern European Summer time zone.,
#  Nurhan Atasoy was born in Reşadiye and now lives in Istanbul.,
#  Istanbul has a metropolitan area of 5343000000.0 and uses the Eastern European Summer Time time zone.,
#  The Year of No Light's sludge metal album Nord (2006-09-06) was followed by Live at Roadburn 2008.The release date of Nord, Year of No Light Album in the sludge metal genre, is 06-09-2006 with their album Live at Roadburn 2008.The Year of No Light album Nord in the sludge metal genre, released on September 6, 2006 was followed by Year of No Light's album Live at Roadburn 2008.Nurhan Atasoy was born in Turkey.,
#  Binali Yıldırım was former Prime Minister of Turkey under current president Recep Tayyip Erdoğan.,
#  Turkey, led by Recep Tayyip Erdoğan and Binali Yildirim, is where Nurhan Atasoy was born .Nurhan,
#  Atasoy was born in Turkey where the current leaders include Recep Tayyip Erdoğan and Binali Yildirim.,
#  Turn Me On by Honeymoon Killers, a noise rock and punk blues genre, has a runtime of 35.1 minutes.,
#  Its producers are Honeymoon Killers themselves and Wharton Tiers.,
#  In the genre of punk blues, the Honeymoon Killers' "Turn Me On" is a 35 minutes 10 seconds example of noise rock produced by Wharton Tiers for this American band.,
#  The band also participated in the production.,
#  The American noise rock band the Honeymoon Killers, self-produced their punk blues album Turn Me On.,
#  Wharton Tiers was the producer and the album runs for 35.1 minutes.,
#  Baroque pop is a fusion genre which includes some elements of pop rock, an example of which is the Train song by Mermaid .Mermaid, released by the band train, is a song in the pop rock genre which also includes the fusion genre Baroque pop.,
#  Mermaid, a song by the band Train, belongs to the genre of pop rock.,
#  An offshoot of pop rock is the fusion genre Baroque pop.,
#  The parent company of Polydor Records is Universal Music Group.,
#  Universal Music Group is the parent company of Polydor Records.,
#  Polydor Records' parent company is Universal Music Group.,
#  Liselotte Grschebina was a photographer who was born in the German Empire.,
#  Liselotte Grschebina was a professional photographer who was born in the German Empire.,
#  Liselotte Grschebina was a professional photographer that was born in the German Empire.,
#  The Pontiac Rageous, a coupe assembled in Michigan, was first and last produced in 1997.,
#  It had its assembly line in Detroit.,
#  The Pontiac Rageous, a car with a coupe body style, assembled in Detroit Michigan, was first and last produced in 1997.In 1997, the Pontiac Rageous coupe (assembled in Detroit, Michigan) went into and ended production.,
#  GMA,
#  New Media is a company in the mass media industry whose headquarters are located in the GMA Network Center.,
#  Inside GMA Network Center lies the mass media industry GMA New Media.,
#  GMA,
#  New Media is a mass media company in the GMA Network Center.,
#  Alan Shepard was born on Nov 18, 1923 in New Hampshire, went to school at NWC and graduated with an MA in 1957 and was a member of the Apollo 14 crew.,
#  Alan Shepard was born on November 18, 1923 in New Hampshire.,
#  Shepard graduated from NWC in 1957 with an M.A. and served as a crew member of Apollo 14.Alan,
#  Shepard was born in New Hampshire on November 18th, 1923.,
#  He graduated from NWC with an M.A. in 1957 and went on to be a crew member of Apollo 14.It's great to be young is a movie from 1956 that runs for 94 minutes.,
#  It stars Cecil Parker and it’s edited by Max Benedict.,
#  Louis Levy composed the music.,
#  The 1956 film "It's Great to Be Young" stars Cecil Parker.,
#  The movie is 94 minutes and was edited by Max Benedict.,
#  Louis Levy composed the music for the film.,
#  It's Great to be Young is a 94 minute movie released in 1956.,
#  It starred Cecil Parker and was edited by Max Benedict.,
#  Louis Levy was the musical composer.,
#  Israeli national Liselotte Grschebina was born in Karlsruhe on May 2, 1908, and died on June 14, 1994.Israeli Liselotte Grschebina was born in Karlsruhe on May 2, 1908 and died on June 14, 1994.Liselotte Grschebina was as Israeli national born in Karlsruhe on May 2, 1908 and died on June 14, 1994.The construction of Alan B. Miller Hall lasted from March 30th, 2007 to June 1st, 2009.,
#  Robert A. M. Stern is the architect of the building.,
#  Alan B. Miller Hall is located at 101 Ukrop Way, Virginia, and the current tenant is the Mason School of Business.,
#  Robert A M Stern is the architect responsible for designing the Alan B. Miller Hall at 101 Ukrop Way in Virginia.,
#  Construction started on the building on the 30th of March, 2007 and was completed on the 1st of June, 2009.,
#  The Mason School of Business are the current occupants of the hall.,
#  Stargate produced the song Mermaid.,
#  The Train song Mermaid was written by the production team Stargate.,
#  A person named Jamie Lawrence is a member of the Brentford F.C. while someone with the same name was the composer for "Death on a Factory Farm" music.,
#  Jamie Lawrence, who played for Brentford F.C., wrote the music for the film 'Death on a Factory Farm'.,
#  Jamie Lawrence, who composed Death on a Factory Farm also played in the club Brentford F.C."Let,
#  ...]

# %% [markdown]
# ## Tokenization
#
# **Exercise 4:** Finding the tokens
# - Define a function which takes as input a file processed by SpaCy and outputs the sequence of tokens identified by spaCy.
# - Print out the result
# - Store the result in a variable called "tokens"

# %%
def SpacyTokSeq(sp_text):
    return [tok for tok in sp_text]

# %%
sp_tokenl = [SpacyTokSeq(s) for s in sp_sent_list]

# %%
sum(map(len, sp_tokenl))
# Out:
# 128191

# %%
sp_tokenl
# Out:
# [[Estádio,
#   Municipal,
#   Coaracy,
#   da,
#   Mata,
#   Fonseca,
#   is,
#   the,
#   name,
#   of,
#   the,
#   ground,
#   of,
#   Agremiação,
#   Sportiva,
#   Arapiraquense,
#   in,
#   Arapiraca,
#   .],
#  [Agremiação,
#   Sportiva,
#   Arapiraquense,
#   ,,
#   nicknamed,
#   ",
#   Alvinegro,
#   ",
#   ,,
#   lay,
#   in,
#   the,
#   Campeonato,
#   Brasileiro,
#   Série,
#   C,
#   league,
#   from,
#   Brazil,
#   .],
#  [Estádio,
#   Municipal,
#   Coaracy,
#   da,
#   Mata,
#   Fonseca,
#   is,
#   the,
#   name,
#   of,
#   the,
#   ground,
#   of,
#   Agremiação,
#   Sportiva,
#   Arapiraquense,
#   in,
#   Arapiraca,
#   .],
#  [Alvinegro,
#   ,,
#   the,
#   nickname,
#   of,
#   Agremiação,
#   Sportiva,
#   Arapiraquense,
#   ,,
#   play,
#   in,
#   the,
#   Campeonato,
#   Brasileiro,
#   Série,
#   C,
#   league,
#   from,
#   Brazil,
#   .],
#  [Nie,
#   Haisheng,
#   ,,
#   born,
#   on,
#   October,
#   13,
#   ,,
#   1964,
#   ,,
#   worked,
#   as,
#   a,
#   fighter,
#   pilot,
#   .],
#  [Nie,
#   Haisheng,
#   is,
#   a,
#   former,
#   fighter,
#   pilot,
#   who,
#   was,
#   born,
#   on,
#   October,
#   13,
#   ,,
#   1964.Nie],
#  [Haisheng, born, on, 10/13/1964, is, a, fighter, pilot, .],
#  [MotorSport, Vision, is, located, in, the, city, of, Fawkham, .],
#  [MotorSport,
#   Vision,
#   is,
#   located,
#   in,
#   the,
#   city,
#   of,
#   Fawkham,
#   ,,
#   UK.MotorSport,
#   Vision,
#   is,
#   located,
#   in,
#   Fawkham.185,
#   centimetre,
#   tall,
#   Aleksandr,
#   Prudnikov,
#   played,
#   for,
#   the,
#   Otkrytiye,
#   Arena,
#   based,
#   FC,
#   Spartak,
#   ,,
#   Moscow,
#   .],
#  [The,
#   185,
#   cm,
#   tall,
#   Aleksandr,
#   Prudnikov,
#   plays,
#   for,
#   FC,
#   Spartak,
#   Moscow,
#   who,
#   call,
#   their,
#   home,
#   ground,
#   Otkrytiye,
#   Arena,
#   .],
#  [Aleksandr,
#   Prudnikov,
#   who,
#   is,
#   185,
#   cm,
#   tall,
#   ,,
#   plays,
#   for,
#   FC,
#   Spartak,
#   Moscow,
#   whose,
#   ground,
#   is,
#   the,
#   Otkrytiye,
#   Arena,
#   .],
#  [Ciudad,
#   Ayala,
#   is,
#   a,
#   city,
#   with,
#   population,
#   density,
#   and,
#   population,
#   of,
#   1604,
#   and,
#   1777539,
#   respectively,
#   ,,
#   where,
#   the,
#   leader,
#   is,
#   called,
#   the,
#   City,
#   Manager,
#   .],
#  [The,
#   government,
#   type,
#   in,
#   the,
#   city,
#   of,
#   Ciudad,
#   Ayala,
#   is,
#   council,
#   -,
#   manager,
#   .],
#  [The,
#   city,
#   of,
#   Ciudad,
#   Ayala,
#   ,,
#   with,
#   a,
#   population,
#   of,
#   1,777,539,
#   ,,
#   is,
#   led,
#   by,
#   a,
#   City,
#   Manager,
#   on,
#   a,
#   council,
#   -,
#   manager,
#   government,
#   system,
#   .],
#  [It,
#   has,
#   a,
#   population,
#   density,
#   of,
#   1604.Ciudad,
#   Ayala,
#   ,,
#   a,
#   city,
#   with,
#   population,
#   density,
#   and,
#   population,
#   of,
#   1604.0,
#   and,
#   1,777,539,
#   respectively,
#   ,,
#   uses,
#   a,
#   type,
#   of,
#   government,
#   called,
#   council,
#   -,
#   manager,
#   government,
#   .],
#  [One, of, the, leaders, of, Ciudad, Ayala, is, the, City, Manager, .],
#  [The,
#   album,
#   1969,
#   :,
#   The,
#   Velvet,
#   Underground,
#   Live,
#   is,
#   preceded,
#   by,
#   the,
#   Velvet,
#   Underground,
#   album,
#   Squeeze,
#   ,,
#   which,
#   was,
#   followed,
#   by,
#   The,
#   Quine,
#   Tapes,
#   .],
#  [The,
#   Velvet,
#   Underground,
#   album,
#   Bootleg,
#   Series,
#   Volume,
#   1,
#   :,
#   The,
#   Quine,
#   Tapes,
#   was,
#   preceded,
#   by,
#   the,
#   album,
#   Squeeze,
#   ,,
#   which,
#   was,
#   followed,
#   by,
#   the,
#   live,
#   album,
#   1969,
#   :,
#   The,
#   Velvet,
#   Underground,
#   Live,
#   .],
#  [The,
#   Bootleg,
#   Series,
#   Volume,
#   I,
#   :,
#   The,
#   Quine,
#   Tapes,
#   is,
#   preceded,
#   by,
#   the,
#   Velvet,
#   Underground,
#   album,
#   Squeeze,
#   which,
#   was,
#   itself,
#   followed,
#   by,
#   the,
#   album,
#   1969,
#   :],
#  [The, Velvet, Underground, Live, .],
#  [Ciudad,
#   Ayala,
#   in,
#   Mexico,
#   with,
#   population,
#   density,
#   of,
#   1604.0,
#   and,
#   elevated,
#   1147.0,
#   above,
#   sea,
#   level,
#   is,
#   in,
#   the,
#   PDT,
#   time,
#   zone,
#   .],
#  [The, leader, here, is, called, the, governator, .],
#  [Ciudad,
#   Ayala,
#   is,
#   a,
#   country,
#   in,
#   Mexico,
#   that,
#   is,
#   located,
#   1147,
#   above,
#   sea,
#   level,
#   and,
#   is,
#   in,
#   the,
#   Pacific,
#   Daylight,
#   time,
#   zone,
#   .],
#  [The,
#   population,
#   density,
#   is,
#   1604,
#   and,
#   the,
#   leader,
#   of,
#   Ciudad,
#   Ayala,
#   is,
#   called,
#   the,
#   governator,
#   .],
#  [Ciudad,
#   Ayala,
#   is,
#   located,
#   in,
#   Mexico,
#   and,
#   has,
#   a,
#   population,
#   density,
#   of,
#   1604,
#   .],
#  [The, city, stands, 1147, m, above, sea, level, .],
#  [The,
#   Governator,
#   is,
#   the,
#   leader,
#   of,
#   Ciudad,
#   Ayala,
#   located,
#   in,
#   the,
#   Pacific,
#   Daylight,
#   time,
#   zone,
#   .],
#  [Olga,
#   Bondareva,
#   died,
#   on,
#   December,
#   9,
#   ,,
#   1991.Olga,
#   Bondareva,
#   died,
#   on,
#   the,
#   9th,
#   of,
#   December,
#   ,,
#   1991.The,
#   date,
#   of,
#   Olga,
#   Bondareva,
#   's,
#   death,
#   was,
#   the,
#   ninth,
#   of,
#   December,
#   1991.Saint,
#   Petersburg,
#   was,
#   founded,
#   on,
#   May,
#   27,
#   ,,
#   1703,
#   and,
#   has,
#   a,
#   total,
#   area,
#   of,
#   1439.0,
#   ,,
#   Olga,
#   Bondareva,
#   passed,
#   away,
#   at,
#   Saint,
#   Petersburg,
#   .],
#  [Saint,
#   Petersburg,
#   ,,
#   where,
#   Olga,
#   Bondareva,
#   died,
#   ,,
#   was,
#   founded,
#   on,
#   the,
#   27th,
#   of,
#   May,
#   ,,
#   1703,
#   and,
#   has,
#   a,
#   total,
#   area,
#   of,
#   approximately,
#   1439,
#   km2.Saint,
#   Petersburg,
#   ,,
#   where,
#   Olga,
#   Bondareva,
#   died,
#   ,,
#   was,
#   founded,
#   on,
#   May,
#   27,
#   ,,
#   1703,
#   and,
#   consists,
#   of,
#   a,
#   total,
#   area,
#   of,
#   1439.0,
#   sq,
#   /,
#   km,
#   .],
#  [The,
#   population,
#   density,
#   of,
#   Ciudad,
#   Ayala,
#   is,
#   1604.0.Ciudad,
#   Ayala,
#   city,
#   has,
#   a,
#   population,
#   density,
#   of,
#   1604.0.The,
#   population,
#   density,
#   in,
#   Ciudad,
#   Ayala,
#   is,
#   1604.Piotr,
#   Hallmann,
#   was,
#   born,
#   on,
#   August,
#   25,
#   ,,
#   1987.Piotr,
#   Hallmann,
#   's,
#   birthday,
#   is,
#   August,
#   25th],
#  [1987.Piotr, Hallmann, was, born, on, the, 25th, of, August, 1987.The],
#  [Darlington,
#   town,
#   has,
#   an,
#   area,
#   code,
#   of,
#   01325.The,
#   telephone,
#   area,
#   code,
#   for,
#   Darlington,
#   is,
#   01325.The,
#   area,
#   code,
#   in,
#   Darlington,
#   is,
#   01325.Pennsylvania,
#   's,
#   Franklin,
#   County,
#   is,
#   found,
#   to,
#   the,
#   west,
#   of,
#   Adams,
#   County,
#   ,,
#   Pennsylvania,
#   and,
#   Pennsylvania,
#   's,
#   Cumberland,
#   County,
#   is,
#   to,
#   the,
#   north,
#   .],
#  [A,
#   monument,
#   to,
#   the,
#   11th,
#   Mississippi,
#   Infantry,
#   was,
#   erected,
#   in,
#   Adams,
#   County,
#   in,
#   the,
#   year,
#   2000,
#   in,
#   the,
#   municipality,
#   of,
#   Gettysburg,
#   and,
#   this,
#   monument,
#   is,
#   categorised,
#   as,
#   a,
#   contributing,
#   property,
#   .],
#  [The,
#   11th,
#   Mississippi,
#   Infantry,
#   Monument,
#   ,,
#   a,
#   Contributing,
#   property,
#   established,
#   in,
#   the,
#   year,
#   2000,
#   in,
#   Adams,
#   County,
#   ,,
#   Pennsylvania,
#   falls,
#   in,
#   the,
#   municipality,
#   of,
#   Gettysburg,
#   ,,
#   Pennsylvania,
#   .],
#  [Adams,
#   County,
#   Pennsylvania,
#   is,
#   East,
#   of,
#   Franklin,
#   County,
#   ,,
#   Pennsylvania,
#   and,
#   has,
#   Cumberland,
#   County,
#   ,,
#   Pennsylvania,
#   to,
#   its,
#   north,
#   .],
#  [The, official, language, of, Israel, is, modern, Hebrew, .],
#  [Israel, ’s, official, language, is, Modern, Hebrew, .],
#  [Modern, Hebrew, is, the, official, language, of, Israel, .],
#  [ENAIRE,
#   is,
#   the,
#   operating,
#   organisation,
#   for,
#   Adolfo,
#   Suarez,
#   Madrid,
#   -,
#   Barajas,
#   airport,
#   .],
#  [This,
#   airport,
#   is,
#   situated,
#   610,
#   meters,
#   above,
#   sea,
#   level,
#   in,
#   Alcobendas,
#   .],
#  [GMA,
#   New,
#   Media,
#   ,,
#   a,
#   company,
#   founded,
#   on,
#   01,
#   -,
#   01,
#   -,
#   2000,
#   are,
#   manufacturers,
#   of,
#   mobile,
#   applications,
#   .],
#  [GMA,
#   New,
#   Media,
#   ,,
#   which,
#   was,
#   founded,
#   on,
#   January,
#   1,
#   ,,
#   2000,
#   ,,
#   is,
#   a,
#   company,
#   that,
#   offers,
#   products,
#   such,
#   as,
#   mobile,
#   applications,
#   .],
#  [GMA,
#   New,
#   Media,
#   makes,
#   mobile,
#   apps,
#   and,
#   was,
#   founded,
#   on,
#   01/01/2000.Hypermarcas,
#   is,
#   a,
#   pharmaceutical,
#   company,
#   located,
#   in,
#   Sao,
#   Paulo,
#   ,,
#   Brazil,
#   .],
#  [Brazil, is, 8514837.14, square, kilometers, in, size, .],
#  [Hypermarcas,
#   ,,
#   a,
#   pharmaceutical,
#   company,
#   ,,
#   is,
#   located,
#   in,
#   Sao,
#   Paulo,
#   within,
#   the,
#   8514837.14,
#   square,
#   kilometres,
#   that,
#   make,
#   up,
#   the,
#   country,
#   of,
#   Brazil,
#   .],
#  [Hypermarcas,
#   ,,
#   a,
#   company,
#   in,
#   the,
#   pharmaceuticals,
#   industry,
#   ,,
#   is,
#   located,
#   in,
#   Sao,
#   Paulo,
#   ,,
#   Brazil,
#   ,,
#   a,
#   country,
#   with,
#   a,
#   total,
#   area,
#   of,
#   8514837.14,
#   square,
#   kilometres,
#   .],
#  [The,
#   Quine,
#   Tapes,
#   are,
#   Rock,
#   music,
#   genre,
#   preceded,
#   by,
#   the,
#   album,
#   Squeeze,
#   ,,
#   and,
#   Squeeze,
#   was,
#   preceded,
#   by,
#   the,
#   album,
#   Andy,
#   Warhol,
#   's,
#   Velvet,
#   Underground,
#   Featuring,
#   Nico,
#   .],
#  [Bootleg,
#   Series,
#   Volume,
#   1,
#   :,
#   The,
#   Quine,
#   Tapes,
#   's,
#   genre,
#   is,
#   rock,
#   ,,
#   and,
#   is,
#   preceded,
#   by,
#   the,
#   Velvet,
#   Underground,
#   album,
#   Squeeze,
#   ,,
#   which,
#   was,
#   preceded,
#   by,
#   the,
#   compilation,
#   album,
#   Andy,
#   Warhol,
#   's,
#   Velvet,
#   Underground,
#   Featuring,
#   Nico,
#   .],
#  [The,
#   album,
#   Bootleg,
#   Series,
#   Volume,
#   1,
#   :,
#   The,
#   Quine,
#   Tapes,
#   fits,
#   into,
#   the,
#   Rock,
#   music,
#   genre,
#   and,
#   was,
#   preceded,
#   by,
#   Squeeze,
#   by,
#   The,
#   Velvet,
#   Underground,
#   ,,
#   which,
#   in,
#   turn,
#   was,
#   preceded,
#   by,
#   Andy,
#   Warhol,
#   's,
#   Velvet,
#   Underground,
#   Featuring,
#   Nico,
#   .],
#  [Dr.,
#   G.,
#   P.,
#   Prabhukumar,
#   is,
#   the,
#   director,
#   of,
#   the,
#   Acharya,
#   Institute,
#   of,
#   Technology,
#   which,
#   is,
#   located,
#   at,
#   Soldevanahalli,
#   ,,
#   Acharya,
#   Dr.,
#   Sarvapalli,
#   Radhakrishnan,
#   Road,
#   ,,
#   Hessarghatta,
#   Main,
#   Road,
#   ,,
#   Bangalore,
#   -,
#   560090,
#   in,
#   India,
#   and,
#   is,
#   affiliated,
#   with,
#   Visvesvaraya,
#   Technological,
#   University,
#   .],
#  [The,
#   Acharya,
#   Institute,
#   of,
#   Technology,
#   campus,
#   is,
#   located,
#   in,
#   Soldevanahalli,
#   ,,
#   Acharya,
#   Dr.,
#   Sarvapalli,
#   Radhakrishnan,
#   Road,
#   ,,
#   Hessarghatta,
#   Main,
#   Road,
#   ,,
#   Bangalore,
#   –,
#   560090,
#   ,,
#   India,
#   .],
#  [Its,
#   director,
#   is,
#   Dr.,
#   G.P.,
#   Prabhukumar,
#   and,
#   it,
#   is,
#   affiliated,
#   to,
#   Visvesvaraya,
#   Technological,
#   University,
#   .],
#  [The,
#   campus,
#   of,
#   the,
#   Acharya,
#   Institute,
#   of,
#   Technology,
#   is,
#   located,
#   at,
#   Soldevanahalli,
#   ,,
#   Acharya,
#   Dr.,
#   Sarvapalli,
#   Radhakrishnan,
#   Road,
#   ,,
#   Hessarghatta,
#   Main,
#   Road,
#   ,,
#   Bangalore,
#   –,
#   560090,
#   ,,
#   India,
#   and,
#   it,
#   is,
#   affiliated,
#   with,
#   the,
#   Visvesvaraya,
#   Technological,
#   University,
#   .],
#  [Its, director, is, Dr., G.P.Prabhukumar, .],
#  [Abraham,
#   A.,
#   Ribicoff,
#   was,
#   born,
#   and,
#   died,
#   in,
#   the,
#   United,
#   States,
#   where,
#   African,
#   Americans,
#   are,
#   an,
#   ethnic,
#   group,
#   .],
#  [Abraham, A.Ribicoff, died, in, the, United, States, .],
#  [It, was, also, his, birthplace, .],
#  [African,
#   Americans,
#   are,
#   an,
#   ethnic,
#   group,
#   in,
#   the,
#   U.S.A.Abraham,
#   A,
#   Ribicoff,
#   was,
#   born,
#   and,
#   died,
#   in,
#   the,
#   United,
#   States,
#   where,
#   African,
#   Americans,
#   are,
#   an,
#   ethnic,
#   group,
#   .],
#  [Music,
#   group,
#   the,
#   Velvet,
#   Underground,
#   produced,
#   and,
#   released,
#   rock,
#   music,
#   album,
#   Bootleg,
#   Series,
#   Volume,
#   1,
#   :,
#   The,
#   Quine,
#   Tapes,
#   under,
#   the,
#   Polydor,
#   Records,
#   record,
#   label,
#   .],
#  [The,
#   album,
#   was,
#   recorded,
#   in,
#   St.,
#   Louis,
#   ,,
#   Missouri,
#   ,,
#   USA,
#   and,
#   has,
#   a,
#   run,
#   time,
#   of,
#   230:05.Bootleg,
#   Series,
#   Volume,
#   1,
#   :,
#   The,
#   Quine,
#   Tapes,
#   created,
#   and,
#   produced,
#   by,
#   The,
#   Velvet,
#   Underground,
#   with,
#   runtime,
#   of,
#   230.05,
#   minutes,
#   was,
#   recorded,
#   in,
#   was,
#   St.,
#   Louis,
#   Missouri,
#   ,,
#   United,
#   States,
#   .],
#  [The, Rock, genre, album, was, recorded, through, Polydor, Records, .],
#  [The,
#   Bootleg,
#   Series,
#   Volume,
#   I,
#   :,
#   The,
#   Quine,
#   Tapes,
#   created,
#   and,
#   produced,
#   by,
#   The,
#   Velvet,
#   Underground,
#   with,
#   runtime,
#   of,
#   230.05,
#   minutes,
#   was,
#   recorded,
#   in,
#   St.,
#   Louis,
#   ,,
#   Missouri,
#   ,,
#   United,
#   States,
#   .],
#  [The,
#   Rock,
#   music,
#   genre,
#   album,
#   was,
#   released,
#   by,
#   the,
#   record,
#   label,
#   Polydor,
#   Records,
#   .],
#  [The, fellowship, of, the, Ring, belongs, to, the, fantasy, genre, .],
#  [George, Allen, &, amp, ;, Unwin, published, it, .],
#  [The,
#   Fellowship,
#   of,
#   the,
#   Ring,
#   was,
#   published,
#   in,
#   the,
#   Fantasy,
#   genre,
#   by,
#   George,
#   Allen,
#   &,
#   amp,
#   ;,
#   Unwin,
#   .],
#  [The,
#   Fellowship,
#   of,
#   the,
#   Ring,
#   ,,
#   from,
#   the,
#   fantasy,
#   genre,
#   ,,
#   was,
#   published,
#   by,
#   George,
#   Allen,
#   &,
#   amp,
#   ;,
#   Unwin,
#   .],
#  [Distinguished,
#   Service,
#   Medal,
#   (,
#   US,
#   Navy,
#   ),
#   recipient,
#   Alan,
#   Shepard,
#   was,
#   born,
#   in,
#   New,
#   Hampshire,
#   but,
#   died,
#   in,
#   California,
#   .],
#  [Awarded,
#   the,
#   Distinguished,
#   Service,
#   Medal,
#   by,
#   The,
#   United,
#   States,
#   Navy,
#   ,,
#   Alan,
#   Shepard,
#   ,,
#   was,
#   born,
#   in,
#   New,
#   Hampshire,
#   ,,
#   and,
#   died,
#   in,
#   California,
#   .],
#  [Alan,
#   Shepard,
#   ,,
#   born,
#   in,
#   New,
#   Hampshire,
#   while,
#   having,
#   died,
#   in,
#   California,
#   ,,
#   was,
#   awarded,
#   the,
#   Distinguished,
#   Service,
#   Medal,
#   by,
#   the,
#   United,
#   States,
#   Navy,
#   .],
#  [Imagine,
#   is,
#   a,
#   song,
#   that,
#   Train,
#   followed,
#   Mermaid,
#   with,
#   ,,
#   which,
#   was,
#   a,
#   song,
#   produced,
#   by,
#   the,
#   production,
#   team,
#   Espionage,
#   ,,
#   and,
#   was,
#   on,
#   their,
#   album,
#   California,
#   37.Train,
#   followed,
#   its,
#   song,
#   Mermaid,
#   ,,
#   from,
#   its,
#   California,
#   37,
#   album,
#   ,,
#   which,
#   was,
#   was,
#   produced,
#   by,
#   the,
#   production,
#   team,
#   Espionage,
#   ,,
#   with,
#   a,
#   song,
#   titled,
#   Imagine,
#   .],
#  [From,
#   the,
#   production,
#   team,
#   Espionage,
#   ,,
#   Train,
#   's,
#   song,
#   Mermaid,
#   (,
#   on,
#   the,
#   California,
#   37,
#   album,
#   ),
#   was,
#   followed,
#   by,
#   Train,
#   's,
#   performance,
#   of,
#   Imagine,
#   by,
#   John,
#   Lennon,
#   .],
#  [The,
#   Train,
#   song,
#   Mermaid,
#   ,,
#   which,
#   belongs,
#   to,
#   the,
#   California,
#   37,
#   Train,
#   album,
#   and,
#   was,
#   produced,
#   by,
#   Espionage,
#   ,,
#   is,
#   followed,
#   by,
#   the,
#   John,
#   Lennon,
#   song,
#   Imagine,
#   .],
#  [Train,
#   's,
#   song,
#   Imagine,
#   came,
#   after,
#   a,
#   song,
#   from,
#   their,
#   California,
#   37,
#   album,
#   ,,
#   titled,
#   Mermaid,
#   ,,
#   which,
#   was,
#   produced,
#   by,
#   the,
#   production,
#   team,
#   Espionage,
#   .],
#  [The,
#   Fellowship,
#   of,
#   the,
#   Ring,
#   was,
#   written,
#   by,
#   J.R.R.,
#   Tolkien,
#   and,
#   was,
#   released,
#   on,
#   July,
#   29,
#   ,,
#   1954,
#   .],
#  [The,
#   Fellowship,
#   of,
#   the,
#   Ring,
#   is,
#   considered,
#   fantasy,
#   and,
#   was,
#   published,
#   by,
#   George,
#   Allen,
#   &,
#   amp,
#   ;,
#   Unwin,
#   .],
#  [The, sequel, to, The, Fellowship, of, the, Ring, was, The, Two, Towers, .],
#  [J.R.R.,
#   Tolkien,
#   is,
#   the,
#   author,
#   of,
#   The,
#   Fellowship,
#   of,
#   the,
#   Ring,
#   released,
#   on,
#   July,
#   29,
#   ,,
#   1954,
#   .],
#  [It, is, a, fantasy, book, published, by, George, Allen, &, amp, ;, Unwin, .],
#  [The, novel, was, followed, by, The, Two, Towers, .],
#  [The, Fellowship, of, the, Ring, belongs, to, the, fantasy, genre, .],
#  [Its, author, is, J.R.R., Tolkien, .],
#  [It,
#   was,
#   published,
#   on,
#   July,
#   29,
#   ,,
#   1954,
#   by,
#   George,
#   Allen,
#   &,
#   amp,
#   ;,
#   Unwin,
#   .],
#  [It, was, followed, by, The, Two, Towers, .],
#  [GMA],
#  [New,
#   Media,
#   lies,
#   in,
#   the,
#   Philippines,
#   where,
#   applications,
#   are,
#   offered,
#   in,
#   the,
#   entertainment,
#   industry,
#   .],
#  [Located,
#   in,
#   the,
#   Philippines,
#   ,,
#   GMA,
#   New,
#   Media,
#   is,
#   an,
#   entertainment,
#   industry,
#   .],
#  [GMA],
#  [New,
#   Media,
#   is,
#   an,
#   entertainment,
#   company,
#   located,
#   in,
#   the,
#   Philippines,
#   .],
#  [English,
#   Without,
#   Tears,
#   ,,
#   written,
#   by,
#   Terence,
#   Rattigan,
#   ,,
#   runs,
#   89,
#   minutes,
#   .],
#  [The, cinematography, for, the, film, was, done, by, Bernard, Knowles, .],
#  [English,
#   Without,
#   Tears,
#   ,,
#   an,
#   89,
#   minute,
#   film,
#   written,
#   by,
#   Terence,
#   Rattigan,
#   ,,
#   features,
#   the,
#   cinematography,
#   of,
#   Bernard,
#   Knowles,
#   .],
#  [Terence,
#   Rattigan,
#   is,
#   the,
#   writer,
#   of,
#   the,
#   89,
#   minute,
#   movie,
#   ´,
#   English,
#   Without,
#   Tears,
#   ´,
#   and,
#   Bernard,
#   Knowles,
#   is,
#   the,
#   cinematographer,
#   .],
#  [George,
#   Monson,
#   was,
#   married,
#   to,
#   Lady,
#   Anne,
#   Monson,
#   ,,
#   a,
#   botanist,
#   ,,
#   who,
#   died,
#   on,
#   February,
#   18,
#   ,,
#   1776.Lady,
#   Anne,
#   Monson,
#   ,,
#   a,
#   professional,
#   botanist,
#   who,
#   was,
#   married,
#   to,
#   George,
#   Monson,
#   ,,
#   died,
#   on,
#   February,
#   18th,
#   ,],
#  [1776.Lady, Anne, Monson, is, the, spouse, of, George, Monson, .],
#  [Her,
#   professional,
#   field,
#   of,
#   study,
#   was,
#   botany,
#   ,,
#   and,
#   she,
#   died,
#   on,
#   18,
#   February,
#   1776.Abdul,
#   Taib,
#   Mahmud,
#   ,,
#   member,
#   of,
#   the,
#   Parti,
#   Pesaka,
#   Bumiputera,
#   Bersatu,
#   party,
#   ,,
#   resides,
#   in,
#   Demak,
#   Jaya,
#   ,,
#   Jalan,
#   Bako,
#   ,,
#   Kuching,
#   ,,
#   Sarawak,
#   .],
#  [Abdul,
#   Taib,
#   Mahmud,
#   ,,
#   a,
#   member,
#   of,
#   the,
#   Parti,
#   Pesaka,
#   Bumiputera,
#   Bersatu,
#   party,
#   ,,
#   resides,
#   in,
#   Demak,
#   Jaya,
#   ,,
#   Jalan,
#   Bako,
#   ,,
#   Kuching,
#   ,,
#   Sarawak,
#   .],
#  [Liselotte,
#   Grschebina,
#   was,
#   an,
#   Israeli,
#   who,
#   attended,
#   the,
#   school,
#   of,
#   Applied,
#   Arts,
#   in,
#   Stuttgart,
#   .],
#  [She, was, born, in, Karlsruhe, ,, Germany, .],
#  [Israel, 's, national, language, is, Modern, Hebrew, .],
#  [Liselotte,
#   Grschebina,
#   is,
#   an,
#   Israeli,
#   national,
#   who,
#   did,
#   her,
#   studies,
#   at,
#   the,
#   School,
#   of,
#   Applied,
#   Arts,
#   in,
#   Stuttgart,
#   and,
#   was,
#   born,
#   in,
#   Karlsruhe,
#   ,,
#   which,
#   is,
#   in,
#   Germany,
#   unlike,
#   Israel,
#   whose,
#   language,
#   is,
#   Modern,
#   Hebrew,
#   .],
#  [Liselotte,
#   Grschebina,
#   was,
#   born,
#   in,
#   Karlsruhe,
#   which,
#   is,
#   located,
#   in,
#   Germany,
#   ,,
#   has,
#   Israeli,
#   nationality,
#   (,
#   the,
#   language,
#   in,
#   Israel,
#   is,
#   Modern,
#   Hebrew,
#   ),
#   ,,
#   and,
#   studied,
#   at,
#   the,
#   School,
#   of,
#   Applied,
#   Arts,
#   in,
#   Stuttgart,
#   .],
#  [Chinabank, 's, location, is, the, Philippines, .],
#  [Chinabank, is, located, in, the, Philippines, .],
#  [The,
#   Train,
#   song,
#   Mermaid,
#   ,,
#   which,
#   is,
#   an,
#   example,
#   of,
#   the,
#   reggae,
#   genre,
#   ,,
#   was,
#   released,
#   under,
#   the,
#   record,
#   labels,
#   of,
#   Columbia,
#   Records,
#   and,
#   Sony,
#   Music,
#   Entertainment,
#   .],
#  [It,
#   was,
#   written,
#   by,
#   Espen,
#   Lind,
#   and,
#   Amund,
#   Bjørklund,
#   and,
#   has,
#   a,
#   total,
#   runtime,
#   of,
#   3,
#   minutes,
#   and,
#   16,
#   seconds,
#   .],
#  [Amund,
#   Bjorklund,
#   and,
#   Espen,
#   Lind,
#   are,
#   writers,
#   of,
#   the,
#   3.16,
#   minute,
#   reggae,
#   song,
#   Mermaid,
#   by,
#   Train,
#   that,
#   was,
#   released,
#   under,
#   Sony,
#   Music,
#   Entertainment,
#   and,
#   Columbia,
#   Records,
#   .],
#  [The,
#   song,
#   Mermaid,
#   was,
#   written,
#   In,
#   the,
#   reggae,
#   music,
#   genre,
#   by,
#   Espen,
#   Lind,
#   and,
#   Amund,
#   Bjorklund,
#   The,
#   song,
#   was,
#   performed,
#   by,
#   Train,
#   and,
#   released,
#   by,
#   Columbia,
#   Records,
#   and,
#   Sony,
#   Music,
#   Entertainment,
#   records,
#   .],
#  [It, has, a, total, runtime, of, three, minutes, and, sixteen, seconds, .],
#  [It,
#   's,
#   Great,
#   to,
#   be,
#   Young,
#   ,,
#   a,
#   1956,
#   film,
#   starring,
#   Cecil,
#   Parker,
#   was,
#   composed,
#   by,
#   Louis,
#   Levy,
#   and,
#   written,
#   by,
#   Ted,
#   Willis,
#   .],
#  [“It,
#   's,
#   Great,
#   to,
#   Be,
#   Young,
#   ”,
#   (,
#   1956,
#   ),
#   was,
#   written,
#   by,
#   Ted,
#   Willis,
#   and,
#   features,
#   music,
#   by,
#   Louis,
#   Levy,
#   .],
#  [A, main, role, in, the, movie, was, given, to, Cecil, Parker, .],
#  [Louis,
#   Levy,
#   is,
#   the,
#   composer,
#   of,
#   the,
#   1956,
#   film,
#   It,
#   's,
#   Great,
#   to,
#   Be,
#   Young,
#   ,,
#   which,
#   is,
#   written,
#   by,
#   Ted,
#   Willis,
#   and,
#   stars,
#   Cecil,
#   Parker,
#   .],
#  [Aaron,
#   Turner,
#   is,
#   a,
#   post,
#   -,
#   metal,
#   musician,
#   from,
#   Massachusetts,
#   who,
#   plays,
#   the,
#   electric,
#   guitar,
#   .],
#  [He,
#   started,
#   performing,
#   in,
#   1995,
#   and,
#   is,
#   a,
#   musician,
#   in,
#   the,
#   Lotus,
#   Eaters,
#   band,
#   .],
#  [Aaron,
#   Turner,
#   is,
#   a,
#   post,
#   -,
#   metal,
#   musician,
#   born,
#   in,
#   Massachusetts,
#   who,
#   plays,
#   electric,
#   guitar,
#   ,,
#   started,
#   performing,
#   in,
#   1995,
#   and,
#   is,
#   in,
#   the,
#   Lotus,
#   Eaters,
#   band,
#   .],
#  [Aaron,
#   Turner,
#   is,
#   a,
#   post,
#   metal,
#   performer,
#   from,
#   Massachusetts,
#   who,
#   plays,
#   the,
#   electric,
#   guitar,
#   ,,
#   started,
#   performing,
#   in,
#   1995,
#   and,
#   is,
#   in,
#   the,
#   Lotus,
#   Eaters,
#   band,
#   .],
#  [Pennsylvania,
#   's,
#   Franklin,
#   County,
#   is,
#   found,
#   to,
#   the,
#   west,
#   of,
#   Adams,
#   County,
#   ,,
#   Pennsylvania,
#   and,
#   Carroll,
#   County,
#   ,,
#   Maryland,
#   is,
#   to,
#   the,
#   southeast,
#   .],
#  [A,
#   monument,
#   to,
#   the,
#   11th,
#   Mississippi,
#   Infantry,
#   was,
#   erected,
#   in,
#   2000,
#   in,
#   Adams,
#   County,
#   and,
#   this,
#   monument,
#   is,
#   classed,
#   as,
#   a,
#   contributing,
#   property,
#   .],
#  [The,
#   11th,
#   Mississippi,
#   Infantry,
#   Monument,
#   was,
#   established,
#   in,
#   2000,
#   in,
#   Adams,
#   County,
#   ,,
#   Pennsylvania,
#   which,
#   has,
#   Carroll,
#   County,
#   ,,
#   Maryland,
#   to,
#   its,
#   southeast,
#   and,
#   Franklin,
#   County,
#   ,,
#   Pennsylvania,
#   to,
#   its,
#   west,
#   .],
#  [The,
#   11th,
#   Mississippi,
#   Infantry,
#   Monument,
#   is,
#   in,
#   the,
#   category,
#   of,
#   contributing,
#   property,
#   .],
#  [The,
#   11th,
#   Mississippi,
#   Infantry,
#   Monument,
#   ,,
#   established,
#   in,
#   2000,
#   ,,
#   falls,
#   under,
#   the,
#   category,
#   of,
#   Contributing,
#   property,
#   and,
#   is,
#   located,
#   in,
#   Adams,
#   County,
#   ,,
#   Pennsylvania,
#   ,,
#   which,
#   has,
#   Carroll,
#   County,
#   ,,
#   Maryland,
#   to,
#   the,
#   southeast,
#   and,
#   Franklin,
#   County,
#   ,,
#   Pennsylvania,
#   to,
#   the,
#   east,
#   .],
#  [The,
#   band,
#   Nord,
#   is,
#   a,
#   sludge,
#   metal,
#   band,
#   that,
#   releases,
#   post,
#   -,
#   metal,
#   .],
#  [They,
#   have,
#   an,
#   album,
#   called,
#   the,
#   Year,
#   of,
#   No,
#   light,
#   that,
#   was,
#   released,
#   on,
#   June,
#   9th,
#   2006,
#   ,,
#   and,
#   was,
#   under,
#   Crucial,
#   Blast,
#   Label,
#   .],
#  [Year, of, No, Light, self, -, produced, their, album, Nord, .],
#  [The,
#   album,
#   was,
#   released,
#   under,
#   the,
#   label,
#   Crucial,
#   Blast,
#   on,
#   September,
#   6th,
#   ,,
#   2006,
#   .],
#  [Nord, falls, into, the, sludge, metal, and, post, -, metal, genres, .],
#  [Ciudad,
#   Ayala,
#   is,
#   a,
#   metropolitan,
#   city,
#   which,
#   has,
#   population,
#   of,
#   1,777,539,
#   with,
#   its,
#   population,
#   density,
#   of,
#   1604.0,
#   and,
#   it,
#   falls,
#   into,
#   UTC,
#   offset,
#   -6,
#   time,
#   zone,
#   .],
#  [One,
#   of,
#   the,
#   leaders,
#   of,
#   Ciudad,
#   Ayala,
#   is,
#   the,
#   City,
#   Manager,
#   which,
#   uses,
#   council,
#   -,
#   manager,
#   government,
#   .],
#  [The,
#   city,
#   Ciudad,
#   Ayala,
#   has,
#   population,
#   1,777,539,
#   making,
#   the,
#   density,
#   1604.0,
#   .],
#  [One,
#   of,
#   the,
#   leaders,
#   in,
#   the,
#   council,
#   -,
#   manager,
#   government,
#   is,
#   the,
#   City,
#   Manager,
#   .],
#  [It,
#   is,
#   in,
#   UTC,
#   offset,
#   -6.The,
#   city,
#   Ciudad,
#   Ayala,
#   has,
#   population,
#   1777539,
#   making,
#   the,
#   density,
#   1604,
#   .],
#  [It, is, a, council, -, managed, government, led, by, a, City, Manager, .],
#  [It, is, in, UTC, offset, -6.Super],
#  [Capers, is, a, 98, minute, film, with, a, $, 2000000.0, budget, .],
#  [It,
#   stars,
#   Tom,
#   Sizemore,
#   and,
#   Michael,
#   Rooker,
#   ,,
#   and,
#   was,
#   written,
#   and,
#   directed,
#   by,
#   Ray,
#   Griggs,
#   .],
#  [Super,
#   Capers,
#   is,
#   a,
#   98,
#   minute,
#   movie,
#   starring,
#   Michael,
#   Rooker,
#   and,
#   Tom,
#   Sizemore,
#   .],
#  [It, was, written, and, directed, by, Ray, Griggs, .],
#  [It,
#   had,
#   a,
#   budget,
#   of,
#   $,
#   2,000,000.The,
#   98,
#   minute,
#   film,
#   Super,
#   Capers,
#   had,
#   a,
#   budget,
#   of,
#   2,
#   million,
#   dollars,
#   .],
#  [It, was, written, and, directed, by, Ray, Griggs, .],
#  [It, starred, Tom, Sizemore, and, also, featured, Michael, Rooker, .],
#  [Darinka,
#   Dentcheva,
#   developed,
#   a,
#   theory,
#   influenced,
#   by,
#   Andrzej,
#   Piotr,
#   Ruszczyński,
#   .],
#  [Darinka, Dentcheva, was, influenced, by, Andrzej, Piotr, Ruszczyński, .],
#  [Darinka, Dentcheva, was, influenced, by, Andrzej, Piotr, Ruszczynski, .],
#  [Born,
#   in,
#   1878,
#   ,,
#   Harry,
#   Carey,
#   later,
#   grew,
#   up,
#   to,
#   write,
#   and,
#   star,
#   in,
#   the,
#   movie,
#   McVeagh,
#   of,
#   the,
#   South,
#   Seas,
#   .],
#  [Harry,
#   Carey,
#   ,,
#   born,
#   in,
#   1878,
#   ,,
#   wrote,
#   and,
#   appeared,
#   in,
#   the,
#   movie,
#   McVeagh,
#   of,
#   the,
#   South,
#   Seas,
#   .],
#  [Harry,
#   Carey,
#   ,,
#   who,
#   was,
#   born,
#   in,
#   1878,
#   ,,
#   wrote,
#   and,
#   starred,
#   the,
#   film,
#   of,
#   McVeagh,
#   of,
#   the,
#   South,
#   Seas,
#   .],
#  [Mexicans,
#   ,,
#   the,
#   inhabitants,
#   of,
#   Mexico,
#   ,,
#   can,
#   use,
#   their,
#   peso,
#   currency,
#   to,
#   purchase,
#   a,
#   dessert,
#   called,
#   Bionico,
#   .],
#  [Bionico,
#   can,
#   be,
#   found,
#   in,
#   Guadalajara,
#   ,,
#   Mexico,
#   ,,
#   and,
#   is,
#   made,
#   from,
#   sour,
#   cream,
#   ,,
#   chopped,
#   fruits,
#   ,,
#   condensed,
#   milk,
#   ,,
#   granola,
#   ,,
#   coconut,
#   and,
#   raisins,
#   .],
#  [They, can, also, buy, cookies, ,, another, dessert, .],
#  [Much,
#   like,
#   a,
#   cookie,
#   ,,
#   Bionico,
#   is,
#   a,
#   dessert,
#   food,
#   whose,
#   ingredients,
#   include,
#   chopped,
#   fruits,
#   ,,
#   sour,
#   cream,
#   ,,
#   condensed,
#   milk,
#   ,,
#   granola,
#   ,,
#   shredded,
#   coconut,
#   and,
#   raisins,
#   .],
#  [Bionico,
#   is,
#   found,
#   in,
#   the,
#   Guadalajara,
#   region,
#   of,
#   Mexico,
#   ,,
#   which,
#   uses,
#   pesos,
#   are,
#   their,
#   currency,
#   and,
#   is,
#   home,
#   to,
#   Mexican,
#   people,
#   .],
#  [Mexico, inhabited, by, Mexicans, has, peso, as, its, currency, .],
#  [Bionico,
#   ,,
#   a,
#   dessert,
#   food,
#   found,
#   in,
#   Guadalajara,
#   ,,
#   Mexico,
#   ,,
#   has,
#   sour,
#   cream,
#   ,,
#   chopped,
#   fruits,
#   ,,
#   condensed,
#   milk,
#   ,,
#   granola,
#   ,,
#   raisins,
#   and,
#   shredded,
#   coconut,
#   as,
#   its,
#   main,
#   ingredients,
#   .],
#  [Cookie, is, a, type, of, dessert, .],
#  [One,
#   of,
#   the,
#   leader,
#   of,
#   Ciudad,
#   Ayala,
#   (,
#   a,
#   city,
#   ),
#   is,
#   called,
#   City,
#   Manager,
#   .],
#  [With,
#   a,
#   population,
#   density,
#   of,
#   1604.0.Ciudad,
#   Ayala,
#   is,
#   a,
#   city,
#   with,
#   a,
#   population,
#   density,
#   of,
#   1,604,
#   .],
#  [One, of, the, leaders, is, called, the, City, Manager, .],
#  [One,
#   of,
#   the,
#   leaders,
#   of,
#   Ciudad,
#   Ayala,
#   ,,
#   a,
#   city,
#   with,
#   a,
#   population,
#   density,
#   of,
#   1604.0,
#   ,,
#   is,
#   the,
#   City,
#   Manager,
#   .],
#  [ENAIRE,
#   ,,
#   based,
#   in,
#   Madrid,
#   ,,
#   Spain,
#   ,,
#   is,
#   the,
#   operating,
#   organisation,
#   for,
#   Adolfo,
#   Suarez,
#   Madrid,
#   -,
#   Barajas,
#   airport,
#   which,
#   is,
#   in,
#   Alcobendas,
#   .],
#  [The,
#   runway,
#   length,
#   at,
#   the,
#   airport,
#   is,
#   3500.Located,
#   in,
#   Madrid,
#   ,,
#   Spain,
#   ,,
#   ENAIRE,
#   operates,
#   the,
#   Adolfo,
#   Suarez,
#   Madrid,
#   -,
#   Barajas,
#   Airport,
#   in,
#   Alcobendas,
#   which,
#   reports,
#   a,
#   runway,
#   length,
#   of,
#   3,500.Adolfo,
#   Suarez,
#   Madrid,
#   -,
#   Barajas,
#   Airport,
#   ,,
#   operated,
#   by,
#   ENAIRE,
#   ,,
#   is,
#   located,
#   in,
#   Alcobendas,
#   while,
#   ENAIRE,
#   is,
#   located,
#   in,
#   Madrid,
#   ,,
#   Spain,
#   .],
#  [The,
#   Airport,
#   's,
#   runway,
#   length,
#   is,
#   3500.Bionico,
#   is,
#   a,
#   dish,
#   served,
#   for,
#   dessert,
#   in,
#   Mexico,
#   ,,
#   where,
#   the,
#   currency,
#   is,
#   the,
#   peso,
#   ,,
#   the,
#   dish,
#   contains,
#   granola,
#   .],
#  [Bionico,
#   ,,
#   a,
#   food,
#   that,
#   requires,
#   granola,
#   as,
#   one,
#   of,
#   its,
#   ingredients,
#   and,
#   served,
#   at,
#   the,
#   dessert,
#   is,
#   found,
#   in,
#   Mexico,
#   .],
#  [The, currency, is, the, Peso, .],
#  [Bionico, is, a, food, found, in, Mexico, (, currency, :, peso, ), .],
#  [Bionico, (, dessert, ), requires, granola, as, one, of, its, ingredients, .],
#  [With,
#   a,
#   periapsis,
#   of,
#   260855000000.0,
#   ,,
#   the,
#   1147,
#   Stavropolis,
#   has,
#   a,
#   epoch,
#   of,
#   31,
#   July,
#   2016,
#   (,
#   JD2457600.5).1147,
#   Stavropolis,
#   epoch,
#   is,
#   31,
#   July,
#   2016,
#   (,
#   Julian,
#   Day,
#   2457600.5,
#   ),
#   and,
#   the,
#   periapsis,
#   of,
#   1147,
#   Stavropolis,
#   is,
#   260855000000.1147],
#  [Stavropolis,
#   has,
#   an,
#   epoch,
#   on,
#   31,
#   July,
#   2016,
#   and,
#   a,
#   periapsis,
#   of,
#   260855000000.0.Ciudad,
#   Ayala,
#   which,
#   is,
#   in,
#   the,
#   Pacific,
#   Daylight,
#   time,
#   zone,
#   has,
#   the,
#   population,
#   density,
#   of,
#   1604.Ciudad,
#   Ayala,
#   city,
#   which,
#   has,
#   a,
#   PDT,
#   time,
#   zone,
#   has,
#   a,
#   population,
#   density,
#   of,
#   1604.0.Ciudad,
#   Ayala,
#   's,
#   time,
#   zone,
#   is,
#   Pacific,
#   Daylight,
#   Time,
#   and,
#   its,
#   population,
#   density,
#   is,
#   1604.0.The,
#   net,
#   income,
#   of,
#   Chinabank,
#   is,
#   15,100,000,000,
#   ,,
#   and,
#   they,
#   have,
#   5594,
#   workers,
#   total,
#   .],
#  [Chinabank,
#   currently,
#   brings,
#   in,
#   a,
#   net,
#   income,
#   of,
#   15100000000,
#   thanks,
#   to,
#   the,
#   efforts,
#   of,
#   its,
#   5594,
#   employees,
#   .],
#  [Chinabank,
#   brings,
#   in,
#   a,
#   net,
#   income,
#   of,
#   15,100,000,000,
#   with,
#   its,
#   5594,
#   employees,
#   .],
#  [Steve,
#   Bright,
#   is,
#   the,
#   creator,
#   of,
#   Bananaman,
#   which,
#   was,
#   last,
#   broadcast,
#   on,
#   April,
#   15th,
#   1986,
#   by,
#   the,
#   BBC.Bananaman,
#   was,
#   created,
#   by,
#   Steve,
#   Bright,
#   and,
#   last,
#   aired,
#   on,
#   April,
#   15th,
#   1986,
#   .],
#  [It,
#   was,
#   broadcast,
#   by,
#   the,
#   BBC.Bananaman,
#   ,,
#   the,
#   TV,
#   show,
#   ,,
#   was,
#   created,
#   by,
#   Steve,
#   Bright,
#   and,
#   was,
#   last,
#   aired,
#   on,
#   15th,
#   April,
#   1986,
#   .],
#  [Bananaman,
#   was,
#   broadcast,
#   on,
#   the,
#   BBC.Bionico,
#   (,
#   a,
#   dish,
#   served,
#   for,
#   dessert,
#   ),
#   is,
#   a,
#   food,
#   found,
#   in,
#   Guadalajara,
#   in,
#   Mexico,
#   .],
#  [The,
#   currency,
#   in,
#   Mexico,
#   is,
#   the,
#   Mexican,
#   peso,
#   inhabited,
#   by,
#   Mexicans,
#   .],
#  [Bionico,
#   (,
#   a,
#   dessert,
#   ),
#   is,
#   a,
#   food,
#   found,
#   in,
#   Guadalajara,
#   in,
#   Mexico,
#   .],
#  [The,
#   currency,
#   in,
#   Mexico,
#   is,
#   the,
#   Mexican,
#   peso,
#   inhabited,
#   by,
#   the,
#   Mexicans,
#   .],
#  [Bionico,
#   is,
#   a,
#   food,
#   found,
#   in,
#   Mexico,
#   and,
#   served,
#   at,
#   the,
#   dessert,
#   course,
#   .],
#  [The, dessert, can, be, found, in, Guadalajara, .],
#  [The, currency, of, Mexico, (, inhabited, by, Mexicans, ), is, Peso, .],
#  [The,
#   Year,
#   of,
#   No,
#   Light,
#   album,
#   Live,
#   at,
#   Roadburn,
#   2008,
#   was,
#   followed,
#   by,
#   their,
#   album,
#   Nord,
#   .],
#  [Live,
#   at,
#   Roadburn,
#   2008,
#   was,
#   preceded,
#   by,
#   the,
#   album,
#   Nord,
#   played,
#   by,
#   Year,
#   of,
#   No,
#   Light,
#   .],
#  [Year,
#   of,
#   No,
#   Light,
#   ,,
#   who,
#   released,
#   the,
#   album,
#   Nord,
#   ,,
#   followed,
#   this,
#   up,
#   with,
#   the,
#   album,
#   Live,
#   at,
#   Roadburn,
#   2008.Alan],
#  [Shepard,
#   was,
#   a,
#   crew,
#   member,
#   of,
#   Apollo,
#   14,
#   who,
#   was,
#   born,
#   November,
#   18th,
#   ,,
#   1923,
#   ,,
#   in,
#   New,
#   Hampshire,
#   and,
#   died,
#   in,
#   California,
#   .],
#  [Alan, Shepard, was, born, in, New, Hampshire, on, November, 18, ,, 1923, .],
#  [He,
#   was,
#   a,
#   crew,
#   member,
#   of,
#   Apollo,
#   14,
#   ,,
#   and,
#   died,
#   later,
#   on,
#   in,
#   California,
#   .],
#  [Alan,
#   Shepard,
#   was,
#   born,
#   on,
#   Nov,
#   18,
#   ,,
#   1923,
#   in,
#   New,
#   Hampshire,
#   ,,
#   was,
#   a,
#   member,
#   of,
#   the,
#   Apollo,
#   14,
#   crew,
#   and,
#   died,
#   in,
#   California,
#   .],
#  [The,
#   ALCO,
#   RS-3,
#   ,,
#   with,
#   a,
#   four,
#   -,
#   stroke,
#   engine,
#   and,
#   12,
#   cylinders,
#   ,,
#   has,
#   a,
#   length,
#   of,
#   17068.8,
#   millimetres,
#   .],
#  [The,
#   four,
#   -,
#   stroke,
#   12,
#   cylinder,
#   ALCO,
#   RS-3,
#   is,
#   17068.8,
#   millimetres,
#   long,
#   .],
#  [The,
#   ALCO,
#   RS-3,
#   has,
#   a,
#   four,
#   -,
#   stroke,
#   engine,
#   and,
#   a,
#   cylinder,
#   count,
#   of,
#   12,
#   which,
#   is,
#   17068.8,
#   mm,
#   in,
#   length,
#   .],
#  [Olga,
#   Nikolaevna,
#   Bondareva,
#   ,,
#   (,
#   born,
#   April,
#   27,
#   ,,
#   1937,
#   ),
#   died,
#   in,
#   Saint,
#   Petersburg,
#   .],
#  [She, was, best, known, for, the, ", Bondareva, -, Shapley, theorem, ..],
#  [Olga,
#   Nikolaevna,
#   Bondareva,
#   ,,
#   known,
#   for,
#   the,
#   Bondareva,
#   -,
#   Shapley,
#   theorem,
#   ,,
#   was,
#   born,
#   on,
#   April,
#   27,
#   ,,
#   1937,
#   and,
#   died,
#   in,
#   Saint,
#   Petersburg,
#   .],
#  [Olga,
#   Bondareva,
#   ,,
#   born,
#   ",
#   Olga,
#   Nikolaevna,
#   Bondareva,
#   ",
#   on,
#   April,
#   27th,
#   ,,
#   1937,
#   and,
#   known,
#   for,
#   the,
#   Bondareva,
#   -,
#   Shapley,
#   theorem,
#   ,,
#   died,
#   in,
#   Saint,
#   Petersburg,
#   .],
#  [Fellowship,
#   of,
#   the,
#   Ring,
#   ,,
#   a,
#   fantasy,
#   novel,
#   created,
#   by,
#   J.R.R.,
#   Tolkien,
#   was,
#   released,
#   on,
#   July,
#   29,
#   ,,
#   1954,
#   ;,
#   the,
#   Hobbit,
#   came,
#   before,
#   The,
#   Fellowship,
#   of,
#   the,
#   Ring,
#   .],
#  [J.R.R.,
#   Tolkien,
#   is,
#   the,
#   author,
#   of,
#   The,
#   Fellowship,
#   of,
#   the,
#   Ring,
#   published,
#   on,
#   July,
#   29,
#   ,,
#   1954,
#   .],
#  [This,
#   book,
#   belongs,
#   to,
#   the,
#   fantasy,
#   genre,
#   and,
#   came,
#   after,
#   The,
#   Hobbit,
#   .],
#  [Fantasy,
#   is,
#   The,
#   Fellowship,
#   of,
#   the,
#   Ring,
#   's,
#   genre,
#   ,,
#   and,
#   it,
#   was,
#   released,
#   on,
#   July,
#   29,
#   ,,
#   1954,
#   .],
#  [The,
#   Fellowship,
#   of,
#   the,
#   Ring,
#   was,
#   written,
#   by,
#   J.R.R.,
#   Tolkien,
#   and,
#   was,
#   preceded,
#   by,
#   the,
#   Hobbit,
#   .],
#  [Train,
#   's,
#   hit,
#   Mermaid,
#   was,
#   put,
#   out,
#   by,
#   the,
#   Sony,
#   Music,
#   Entertainment,
#   record,
#   label,
#   ,,
#   was,
#   written,
#   by,
#   Amund,
#   Bjørklund,
#   with,
#   the,
#   producer,
#   Stargate,
#   .],
#  [Train,
#   followed,
#   Mermaid,
#   with,
#   Imagine,
#   ,,
#   a,
#   song,
#   by,
#   John,
#   Lennon,
#   where,
#   Mermaid,
#   was,
#   produced,
#   by,
#   the,
#   Espionage,
#   production,
#   team,
#   .],
#  [The,
#   song,
#   Mermaid,
#   ,,
#   by,
#   Train,
#   ,,
#   is,
#   a,
#   Sony,
#   Music,
#   Entertainment,
#   release,
#   produced,
#   by,
#   Stargate,
#   along,
#   with,
#   the,
#   production,
#   team,
#   Espionage,
#   .],
#  [Mermaid,
#   ,,
#   written,
#   by,
#   Amund,
#   Bjorklund,
#   ,,
#   is,
#   followed,
#   by,
#   John,
#   Lennon,
#   's,
#   Imagine,
#   .],
#  [The,
#   Train,
#   song,
#   Mermaid,
#   written,
#   by,
#   Amund,
#   Bjørklund,
#   and,
#   production,
#   team,
#   Stargate,
#   was,
#   produced,
#   by,
#   the,
#   production,
#   team,
#   Espionage,
#   and,
#   released,
#   under,
#   the,
#   record,
#   label,
#   Sony,
#   Music,
#   Entertainment,
#   .],
#  [It,
#   was,
#   followed,
#   by,
#   the,
#   release,
#   of,
#   Imagine,
#   by,
#   John,
#   Lennon,
#   performed,
#   by,
#   Train,
#   .],
#  [Year,
#   of,
#   No,
#   Light,
#   produced,
#   an,
#   album,
#   called,
#   Nord,
#   on,
#   6/9/2006,
#   which,
#   is,
#   58.41,
#   minutes,
#   long,
#   .],
#  [They,
#   came,
#   out,
#   with,
#   the,
#   Demo,
#   2004,
#   album,
#   first,
#   ,,
#   followed,
#   by,
#   Nord,
#   ,,
#   and,
#   then,
#   the,
#   album,
#   Live,
#   at,
#   Roadburn,
#   in,
#   2008.The,
#   Year,
#   of,
#   No,
#   Light,
#   album,
#   Nord,
#   with,
#   runtime,
#   of,
#   58.41,
#   minutes,
#   was,
#   released,
#   by,
#   the,
#   artist,
#   on,
#   the,
#   date,
#   2006,
#   -,
#   09,
#   -,
#   06,
#   .],
#  [It,
#   was,
#   preceded,
#   by,
#   Year,
#   of,
#   No,
#   Light,
#   's,
#   album,
#   Demo,
#   2004,
#   and,
#   followed,
#   by,
#   Year,
#   of,
#   No,
#   Light,
#   's,
#   album,
#   Live,
#   at,
#   Roadburn,
#   2008.The,
#   album,
#   Nord,
#   by,
#   Year,
#   of,
#   No,
#   Light,
#   with,
#   runtime,
#   of,
#   58,
#   minutes,
#   and,
#   41,
#   seconds,
#   was,
#   released,
#   on,
#   September,
#   6,
#   ,,
#   2006.The,
#   album,
#   Nord,
#   was,
#   preceded,
#   by,
#   the,
#   album,
#   Demo,
#   2004,
#   and,
#   followed,
#   by,
#   Live,
#   at,
#   Roadburn,
#   2008,
#   .The],
#  [11th,
#   Mississippi,
#   Infantry,
#   Monument,
#   is,
#   placed,
#   in,
#   the,
#   municipality,
#   of,
#   Gettysburg,
#   in,
#   Pennsylvania,
#   ,,
#   in,
#   Adams,
#   County,
#   ,,
#   USA,
#   .],
#  [Adams,
#   County,
#   has,
#   Carroll,
#   County,
#   ,,
#   Maryland,
#   to,
#   its,
#   southeast,
#   and,
#   the,
#   11th,
#   Mississippi,
#   Infantry,
#   Monument,
#   is,
#   categorized,
#   as,
#   a,
#   Contributing,
#   Property,
#   .],
#  [The,
#   11th,
#   Mississippi,
#   Infantry,
#   Monument,
#   is,
#   categorised,
#   as,
#   a,
#   contributing,
#   property,
#   and,
#   stands,
#   in,
#   Adams,
#   County,
#   ,,
#   Pennsylvania,
#   in,
#   the,
#   municipality,
#   of,
#   Gettysburg,
#   in,
#   the,
#   USA,
#   .],
#  [Carroll, County, Maryland, is, southeast, of, Adams, County, .],
#  [The,
#   11th,
#   Mississippi,
#   Infantry,
#   Monument,
#   's,
#   location,
#   is,
#   Adams,
#   County,
#   ,,
#   Pennsylvania,
#   ,,
#   USA,
#   ,,
#   in,
#   the,
#   municipality,
#   of,
#   Gettysburg,
#   .],
#  [To,
#   the,
#   southeast,
#   of,
#   Adams,
#   County,
#   ,,
#   lies,
#   Carroll,
#   County,
#   ,,
#   Maryland,
#   .],
#  [The,
#   11th,
#   Mississippi,
#   Infantry,
#   Monument,
#   is,
#   a,
#   contributing,
#   property,
#   .],
#  [Israeli,
#   national,
#   Liselotte,
#   Grschebina,
#   was,
#   born,
#   in,
#   the,
#   German,
#   Empire,
#   and,
#   died,
#   in,
#   Israel,
#   on,
#   June,
#   14,
#   ,,
#   1994.Liselotte,
#   Grschebina,
#   died,
#   in,
#   Israel,
#   on,
#   June,
#   14,
#   ,,
#   1994,
#   .],
#  [Though,
#   she,
#   had,
#   Israeli,
#   nationality,
#   ,,
#   she,
#   was,
#   born,
#   in,
#   the,
#   German,
#   Empire,
#   .],
#  [Liselotte,
#   Grschebina,
#   was,
#   an,
#   Israeli,
#   national,
#   born,
#   in,
#   the,
#   German,
#   Empire,
#   .],
#  [She, died, on, June, 14, ,, 1994, in, Israel, .],
#  [Located,
#   in,
#   King,
#   of,
#   Prussia,
#   ,,
#   Pennsylvania,
#   ,,
#   AmeriGas,
#   is,
#   an,
#   energy,
#   company,
#   that,
#   serves,
#   the,
#   United,
#   States,
#   .],
#  [AmeriGas,
#   has,
#   an,
#   operating,
#   income,
#   of,
#   $,
#   380,700,000,
#   and,
#   net,
#   income,
#   of,
#   $,
#   211,200,000.Currently,
#   serving,
#   all,
#   regions,
#   of,
#   the,
#   United,
#   States,
#   ,,
#   AmeriGas,
#   is,
#   headquartered,
#   in,
#   the,
#   King,
#   of,
#   Prussia,
#   ,,
#   Pennsylvania,
#   in,
#   the,
#   United,
#   States,
#   .],
#  [An,
#   established,
#   company,
#   in,
#   the,
#   energy,
#   industry,
#   ,,
#   AmeriGas,
#   has,
#   an,
#   operating,
#   income,
#   of,
#   $,
#   380,700,000,
#   and,
#   a,
#   net,
#   income,
#   of,
#   $,
#   211,200,000.A,
#   US,
#   provider,
#   in,
#   the,
#   energy,
#   industry,
#   ,,
#   AmeriGas,
#   is,
#   located,
#   in,
#   the,
#   King,
#   of,
#   Prussia,
#   ,,
#   Pennsylvania,
#   in,
#   the,
#   United,
#   States,
#   ,,
#   and,
#   has,
#   an,
#   operating,
#   income,
#   of,
#   $,
#   380,700,000,
#   with,
#   a,
#   net,
#   income,
#   of,
#   $,
#   211,200,000.Discovered,
#   in,
#   1927,
#   by,
#   Grigory,
#   Neujmin,
#   ,,
#   1147,
#   Stavropolis,
#   has,
#   an,
#   apoapsis,
#   of,
#   418476000000,
#   and,
#   an,
#   orbital,
#   period,
#   of,
#   1249.6,
#   days,
#   .],
#  [The,
#   asteroid,
#   1147,
#   Stavropolis,
#   was,
#   discovered,
#   by,
#   Grigory,
#   Neujmin,
#   on,
#   the,
#   11th,
#   of,
#   June,
#   1929,
#   .],
#  [It,
#   has,
#   an,
#   orbital,
#   period,
#   of,
#   1249.6,
#   days,
#   and,
#   an,
#   apoapsis,
#   of,
#   418476000000.0.1147,
#   Stavropolis,
#   is,
#   an,
#   asteroid,
#   ,,
#   discovered,
#   on,
#   11,
#   June,
#   1929,
#   by,
#   Grigory,
#   Neujmin,
#   .],
#  [Its, apoapsis, is, 418476000000.0, AU, and, the, orbital, period, is],
#  [1249.6.Ciudad,
#   Ayala,
#   is,
#   a,
#   city,
#   which,
#   is,
#   located,
#   1147,
#   m,
#   above,
#   sea,
#   level,
#   and,
#   has,
#   a,
#   UTC,
#   offset,
#   of,
#   -6,
#   .],
#  [Ciudad,
#   Ayala,
#   is,
#   located,
#   in,
#   Mexico,
#   and,
#   has,
#   a,
#   leader,
#   called,
#   the,
#   Governator,
#   .],
#  [Ciudad,
#   Ayala,
#   ruled,
#   by,
#   governator,
#   is,
#   in,
#   the,
#   country,
#   of,
#   Mexico,
#   with,
#   offset,
#   of,
#   -6,
#   as,
#   well,
#   as,
#   sea,
#   level,
#   of,
#   1147.0.Ciudad,
#   Ayala,
#   is,
#   located,
#   in,
#   Mexico,
#   ,,
#   with,
#   a,
#   UTC,
#   offset],
#  [-6, .],
#  [The,
#   city,
#   has,
#   an,
#   elevation,
#   of,
#   1147.0,
#   above,
#   sea,
#   level,
#   and,
#   its,
#   leader,
#   is,
#   called,
#   the,
#   governator,
#   .],
#  [Morelos, ,, in, Ciudad, Ayala, ,, is, in, the, UTC, offset, -6, timezone, .],
#  [Ciudad,
#   Ayala,
#   ,,
#   which,
#   has,
#   a,
#   UTC,
#   offset,
#   of,
#   -6,
#   ,,
#   is,
#   part,
#   of,
#   Morelos,
#   .],
#  [The,
#   UTC,
#   offset,
#   of,
#   Ciudad,
#   Ayala,
#   which,
#   is,
#   part,
#   of,
#   Morelos,
#   is,
#   -6.Lady],
#  [Anne, Monson, 's, spouse, was, George, Monson, .],
#  [The, spouse, of, George, Monson, is, Lady, Anne, Monson, .],
#  [Lady, Anne, Monson, is, the, spouse, of, George, Monson, .],
#  [With,
#   17000,
#   members,
#   ,,
#   Agremiação,
#   Sportiva,
#   Arapiraquense,
#   play,
#   in,
#   the,
#   Campeonato,
#   Brasileiro,
#   Série,
#   C,
#   league,
#   ,,
#   of,
#   which,
#   Vila,
#   Nova,
#   Futebol,
#   Clube,
#   have,
#   been,
#   champions,
#   .],
#  [Agremiação,
#   Sportiva,
#   Arapiraquense,
#   is,
#   a,
#   club,
#   of,
#   17000,
#   members,
#   in,
#   the,
#   Campeonato,
#   Brasileiro,
#   Série,
#   C,
#   league,
#   along,
#   with,
#   the,
#   Vila,
#   Nova,
#   Futebol,
#   Clube,
#   .],
#  [Agremiação,
#   Sportiva,
#   Arapiraquense,
#   play,
#   in,
#   the,
#   Campeonato,
#   Brasileiro,
#   Série,
#   C,
#   league,
#   .],
#  [The, club, currently, has, 17000, members, .],
#  [The, Vila, Nova, Futebol, Clube, were, champions, of, the, league, .],
#  [In,
#   the,
#   region,
#   of,
#   Jalisco,
#   ,,
#   Mexico,
#   ,,
#   is,
#   a,
#   food,
#   dish,
#   served,
#   for,
#   dessert,
#   called,
#   Bionico,
#   .],
#  [Bionico,
#   ,,
#   a,
#   food,
#   found,
#   in,
#   the,
#   Jalisco,
#   region,
#   of,
#   Mexico,
#   ,,
#   is,
#   served,
#   at,
#   the,
#   dessert,
#   course,
#   .],
#  [Bionico,
#   (,
#   a,
#   dessert,
#   ),
#   is,
#   a,
#   food,
#   found,
#   in,
#   the,
#   region,
#   of,
#   Jalisco,
#   in,
#   Mexico,
#   .],
#  [The,
#   Quine,
#   Tapes,
#   was,
#   produced,
#   by,
#   The,
#   Velvet,
#   Underground,
#   in,
#   St.,
#   Louis,
#   ,,
#   Missouri,
#   ,,
#   United,
#   States,
#   ;,
#   its,
#   genre,
#   is,
#   rock,
#   .],
#  [The,
#   rock,
#   album,
#   Bootleg,
#   Series,
#   Volume,
#   1,
#   :,
#   The,
#   Quine,
#   Tapes,
#   was,
#   produced,
#   and,
#   recorded,
#   by,
#   the,
#   Velvet,
#   Underground,
#   in,
#   St.,
#   Louis,
#   ,,
#   Missouri,
#   ,,
#   USA.The,
#   Velvet,
#   Underground,
#   recorded,
#   Rock,
#   album,
#   The,
#   Bootleg,
#   Series,
#   Volume],
#  [I,
#   :,
#   The,
#   Quine,
#   Tapes,
#   in,
#   St.,
#   Louis,
#   ,,
#   Missouri,
#   ,,
#   USA.Gdynia,
#   city,
#   in,
#   Poland,
#   has,
#   time,
#   zone,
#   of,
#   UTC,
#   +2,
#   .Gdynia],
#  [in,
#   Poland,
#   has,
#   a,
#   UTC,
#   (,
#   Coordinate,
#   Universal,
#   Time,
#   ),
#   offset,
#   of,
#   +2.Gdynia,
#   ,,
#   Poland,
#   has,
#   a,
#   UTC,
#   of,
#   +02:00.Year,
#   of,
#   No,
#   Light,
#   is,
#   a,
#   band,
#   whose,
#   members,
#   include,
#   a,
#   former,
#   guitarist,
#   for,
#   Monarch,
#   has,
#   created,
#   an,
#   album,
#   called,
#   Nord,
#   .],
#  [Nord,
#   is,
#   an,
#   album,
#   by,
#   Year,
#   of,
#   No,
#   Light,
#   ,,
#   which,
#   is,
#   associated,
#   with,
#   the,
#   band,
#   Monarch,
#   .],
#  [Born,
#   in,
#   Zaoyang,
#   city,
#   ,,
#   Hubei,
#   ,,
#   Nie,
#   Haisheng,
#   participated,
#   in,
#   the,
#   Shenzhou,
#   6,
#   mission,
#   .],
#  [Shenzhou,
#   6,
#   crew,
#   member,
#   Nie,
#   Haisheng,
#   was,
#   born,
#   in,
#   Zaoyang,
#   in,
#   Hubei,
#   province,
#   .],
#  [Born,
#   in,
#   Zaoyang,
#   ,,
#   Hubei,
#   ,,
#   Nie,
#   Haisheng,
#   participated,
#   in,
#   Shenzhou,
#   6.Aleksandr,
#   Prudnikov,
#   ,,
#   185,
#   cm,
#   tall,
#   played,
#   for,
#   FC,
#   Spartak,
#   Moscow,
#   's,
#   youth,
#   team,
#   .],
#  [FC, Spartak, Moscow, is, based, in, the, Otkrytiye, Arena, .],
#  [Aleksandr,
#   Prudnikov,
#   who,
#   is,
#   185,
#   cm,
#   tall,
#   is,
#   a,
#   member,
#   of,
#   the,
#   youth,
#   side,
#   of,
#   FC,
#   Spartak,
#   Moscow,
#   .],
#  [The, home, ground, of, FC, Spartak, Moscow, is, Otkrytiye, Arena, .],
#  [Aleksandr,
#   Prudnikov,
#   is,
#   185.0,
#   cm,
#   tall,
#   and,
#   played,
#   for,
#   the,
#   FC,
#   Spartak,
#   Moscow,
#   at,
#   the,
#   Otkrytiye,
#   Arena,
#   .],
#  [The,
#   Pontiac,
#   Rageous,
#   assembled,
#   in,
#   Michigan,
#   with,
#   assembly,
#   line,
#   in,
#   Detroit,
#   was,
#   last,
#   produced,
#   in,
#   1997.Ending,
#   its,
#   production,
#   in,
#   1997,
#   ,,
#   the,
#   Pontiac,
#   Rageous,
#   was,
#   assembled,
#   in,
#   Detroit,
#   ,,
#   Michigan,
#   .],
#  [Ending,
#   in,
#   1997,
#   ,,
#   the,
#   Pontiac,
#   Rageous,
#   was,
#   assembled,
#   in,
#   Detroit,
#   ,,
#   Michigan,
#   .],
#  [The,
#   total,
#   area,
#   of,
#   the,
#   city,
#   of,
#   Detroit,
#   is,
#   370.03,
#   square,
#   kilometers,
#   .],
#  [Detroit, has, a, total, area, of, 370.03, square, kilometers, .],
#  [English,
#   Without,
#   Tears,
#   ,,
#   a,
#   film,
#   directed,
#   by,
#   Harold,
#   French,
#   and,
#   composed,
#   by,
#   Nicholas,
#   Brodszky,
#   ,,
#   was,
#   released,
#   on,
#   07,
#   -,
#   28,
#   -,
#   1944,
#   .],
#  [The, film, length, is, 89, minutes, .],
#  [The,
#   89,
#   minute,
#   movie,
#   ´,
#   English,
#   Without,
#   Tears,
#   ´,
#   was,
#   directed,
#   by,
#   Harold,
#   French,
#   ,,
#   and,
#   released,
#   on,
#   7,
#   -,
#   28,
#   -,
#   1944,
#   .],
#  [The,
#   songs,
#   used,
#   throughout,
#   the,
#   movie,
#   were,
#   composed,
#   by,
#   Nicholas,
#   Brodszky,
#   .],
#  [English,
#   Without,
#   Tears,
#   is,
#   a,
#   movie,
#   directed,
#   by,
#   Harold,
#   French,
#   and,
#   musically,
#   composed,
#   by,
#   Nicholas,
#   Brodszky,
#   .],
#  [It,
#   runs,
#   for,
#   89,
#   minutes,
#   and,
#   was,
#   released,
#   on,
#   July,
#   7th,
#   ,,
#   1944.GMA,
#   New,
#   Media,
#   is,
#   located,
#   in,
#   the,
#   GMA,
#   Network,
#   Center,
#   .],
#  [GMA,
#   New,
#   Media,
#   headquarters,
#   are,
#   located,
#   in,
#   the,
#   GMA,
#   Network,
#   Center,
#   .],
#  [GMA],
#  [New, Media, is, located, inside, GMA, Network, Center, .],
#  [Olga, Bondareva, 's, professional, field, is, Economics, .],
#  [Olga, Bondareva, is, an, economist, .],
#  [Olga, Bondareva, currently, works, in, the, field, of, Economics, .],
#  [The,
#   music,
#   of,
#   the,
#   film,
#   English,
#   Without,
#   Tears,
#   is,
#   composed,
#   by,
#   Nicholas,
#   Brodszky,
#   .],
#  [Nicholas,
#   Brodszky,
#   composed,
#   music,
#   of,
#   the,
#   movie,
#   English,
#   Without,
#   Tears,
#   .],
#  [Nicholas,
#   Brodszky,
#   was,
#   a,
#   composer,
#   of,
#   the,
#   songs,
#   that,
#   were,
#   used,
#   in,
#   English,
#   Without,
#   Tears,
#   .],
#  [The,
#   BBC,
#   (,
#   located,
#   in,
#   Broadcasting,
#   House,
#   in,
#   London,
#   ),
#   last,
#   aired,
#   creator,
#   Steve,
#   Bright,
#   's,
#   Bananaman,
#   ,,
#   starring,
#   Bill,
#   Oddie,
#   ,,
#   on,
#   April,
#   15th,
#   ,,
#   1986.The,
#   BBC,
#   (,
#   Broadcasting,
#   House,
#   ),
#   is,
#   based,
#   in,
#   London,
#   .],
#  [The,
#   show,
#   Bananaman,
#   that,
#   starred,
#   Bill,
#   Oddie,
#   was,
#   broadcasted,
#   by,
#   BBC,
#   and,
#   last,
#   aired,
#   on,
#   April,
#   15th,
#   ,,
#   1986,
#   .],
#  [The, creator, of, Bananaman, was, Steve, Bright, .],
#  [Broadcasting,
#   House,
#   is,
#   also,
#   known,
#   as,
#   the,
#   Headquarters,
#   of,
#   the,
#   BBC,
#   .],
#  [One,
#   of,
#   the,
#   BBC,
#   television,
#   shows,
#   ,,
#   Bananaman,
#   was,
#   created,
#   by,
#   Steve,
#   Bright,
#   and,
#   starred,
#   Bill,
#   Oddie,
#   .],
#  [Bananaman,
#   's,
#   last,
#   episode,
#   was,
#   broadcast,
#   on,
#   April,
#   15,
#   ,,
#   1986.Montreal,
#   Locomotive,
#   Works,
#   built,
#   the,
#   ALCO,
#   RS-3,
#   between,
#   May,
#   1950,
#   and,
#   August,
#   1956.The],
#  [ALCO,
#   RS-3,
#   ,,
#   built,
#   by,
#   Montreal,
#   Locomotive,
#   Works,
#   ,,
#   was,
#   produced,
#   between,
#   May,
#   1950,
#   and,
#   August,
#   1956.The],
#  [ALCO,
#   RS-3,
#   was,
#   built,
#   by,
#   the,
#   Montreal,
#   Locomotive,
#   Works,
#   and,
#   was,
#   produced,
#   between,
#   May,
#   1950,
#   and,
#   August,
#   1956.Agremiacao],
#  [Sportiva,
#   Arapiraquense,
#   has,
#   17000,
#   members,
#   and,
#   play,
#   in,
#   the,
#   Campeonato,
#   Brasileiro,
#   Serie,
#   C,
#   league,
#   .],
#  [The, champions, of, the, league, have, been, Vila, Nova, Futebol, Clube, .],
#  [Agremiação,
#   Sportiva,
#   Arapiraquense,
#   has,
#   17000,
#   members,
#   and,
#   play,
#   in,
#   the,
#   Campeonato,
#   Brasileiro,
#   Série,
#   C,
#   league,
#   ,,
#   which,
#   Vila,
#   Nova,
#   Futebol,
#   Clube,
#   are,
#   the,
#   champions,
#   of,
#   .],
#  [Agremiacao,
#   Sportiva,
#   Arapiraquense,
#   has,
#   17000,
#   members,
#   and,
#   plays,
#   in,
#   the,
#   Campeonato,
#   Brasileiro,
#   Serie,
#   C,
#   league,
#   of,
#   which,
#   the,
#   Vila,
#   Nova,
#   Futebol,
#   Clube,
#   were,
#   champions,
#   .],
#  [Cecil, Parker, had, a, main, role, in, It, 's, Great, to, Be, Young, .],
#  [Cecil,
#   Parker,
#   starred,
#   in,
#   the,
#   1956,
#   movie,
#   It,
#   's,
#   Great,
#   to,
#   Be,
#   Young,
#   .],
#  [It, 's, Great, to, be, Young, is, a, 1956, film, starring, Cecil, Parker, .],
#  [The, movie, ", Super, Capers, ", was, directed, by, Ray, Griggs, .],
#  [Super, Capers, is, directed, by, Ray, Griggs, .],
#  [Ray, Griggs, is, the, director, of, Super, Capers, .],
#  [The,
#   sludge,
#   metal,
#   and,
#   post,
#   metal,
#   album,
#   Nord,
#   was,
#   produced,
#   and,
#   created,
#   by,
#   the,
#   artist,
#   Year,
#   of,
#   No,
#   Light,
#   and,
#   was,
#   released,
#   by,
#   the,
#   record,
#   label,
#   Crucial,
#   blast,
#   on,
#   06,
#   -,
#   09,
#   -,
#   2006,
#   .],
#  [It,
#   was,
#   followed,
#   by,
#   the,
#   album,
#   Live,
#   at,
#   Roadburn,
#   2008.The,
#   Year,
#   of,
#   No,
#   Light,
#   self,
#   produced,
#   album,
#   Nord,
#   ,,
#   a,
#   sludge,
#   and,
#   post,
#   -,
#   metal,
#   genre,
#   was,
#   released,
#   on,
#   September,
#   6,
#   ,,
#   2006,
#   .],
#  [Its,
#   record,
#   label,
#   is,
#   Crucial,
#   Blast,
#   and,
#   was,
#   followed,
#   by,
#   Live,
#   at,
#   Roadburn,
#   2008.The,
#   self,
#   -,
#   produced,
#   Year,
#   of,
#   No,
#   Light,
#   post,
#   metal,
#   and,
#   sludge,
#   metal,
#   album,
#   Nord,
#   was,
#   released,
#   on,
#   2006,
#   -,
#   09,
# ...
#   plays,
#   for,
#   FC,
#   Amkar,
#   Perm,
#   ,,
#   which,
#   is,
#   managed,
#   by,
#   Gadzhi,
#   Gadzhiyev,
#   .],
#  [Aleksandr,
#   Prudnikov,
#   is,
#   also,
#   a,
#   member,
#   of,
#   the,
#   youth,
#   side,
#   of,
#   FC,
#   Spartak,
#   Moscow,
#   .],
#  [The,
#   Adolfo,
#   Suárez,
#   Madrid,
#   –,
#   Barajas,
#   Airport,
#   in,
#   Alcobendas,
#   ,,
#   Madrid,
#   ,,
#   Spain,
#   operated,
#   by,
#   ENAIRE,
#   has,
#   a,
#   runway,
#   called,
#   14R/32L,
#   with,
#   the,
#   length,
#   of,
#   4,349.Adolfo,
#   Suárez,
#   Madrid,
#   –,
#   Barajas,
#   Airport,
#   is,
#   located,
#   in,
#   Alcobendas,
#   .],
#  [This,
#   airport,
#   is,
#   operated,
#   by,
#   ENAIRE,
#   ,,
#   which,
#   is,
#   located,
#   in,
#   Madrid,
#   ,,
#   Spain,
#   .],
#  [The, runway, is, named, 14R/32L, and, has, a, length, of, 4,349, meters, .],
#  [Adolfo,
#   Suarez,
#   Madrid,
#   -,
#   Barajas,
#   Airport,
#   is,
#   operated,
#   by,
#   ENAIRE,
#   which,
#   is,
#   located,
#   in,
#   Alcobendas,
#   in,
#   Madrid,
#   ,,
#   Spain,
#   .],
#  [The,
#   runway,
#   length,
#   and,
#   the,
#   name,
#   of,
#   the,
#   runway,
#   of,
#   the,
#   airport,
#   is,
#   4349.0,
#   .],
#  [and,
#   14R/32L.The,
#   drum,
#   kit,
#   is,
#   an,
#   instrument,
#   used,
#   in,
#   the,
#   punk,
#   blues,
#   genre,
#   .],
#  [The, drum, kit, is, an, instrument, of, punk, blues, .],
#  [Punk, blues, usually, uses, a, drum, kit, .],
#  [Liselotte,
#   Grschebina,
#   was,
#   born,
#   in,
#   Karlsruhe,
#   and,
#   died,
#   in,
#   Israel,
#   on,
#   June,
#   14th,
#   ,,
#   1994.Liselotte,
#   Grschebina,
#   was,
#   born,
#   in,
#   Karlsruhe,
#   and,
#   died,
#   on,
#   June,
#   14th,
#   ,,
#   1994,
#   in,
#   Israel,
#   .],
#  [One,
#   of,
#   the,
#   official,
#   languages,
#   of,
#   Israel,
#   Is,
#   Modern,
#   Standard,
#   Arabic,
#   .],
#  [The, official, language, of, Israel, is, Modern, Standard, Arabic, .],
#  [Liselotte,
#   Grschebina,
#   was,
#   born,
#   in,
#   Karlsruhe,
#   which,
#   is,
#   known,
#   for,
#   having,
#   Oberbürgermeister,
#   as,
#   a,
#   leader,
#   .],
#  [Liselotte,
#   Grschebina,
#   was,
#   born,
#   in,
#   Karlsruhe,
#   ,,
#   which,
#   has,
#   Oberbürgermeister,
#   as,
#   its,
#   leader,
#   .],
#  [Karlsruhe,
#   ,,
#   the,
#   birthplace,
#   of,
#   Liselotte,
#   Grschebina,
#   ,,
#   has,
#   a,
#   leader,
#   named,
#   Oberburgermeister,
#   .],
#  [The,
#   Acharya,
#   Institute,
#   of,
#   Technology,
#   is,
#   affiliated,
#   to,
#   Visvesvaraya,
#   Technological,
#   University,
#   ,,
#   and,
#   offers,
#   Tennis,
#   as,
#   a,
#   sport,
#   .],
#  [The,
#   All,
#   India,
#   Council,
#   for,
#   Technical,
#   Education,
#   which,
#   is,
#   located,
#   in,
#   Mumbai,
#   gave,
#   the,
#   institute,
#   Technical,
#   Campus,
#   status,
#   .],
#  [The,
#   address,
#   for,
#   the,
#   campus,
#   is,
#   :,
#   Soldevanahalli,
#   ,,
#   Acharya,
#   Dr.,
#   Sarvapalli,
#   Radhakrishnan,
#   Road,
#   ,,
#   Hessarghatta,
#   Main,
#   Road,
#   ,,
#   Bangalore,
#   -,
#   560090.Tennis,
#   is,
#   one,
#   of,
#   the,
#   sports,
#   offered,
#   at,
#   the,
#   Acharya,
#   Institute,
#   of,
#   Technology,
#   which,
#   is,
#   affiliated,
#   to,
#   Visvesvaraya,
#   Technological,
#   University,
#   .],
#  [The,
#   All,
#   India,
#   Council,
#   for,
#   Technical,
#   Education,
#   which,
#   is,
#   located,
#   in,
#   Mumbai,
#   gave,
#   the,
#   institute,
#   Technical,
#   Campus,
#   status,
#   .],
#  [The,
#   address,
#   for,
#   the,
#   campus,
#   is,
#   :,
#   Soldevanahalli,
#   ,,
#   Acharya,
#   Dr.,
#   Sarvapalli,
#   Radhakrishnan,
#   Road,
#   ,,
#   Hessarghatta,
#   Main,
#   Road,
#   ,,
#   Bangalore,
#   -,
#   560090.Acharya,
#   Institute,
#   of,
#   Technology,
#   was,
#   given,
#   the,
#   ',
#   Technical,
#   Campus,
#   ',
#   status,
#   by,
#   All,
#   India,
#   Council,
#   for,
#   Technical,
#   Education,
#   ,,
#   has,
#   tennis,
#   as,
#   one,
#   of,
#   their,
#   sports,
#   offered,
#   and,
#   is,
#   affiliated,
#   with,
#   the,
#   Visvesvaraya,
#   Technological,
#   University,
#   .],
#  [All,
#   India,
#   Council,
#   for,
#   Technical,
#   Education,
#   is,
#   located,
#   in,
#   Mumbai,
#   and,
#   the,
#   campus,
#   of,
#   the,
#   Acharya,
#   Institute,
#   of,
#   Technology,
#   is,
#   located,
#   at,
#   Soldevanahalli,
#   ,,
#   Acharya,
#   Dr.,
#   Sarvapalli,
#   Radhakrishnan,
#   Road,
#   ,,
#   Hessarghatta,
#   Main,
#   Road,
#   ,,
#   Bangalore,
#   –,
#   560090.Tom,
#   Sizemore,
#   stars,
#   in,
#   Super,
#   Capers,
#   which,
#   starred,
#   Michael,
#   Rooker,
#   .],
#  [The,
#   film,
#   Super,
#   Capers,
#   stars,
#   both,
#   Michael,
#   Rooker,
#   and,
#   Tom,
#   Sizemore,
#   .],
#  [Tom,
#   Sizemore,
#   stars,
#   in,
#   Super,
#   Capers,
#   ,,
#   a,
#   film,
#   in,
#   which,
#   Michael,
#   Rooker,
#   also,
#   plays,
#   in,
#   .],
#  [Super,
#   Capers,
#   starred,
#   Michael,
#   Rooker,
#   ,,
#   who,
#   was,
#   born,
#   in,
#   Jasper,
#   ,,
#   Alabama,
#   .],
#  [Super,
#   Capers,
#   is,
#   a,
#   film,
#   starring,
#   Michael,
#   Rooker,
#   ,,
#   who,
#   was,
#   born,
#   in,
#   Jasper,
#   ,,
#   Alabama,
#   .],
#  [Michael,
#   Rooker,
#   ,,
#   who,
#   played,
#   in,
#   Super,
#   Capers,
#   ,,
#   was,
#   born,
#   in,
#   Jasper,
#   ,,
#   Alabama,
#   .],
#  [Grigory, Neujmin, discovered, 1147, Stavropolis, on, June, 11th, ,, 1929, .],
#  [It,
#   has,
#   an,
#   apoapsis,
#   of,
#   418476000000.0,
#   and,
#   an,
#   absolute,
#   magnitude,
#   of,
#   11.5.On,
#   June,
#   11,
#   ,,
#   1929,
#   ,,
#   Grigory,
#   Neujmin,
#   discovered,
#   the,
#   asteroid,
#   1147,
#   Stavropolis,
#   .],
#  [It,
#   has,
#   an,
#   apoapsis,
#   of,
#   418476000000.0,
#   and,
#   an,
#   absolute,
#   magnitude,
#   of,
#   11.5.Grigory,
#   Neujmin,
#   discovered,
#   the,
#   asteroid,
#   1147,
#   Stavropolis,
#   on,
#   June,
#   11,
#   ,,
#   1929,
#   .],
#  [It,
#   has,
#   an,
#   absolute,
#   magnitude,
#   of,
#   11.5,
#   with,
#   418476000000.0,
#   AU.After,
#   releasing,
#   their,
#   album,
#   Squeeze,
#   ,,
#   music,
#   group,
#   the,
#   Velvet,
#   Underground,
#   produced,
#   and,
#   released,
#   rock,
#   music,
#   album,
#   Bootleg,
#   Series,
#   Volume,
#   1,
#   :,
#   The,
#   Quine,
#   Tapes,
#   ,,
#   which,
#   they,
#   recorded,
#   in,
#   St,
#   Louis,
#   Missouri,
#   ,,
#   USA],
#  [The,
#   album,
#   was,
#   released,
#   on,
#   2001,
#   -,
#   10,
#   -,
#   16,
#   under,
#   the,
#   Polydor,
#   and,
#   Universal,
#   Music,
#   Group,
#   record,
#   labels,
#   and,
#   has,
#   a,
#   total,
#   run,
#   time,
#   of,
#   230:05,
#   minutes,
#   .],
#  [Bootleg,
#   Series,
#   Volume,
#   1,
#   :,
#   The,
#   Quine,
#   Tapes,
#   with,
#   run,
#   time,
#   of,
#   230:05,
#   was,
#   recorded,
#   under,
#   the,
#   Polydor,
#   Records,
#   and,
#   Universal,
#   Music,
#   Group,
#   record,
#   label,
#   in,
#   St.,
#   Louis,
#   ,,
#   Missouri,
#   ,,
#   United,
#   States,
#   and,
#   released,
#   on,
#   October,
#   ,,
#   16,
#   ,,
#   2001,
#   .],
#  [It, was, preceded, by, Squeeze, by, The, Velvet, Underground, .],
#  [The,
#   Bootleg,
#   Series,
#   Volume,
#   I,
#   :,
#   The,
#   Quine,
#   Tapes,
#   with,
#   runtime,
#   of,
#   230.05,
#   minutes,
#   was,
#   recorded,
#   in,
#   St.,
#   Louis,
#   Missouri,
#   ,,
#   United,
#   States,
#   and,
#   released,
#   on,
#   10,
#   -,
#   16,
#   -,
#   2001,
#   .],
#  [Recorded,
#   through,
#   Polydor,
#   Records,
#   and,
#   Universal,
#   Music,
#   Group,
#   record,
#   label,
#   the,
#   album,
#   was,
#   preceded,
#   by,
#   the,
#   album,
#   Squeeze.1147,
#   Stavropolis,
#   discovered,
#   on,
#   June,
#   11,
#   ,,
#   1929,
#   with,
#   rotation,
#   period,
#   of,
#   20378.5,
#   has,
#   a,
#   periapsis,
#   of,
#   260855000000.0,
#   and,
#   apoapsis,
#   of,
#   418476000000.0,
#   .],
#  [The,
#   orbital,
#   period,
#   of,
#   the,
#   asteroid,
#   is,
#   1249.6,
#   days.1147,
#   Stavropolis,
#   is,
#   an,
#   asteroid,
#   ,,
#   discovered,
#   on,
#   June,
#   1929,
#   .],
#  [It, has, a, rotation, period, of, 20378.5, .],
#  [Its,
#   periapsis,
#   is,
#   260855000000.0,
#   ,,
#   the,
#   apoapsis,
#   of,
#   the,
#   asteroid,
#   is,
#   418476000000,
#   AU,
#   and,
#   the,
#   orbital,
#   period,
#   is,
#   1249.6.The,
#   asteroid,
#   1147,
#   Stavropolis,
#   discovered,
#   on,
#   the,
#   11th,
#   of,
#   June,
#   1929,
#   with,
#   a,
#   rotation,
#   period,
#   of,
#   20378.5,
#   has,
#   a,
#   periapsis,
#   of,
#   260855000000,
#   and,
#   apoapsis,
#   of,
#   418476000000.0,
#   .],
#  [The, orbital, period, of, this, asteroid, is, 1249.6, days, .],
#  [John,
#   Mills,
#   died,
#   in,
#   2005.Nurhan,
#   Atasoy,
#   who,
#   was,
#   born,
#   in,
#   Reşadiye,
#   ,,
#   has,
#   his,
#   residence,
#   in,
#   Istanbul,
#   .],
#  [Istanbul,
#   metro,
#   area,
#   is,
#   5,343,
#   square,
#   kilometers,
#   and,
#   its,
#   time,
#   zone,
#   is,
#   Eastern,
#   European,
#   Summer,
#   Time,
#   .],
#  [Nurhan,
#   Atasoy,
#   whose,
#   birth,
#   place,
#   is,
#   Resadiye,
#   ,,
#   also,
#   had,
#   his,
#   residence,
#   in,
#   Istanbul,
#   with,
#   a,
#   metropolitan,
#   area,
#   of,
#   5,343,
#   km²,
#   .],
#  [Istanbul, is, in, the, Eastern, European, Summer, time, zone, .],
#  [Nurhan, Atasoy, was, born, in, Reşadiye, and, now, lives, in, Istanbul, .],
#  [Istanbul,
#   has,
#   a,
#   metropolitan,
#   area,
#   of,
#   5343000000.0,
#   and,
#   uses,
#   the,
#   Eastern,
#   European,
#   Summer,
#   Time,
#   time,
#   zone,
#   .],
#  [The,
#   Year,
#   of,
#   No,
#   Light,
#   's,
#   sludge,
#   metal,
#   album,
#   Nord,
#   (,
#   2006,
#   -,
#   09,
#   -,
#   06,
#   ),
#   was,
#   followed,
#   by,
#   Live,
#   at,
#   Roadburn,
#   2008.The,
#   release,
#   date,
#   of,
#   Nord,
#   ,,
#   Year,
#   of,
#   No,
#   Light,
#   Album,
#   in,
#   the,
#   sludge,
#   metal,
#   genre,
#   ,,
#   is,
#   06,
#   -,
#   09,
#   -,
#   2006,
#   with,
#   their,
#   album,
#   Live,
#   at,
#   Roadburn,
#   2008.The,
#   Year,
#   of,
#   No,
#   Light,
#   album,
#   Nord,
#   in,
#   the,
#   sludge,
#   metal,
#   genre,
#   ,,
#   released,
#   on,
#   September,
#   6,
#   ,,
#   2006,
#   was,
#   followed,
#   by,
#   Year,
#   of,
#   No,
#   Light,
#   's,
#   album,
#   Live,
#   at,
#   Roadburn,
#   2008.Nurhan,
#   Atasoy,
#   was,
#   born,
#   in,
#   Turkey,
#   .],
#  [Binali,
#   Yıldırım,
#   was,
#   former,
#   Prime,
#   Minister,
#   of,
#   Turkey,
#   under,
#   current,
#   president,
#   Recep,
#   Tayyip,
#   Erdoğan,
#   .],
#  [Turkey,
#   ,,
#   led,
#   by,
#   Recep,
#   Tayyip,
#   Erdoğan,
#   and,
#   Binali,
#   Yildirim,
#   ,,
#   is,
#   where,
#   Nurhan,
#   Atasoy,
#   was,
#   born,
#   .Nurhan],
#  [Atasoy,
#   was,
#   born,
#   in,
#   Turkey,
#   where,
#   the,
#   current,
#   leaders,
#   include,
#   Recep,
#   Tayyip,
#   Erdoğan,
#   and,
#   Binali,
#   Yildirim,
#   .],
#  [Turn,
#   Me,
#   On,
#   by,
#   Honeymoon,
#   Killers,
#   ,,
#   a,
#   noise,
#   rock,
#   and,
#   punk,
#   blues,
#   genre,
#   ,,
#   has,
#   a,
#   runtime,
#   of,
#   35.1,
#   minutes,
#   .],
#  [Its, producers, are, Honeymoon, Killers, themselves, and, Wharton, Tiers, .],
#  [In,
#   the,
#   genre,
#   of,
#   punk,
#   blues,
#   ,,
#   the,
#   Honeymoon,
#   Killers,
#   ',
#   ",
#   Turn,
#   Me,
#   On,
#   ",
#   is,
#   a,
#   35,
#   minutes,
#   10,
#   seconds,
#   example,
#   of,
#   noise,
#   rock,
#   produced,
#   by,
#   Wharton,
#   Tiers,
#   for,
#   this,
#   American,
#   band,
#   .],
#  [The, band, also, participated, in, the, production, .],
#  [The,
#   American,
#   noise,
#   rock,
#   band,
#   the,
#   Honeymoon,
#   Killers,
#   ,,
#   self,
#   -,
#   produced,
#   their,
#   punk,
#   blues,
#   album,
#   Turn,
#   Me,
#   On,
#   .],
#  [Wharton,
#   Tiers,
#   was,
#   the,
#   producer,
#   and,
#   the,
#   album,
#   runs,
#   for,
#   35.1,
#   minutes,
#   .],
#  [Baroque,
#   pop,
#   is,
#   a,
#   fusion,
#   genre,
#   which,
#   includes,
#   some,
#   elements,
#   of,
#   pop,
#   rock,
#   ,,
#   an,
#   example,
#   of,
#   which,
#   is,
#   the,
#   Train,
#   song,
#   by,
#   Mermaid,
#   .Mermaid,
#   ,,
#   released,
#   by,
#   the,
#   band,
#   train,
#   ,,
#   is,
#   a,
#   song,
#   in,
#   the,
#   pop,
#   rock,
#   genre,
#   which,
#   also,
#   includes,
#   the,
#   fusion,
#   genre,
#   Baroque,
#   pop,
#   .],
#  [Mermaid,
#   ,,
#   a,
#   song,
#   by,
#   the,
#   band,
#   Train,
#   ,,
#   belongs,
#   to,
#   the,
#   genre,
#   of,
#   pop,
#   rock,
#   .],
#  [An, offshoot, of, pop, rock, is, the, fusion, genre, Baroque, pop, .],
#  [The, parent, company, of, Polydor, Records, is, Universal, Music, Group, .],
#  [Universal, Music, Group, is, the, parent, company, of, Polydor, Records, .],
#  [Polydor, Records, ', parent, company, is, Universal, Music, Group, .],
#  [Liselotte,
#   Grschebina,
#   was,
#   a,
#   photographer,
#   who,
#   was,
#   born,
#   in,
#   the,
#   German,
#   Empire,
#   .],
#  [Liselotte,
#   Grschebina,
#   was,
#   a,
#   professional,
#   photographer,
#   who,
#   was,
#   born,
#   in,
#   the,
#   German,
#   Empire,
#   .],
#  [Liselotte,
#   Grschebina,
#   was,
#   a,
#   professional,
#   photographer,
#   that,
#   was,
#   born,
#   in,
#   the,
#   German,
#   Empire,
#   .],
#  [The,
#   Pontiac,
#   Rageous,
#   ,,
#   a,
#   coupe,
#   assembled,
#   in,
#   Michigan,
#   ,,
#   was,
#   first,
#   and,
#   last,
#   produced,
#   in,
#   1997,
#   .],
#  [It, had, its, assembly, line, in, Detroit, .],
#  [The,
#   Pontiac,
#   Rageous,
#   ,,
#   a,
#   car,
#   with,
#   a,
#   coupe,
#   body,
#   style,
#   ,,
#   assembled,
#   in,
#   Detroit,
#   Michigan,
#   ,,
#   was,
#   first,
#   and,
#   last,
#   produced,
#   in,
#   1997.In,
#   1997,
#   ,,
#   the,
#   Pontiac,
#   Rageous,
#   coupe,
#   (,
#   assembled,
#   in,
#   Detroit,
#   ,,
#   Michigan,
#   ),
#   went,
#   into,
#   and,
#   ended,
#   production,
#   .],
#  [GMA],
#  [New,
#   Media,
#   is,
#   a,
#   company,
#   in,
#   the,
#   mass,
#   media,
#   industry,
#   whose,
#   headquarters,
#   are,
#   located,
#   in,
#   the,
#   GMA,
#   Network,
#   Center,
#   .],
#  [Inside,
#   GMA,
#   Network,
#   Center,
#   lies,
#   the,
#   mass,
#   media,
#   industry,
#   GMA,
#   New,
#   Media,
#   .],
#  [GMA],
#  [New, Media, is, a, mass, media, company, in, the, GMA, Network, Center, .],
#  [Alan,
#   Shepard,
#   was,
#   born,
#   on,
#   Nov,
#   18,
#   ,,
#   1923,
#   in,
#   New,
#   Hampshire,
#   ,,
#   went,
#   to,
#   school,
#   at,
#   NWC,
#   and,
#   graduated,
#   with,
#   an,
#   MA,
#   in,
#   1957,
#   and,
#   was,
#   a,
#   member,
#   of,
#   the,
#   Apollo,
#   14,
#   crew,
#   .],
#  [Alan, Shepard, was, born, on, November, 18, ,, 1923, in, New, Hampshire, .],
#  [Shepard,
#   graduated,
#   from,
#   NWC,
#   in,
#   1957,
#   with,
#   an,
#   M.A.,
#   and,
#   served,
#   as,
#   a,
#   crew,
#   member,
#   of,
#   Apollo,
#   14.Alan],
#  [Shepard, was, born, in, New, Hampshire, on, November, 18th, ,, 1923, .],
#  [He,
#   graduated,
#   from,
#   NWC,
#   with,
#   an,
#   M.A.,
#   in,
#   1957,
#   and,
#   went,
#   on,
#   to,
#   be,
#   a,
#   crew,
#   member,
#   of,
#   Apollo,
#   14.It,
#   's,
#   great,
#   to,
#   be,
#   young,
#   is,
#   a,
#   movie,
#   from,
#   1956,
#   that,
#   runs,
#   for,
#   94,
#   minutes,
#   .],
#  [It, stars, Cecil, Parker, and, it, ’s, edited, by, Max, Benedict, .],
#  [Louis, Levy, composed, the, music, .],
#  [The,
#   1956,
#   film,
#   ",
#   It,
#   's,
#   Great,
#   to,
#   Be,
#   Young,
#   ",
#   stars,
#   Cecil,
#   Parker,
#   .],
#  [The, movie, is, 94, minutes, and, was, edited, by, Max, Benedict, .],
#  [Louis, Levy, composed, the, music, for, the, film, .],
#  [It,
#   's,
#   Great,
#   to,
#   be,
#   Young,
#   is,
#   a,
#   94,
#   minute,
#   movie,
#   released,
#   in,
#   1956,
#   .],
#  [It, starred, Cecil, Parker, and, was, edited, by, Max, Benedict, .],
#  [Louis, Levy, was, the, musical, composer, .],
#  [Israeli,
#   national,
#   Liselotte,
#   Grschebina,
#   was,
#   born,
#   in,
#   Karlsruhe,
#   on,
#   May,
#   2,
#   ,,
#   1908,
#   ,,
#   and,
#   died,
#   on,
#   June,
#   14,
#   ,,
#   1994.Israeli,
#   Liselotte,
#   Grschebina,
#   was,
#   born,
#   in,
#   Karlsruhe,
#   on,
#   May,
#   2,
#   ,,
#   1908,
#   and,
#   died,
#   on,
#   June,
#   14,
#   ,,
#   1994.Liselotte,
#   Grschebina,
#   was,
#   as,
#   Israeli,
#   national,
#   born,
#   in,
#   Karlsruhe,
#   on,
#   May,
#   2,
#   ,,
#   1908,
#   and,
#   died,
#   on,
#   June,
#   14,
#   ,,
#   1994.The,
#   construction,
#   of,
#   Alan,
#   B.,
#   Miller,
#   Hall,
#   lasted,
#   from,
#   March,
#   30th,
#   ,,
#   2007,
#   to,
#   June,
#   1st,
#   ,,
#   2009,
#   .],
#  [Robert, A., M., Stern, is, the, architect, of, the, building, .],
#  [Alan,
#   B.,
#   Miller,
#   Hall,
#   is,
#   located,
#   at,
#   101,
#   Ukrop,
#   Way,
#   ,,
#   Virginia,
#   ,,
#   and,
#   the,
#   current,
#   tenant,
#   is,
#   the,
#   Mason,
#   School,
#   of,
#   Business,
#   .],
#  [Robert,
#   A,
#   M,
#   Stern,
#   is,
#   the,
#   architect,
#   responsible,
#   for,
#   designing,
#   the,
#   Alan,
#   B.,
#   Miller,
#   Hall,
#   at,
#   101,
#   Ukrop,
#   Way,
#   in,
#   Virginia,
#   .],
#  [Construction,
#   started,
#   on,
#   the,
#   building,
#   on,
#   the,
#   30th,
#   of,
#   March,
#   ,,
#   2007,
#   and,
#   was,
#   completed,
#   on,
#   the,
#   1st,
#   of,
#   June,
#   ,,
#   2009,
#   .],
#  [The,
#   Mason,
#   School,
#   of,
#   Business,
#   are,
#   the,
#   current,
#   occupants,
#   of,
#   the,
#   hall,
#   .],
#  [Stargate, produced, the, song, Mermaid, .],
#  [The,
#   Train,
#   song,
#   Mermaid,
#   was,
#   written,
#   by,
#   the,
#   production,
#   team,
#   Stargate,
#   .],
#  [A,
#   person,
#   named,
#   Jamie,
#   Lawrence,
#   is,
#   a,
#   member,
#   of,
#   the,
#   Brentford,
#   F.C.,
#   while,
#   someone,
#   with,
#   the,
#   same,
#   name,
#   was,
#   the,
#   composer,
#   for,
#   ",
#   Death,
#   on,
#   a,
#   Factory,
#   Farm,
#   ",
#   music,
#   .],
#  [Jamie,
#   Lawrence,
#   ,,
#   who,
#   played,
#   for,
#   Brentford,
#   F.C.,
#   ,,
#   wrote,
#   the,
#   music,
#   for,
#   the,
#   film,
#   ',
#   Death,
#   on,
#   a,
#   Factory,
#   Farm',
#   .],
#  [Jamie,
#   Lawrence,
#   ,,
#   who,
#   composed,
#   Death,
#   on,
#   a,
#   Factory,
#   Farm,
#   also,
#   played,
#   in,
#   the,
#   club,
#   Brentford,
#   F.C."Let],
#  ...]

# %% [markdown]
# ## Lowercasing and Removing Punctuation
#
# **Exercise 5**
#
# * Use the [maketrans()]( https://docs.python.org/3/library/stdtypes.html?highlight=maketrans#str.maketrans) function to define a translation table which maps each punctuation sign to an empty string. Use the maketrans function with 3 arguments where the third argument is the list of punctuation signs.
# **Hint:** In Python, string.punctuation returns the string made of all punctuation signs.
# N.B. string.punctuation is a method in the string module. Therefore you must first import string.
#
# * Define a function which lower case a list of tokens and removes punctuation signs
# * Apply this function to the list of tokens produced in the preceding exercise

# %%
import string

# %%
mytable = str.maketrans(dict(zip(string.punctuation, [''] * len(string.punctuation))))
"lOl,".lower().translate(mytable)
# Out:
# 'lol'

# %%
def Processing(tokens, punkt_s=string.punctuation):
    empt = [''] * len(punkt_s)
    mytable = str.maketrans(dict(zip(punkt_s, empt)))  # Replace with actual chars
    l = []
    
    for i, t in enumerate(tokens):
        processed_token = str(t).lower().translate(mytable)
        l.append(processed_token)
    return l

# %%
sp_tokenl = [Processing(s, ) for s in sp_tokenl]
sp_tokenl
# Out:
# [['estádio',
#   'municipal',
#   'coaracy',
#   'da',
#   'mata',
#   'fonseca',
#   'is',
#   'the',
#   'name',
#   'of',
#   'the',
#   'ground',
#   'of',
#   'agremiação',
#   'sportiva',
#   'arapiraquense',
#   'in',
#   'arapiraca',
#   ''],
#  ['agremiação',
#   'sportiva',
#   'arapiraquense',
#   '',
#   'nicknamed',
#   '',
#   'alvinegro',
#   '',
#   '',
#   'lay',
#   'in',
#   'the',
#   'campeonato',
#   'brasileiro',
#   'série',
#   'c',
#   'league',
#   'from',
#   'brazil',
#   ''],
#  ['estádio',
#   'municipal',
#   'coaracy',
#   'da',
#   'mata',
#   'fonseca',
#   'is',
#   'the',
#   'name',
#   'of',
#   'the',
#   'ground',
#   'of',
#   'agremiação',
#   'sportiva',
#   'arapiraquense',
#   'in',
#   'arapiraca',
#   ''],
#  ['alvinegro',
#   '',
#   'the',
#   'nickname',
#   'of',
#   'agremiação',
#   'sportiva',
#   'arapiraquense',
#   '',
#   'play',
#   'in',
#   'the',
#   'campeonato',
#   'brasileiro',
#   'série',
#   'c',
#   'league',
#   'from',
#   'brazil',
#   ''],
#  ['nie',
#   'haisheng',
#   '',
#   'born',
#   'on',
#   'october',
#   '13',
#   '',
#   '1964',
#   '',
#   'worked',
#   'as',
#   'a',
#   'fighter',
#   'pilot',
#   ''],
#  ['nie',
#   'haisheng',
#   'is',
#   'a',
#   'former',
#   'fighter',
#   'pilot',
#   'who',
#   'was',
#   'born',
#   'on',
#   'october',
#   '13',
#   '',
#   '1964nie'],
#  ['haisheng', 'born', 'on', '10131964', 'is', 'a', 'fighter', 'pilot', ''],
#  ['motorsport',
#   'vision',
#   'is',
#   'located',
#   'in',
#   'the',
#   'city',
#   'of',
#   'fawkham',
#   ''],
#  ['motorsport',
#   'vision',
#   'is',
#   'located',
#   'in',
#   'the',
#   'city',
#   'of',
#   'fawkham',
#   '',
#   'ukmotorsport',
#   'vision',
#   'is',
#   'located',
#   'in',
#   'fawkham185',
#   'centimetre',
#   'tall',
#   'aleksandr',
#   'prudnikov',
#   'played',
#   'for',
#   'the',
#   'otkrytiye',
#   'arena',
#   'based',
#   'fc',
#   'spartak',
#   '',
#   'moscow',
#   ''],
#  ['the',
#   '185',
#   'cm',
#   'tall',
#   'aleksandr',
#   'prudnikov',
#   'plays',
#   'for',
#   'fc',
#   'spartak',
#   'moscow',
#   'who',
#   'call',
#   'their',
#   'home',
#   'ground',
#   'otkrytiye',
#   'arena',
#   ''],
#  ['aleksandr',
#   'prudnikov',
#   'who',
#   'is',
#   '185',
#   'cm',
#   'tall',
#   '',
#   'plays',
#   'for',
#   'fc',
#   'spartak',
#   'moscow',
#   'whose',
#   'ground',
#   'is',
#   'the',
#   'otkrytiye',
#   'arena',
#   ''],
#  ['ciudad',
#   'ayala',
#   'is',
#   'a',
#   'city',
#   'with',
#   'population',
#   'density',
#   'and',
#   'population',
#   'of',
#   '1604',
#   'and',
#   '1777539',
#   'respectively',
#   '',
#   'where',
#   'the',
#   'leader',
#   'is',
#   'called',
#   'the',
#   'city',
#   'manager',
#   ''],
#  ['the',
#   'government',
#   'type',
#   'in',
#   'the',
#   'city',
#   'of',
#   'ciudad',
#   'ayala',
#   'is',
#   'council',
#   '',
#   'manager',
#   ''],
#  ['the',
#   'city',
#   'of',
#   'ciudad',
#   'ayala',
#   '',
#   'with',
#   'a',
#   'population',
#   'of',
#   '1777539',
#   '',
#   'is',
#   'led',
#   'by',
#   'a',
#   'city',
#   'manager',
#   'on',
#   'a',
#   'council',
#   '',
#   'manager',
#   'government',
#   'system',
#   ''],
#  ['it',
#   'has',
#   'a',
#   'population',
#   'density',
#   'of',
#   '1604ciudad',
#   'ayala',
#   '',
#   'a',
#   'city',
#   'with',
#   'population',
#   'density',
#   'and',
#   'population',
#   'of',
#   '16040',
#   'and',
#   '1777539',
#   'respectively',
#   '',
#   'uses',
#   'a',
#   'type',
#   'of',
#   'government',
#   'called',
#   'council',
#   '',
#   'manager',
#   'government',
#   ''],
#  ['one',
#   'of',
#   'the',
#   'leaders',
#   'of',
#   'ciudad',
#   'ayala',
#   'is',
#   'the',
#   'city',
#   'manager',
#   ''],
#  ['the',
#   'album',
#   '1969',
#   '',
#   'the',
#   'velvet',
#   'underground',
#   'live',
#   'is',
#   'preceded',
#   'by',
#   'the',
#   'velvet',
#   'underground',
#   'album',
#   'squeeze',
#   '',
#   'which',
#   'was',
#   'followed',
#   'by',
#   'the',
#   'quine',
#   'tapes',
#   ''],
#  ['the',
#   'velvet',
#   'underground',
#   'album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   'was',
#   'preceded',
#   'by',
#   'the',
#   'album',
#   'squeeze',
#   '',
#   'which',
#   'was',
#   'followed',
#   'by',
#   'the',
#   'live',
#   'album',
#   '1969',
#   '',
#   'the',
#   'velvet',
#   'underground',
#   'live',
#   ''],
#  ['the',
#   'bootleg',
#   'series',
#   'volume',
#   'i',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   'is',
#   'preceded',
#   'by',
#   'the',
#   'velvet',
#   'underground',
#   'album',
#   'squeeze',
#   'which',
#   'was',
#   'itself',
#   'followed',
#   'by',
#   'the',
#   'album',
#   '1969',
#   ''],
#  ['the', 'velvet', 'underground', 'live', ''],
#  ['ciudad',
#   'ayala',
#   'in',
#   'mexico',
#   'with',
#   'population',
#   'density',
#   'of',
#   '16040',
#   'and',
#   'elevated',
#   '11470',
#   'above',
#   'sea',
#   'level',
#   'is',
#   'in',
#   'the',
#   'pdt',
#   'time',
#   'zone',
#   ''],
#  ['the', 'leader', 'here', 'is', 'called', 'the', 'governator', ''],
#  ['ciudad',
#   'ayala',
#   'is',
#   'a',
#   'country',
#   'in',
#   'mexico',
#   'that',
#   'is',
#   'located',
#   '1147',
#   'above',
#   'sea',
#   'level',
#   'and',
#   'is',
#   'in',
#   'the',
#   'pacific',
#   'daylight',
#   'time',
#   'zone',
#   ''],
#  ['the',
#   'population',
#   'density',
#   'is',
#   '1604',
#   'and',
#   'the',
#   'leader',
#   'of',
#   'ciudad',
#   'ayala',
#   'is',
#   'called',
#   'the',
#   'governator',
#   ''],
#  ['ciudad',
#   'ayala',
#   'is',
#   'located',
#   'in',
#   'mexico',
#   'and',
#   'has',
#   'a',
#   'population',
#   'density',
#   'of',
#   '1604',
#   ''],
#  ['the', 'city', 'stands', '1147', 'm', 'above', 'sea', 'level', ''],
#  ['the',
#   'governator',
#   'is',
#   'the',
#   'leader',
#   'of',
#   'ciudad',
#   'ayala',
#   'located',
#   'in',
#   'the',
#   'pacific',
#   'daylight',
#   'time',
#   'zone',
#   ''],
#  ['olga',
#   'bondareva',
#   'died',
#   'on',
#   'december',
#   '9',
#   '',
#   '1991olga',
#   'bondareva',
#   'died',
#   'on',
#   'the',
#   '9th',
#   'of',
#   'december',
#   '',
#   '1991the',
#   'date',
#   'of',
#   'olga',
#   'bondareva',
#   's',
#   'death',
#   'was',
#   'the',
#   'ninth',
#   'of',
#   'december',
#   '1991saint',
#   'petersburg',
#   'was',
#   'founded',
#   'on',
#   'may',
#   '27',
#   '',
#   '1703',
#   'and',
#   'has',
#   'a',
#   'total',
#   'area',
#   'of',
#   '14390',
#   '',
#   'olga',
#   'bondareva',
#   'passed',
#   'away',
#   'at',
#   'saint',
#   'petersburg',
#   ''],
#  ['saint',
#   'petersburg',
#   '',
#   'where',
#   'olga',
#   'bondareva',
#   'died',
#   '',
#   'was',
#   'founded',
#   'on',
#   'the',
#   '27th',
#   'of',
#   'may',
#   '',
#   '1703',
#   'and',
#   'has',
#   'a',
#   'total',
#   'area',
#   'of',
#   'approximately',
#   '1439',
#   'km2saint',
#   'petersburg',
#   '',
#   'where',
#   'olga',
#   'bondareva',
#   'died',
#   '',
#   'was',
#   'founded',
#   'on',
#   'may',
#   '27',
#   '',
#   '1703',
#   'and',
#   'consists',
#   'of',
#   'a',
#   'total',
#   'area',
#   'of',
#   '14390',
#   'sq',
#   '',
#   'km',
#   ''],
#  ['the',
#   'population',
#   'density',
#   'of',
#   'ciudad',
#   'ayala',
#   'is',
#   '16040ciudad',
#   'ayala',
#   'city',
#   'has',
#   'a',
#   'population',
#   'density',
#   'of',
#   '16040the',
#   'population',
#   'density',
#   'in',
#   'ciudad',
#   'ayala',
#   'is',
#   '1604piotr',
#   'hallmann',
#   'was',
#   'born',
#   'on',
#   'august',
#   '25',
#   '',
#   '1987piotr',
#   'hallmann',
#   's',
#   'birthday',
#   'is',
#   'august',
#   '25th'],
#  ['1987piotr',
#   'hallmann',
#   'was',
#   'born',
#   'on',
#   'the',
#   '25th',
#   'of',
#   'august',
#   '1987the'],
#  ['darlington',
#   'town',
#   'has',
#   'an',
#   'area',
#   'code',
#   'of',
#   '01325the',
#   'telephone',
#   'area',
#   'code',
#   'for',
#   'darlington',
#   'is',
#   '01325the',
#   'area',
#   'code',
#   'in',
#   'darlington',
#   'is',
#   '01325pennsylvania',
#   's',
#   'franklin',
#   'county',
#   'is',
#   'found',
#   'to',
#   'the',
#   'west',
#   'of',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'and',
#   'pennsylvania',
#   's',
#   'cumberland',
#   'county',
#   'is',
#   'to',
#   'the',
#   'north',
#   ''],
#  ['a',
#   'monument',
#   'to',
#   'the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'was',
#   'erected',
#   'in',
#   'adams',
#   'county',
#   'in',
#   'the',
#   'year',
#   '2000',
#   'in',
#   'the',
#   'municipality',
#   'of',
#   'gettysburg',
#   'and',
#   'this',
#   'monument',
#   'is',
#   'categorised',
#   'as',
#   'a',
#   'contributing',
#   'property',
#   ''],
#  ['the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   '',
#   'a',
#   'contributing',
#   'property',
#   'established',
#   'in',
#   'the',
#   'year',
#   '2000',
#   'in',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'falls',
#   'in',
#   'the',
#   'municipality',
#   'of',
#   'gettysburg',
#   '',
#   'pennsylvania',
#   ''],
#  ['adams',
#   'county',
#   'pennsylvania',
#   'is',
#   'east',
#   'of',
#   'franklin',
#   'county',
#   '',
#   'pennsylvania',
#   'and',
#   'has',
#   'cumberland',
#   'county',
#   '',
#   'pennsylvania',
#   'to',
#   'its',
#   'north',
#   ''],
#  ['the', 'official', 'language', 'of', 'israel', 'is', 'modern', 'hebrew', ''],
#  ['israel', '’s', 'official', 'language', 'is', 'modern', 'hebrew', ''],
#  ['modern', 'hebrew', 'is', 'the', 'official', 'language', 'of', 'israel', ''],
#  ['enaire',
#   'is',
#   'the',
#   'operating',
#   'organisation',
#   'for',
#   'adolfo',
#   'suarez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   ''],
#  ['this',
#   'airport',
#   'is',
#   'situated',
#   '610',
#   'meters',
#   'above',
#   'sea',
#   'level',
#   'in',
#   'alcobendas',
#   ''],
#  ['gma',
#   'new',
#   'media',
#   '',
#   'a',
#   'company',
#   'founded',
#   'on',
#   '01',
#   '',
#   '01',
#   '',
#   '2000',
#   'are',
#   'manufacturers',
#   'of',
#   'mobile',
#   'applications',
#   ''],
#  ['gma',
#   'new',
#   'media',
#   '',
#   'which',
#   'was',
#   'founded',
#   'on',
#   'january',
#   '1',
#   '',
#   '2000',
#   '',
#   'is',
#   'a',
#   'company',
#   'that',
#   'offers',
#   'products',
#   'such',
#   'as',
#   'mobile',
#   'applications',
#   ''],
#  ['gma',
#   'new',
#   'media',
#   'makes',
#   'mobile',
#   'apps',
#   'and',
#   'was',
#   'founded',
#   'on',
#   '01012000hypermarcas',
#   'is',
#   'a',
#   'pharmaceutical',
#   'company',
#   'located',
#   'in',
#   'sao',
#   'paulo',
#   '',
#   'brazil',
#   ''],
#  ['brazil', 'is', '851483714', 'square', 'kilometers', 'in', 'size', ''],
#  ['hypermarcas',
#   '',
#   'a',
#   'pharmaceutical',
#   'company',
#   '',
#   'is',
#   'located',
#   'in',
#   'sao',
#   'paulo',
#   'within',
#   'the',
#   '851483714',
#   'square',
#   'kilometres',
#   'that',
#   'make',
#   'up',
#   'the',
#   'country',
#   'of',
#   'brazil',
#   ''],
#  ['hypermarcas',
#   '',
#   'a',
#   'company',
#   'in',
#   'the',
#   'pharmaceuticals',
#   'industry',
#   '',
#   'is',
#   'located',
#   'in',
#   'sao',
#   'paulo',
#   '',
#   'brazil',
#   '',
#   'a',
#   'country',
#   'with',
#   'a',
#   'total',
#   'area',
#   'of',
#   '851483714',
#   'square',
#   'kilometres',
#   ''],
#  ['the',
#   'quine',
#   'tapes',
#   'are',
#   'rock',
#   'music',
#   'genre',
#   'preceded',
#   'by',
#   'the',
#   'album',
#   'squeeze',
#   '',
#   'and',
#   'squeeze',
#   'was',
#   'preceded',
#   'by',
#   'the',
#   'album',
#   'andy',
#   'warhol',
#   's',
#   'velvet',
#   'underground',
#   'featuring',
#   'nico',
#   ''],
#  ['bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   's',
#   'genre',
#   'is',
#   'rock',
#   '',
#   'and',
#   'is',
#   'preceded',
#   'by',
#   'the',
#   'velvet',
#   'underground',
#   'album',
#   'squeeze',
#   '',
#   'which',
#   'was',
#   'preceded',
#   'by',
#   'the',
#   'compilation',
#   'album',
#   'andy',
#   'warhol',
#   's',
#   'velvet',
#   'underground',
#   'featuring',
#   'nico',
#   ''],
#  ['the',
#   'album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   'fits',
#   'into',
#   'the',
#   'rock',
#   'music',
#   'genre',
#   'and',
#   'was',
#   'preceded',
#   'by',
#   'squeeze',
#   'by',
#   'the',
#   'velvet',
#   'underground',
#   '',
#   'which',
#   'in',
#   'turn',
#   'was',
#   'preceded',
#   'by',
#   'andy',
#   'warhol',
#   's',
#   'velvet',
#   'underground',
#   'featuring',
#   'nico',
#   ''],
#  ['dr',
#   'g',
#   'p',
#   'prabhukumar',
#   'is',
#   'the',
#   'director',
#   'of',
#   'the',
#   'acharya',
#   'institute',
#   'of',
#   'technology',
#   'which',
#   'is',
#   'located',
#   'at',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '',
#   '560090',
#   'in',
#   'india',
#   'and',
#   'is',
#   'affiliated',
#   'with',
#   'visvesvaraya',
#   'technological',
#   'university',
#   ''],
#  ['the',
#   'acharya',
#   'institute',
#   'of',
#   'technology',
#   'campus',
#   'is',
#   'located',
#   'in',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '–',
#   '560090',
#   '',
#   'india',
#   ''],
#  ['its',
#   'director',
#   'is',
#   'dr',
#   'gp',
#   'prabhukumar',
#   'and',
#   'it',
#   'is',
#   'affiliated',
#   'to',
#   'visvesvaraya',
#   'technological',
#   'university',
#   ''],
#  ['the',
#   'campus',
#   'of',
#   'the',
#   'acharya',
#   'institute',
#   'of',
#   'technology',
#   'is',
#   'located',
#   'at',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '–',
#   '560090',
#   '',
#   'india',
#   'and',
#   'it',
#   'is',
#   'affiliated',
#   'with',
#   'the',
#   'visvesvaraya',
#   'technological',
#   'university',
#   ''],
#  ['its', 'director', 'is', 'dr', 'gpprabhukumar', ''],
#  ['abraham',
#   'a',
#   'ribicoff',
#   'was',
#   'born',
#   'and',
#   'died',
#   'in',
#   'the',
#   'united',
#   'states',
#   'where',
#   'african',
#   'americans',
#   'are',
#   'an',
#   'ethnic',
#   'group',
#   ''],
#  ['abraham', 'aribicoff', 'died', 'in', 'the', 'united', 'states', ''],
#  ['it', 'was', 'also', 'his', 'birthplace', ''],
#  ['african',
#   'americans',
#   'are',
#   'an',
#   'ethnic',
#   'group',
#   'in',
#   'the',
#   'usaabraham',
#   'a',
#   'ribicoff',
#   'was',
#   'born',
#   'and',
#   'died',
#   'in',
#   'the',
#   'united',
#   'states',
#   'where',
#   'african',
#   'americans',
#   'are',
#   'an',
#   'ethnic',
#   'group',
#   ''],
#  ['music',
#   'group',
#   'the',
#   'velvet',
#   'underground',
#   'produced',
#   'and',
#   'released',
#   'rock',
#   'music',
#   'album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   'under',
#   'the',
#   'polydor',
#   'records',
#   'record',
#   'label',
#   ''],
#  ['the',
#   'album',
#   'was',
#   'recorded',
#   'in',
#   'st',
#   'louis',
#   '',
#   'missouri',
#   '',
#   'usa',
#   'and',
#   'has',
#   'a',
#   'run',
#   'time',
#   'of',
#   '23005bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   'created',
#   'and',
#   'produced',
#   'by',
#   'the',
#   'velvet',
#   'underground',
#   'with',
#   'runtime',
#   'of',
#   '23005',
#   'minutes',
#   'was',
#   'recorded',
#   'in',
#   'was',
#   'st',
#   'louis',
#   'missouri',
#   '',
#   'united',
#   'states',
#   ''],
#  ['the',
#   'rock',
#   'genre',
#   'album',
#   'was',
#   'recorded',
#   'through',
#   'polydor',
#   'records',
#   ''],
#  ['the',
#   'bootleg',
#   'series',
#   'volume',
#   'i',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   'created',
#   'and',
#   'produced',
#   'by',
#   'the',
#   'velvet',
#   'underground',
#   'with',
#   'runtime',
#   'of',
#   '23005',
#   'minutes',
#   'was',
#   'recorded',
#   'in',
#   'st',
#   'louis',
#   '',
#   'missouri',
#   '',
#   'united',
#   'states',
#   ''],
#  ['the',
#   'rock',
#   'music',
#   'genre',
#   'album',
#   'was',
#   'released',
#   'by',
#   'the',
#   'record',
#   'label',
#   'polydor',
#   'records',
#   ''],
#  ['the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   'belongs',
#   'to',
#   'the',
#   'fantasy',
#   'genre',
#   ''],
#  ['george', 'allen', '', 'amp', '', 'unwin', 'published', 'it', ''],
#  ['the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   'was',
#   'published',
#   'in',
#   'the',
#   'fantasy',
#   'genre',
#   'by',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   '',
#   'from',
#   'the',
#   'fantasy',
#   'genre',
#   '',
#   'was',
#   'published',
#   'by',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['distinguished',
#   'service',
#   'medal',
#   '',
#   'us',
#   'navy',
#   '',
#   'recipient',
#   'alan',
#   'shepard',
#   'was',
#   'born',
#   'in',
#   'new',
#   'hampshire',
#   'but',
#   'died',
#   'in',
#   'california',
#   ''],
#  ['awarded',
#   'the',
#   'distinguished',
#   'service',
#   'medal',
#   'by',
#   'the',
#   'united',
#   'states',
#   'navy',
#   '',
#   'alan',
#   'shepard',
#   '',
#   'was',
#   'born',
#   'in',
#   'new',
#   'hampshire',
#   '',
#   'and',
#   'died',
#   'in',
#   'california',
#   ''],
#  ['alan',
#   'shepard',
#   '',
#   'born',
#   'in',
#   'new',
#   'hampshire',
#   'while',
#   'having',
#   'died',
#   'in',
#   'california',
#   '',
#   'was',
#   'awarded',
#   'the',
#   'distinguished',
#   'service',
#   'medal',
#   'by',
#   'the',
#   'united',
#   'states',
#   'navy',
#   ''],
#  ['imagine',
#   'is',
#   'a',
#   'song',
#   'that',
#   'train',
#   'followed',
#   'mermaid',
#   'with',
#   '',
#   'which',
#   'was',
#   'a',
#   'song',
#   'produced',
#   'by',
#   'the',
#   'production',
#   'team',
#   'espionage',
#   '',
#   'and',
#   'was',
#   'on',
#   'their',
#   'album',
#   'california',
#   '37train',
#   'followed',
#   'its',
#   'song',
#   'mermaid',
#   '',
#   'from',
#   'its',
#   'california',
#   '37',
#   'album',
#   '',
#   'which',
#   'was',
#   'was',
#   'produced',
#   'by',
#   'the',
#   'production',
#   'team',
#   'espionage',
#   '',
#   'with',
#   'a',
#   'song',
#   'titled',
#   'imagine',
#   ''],
#  ['from',
#   'the',
#   'production',
#   'team',
#   'espionage',
#   '',
#   'train',
#   's',
#   'song',
#   'mermaid',
#   '',
#   'on',
#   'the',
#   'california',
#   '37',
#   'album',
#   '',
#   'was',
#   'followed',
#   'by',
#   'train',
#   's',
#   'performance',
#   'of',
#   'imagine',
#   'by',
#   'john',
#   'lennon',
#   ''],
#  ['the',
#   'train',
#   'song',
#   'mermaid',
#   '',
#   'which',
#   'belongs',
#   'to',
#   'the',
#   'california',
#   '37',
#   'train',
#   'album',
#   'and',
#   'was',
#   'produced',
#   'by',
#   'espionage',
#   '',
#   'is',
#   'followed',
#   'by',
#   'the',
#   'john',
#   'lennon',
#   'song',
#   'imagine',
#   ''],
#  ['train',
#   's',
#   'song',
#   'imagine',
#   'came',
#   'after',
#   'a',
#   'song',
#   'from',
#   'their',
#   'california',
#   '37',
#   'album',
#   '',
#   'titled',
#   'mermaid',
#   '',
#   'which',
#   'was',
#   'produced',
#   'by',
#   'the',
#   'production',
#   'team',
#   'espionage',
#   ''],
#  ['the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   'was',
#   'written',
#   'by',
#   'jrr',
#   'tolkien',
#   'and',
#   'was',
#   'released',
#   'on',
#   'july',
#   '29',
#   '',
#   '1954',
#   ''],
#  ['the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   'is',
#   'considered',
#   'fantasy',
#   'and',
#   'was',
#   'published',
#   'by',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['the',
#   'sequel',
#   'to',
#   'the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   'was',
#   'the',
#   'two',
#   'towers',
#   ''],
#  ['jrr',
#   'tolkien',
#   'is',
#   'the',
#   'author',
#   'of',
#   'the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   'released',
#   'on',
#   'july',
#   '29',
#   '',
#   '1954',
#   ''],
#  ['it',
#   'is',
#   'a',
#   'fantasy',
#   'book',
#   'published',
#   'by',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['the', 'novel', 'was', 'followed', 'by', 'the', 'two', 'towers', ''],
#  ['the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   'belongs',
#   'to',
#   'the',
#   'fantasy',
#   'genre',
#   ''],
#  ['its', 'author', 'is', 'jrr', 'tolkien', ''],
#  ['it',
#   'was',
#   'published',
#   'on',
#   'july',
#   '29',
#   '',
#   '1954',
#   'by',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['it', 'was', 'followed', 'by', 'the', 'two', 'towers', ''],
#  ['gma'],
#  ['new',
#   'media',
#   'lies',
#   'in',
#   'the',
#   'philippines',
#   'where',
#   'applications',
#   'are',
#   'offered',
#   'in',
#   'the',
#   'entertainment',
#   'industry',
#   ''],
#  ['located',
#   'in',
#   'the',
#   'philippines',
#   '',
#   'gma',
#   'new',
#   'media',
#   'is',
#   'an',
#   'entertainment',
#   'industry',
#   ''],
#  ['gma'],
#  ['new',
#   'media',
#   'is',
#   'an',
#   'entertainment',
#   'company',
#   'located',
#   'in',
#   'the',
#   'philippines',
#   ''],
#  ['english',
#   'without',
#   'tears',
#   '',
#   'written',
#   'by',
#   'terence',
#   'rattigan',
#   '',
#   'runs',
#   '89',
#   'minutes',
#   ''],
#  ['the',
#   'cinematography',
#   'for',
#   'the',
#   'film',
#   'was',
#   'done',
#   'by',
#   'bernard',
#   'knowles',
#   ''],
#  ['english',
#   'without',
#   'tears',
#   '',
#   'an',
#   '89',
#   'minute',
#   'film',
#   'written',
#   'by',
#   'terence',
#   'rattigan',
#   '',
#   'features',
#   'the',
#   'cinematography',
#   'of',
#   'bernard',
#   'knowles',
#   ''],
#  ['terence',
#   'rattigan',
#   'is',
#   'the',
#   'writer',
#   'of',
#   'the',
#   '89',
#   'minute',
#   'movie',
#   '´',
#   'english',
#   'without',
#   'tears',
#   '´',
#   'and',
#   'bernard',
#   'knowles',
#   'is',
#   'the',
#   'cinematographer',
#   ''],
#  ['george',
#   'monson',
#   'was',
#   'married',
#   'to',
#   'lady',
#   'anne',
#   'monson',
#   '',
#   'a',
#   'botanist',
#   '',
#   'who',
#   'died',
#   'on',
#   'february',
#   '18',
#   '',
#   '1776lady',
#   'anne',
#   'monson',
#   '',
#   'a',
#   'professional',
#   'botanist',
#   'who',
#   'was',
#   'married',
#   'to',
#   'george',
#   'monson',
#   '',
#   'died',
#   'on',
#   'february',
#   '18th',
#   ''],
#  ['1776lady',
#   'anne',
#   'monson',
#   'is',
#   'the',
#   'spouse',
#   'of',
#   'george',
#   'monson',
#   ''],
#  ['her',
#   'professional',
#   'field',
#   'of',
#   'study',
#   'was',
#   'botany',
#   '',
#   'and',
#   'she',
#   'died',
#   'on',
#   '18',
#   'february',
#   '1776abdul',
#   'taib',
#   'mahmud',
#   '',
#   'member',
#   'of',
#   'the',
#   'parti',
#   'pesaka',
#   'bumiputera',
#   'bersatu',
#   'party',
#   '',
#   'resides',
#   'in',
#   'demak',
#   'jaya',
#   '',
#   'jalan',
#   'bako',
#   '',
#   'kuching',
#   '',
#   'sarawak',
#   ''],
#  ['abdul',
#   'taib',
#   'mahmud',
#   '',
#   'a',
#   'member',
#   'of',
#   'the',
#   'parti',
#   'pesaka',
#   'bumiputera',
#   'bersatu',
#   'party',
#   '',
#   'resides',
#   'in',
#   'demak',
#   'jaya',
#   '',
#   'jalan',
#   'bako',
#   '',
#   'kuching',
#   '',
#   'sarawak',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'was',
#   'an',
#   'israeli',
#   'who',
#   'attended',
#   'the',
#   'school',
#   'of',
#   'applied',
#   'arts',
#   'in',
#   'stuttgart',
#   ''],
#  ['she', 'was', 'born', 'in', 'karlsruhe', '', 'germany', ''],
#  ['israel', 's', 'national', 'language', 'is', 'modern', 'hebrew', ''],
#  ['liselotte',
#   'grschebina',
#   'is',
#   'an',
#   'israeli',
#   'national',
#   'who',
#   'did',
#   'her',
#   'studies',
#   'at',
#   'the',
#   'school',
#   'of',
#   'applied',
#   'arts',
#   'in',
#   'stuttgart',
#   'and',
#   'was',
#   'born',
#   'in',
#   'karlsruhe',
#   '',
#   'which',
#   'is',
#   'in',
#   'germany',
#   'unlike',
#   'israel',
#   'whose',
#   'language',
#   'is',
#   'modern',
#   'hebrew',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'was',
#   'born',
#   'in',
#   'karlsruhe',
#   'which',
#   'is',
#   'located',
#   'in',
#   'germany',
#   '',
#   'has',
#   'israeli',
#   'nationality',
#   '',
#   'the',
#   'language',
#   'in',
#   'israel',
#   'is',
#   'modern',
#   'hebrew',
#   '',
#   '',
#   'and',
#   'studied',
#   'at',
#   'the',
#   'school',
#   'of',
#   'applied',
#   'arts',
#   'in',
#   'stuttgart',
#   ''],
#  ['chinabank', 's', 'location', 'is', 'the', 'philippines', ''],
#  ['chinabank', 'is', 'located', 'in', 'the', 'philippines', ''],
#  ['the',
#   'train',
#   'song',
#   'mermaid',
#   '',
#   'which',
#   'is',
#   'an',
#   'example',
#   'of',
#   'the',
#   'reggae',
#   'genre',
#   '',
#   'was',
#   'released',
#   'under',
#   'the',
#   'record',
#   'labels',
#   'of',
#   'columbia',
#   'records',
#   'and',
#   'sony',
#   'music',
#   'entertainment',
#   ''],
#  ['it',
#   'was',
#   'written',
#   'by',
#   'espen',
#   'lind',
#   'and',
#   'amund',
#   'bjørklund',
#   'and',
#   'has',
#   'a',
#   'total',
#   'runtime',
#   'of',
#   '3',
#   'minutes',
#   'and',
#   '16',
#   'seconds',
#   ''],
#  ['amund',
#   'bjorklund',
#   'and',
#   'espen',
#   'lind',
#   'are',
#   'writers',
#   'of',
#   'the',
#   '316',
#   'minute',
#   'reggae',
#   'song',
#   'mermaid',
#   'by',
#   'train',
#   'that',
#   'was',
#   'released',
#   'under',
#   'sony',
#   'music',
#   'entertainment',
#   'and',
#   'columbia',
#   'records',
#   ''],
#  ['the',
#   'song',
#   'mermaid',
#   'was',
#   'written',
#   'in',
#   'the',
#   'reggae',
#   'music',
#   'genre',
#   'by',
#   'espen',
#   'lind',
#   'and',
#   'amund',
#   'bjorklund',
#   'the',
#   'song',
#   'was',
#   'performed',
#   'by',
#   'train',
#   'and',
#   'released',
#   'by',
#   'columbia',
#   'records',
#   'and',
#   'sony',
#   'music',
#   'entertainment',
#   'records',
#   ''],
#  ['it',
#   'has',
#   'a',
#   'total',
#   'runtime',
#   'of',
#   'three',
#   'minutes',
#   'and',
#   'sixteen',
#   'seconds',
#   ''],
#  ['it',
#   's',
#   'great',
#   'to',
#   'be',
#   'young',
#   '',
#   'a',
#   '1956',
#   'film',
#   'starring',
#   'cecil',
#   'parker',
#   'was',
#   'composed',
#   'by',
#   'louis',
#   'levy',
#   'and',
#   'written',
#   'by',
#   'ted',
#   'willis',
#   ''],
#  ['“it',
#   's',
#   'great',
#   'to',
#   'be',
#   'young',
#   '”',
#   '',
#   '1956',
#   '',
#   'was',
#   'written',
#   'by',
#   'ted',
#   'willis',
#   'and',
#   'features',
#   'music',
#   'by',
#   'louis',
#   'levy',
#   ''],
#  ['a',
#   'main',
#   'role',
#   'in',
#   'the',
#   'movie',
#   'was',
#   'given',
#   'to',
#   'cecil',
#   'parker',
#   ''],
#  ['louis',
#   'levy',
#   'is',
#   'the',
#   'composer',
#   'of',
#   'the',
#   '1956',
#   'film',
#   'it',
#   's',
#   'great',
#   'to',
#   'be',
#   'young',
#   '',
#   'which',
#   'is',
#   'written',
#   'by',
#   'ted',
#   'willis',
#   'and',
#   'stars',
#   'cecil',
#   'parker',
#   ''],
#  ['aaron',
#   'turner',
#   'is',
#   'a',
#   'post',
#   '',
#   'metal',
#   'musician',
#   'from',
#   'massachusetts',
#   'who',
#   'plays',
#   'the',
#   'electric',
#   'guitar',
#   ''],
#  ['he',
#   'started',
#   'performing',
#   'in',
#   '1995',
#   'and',
#   'is',
#   'a',
#   'musician',
#   'in',
#   'the',
#   'lotus',
#   'eaters',
#   'band',
#   ''],
#  ['aaron',
#   'turner',
#   'is',
#   'a',
#   'post',
#   '',
#   'metal',
#   'musician',
#   'born',
#   'in',
#   'massachusetts',
#   'who',
#   'plays',
#   'electric',
#   'guitar',
#   '',
#   'started',
#   'performing',
#   'in',
#   '1995',
#   'and',
#   'is',
#   'in',
#   'the',
#   'lotus',
#   'eaters',
#   'band',
#   ''],
#  ['aaron',
#   'turner',
#   'is',
#   'a',
#   'post',
#   'metal',
#   'performer',
#   'from',
#   'massachusetts',
#   'who',
#   'plays',
#   'the',
#   'electric',
#   'guitar',
#   '',
#   'started',
#   'performing',
#   'in',
#   '1995',
#   'and',
#   'is',
#   'in',
#   'the',
#   'lotus',
#   'eaters',
#   'band',
#   ''],
#  ['pennsylvania',
#   's',
#   'franklin',
#   'county',
#   'is',
#   'found',
#   'to',
#   'the',
#   'west',
#   'of',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'and',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   'is',
#   'to',
#   'the',
#   'southeast',
#   ''],
#  ['a',
#   'monument',
#   'to',
#   'the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'was',
#   'erected',
#   'in',
#   '2000',
#   'in',
#   'adams',
#   'county',
#   'and',
#   'this',
#   'monument',
#   'is',
#   'classed',
#   'as',
#   'a',
#   'contributing',
#   'property',
#   ''],
#  ['the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'was',
#   'established',
#   'in',
#   '2000',
#   'in',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'which',
#   'has',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   'to',
#   'its',
#   'southeast',
#   'and',
#   'franklin',
#   'county',
#   '',
#   'pennsylvania',
#   'to',
#   'its',
#   'west',
#   ''],
#  ['the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'is',
#   'in',
#   'the',
#   'category',
#   'of',
#   'contributing',
#   'property',
#   ''],
#  ['the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   '',
#   'established',
#   'in',
#   '2000',
#   '',
#   'falls',
#   'under',
#   'the',
#   'category',
#   'of',
#   'contributing',
#   'property',
#   'and',
#   'is',
#   'located',
#   'in',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   '',
#   'which',
#   'has',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   'to',
#   'the',
#   'southeast',
#   'and',
#   'franklin',
#   'county',
#   '',
#   'pennsylvania',
#   'to',
#   'the',
#   'east',
#   ''],
#  ['the',
#   'band',
#   'nord',
#   'is',
#   'a',
#   'sludge',
#   'metal',
#   'band',
#   'that',
#   'releases',
#   'post',
#   '',
#   'metal',
#   ''],
#  ['they',
#   'have',
#   'an',
#   'album',
#   'called',
#   'the',
#   'year',
#   'of',
#   'no',
#   'light',
#   'that',
#   'was',
#   'released',
#   'on',
#   'june',
#   '9th',
#   '2006',
#   '',
#   'and',
#   'was',
#   'under',
#   'crucial',
#   'blast',
#   'label',
#   ''],
#  ['year',
#   'of',
#   'no',
#   'light',
#   'self',
#   '',
#   'produced',
#   'their',
#   'album',
#   'nord',
#   ''],
#  ['the',
#   'album',
#   'was',
#   'released',
#   'under',
#   'the',
#   'label',
#   'crucial',
#   'blast',
#   'on',
#   'september',
#   '6th',
#   '',
#   '2006',
#   ''],
#  ['nord',
#   'falls',
#   'into',
#   'the',
#   'sludge',
#   'metal',
#   'and',
#   'post',
#   '',
#   'metal',
#   'genres',
#   ''],
#  ['ciudad',
#   'ayala',
#   'is',
#   'a',
#   'metropolitan',
#   'city',
#   'which',
#   'has',
#   'population',
#   'of',
#   '1777539',
#   'with',
#   'its',
#   'population',
#   'density',
#   'of',
#   '16040',
#   'and',
#   'it',
#   'falls',
#   'into',
#   'utc',
#   'offset',
#   '6',
#   'time',
#   'zone',
#   ''],
#  ['one',
#   'of',
#   'the',
#   'leaders',
#   'of',
#   'ciudad',
#   'ayala',
#   'is',
#   'the',
#   'city',
#   'manager',
#   'which',
#   'uses',
#   'council',
#   '',
#   'manager',
#   'government',
#   ''],
#  ['the',
#   'city',
#   'ciudad',
#   'ayala',
#   'has',
#   'population',
#   '1777539',
#   'making',
#   'the',
#   'density',
#   '16040',
#   ''],
#  ['one',
#   'of',
#   'the',
#   'leaders',
#   'in',
#   'the',
#   'council',
#   '',
#   'manager',
#   'government',
#   'is',
#   'the',
#   'city',
#   'manager',
#   ''],
#  ['it',
#   'is',
#   'in',
#   'utc',
#   'offset',
#   '6the',
#   'city',
#   'ciudad',
#   'ayala',
#   'has',
#   'population',
#   '1777539',
#   'making',
#   'the',
#   'density',
#   '1604',
#   ''],
#  ['it',
#   'is',
#   'a',
#   'council',
#   '',
#   'managed',
#   'government',
#   'led',
#   'by',
#   'a',
#   'city',
#   'manager',
#   ''],
#  ['it', 'is', 'in', 'utc', 'offset', '6super'],
#  ['capers',
#   'is',
#   'a',
#   '98',
#   'minute',
#   'film',
#   'with',
#   'a',
#   '',
#   '20000000',
#   'budget',
#   ''],
#  ['it',
#   'stars',
#   'tom',
#   'sizemore',
#   'and',
#   'michael',
#   'rooker',
#   '',
#   'and',
#   'was',
#   'written',
#   'and',
#   'directed',
#   'by',
#   'ray',
#   'griggs',
#   ''],
#  ['super',
#   'capers',
#   'is',
#   'a',
#   '98',
#   'minute',
#   'movie',
#   'starring',
#   'michael',
#   'rooker',
#   'and',
#   'tom',
#   'sizemore',
#   ''],
#  ['it', 'was', 'written', 'and', 'directed', 'by', 'ray', 'griggs', ''],
#  ['it',
#   'had',
#   'a',
#   'budget',
#   'of',
#   '',
#   '2000000the',
#   '98',
#   'minute',
#   'film',
#   'super',
#   'capers',
#   'had',
#   'a',
#   'budget',
#   'of',
#   '2',
#   'million',
#   'dollars',
#   ''],
#  ['it', 'was', 'written', 'and', 'directed', 'by', 'ray', 'griggs', ''],
#  ['it',
#   'starred',
#   'tom',
#   'sizemore',
#   'and',
#   'also',
#   'featured',
#   'michael',
#   'rooker',
#   ''],
#  ['darinka',
#   'dentcheva',
#   'developed',
#   'a',
#   'theory',
#   'influenced',
#   'by',
#   'andrzej',
#   'piotr',
#   'ruszczyński',
#   ''],
#  ['darinka',
#   'dentcheva',
#   'was',
#   'influenced',
#   'by',
#   'andrzej',
#   'piotr',
#   'ruszczyński',
#   ''],
#  ['darinka',
#   'dentcheva',
#   'was',
#   'influenced',
#   'by',
#   'andrzej',
#   'piotr',
#   'ruszczynski',
#   ''],
#  ['born',
#   'in',
#   '1878',
#   '',
#   'harry',
#   'carey',
#   'later',
#   'grew',
#   'up',
#   'to',
#   'write',
#   'and',
#   'star',
#   'in',
#   'the',
#   'movie',
#   'mcveagh',
#   'of',
#   'the',
#   'south',
#   'seas',
#   ''],
#  ['harry',
#   'carey',
#   '',
#   'born',
#   'in',
#   '1878',
#   '',
#   'wrote',
#   'and',
#   'appeared',
#   'in',
#   'the',
#   'movie',
#   'mcveagh',
#   'of',
#   'the',
#   'south',
#   'seas',
#   ''],
#  ['harry',
#   'carey',
#   '',
#   'who',
#   'was',
#   'born',
#   'in',
#   '1878',
#   '',
#   'wrote',
#   'and',
#   'starred',
#   'the',
#   'film',
#   'of',
#   'mcveagh',
#   'of',
#   'the',
#   'south',
#   'seas',
#   ''],
#  ['mexicans',
#   '',
#   'the',
#   'inhabitants',
#   'of',
#   'mexico',
#   '',
#   'can',
#   'use',
#   'their',
#   'peso',
#   'currency',
#   'to',
#   'purchase',
#   'a',
#   'dessert',
#   'called',
#   'bionico',
#   ''],
#  ['bionico',
#   'can',
#   'be',
#   'found',
#   'in',
#   'guadalajara',
#   '',
#   'mexico',
#   '',
#   'and',
#   'is',
#   'made',
#   'from',
#   'sour',
#   'cream',
#   '',
#   'chopped',
#   'fruits',
#   '',
#   'condensed',
#   'milk',
#   '',
#   'granola',
#   '',
#   'coconut',
#   'and',
#   'raisins',
#   ''],
#  ['they', 'can', 'also', 'buy', 'cookies', '', 'another', 'dessert', ''],
#  ['much',
#   'like',
#   'a',
#   'cookie',
#   '',
#   'bionico',
#   'is',
#   'a',
#   'dessert',
#   'food',
#   'whose',
#   'ingredients',
#   'include',
#   'chopped',
#   'fruits',
#   '',
#   'sour',
#   'cream',
#   '',
#   'condensed',
#   'milk',
#   '',
#   'granola',
#   '',
#   'shredded',
#   'coconut',
#   'and',
#   'raisins',
#   ''],
#  ['bionico',
#   'is',
#   'found',
#   'in',
#   'the',
#   'guadalajara',
#   'region',
#   'of',
#   'mexico',
#   '',
#   'which',
#   'uses',
#   'pesos',
#   'are',
#   'their',
#   'currency',
#   'and',
#   'is',
#   'home',
#   'to',
#   'mexican',
#   'people',
#   ''],
#  ['mexico',
#   'inhabited',
#   'by',
#   'mexicans',
#   'has',
#   'peso',
#   'as',
#   'its',
#   'currency',
#   ''],
#  ['bionico',
#   '',
#   'a',
#   'dessert',
#   'food',
#   'found',
#   'in',
#   'guadalajara',
#   '',
#   'mexico',
#   '',
#   'has',
#   'sour',
#   'cream',
#   '',
#   'chopped',
#   'fruits',
#   '',
#   'condensed',
#   'milk',
#   '',
#   'granola',
#   '',
#   'raisins',
#   'and',
#   'shredded',
#   'coconut',
#   'as',
#   'its',
#   'main',
#   'ingredients',
#   ''],
#  ['cookie', 'is', 'a', 'type', 'of', 'dessert', ''],
#  ['one',
#   'of',
#   'the',
#   'leader',
#   'of',
#   'ciudad',
#   'ayala',
#   '',
#   'a',
#   'city',
#   '',
#   'is',
#   'called',
#   'city',
#   'manager',
#   ''],
#  ['with',
#   'a',
#   'population',
#   'density',
#   'of',
#   '16040ciudad',
#   'ayala',
#   'is',
#   'a',
#   'city',
#   'with',
#   'a',
#   'population',
#   'density',
#   'of',
#   '1604',
#   ''],
#  ['one', 'of', 'the', 'leaders', 'is', 'called', 'the', 'city', 'manager', ''],
#  ['one',
#   'of',
#   'the',
#   'leaders',
#   'of',
#   'ciudad',
#   'ayala',
#   '',
#   'a',
#   'city',
#   'with',
#   'a',
#   'population',
#   'density',
#   'of',
#   '16040',
#   '',
#   'is',
#   'the',
#   'city',
#   'manager',
#   ''],
#  ['enaire',
#   '',
#   'based',
#   'in',
#   'madrid',
#   '',
#   'spain',
#   '',
#   'is',
#   'the',
#   'operating',
#   'organisation',
#   'for',
#   'adolfo',
#   'suarez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   'which',
#   'is',
#   'in',
#   'alcobendas',
#   ''],
#  ['the',
#   'runway',
#   'length',
#   'at',
#   'the',
#   'airport',
#   'is',
#   '3500located',
#   'in',
#   'madrid',
#   '',
#   'spain',
#   '',
#   'enaire',
#   'operates',
#   'the',
#   'adolfo',
#   'suarez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   'in',
#   'alcobendas',
#   'which',
#   'reports',
#   'a',
#   'runway',
#   'length',
#   'of',
#   '3500adolfo',
#   'suarez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   '',
#   'operated',
#   'by',
#   'enaire',
#   '',
#   'is',
#   'located',
#   'in',
#   'alcobendas',
#   'while',
#   'enaire',
#   'is',
#   'located',
#   'in',
#   'madrid',
#   '',
#   'spain',
#   ''],
#  ['the',
#   'airport',
#   's',
#   'runway',
#   'length',
#   'is',
#   '3500bionico',
#   'is',
#   'a',
#   'dish',
#   'served',
#   'for',
#   'dessert',
#   'in',
#   'mexico',
#   '',
#   'where',
#   'the',
#   'currency',
#   'is',
#   'the',
#   'peso',
#   '',
#   'the',
#   'dish',
#   'contains',
#   'granola',
#   ''],
#  ['bionico',
#   '',
#   'a',
#   'food',
#   'that',
#   'requires',
#   'granola',
#   'as',
#   'one',
#   'of',
#   'its',
#   'ingredients',
#   'and',
#   'served',
#   'at',
#   'the',
#   'dessert',
#   'is',
#   'found',
#   'in',
#   'mexico',
#   ''],
#  ['the', 'currency', 'is', 'the', 'peso', ''],
#  ['bionico',
#   'is',
#   'a',
#   'food',
#   'found',
#   'in',
#   'mexico',
#   '',
#   'currency',
#   '',
#   'peso',
#   '',
#   ''],
#  ['bionico',
#   '',
#   'dessert',
#   '',
#   'requires',
#   'granola',
#   'as',
#   'one',
#   'of',
#   'its',
#   'ingredients',
#   ''],
#  ['with',
#   'a',
#   'periapsis',
#   'of',
#   '2608550000000',
#   '',
#   'the',
#   '1147',
#   'stavropolis',
#   'has',
#   'a',
#   'epoch',
#   'of',
#   '31',
#   'july',
#   '2016',
#   '',
#   'jd245760051147',
#   'stavropolis',
#   'epoch',
#   'is',
#   '31',
#   'july',
#   '2016',
#   '',
#   'julian',
#   'day',
#   '24576005',
#   '',
#   'and',
#   'the',
#   'periapsis',
#   'of',
#   '1147',
#   'stavropolis',
#   'is',
#   '2608550000001147'],
#  ['stavropolis',
#   'has',
#   'an',
#   'epoch',
#   'on',
#   '31',
#   'july',
#   '2016',
#   'and',
#   'a',
#   'periapsis',
#   'of',
#   '2608550000000ciudad',
#   'ayala',
#   'which',
#   'is',
#   'in',
#   'the',
#   'pacific',
#   'daylight',
#   'time',
#   'zone',
#   'has',
#   'the',
#   'population',
#   'density',
#   'of',
#   '1604ciudad',
#   'ayala',
#   'city',
#   'which',
#   'has',
#   'a',
#   'pdt',
#   'time',
#   'zone',
#   'has',
#   'a',
#   'population',
#   'density',
#   'of',
#   '16040ciudad',
#   'ayala',
#   's',
#   'time',
#   'zone',
#   'is',
#   'pacific',
#   'daylight',
#   'time',
#   'and',
#   'its',
#   'population',
#   'density',
#   'is',
#   '16040the',
#   'net',
#   'income',
#   'of',
#   'chinabank',
#   'is',
#   '15100000000',
#   '',
#   'and',
#   'they',
#   'have',
#   '5594',
#   'workers',
#   'total',
#   ''],
#  ['chinabank',
#   'currently',
#   'brings',
#   'in',
#   'a',
#   'net',
#   'income',
#   'of',
#   '15100000000',
#   'thanks',
#   'to',
#   'the',
#   'efforts',
#   'of',
#   'its',
#   '5594',
#   'employees',
#   ''],
#  ['chinabank',
#   'brings',
#   'in',
#   'a',
#   'net',
#   'income',
#   'of',
#   '15100000000',
#   'with',
#   'its',
#   '5594',
#   'employees',
#   ''],
#  ['steve',
#   'bright',
#   'is',
#   'the',
#   'creator',
#   'of',
#   'bananaman',
#   'which',
#   'was',
#   'last',
#   'broadcast',
#   'on',
#   'april',
#   '15th',
#   '1986',
#   'by',
#   'the',
#   'bbcbananaman',
#   'was',
#   'created',
#   'by',
#   'steve',
#   'bright',
#   'and',
#   'last',
#   'aired',
#   'on',
#   'april',
#   '15th',
#   '1986',
#   ''],
#  ['it',
#   'was',
#   'broadcast',
#   'by',
#   'the',
#   'bbcbananaman',
#   '',
#   'the',
#   'tv',
#   'show',
#   '',
#   'was',
#   'created',
#   'by',
#   'steve',
#   'bright',
#   'and',
#   'was',
#   'last',
#   'aired',
#   'on',
#   '15th',
#   'april',
#   '1986',
#   ''],
#  ['bananaman',
#   'was',
#   'broadcast',
#   'on',
#   'the',
#   'bbcbionico',
#   '',
#   'a',
#   'dish',
#   'served',
#   'for',
#   'dessert',
#   '',
#   'is',
#   'a',
#   'food',
#   'found',
#   'in',
#   'guadalajara',
#   'in',
#   'mexico',
#   ''],
#  ['the',
#   'currency',
#   'in',
#   'mexico',
#   'is',
#   'the',
#   'mexican',
#   'peso',
#   'inhabited',
#   'by',
#   'mexicans',
#   ''],
#  ['bionico',
#   '',
#   'a',
#   'dessert',
#   '',
#   'is',
#   'a',
#   'food',
#   'found',
#   'in',
#   'guadalajara',
#   'in',
#   'mexico',
#   ''],
#  ['the',
#   'currency',
#   'in',
#   'mexico',
#   'is',
#   'the',
#   'mexican',
#   'peso',
#   'inhabited',
#   'by',
#   'the',
#   'mexicans',
#   ''],
#  ['bionico',
#   'is',
#   'a',
#   'food',
#   'found',
#   'in',
#   'mexico',
#   'and',
#   'served',
#   'at',
#   'the',
#   'dessert',
#   'course',
#   ''],
#  ['the', 'dessert', 'can', 'be', 'found', 'in', 'guadalajara', ''],
#  ['the',
#   'currency',
#   'of',
#   'mexico',
#   '',
#   'inhabited',
#   'by',
#   'mexicans',
#   '',
#   'is',
#   'peso',
#   ''],
#  ['the',
#   'year',
#   'of',
#   'no',
#   'light',
#   'album',
#   'live',
#   'at',
#   'roadburn',
#   '2008',
#   'was',
#   'followed',
#   'by',
#   'their',
#   'album',
#   'nord',
#   ''],
#  ['live',
#   'at',
#   'roadburn',
#   '2008',
#   'was',
#   'preceded',
#   'by',
#   'the',
#   'album',
#   'nord',
#   'played',
#   'by',
#   'year',
#   'of',
#   'no',
#   'light',
#   ''],
#  ['year',
#   'of',
#   'no',
#   'light',
#   '',
#   'who',
#   'released',
#   'the',
#   'album',
#   'nord',
#   '',
#   'followed',
#   'this',
#   'up',
#   'with',
#   'the',
#   'album',
#   'live',
#   'at',
#   'roadburn',
#   '2008alan'],
#  ['shepard',
#   'was',
#   'a',
#   'crew',
#   'member',
#   'of',
#   'apollo',
#   '14',
#   'who',
#   'was',
#   'born',
#   'november',
#   '18th',
#   '',
#   '1923',
#   '',
#   'in',
#   'new',
#   'hampshire',
#   'and',
#   'died',
#   'in',
#   'california',
#   ''],
#  ['alan',
#   'shepard',
#   'was',
#   'born',
#   'in',
#   'new',
#   'hampshire',
#   'on',
#   'november',
#   '18',
#   '',
#   '1923',
#   ''],
#  ['he',
#   'was',
#   'a',
#   'crew',
#   'member',
#   'of',
#   'apollo',
#   '14',
#   '',
#   'and',
#   'died',
#   'later',
#   'on',
#   'in',
#   'california',
#   ''],
#  ['alan',
#   'shepard',
#   'was',
#   'born',
#   'on',
#   'nov',
#   '18',
#   '',
#   '1923',
#   'in',
#   'new',
#   'hampshire',
#   '',
#   'was',
#   'a',
#   'member',
#   'of',
#   'the',
#   'apollo',
#   '14',
#   'crew',
#   'and',
#   'died',
#   'in',
#   'california',
#   ''],
#  ['the',
#   'alco',
#   'rs3',
#   '',
#   'with',
#   'a',
#   'four',
#   '',
#   'stroke',
#   'engine',
#   'and',
#   '12',
#   'cylinders',
#   '',
#   'has',
#   'a',
#   'length',
#   'of',
#   '170688',
#   'millimetres',
#   ''],
#  ['the',
#   'four',
#   '',
#   'stroke',
#   '12',
#   'cylinder',
#   'alco',
#   'rs3',
#   'is',
#   '170688',
#   'millimetres',
#   'long',
#   ''],
#  ['the',
#   'alco',
#   'rs3',
#   'has',
#   'a',
#   'four',
#   '',
#   'stroke',
#   'engine',
#   'and',
#   'a',
#   'cylinder',
#   'count',
#   'of',
#   '12',
#   'which',
#   'is',
#   '170688',
#   'mm',
#   'in',
#   'length',
#   ''],
#  ['olga',
#   'nikolaevna',
#   'bondareva',
#   '',
#   '',
#   'born',
#   'april',
#   '27',
#   '',
#   '1937',
#   '',
#   'died',
#   'in',
#   'saint',
#   'petersburg',
#   ''],
#  ['she',
#   'was',
#   'best',
#   'known',
#   'for',
#   'the',
#   '',
#   'bondareva',
#   '',
#   'shapley',
#   'theorem',
#   ''],
#  ['olga',
#   'nikolaevna',
#   'bondareva',
#   '',
#   'known',
#   'for',
#   'the',
#   'bondareva',
#   '',
#   'shapley',
#   'theorem',
#   '',
#   'was',
#   'born',
#   'on',
#   'april',
#   '27',
#   '',
#   '1937',
#   'and',
#   'died',
#   'in',
#   'saint',
#   'petersburg',
#   ''],
#  ['olga',
#   'bondareva',
#   '',
#   'born',
#   '',
#   'olga',
#   'nikolaevna',
#   'bondareva',
#   '',
#   'on',
#   'april',
#   '27th',
#   '',
#   '1937',
#   'and',
#   'known',
#   'for',
#   'the',
#   'bondareva',
#   '',
#   'shapley',
#   'theorem',
#   '',
#   'died',
#   'in',
#   'saint',
#   'petersburg',
#   ''],
#  ['fellowship',
#   'of',
#   'the',
#   'ring',
#   '',
#   'a',
#   'fantasy',
#   'novel',
#   'created',
#   'by',
#   'jrr',
#   'tolkien',
#   'was',
#   'released',
#   'on',
#   'july',
#   '29',
#   '',
#   '1954',
#   '',
#   'the',
#   'hobbit',
#   'came',
#   'before',
#   'the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   ''],
#  ['jrr',
#   'tolkien',
#   'is',
#   'the',
#   'author',
#   'of',
#   'the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   'published',
#   'on',
#   'july',
#   '29',
#   '',
#   '1954',
#   ''],
#  ['this',
#   'book',
#   'belongs',
#   'to',
#   'the',
#   'fantasy',
#   'genre',
#   'and',
#   'came',
#   'after',
#   'the',
#   'hobbit',
#   ''],
#  ['fantasy',
#   'is',
#   'the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   's',
#   'genre',
#   '',
#   'and',
#   'it',
#   'was',
#   'released',
#   'on',
#   'july',
#   '29',
#   '',
#   '1954',
#   ''],
#  ['the',
#   'fellowship',
#   'of',
#   'the',
#   'ring',
#   'was',
#   'written',
#   'by',
#   'jrr',
#   'tolkien',
#   'and',
#   'was',
#   'preceded',
#   'by',
#   'the',
#   'hobbit',
#   ''],
#  ['train',
#   's',
#   'hit',
#   'mermaid',
#   'was',
#   'put',
#   'out',
#   'by',
#   'the',
#   'sony',
#   'music',
#   'entertainment',
#   'record',
#   'label',
#   '',
#   'was',
#   'written',
#   'by',
#   'amund',
#   'bjørklund',
#   'with',
#   'the',
#   'producer',
#   'stargate',
#   ''],
#  ['train',
#   'followed',
#   'mermaid',
#   'with',
#   'imagine',
#   '',
#   'a',
#   'song',
#   'by',
#   'john',
#   'lennon',
#   'where',
#   'mermaid',
#   'was',
#   'produced',
#   'by',
#   'the',
#   'espionage',
#   'production',
#   'team',
#   ''],
#  ['the',
#   'song',
#   'mermaid',
#   '',
#   'by',
#   'train',
#   '',
#   'is',
#   'a',
#   'sony',
#   'music',
#   'entertainment',
#   'release',
#   'produced',
#   'by',
#   'stargate',
#   'along',
#   'with',
#   'the',
#   'production',
#   'team',
#   'espionage',
#   ''],
#  ['mermaid',
#   '',
#   'written',
#   'by',
#   'amund',
#   'bjorklund',
#   '',
#   'is',
#   'followed',
#   'by',
#   'john',
#   'lennon',
#   's',
#   'imagine',
#   ''],
#  ['the',
#   'train',
#   'song',
#   'mermaid',
#   'written',
#   'by',
#   'amund',
#   'bjørklund',
#   'and',
#   'production',
#   'team',
#   'stargate',
#   'was',
#   'produced',
#   'by',
#   'the',
#   'production',
#   'team',
#   'espionage',
#   'and',
#   'released',
#   'under',
#   'the',
#   'record',
#   'label',
#   'sony',
#   'music',
#   'entertainment',
#   ''],
#  ['it',
#   'was',
#   'followed',
#   'by',
#   'the',
#   'release',
#   'of',
#   'imagine',
#   'by',
#   'john',
#   'lennon',
#   'performed',
#   'by',
#   'train',
#   ''],
#  ['year',
#   'of',
#   'no',
#   'light',
#   'produced',
#   'an',
#   'album',
#   'called',
#   'nord',
#   'on',
#   '692006',
#   'which',
#   'is',
#   '5841',
#   'minutes',
#   'long',
#   ''],
#  ['they',
#   'came',
#   'out',
#   'with',
#   'the',
#   'demo',
#   '2004',
#   'album',
#   'first',
#   '',
#   'followed',
#   'by',
#   'nord',
#   '',
#   'and',
#   'then',
#   'the',
#   'album',
#   'live',
#   'at',
#   'roadburn',
#   'in',
#   '2008the',
#   'year',
#   'of',
#   'no',
#   'light',
#   'album',
#   'nord',
#   'with',
#   'runtime',
#   'of',
#   '5841',
#   'minutes',
#   'was',
#   'released',
#   'by',
#   'the',
#   'artist',
#   'on',
#   'the',
#   'date',
#   '2006',
#   '',
#   '09',
#   '',
#   '06',
#   ''],
#  ['it',
#   'was',
#   'preceded',
#   'by',
#   'year',
#   'of',
#   'no',
#   'light',
#   's',
#   'album',
#   'demo',
#   '2004',
#   'and',
#   'followed',
#   'by',
#   'year',
#   'of',
#   'no',
#   'light',
#   's',
#   'album',
#   'live',
#   'at',
#   'roadburn',
#   '2008the',
#   'album',
#   'nord',
#   'by',
#   'year',
#   'of',
#   'no',
#   'light',
#   'with',
#   'runtime',
#   'of',
#   '58',
#   'minutes',
#   'and',
#   '41',
#   'seconds',
#   'was',
#   'released',
#   'on',
#   'september',
#   '6',
#   '',
#   '2006the',
#   'album',
#   'nord',
#   'was',
#   'preceded',
#   'by',
#   'the',
#   'album',
#   'demo',
#   '2004',
#   'and',
#   'followed',
#   'by',
#   'live',
#   'at',
#   'roadburn',
#   '2008',
#   'the'],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'is',
#   'placed',
#   'in',
#   'the',
#   'municipality',
#   'of',
#   'gettysburg',
#   'in',
#   'pennsylvania',
#   '',
#   'in',
#   'adams',
#   'county',
#   '',
#   'usa',
#   ''],
#  ['adams',
#   'county',
#   'has',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   'to',
#   'its',
#   'southeast',
#   'and',
#   'the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'is',
#   'categorized',
#   'as',
#   'a',
#   'contributing',
#   'property',
#   ''],
#  ['the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'is',
#   'categorised',
#   'as',
#   'a',
#   'contributing',
#   'property',
#   'and',
#   'stands',
#   'in',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'in',
#   'the',
#   'municipality',
#   'of',
#   'gettysburg',
#   'in',
#   'the',
#   'usa',
#   ''],
#  ['carroll',
#   'county',
#   'maryland',
#   'is',
#   'southeast',
#   'of',
#   'adams',
#   'county',
#   ''],
#  ['the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   's',
#   'location',
#   'is',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   '',
#   'usa',
#   '',
#   'in',
#   'the',
#   'municipality',
#   'of',
#   'gettysburg',
#   ''],
#  ['to',
#   'the',
#   'southeast',
#   'of',
#   'adams',
#   'county',
#   '',
#   'lies',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   ''],
#  ['the',
#   '11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'is',
#   'a',
#   'contributing',
#   'property',
#   ''],
#  ['israeli',
#   'national',
#   'liselotte',
#   'grschebina',
#   'was',
#   'born',
#   'in',
#   'the',
#   'german',
#   'empire',
#   'and',
#   'died',
#   'in',
#   'israel',
#   'on',
#   'june',
#   '14',
#   '',
#   '1994liselotte',
#   'grschebina',
#   'died',
#   'in',
#   'israel',
#   'on',
#   'june',
#   '14',
#   '',
#   '1994',
#   ''],
#  ['though',
#   'she',
#   'had',
#   'israeli',
#   'nationality',
#   '',
#   'she',
#   'was',
#   'born',
#   'in',
#   'the',
#   'german',
#   'empire',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'was',
#   'an',
#   'israeli',
#   'national',
#   'born',
#   'in',
#   'the',
#   'german',
#   'empire',
#   ''],
#  ['she', 'died', 'on', 'june', '14', '', '1994', 'in', 'israel', ''],
#  ['located',
#   'in',
#   'king',
#   'of',
#   'prussia',
#   '',
#   'pennsylvania',
#   '',
#   'amerigas',
#   'is',
#   'an',
#   'energy',
#   'company',
#   'that',
#   'serves',
#   'the',
#   'united',
#   'states',
#   ''],
#  ['amerigas',
#   'has',
#   'an',
#   'operating',
#   'income',
#   'of',
#   '',
#   '380700000',
#   'and',
#   'net',
#   'income',
#   'of',
#   '',
#   '211200000currently',
#   'serving',
#   'all',
#   'regions',
#   'of',
#   'the',
#   'united',
#   'states',
#   '',
#   'amerigas',
#   'is',
#   'headquartered',
#   'in',
#   'the',
#   'king',
#   'of',
#   'prussia',
#   '',
#   'pennsylvania',
#   'in',
#   'the',
#   'united',
#   'states',
#   ''],
#  ['an',
#   'established',
#   'company',
#   'in',
#   'the',
#   'energy',
#   'industry',
#   '',
#   'amerigas',
#   'has',
#   'an',
#   'operating',
#   'income',
#   'of',
#   '',
#   '380700000',
#   'and',
#   'a',
#   'net',
#   'income',
#   'of',
#   '',
#   '211200000a',
#   'us',
#   'provider',
#   'in',
#   'the',
#   'energy',
#   'industry',
#   '',
#   'amerigas',
#   'is',
#   'located',
#   'in',
#   'the',
#   'king',
#   'of',
#   'prussia',
#   '',
#   'pennsylvania',
#   'in',
#   'the',
#   'united',
#   'states',
#   '',
#   'and',
#   'has',
#   'an',
#   'operating',
#   'income',
#   'of',
#   '',
#   '380700000',
#   'with',
#   'a',
#   'net',
#   'income',
#   'of',
#   '',
#   '211200000discovered',
#   'in',
#   '1927',
#   'by',
#   'grigory',
#   'neujmin',
#   '',
#   '1147',
#   'stavropolis',
#   'has',
#   'an',
#   'apoapsis',
#   'of',
#   '418476000000',
#   'and',
#   'an',
#   'orbital',
#   'period',
#   'of',
#   '12496',
#   'days',
#   ''],
#  ['the',
#   'asteroid',
#   '1147',
#   'stavropolis',
#   'was',
#   'discovered',
#   'by',
#   'grigory',
#   'neujmin',
#   'on',
#   'the',
#   '11th',
#   'of',
#   'june',
#   '1929',
#   ''],
#  ['it',
#   'has',
#   'an',
#   'orbital',
#   'period',
#   'of',
#   '12496',
#   'days',
#   'and',
#   'an',
#   'apoapsis',
#   'of',
#   '41847600000001147',
#   'stavropolis',
#   'is',
#   'an',
#   'asteroid',
#   '',
#   'discovered',
#   'on',
#   '11',
#   'june',
#   '1929',
#   'by',
#   'grigory',
#   'neujmin',
#   ''],
#  ['its',
#   'apoapsis',
#   'is',
#   '4184760000000',
#   'au',
#   'and',
#   'the',
#   'orbital',
#   'period',
#   'is'],
#  ['12496ciudad',
#   'ayala',
#   'is',
#   'a',
#   'city',
#   'which',
#   'is',
#   'located',
#   '1147',
#   'm',
#   'above',
#   'sea',
#   'level',
#   'and',
#   'has',
#   'a',
#   'utc',
#   'offset',
#   'of',
#   '6',
#   ''],
#  ['ciudad',
#   'ayala',
#   'is',
#   'located',
#   'in',
#   'mexico',
#   'and',
#   'has',
#   'a',
#   'leader',
#   'called',
#   'the',
#   'governator',
#   ''],
#  ['ciudad',
#   'ayala',
#   'ruled',
#   'by',
#   'governator',
#   'is',
#   'in',
#   'the',
#   'country',
#   'of',
#   'mexico',
#   'with',
#   'offset',
#   'of',
#   '6',
#   'as',
#   'well',
#   'as',
#   'sea',
#   'level',
#   'of',
#   '11470ciudad',
#   'ayala',
#   'is',
#   'located',
#   'in',
#   'mexico',
#   '',
#   'with',
#   'a',
#   'utc',
#   'offset'],
#  ['6', ''],
#  ['the',
#   'city',
#   'has',
#   'an',
#   'elevation',
#   'of',
#   '11470',
#   'above',
#   'sea',
#   'level',
#   'and',
#   'its',
#   'leader',
# ...
#   'institute',
#   'of',
#   'technology',
#   'was',
#   'given',
#   'the',
#   '',
#   'technical',
#   'campus',
#   '',
#   'status',
#   'by',
#   'all',
#   'india',
#   'council',
#   'for',
#   'technical',
#   'education',
#   '',
#   'has',
#   'tennis',
#   'as',
#   'one',
#   'of',
#   'their',
#   'sports',
#   'offered',
#   'and',
#   'is',
#   'affiliated',
#   'with',
#   'the',
#   'visvesvaraya',
#   'technological',
#   'university',
#   ''],
#  ['all',
#   'india',
#   'council',
#   'for',
#   'technical',
#   'education',
#   'is',
#   'located',
#   'in',
#   'mumbai',
#   'and',
#   'the',
#   'campus',
#   'of',
#   'the',
#   'acharya',
#   'institute',
#   'of',
#   'technology',
#   'is',
#   'located',
#   'at',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '–',
#   '560090tom',
#   'sizemore',
#   'stars',
#   'in',
#   'super',
#   'capers',
#   'which',
#   'starred',
#   'michael',
#   'rooker',
#   ''],
#  ['the',
#   'film',
#   'super',
#   'capers',
#   'stars',
#   'both',
#   'michael',
#   'rooker',
#   'and',
#   'tom',
#   'sizemore',
#   ''],
#  ['tom',
#   'sizemore',
#   'stars',
#   'in',
#   'super',
#   'capers',
#   '',
#   'a',
#   'film',
#   'in',
#   'which',
#   'michael',
#   'rooker',
#   'also',
#   'plays',
#   'in',
#   ''],
#  ['super',
#   'capers',
#   'starred',
#   'michael',
#   'rooker',
#   '',
#   'who',
#   'was',
#   'born',
#   'in',
#   'jasper',
#   '',
#   'alabama',
#   ''],
#  ['super',
#   'capers',
#   'is',
#   'a',
#   'film',
#   'starring',
#   'michael',
#   'rooker',
#   '',
#   'who',
#   'was',
#   'born',
#   'in',
#   'jasper',
#   '',
#   'alabama',
#   ''],
#  ['michael',
#   'rooker',
#   '',
#   'who',
#   'played',
#   'in',
#   'super',
#   'capers',
#   '',
#   'was',
#   'born',
#   'in',
#   'jasper',
#   '',
#   'alabama',
#   ''],
#  ['grigory',
#   'neujmin',
#   'discovered',
#   '1147',
#   'stavropolis',
#   'on',
#   'june',
#   '11th',
#   '',
#   '1929',
#   ''],
#  ['it',
#   'has',
#   'an',
#   'apoapsis',
#   'of',
#   '4184760000000',
#   'and',
#   'an',
#   'absolute',
#   'magnitude',
#   'of',
#   '115on',
#   'june',
#   '11',
#   '',
#   '1929',
#   '',
#   'grigory',
#   'neujmin',
#   'discovered',
#   'the',
#   'asteroid',
#   '1147',
#   'stavropolis',
#   ''],
#  ['it',
#   'has',
#   'an',
#   'apoapsis',
#   'of',
#   '4184760000000',
#   'and',
#   'an',
#   'absolute',
#   'magnitude',
#   'of',
#   '115grigory',
#   'neujmin',
#   'discovered',
#   'the',
#   'asteroid',
#   '1147',
#   'stavropolis',
#   'on',
#   'june',
#   '11',
#   '',
#   '1929',
#   ''],
#  ['it',
#   'has',
#   'an',
#   'absolute',
#   'magnitude',
#   'of',
#   '115',
#   'with',
#   '4184760000000',
#   'auafter',
#   'releasing',
#   'their',
#   'album',
#   'squeeze',
#   '',
#   'music',
#   'group',
#   'the',
#   'velvet',
#   'underground',
#   'produced',
#   'and',
#   'released',
#   'rock',
#   'music',
#   'album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   '',
#   'which',
#   'they',
#   'recorded',
#   'in',
#   'st',
#   'louis',
#   'missouri',
#   '',
#   'usa'],
#  ['the',
#   'album',
#   'was',
#   'released',
#   'on',
#   '2001',
#   '',
#   '10',
#   '',
#   '16',
#   'under',
#   'the',
#   'polydor',
#   'and',
#   'universal',
#   'music',
#   'group',
#   'record',
#   'labels',
#   'and',
#   'has',
#   'a',
#   'total',
#   'run',
#   'time',
#   'of',
#   '23005',
#   'minutes',
#   ''],
#  ['bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   'with',
#   'run',
#   'time',
#   'of',
#   '23005',
#   'was',
#   'recorded',
#   'under',
#   'the',
#   'polydor',
#   'records',
#   'and',
#   'universal',
#   'music',
#   'group',
#   'record',
#   'label',
#   'in',
#   'st',
#   'louis',
#   '',
#   'missouri',
#   '',
#   'united',
#   'states',
#   'and',
#   'released',
#   'on',
#   'october',
#   '',
#   '16',
#   '',
#   '2001',
#   ''],
#  ['it',
#   'was',
#   'preceded',
#   'by',
#   'squeeze',
#   'by',
#   'the',
#   'velvet',
#   'underground',
#   ''],
#  ['the',
#   'bootleg',
#   'series',
#   'volume',
#   'i',
#   '',
#   'the',
#   'quine',
#   'tapes',
#   'with',
#   'runtime',
#   'of',
#   '23005',
#   'minutes',
#   'was',
#   'recorded',
#   'in',
#   'st',
#   'louis',
#   'missouri',
#   '',
#   'united',
#   'states',
#   'and',
#   'released',
#   'on',
#   '10',
#   '',
#   '16',
#   '',
#   '2001',
#   ''],
#  ['recorded',
#   'through',
#   'polydor',
#   'records',
#   'and',
#   'universal',
#   'music',
#   'group',
#   'record',
#   'label',
#   'the',
#   'album',
#   'was',
#   'preceded',
#   'by',
#   'the',
#   'album',
#   'squeeze1147',
#   'stavropolis',
#   'discovered',
#   'on',
#   'june',
#   '11',
#   '',
#   '1929',
#   'with',
#   'rotation',
#   'period',
#   'of',
#   '203785',
#   'has',
#   'a',
#   'periapsis',
#   'of',
#   '2608550000000',
#   'and',
#   'apoapsis',
#   'of',
#   '4184760000000',
#   ''],
#  ['the',
#   'orbital',
#   'period',
#   'of',
#   'the',
#   'asteroid',
#   'is',
#   '12496',
#   'days1147',
#   'stavropolis',
#   'is',
#   'an',
#   'asteroid',
#   '',
#   'discovered',
#   'on',
#   'june',
#   '1929',
#   ''],
#  ['it', 'has', 'a', 'rotation', 'period', 'of', '203785', ''],
#  ['its',
#   'periapsis',
#   'is',
#   '2608550000000',
#   '',
#   'the',
#   'apoapsis',
#   'of',
#   'the',
#   'asteroid',
#   'is',
#   '418476000000',
#   'au',
#   'and',
#   'the',
#   'orbital',
#   'period',
#   'is',
#   '12496the',
#   'asteroid',
#   '1147',
#   'stavropolis',
#   'discovered',
#   'on',
#   'the',
#   '11th',
#   'of',
#   'june',
#   '1929',
#   'with',
#   'a',
#   'rotation',
#   'period',
#   'of',
#   '203785',
#   'has',
#   'a',
#   'periapsis',
#   'of',
#   '260855000000',
#   'and',
#   'apoapsis',
#   'of',
#   '4184760000000',
#   ''],
#  ['the',
#   'orbital',
#   'period',
#   'of',
#   'this',
#   'asteroid',
#   'is',
#   '12496',
#   'days',
#   ''],
#  ['john',
#   'mills',
#   'died',
#   'in',
#   '2005nurhan',
#   'atasoy',
#   'who',
#   'was',
#   'born',
#   'in',
#   'reşadiye',
#   '',
#   'has',
#   'his',
#   'residence',
#   'in',
#   'istanbul',
#   ''],
#  ['istanbul',
#   'metro',
#   'area',
#   'is',
#   '5343',
#   'square',
#   'kilometers',
#   'and',
#   'its',
#   'time',
#   'zone',
#   'is',
#   'eastern',
#   'european',
#   'summer',
#   'time',
#   ''],
#  ['nurhan',
#   'atasoy',
#   'whose',
#   'birth',
#   'place',
#   'is',
#   'resadiye',
#   '',
#   'also',
#   'had',
#   'his',
#   'residence',
#   'in',
#   'istanbul',
#   'with',
#   'a',
#   'metropolitan',
#   'area',
#   'of',
#   '5343',
#   'km²',
#   ''],
#  ['istanbul',
#   'is',
#   'in',
#   'the',
#   'eastern',
#   'european',
#   'summer',
#   'time',
#   'zone',
#   ''],
#  ['nurhan',
#   'atasoy',
#   'was',
#   'born',
#   'in',
#   'reşadiye',
#   'and',
#   'now',
#   'lives',
#   'in',
#   'istanbul',
#   ''],
#  ['istanbul',
#   'has',
#   'a',
#   'metropolitan',
#   'area',
#   'of',
#   '53430000000',
#   'and',
#   'uses',
#   'the',
#   'eastern',
#   'european',
#   'summer',
#   'time',
#   'time',
#   'zone',
#   ''],
#  ['the',
#   'year',
#   'of',
#   'no',
#   'light',
#   's',
#   'sludge',
#   'metal',
#   'album',
#   'nord',
#   '',
#   '2006',
#   '',
#   '09',
#   '',
#   '06',
#   '',
#   'was',
#   'followed',
#   'by',
#   'live',
#   'at',
#   'roadburn',
#   '2008the',
#   'release',
#   'date',
#   'of',
#   'nord',
#   '',
#   'year',
#   'of',
#   'no',
#   'light',
#   'album',
#   'in',
#   'the',
#   'sludge',
#   'metal',
#   'genre',
#   '',
#   'is',
#   '06',
#   '',
#   '09',
#   '',
#   '2006',
#   'with',
#   'their',
#   'album',
#   'live',
#   'at',
#   'roadburn',
#   '2008the',
#   'year',
#   'of',
#   'no',
#   'light',
#   'album',
#   'nord',
#   'in',
#   'the',
#   'sludge',
#   'metal',
#   'genre',
#   '',
#   'released',
#   'on',
#   'september',
#   '6',
#   '',
#   '2006',
#   'was',
#   'followed',
#   'by',
#   'year',
#   'of',
#   'no',
#   'light',
#   's',
#   'album',
#   'live',
#   'at',
#   'roadburn',
#   '2008nurhan',
#   'atasoy',
#   'was',
#   'born',
#   'in',
#   'turkey',
#   ''],
#  ['binali',
#   'yıldırım',
#   'was',
#   'former',
#   'prime',
#   'minister',
#   'of',
#   'turkey',
#   'under',
#   'current',
#   'president',
#   'recep',
#   'tayyip',
#   'erdoğan',
#   ''],
#  ['turkey',
#   '',
#   'led',
#   'by',
#   'recep',
#   'tayyip',
#   'erdoğan',
#   'and',
#   'binali',
#   'yildirim',
#   '',
#   'is',
#   'where',
#   'nurhan',
#   'atasoy',
#   'was',
#   'born',
#   'nurhan'],
#  ['atasoy',
#   'was',
#   'born',
#   'in',
#   'turkey',
#   'where',
#   'the',
#   'current',
#   'leaders',
#   'include',
#   'recep',
#   'tayyip',
#   'erdoğan',
#   'and',
#   'binali',
#   'yildirim',
#   ''],
#  ['turn',
#   'me',
#   'on',
#   'by',
#   'honeymoon',
#   'killers',
#   '',
#   'a',
#   'noise',
#   'rock',
#   'and',
#   'punk',
#   'blues',
#   'genre',
#   '',
#   'has',
#   'a',
#   'runtime',
#   'of',
#   '351',
#   'minutes',
#   ''],
#  ['its',
#   'producers',
#   'are',
#   'honeymoon',
#   'killers',
#   'themselves',
#   'and',
#   'wharton',
#   'tiers',
#   ''],
#  ['in',
#   'the',
#   'genre',
#   'of',
#   'punk',
#   'blues',
#   '',
#   'the',
#   'honeymoon',
#   'killers',
#   '',
#   '',
#   'turn',
#   'me',
#   'on',
#   '',
#   'is',
#   'a',
#   '35',
#   'minutes',
#   '10',
#   'seconds',
#   'example',
#   'of',
#   'noise',
#   'rock',
#   'produced',
#   'by',
#   'wharton',
#   'tiers',
#   'for',
#   'this',
#   'american',
#   'band',
#   ''],
#  ['the', 'band', 'also', 'participated', 'in', 'the', 'production', ''],
#  ['the',
#   'american',
#   'noise',
#   'rock',
#   'band',
#   'the',
#   'honeymoon',
#   'killers',
#   '',
#   'self',
#   '',
#   'produced',
#   'their',
#   'punk',
#   'blues',
#   'album',
#   'turn',
#   'me',
#   'on',
#   ''],
#  ['wharton',
#   'tiers',
#   'was',
#   'the',
#   'producer',
#   'and',
#   'the',
#   'album',
#   'runs',
#   'for',
#   '351',
#   'minutes',
#   ''],
#  ['baroque',
#   'pop',
#   'is',
#   'a',
#   'fusion',
#   'genre',
#   'which',
#   'includes',
#   'some',
#   'elements',
#   'of',
#   'pop',
#   'rock',
#   '',
#   'an',
#   'example',
#   'of',
#   'which',
#   'is',
#   'the',
#   'train',
#   'song',
#   'by',
#   'mermaid',
#   'mermaid',
#   '',
#   'released',
#   'by',
#   'the',
#   'band',
#   'train',
#   '',
#   'is',
#   'a',
#   'song',
#   'in',
#   'the',
#   'pop',
#   'rock',
#   'genre',
#   'which',
#   'also',
#   'includes',
#   'the',
#   'fusion',
#   'genre',
#   'baroque',
#   'pop',
#   ''],
#  ['mermaid',
#   '',
#   'a',
#   'song',
#   'by',
#   'the',
#   'band',
#   'train',
#   '',
#   'belongs',
#   'to',
#   'the',
#   'genre',
#   'of',
#   'pop',
#   'rock',
#   ''],
#  ['an',
#   'offshoot',
#   'of',
#   'pop',
#   'rock',
#   'is',
#   'the',
#   'fusion',
#   'genre',
#   'baroque',
#   'pop',
#   ''],
#  ['the',
#   'parent',
#   'company',
#   'of',
#   'polydor',
#   'records',
#   'is',
#   'universal',
#   'music',
#   'group',
#   ''],
#  ['universal',
#   'music',
#   'group',
#   'is',
#   'the',
#   'parent',
#   'company',
#   'of',
#   'polydor',
#   'records',
#   ''],
#  ['polydor',
#   'records',
#   '',
#   'parent',
#   'company',
#   'is',
#   'universal',
#   'music',
#   'group',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'was',
#   'a',
#   'photographer',
#   'who',
#   'was',
#   'born',
#   'in',
#   'the',
#   'german',
#   'empire',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'was',
#   'a',
#   'professional',
#   'photographer',
#   'who',
#   'was',
#   'born',
#   'in',
#   'the',
#   'german',
#   'empire',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'was',
#   'a',
#   'professional',
#   'photographer',
#   'that',
#   'was',
#   'born',
#   'in',
#   'the',
#   'german',
#   'empire',
#   ''],
#  ['the',
#   'pontiac',
#   'rageous',
#   '',
#   'a',
#   'coupe',
#   'assembled',
#   'in',
#   'michigan',
#   '',
#   'was',
#   'first',
#   'and',
#   'last',
#   'produced',
#   'in',
#   '1997',
#   ''],
#  ['it', 'had', 'its', 'assembly', 'line', 'in', 'detroit', ''],
#  ['the',
#   'pontiac',
#   'rageous',
#   '',
#   'a',
#   'car',
#   'with',
#   'a',
#   'coupe',
#   'body',
#   'style',
#   '',
#   'assembled',
#   'in',
#   'detroit',
#   'michigan',
#   '',
#   'was',
#   'first',
#   'and',
#   'last',
#   'produced',
#   'in',
#   '1997in',
#   '1997',
#   '',
#   'the',
#   'pontiac',
#   'rageous',
#   'coupe',
#   '',
#   'assembled',
#   'in',
#   'detroit',
#   '',
#   'michigan',
#   '',
#   'went',
#   'into',
#   'and',
#   'ended',
#   'production',
#   ''],
#  ['gma'],
#  ['new',
#   'media',
#   'is',
#   'a',
#   'company',
#   'in',
#   'the',
#   'mass',
#   'media',
#   'industry',
#   'whose',
#   'headquarters',
#   'are',
#   'located',
#   'in',
#   'the',
#   'gma',
#   'network',
#   'center',
#   ''],
#  ['inside',
#   'gma',
#   'network',
#   'center',
#   'lies',
#   'the',
#   'mass',
#   'media',
#   'industry',
#   'gma',
#   'new',
#   'media',
#   ''],
#  ['gma'],
#  ['new',
#   'media',
#   'is',
#   'a',
#   'mass',
#   'media',
#   'company',
#   'in',
#   'the',
#   'gma',
#   'network',
#   'center',
#   ''],
#  ['alan',
#   'shepard',
#   'was',
#   'born',
#   'on',
#   'nov',
#   '18',
#   '',
#   '1923',
#   'in',
#   'new',
#   'hampshire',
#   '',
#   'went',
#   'to',
#   'school',
#   'at',
#   'nwc',
#   'and',
#   'graduated',
#   'with',
#   'an',
#   'ma',
#   'in',
#   '1957',
#   'and',
#   'was',
#   'a',
#   'member',
#   'of',
#   'the',
#   'apollo',
#   '14',
#   'crew',
#   ''],
#  ['alan',
#   'shepard',
#   'was',
#   'born',
#   'on',
#   'november',
#   '18',
#   '',
#   '1923',
#   'in',
#   'new',
#   'hampshire',
#   ''],
#  ['shepard',
#   'graduated',
#   'from',
#   'nwc',
#   'in',
#   '1957',
#   'with',
#   'an',
#   'ma',
#   'and',
#   'served',
#   'as',
#   'a',
#   'crew',
#   'member',
#   'of',
#   'apollo',
#   '14alan'],
#  ['shepard',
#   'was',
#   'born',
#   'in',
#   'new',
#   'hampshire',
#   'on',
#   'november',
#   '18th',
#   '',
#   '1923',
#   ''],
#  ['he',
#   'graduated',
#   'from',
#   'nwc',
#   'with',
#   'an',
#   'ma',
#   'in',
#   '1957',
#   'and',
#   'went',
#   'on',
#   'to',
#   'be',
#   'a',
#   'crew',
#   'member',
#   'of',
#   'apollo',
#   '14it',
#   's',
#   'great',
#   'to',
#   'be',
#   'young',
#   'is',
#   'a',
#   'movie',
#   'from',
#   '1956',
#   'that',
#   'runs',
#   'for',
#   '94',
#   'minutes',
#   ''],
#  ['it',
#   'stars',
#   'cecil',
#   'parker',
#   'and',
#   'it',
#   '’s',
#   'edited',
#   'by',
#   'max',
#   'benedict',
#   ''],
#  ['louis', 'levy', 'composed', 'the', 'music', ''],
#  ['the',
#   '1956',
#   'film',
#   '',
#   'it',
#   's',
#   'great',
#   'to',
#   'be',
#   'young',
#   '',
#   'stars',
#   'cecil',
#   'parker',
#   ''],
#  ['the',
#   'movie',
#   'is',
#   '94',
#   'minutes',
#   'and',
#   'was',
#   'edited',
#   'by',
#   'max',
#   'benedict',
#   ''],
#  ['louis', 'levy', 'composed', 'the', 'music', 'for', 'the', 'film', ''],
#  ['it',
#   's',
#   'great',
#   'to',
#   'be',
#   'young',
#   'is',
#   'a',
#   '94',
#   'minute',
#   'movie',
#   'released',
#   'in',
#   '1956',
#   ''],
#  ['it',
#   'starred',
#   'cecil',
#   'parker',
#   'and',
#   'was',
#   'edited',
#   'by',
#   'max',
#   'benedict',
#   ''],
#  ['louis', 'levy', 'was', 'the', 'musical', 'composer', ''],
#  ['israeli',
#   'national',
#   'liselotte',
#   'grschebina',
#   'was',
#   'born',
#   'in',
#   'karlsruhe',
#   'on',
#   'may',
#   '2',
#   '',
#   '1908',
#   '',
#   'and',
#   'died',
#   'on',
#   'june',
#   '14',
#   '',
#   '1994israeli',
#   'liselotte',
#   'grschebina',
#   'was',
#   'born',
#   'in',
#   'karlsruhe',
#   'on',
#   'may',
#   '2',
#   '',
#   '1908',
#   'and',
#   'died',
#   'on',
#   'june',
#   '14',
#   '',
#   '1994liselotte',
#   'grschebina',
#   'was',
#   'as',
#   'israeli',
#   'national',
#   'born',
#   'in',
#   'karlsruhe',
#   'on',
#   'may',
#   '2',
#   '',
#   '1908',
#   'and',
#   'died',
#   'on',
#   'june',
#   '14',
#   '',
#   '1994the',
#   'construction',
#   'of',
#   'alan',
#   'b',
#   'miller',
#   'hall',
#   'lasted',
#   'from',
#   'march',
#   '30th',
#   '',
#   '2007',
#   'to',
#   'june',
#   '1st',
#   '',
#   '2009',
#   ''],
#  ['robert',
#   'a',
#   'm',
#   'stern',
#   'is',
#   'the',
#   'architect',
#   'of',
#   'the',
#   'building',
#   ''],
#  ['alan',
#   'b',
#   'miller',
#   'hall',
#   'is',
#   'located',
#   'at',
#   '101',
#   'ukrop',
#   'way',
#   '',
#   'virginia',
#   '',
#   'and',
#   'the',
#   'current',
#   'tenant',
#   'is',
#   'the',
#   'mason',
#   'school',
#   'of',
#   'business',
#   ''],
#  ['robert',
#   'a',
#   'm',
#   'stern',
#   'is',
#   'the',
#   'architect',
#   'responsible',
#   'for',
#   'designing',
#   'the',
#   'alan',
#   'b',
#   'miller',
#   'hall',
#   'at',
#   '101',
#   'ukrop',
#   'way',
#   'in',
#   'virginia',
#   ''],
#  ['construction',
#   'started',
#   'on',
#   'the',
#   'building',
#   'on',
#   'the',
#   '30th',
#   'of',
#   'march',
#   '',
#   '2007',
#   'and',
#   'was',
#   'completed',
#   'on',
#   'the',
#   '1st',
#   'of',
#   'june',
#   '',
#   '2009',
#   ''],
#  ['the',
#   'mason',
#   'school',
#   'of',
#   'business',
#   'are',
#   'the',
#   'current',
#   'occupants',
#   'of',
#   'the',
#   'hall',
#   ''],
#  ['stargate', 'produced', 'the', 'song', 'mermaid', ''],
#  ['the',
#   'train',
#   'song',
#   'mermaid',
#   'was',
#   'written',
#   'by',
#   'the',
#   'production',
#   'team',
#   'stargate',
#   ''],
#  ['a',
#   'person',
#   'named',
#   'jamie',
#   'lawrence',
#   'is',
#   'a',
#   'member',
#   'of',
#   'the',
#   'brentford',
#   'fc',
#   'while',
#   'someone',
#   'with',
#   'the',
#   'same',
#   'name',
#   'was',
#   'the',
#   'composer',
#   'for',
#   '',
#   'death',
#   'on',
#   'a',
#   'factory',
#   'farm',
#   '',
#   'music',
#   ''],
#  ['jamie',
#   'lawrence',
#   '',
#   'who',
#   'played',
#   'for',
#   'brentford',
#   'fc',
#   '',
#   'wrote',
#   'the',
#   'music',
#   'for',
#   'the',
#   'film',
#   '',
#   'death',
#   'on',
#   'a',
#   'factory',
#   'farm',
#   ''],
#  ['jamie',
#   'lawrence',
#   '',
#   'who',
#   'composed',
#   'death',
#   'on',
#   'a',
#   'factory',
#   'farm',
#   'also',
#   'played',
#   'in',
#   'the',
#   'club',
#   'brentford',
#   'fclet'],
#  ...]

# %% [markdown]
# ## Removing Stop Words
#
# **Exercise 6**
# * Define a function which takes in a list of lists of tokens and removes stop words from them
# * Apply this function to the list of tokens created in the previous exercise
#
# * **Hints**
#   - NLTK stopwords.words('english') returns a list of stopwords for English
#   - Use this list to remove all stop words from the tokenized sentences
#   - Python: the syntax "w not in l" allows you to check that string w is not in the list l

# %%
nltk.download('stopwords')
stop_en = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /home/tacit/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def StopWordsRem(token_l, stop_l = stop_en):
    token_clean = []
    for s in token_l:
        s1 = [word for word in s if word not in stop_l]
        token_clean.append(s1)
    return token_clean

# %%
sp_tokenl = StopWordsRem(sp_tokenl)
sp_tokenl
# Out:
# [['estádio',
#   'municipal',
#   'coaracy',
#   'da',
#   'mata',
#   'fonseca',
#   'name',
#   'ground',
#   'agremiação',
#   'sportiva',
#   'arapiraquense',
#   'arapiraca',
#   ''],
#  ['agremiação',
#   'sportiva',
#   'arapiraquense',
#   '',
#   'nicknamed',
#   '',
#   'alvinegro',
#   '',
#   '',
#   'lay',
#   'campeonato',
#   'brasileiro',
#   'série',
#   'c',
#   'league',
#   'brazil',
#   ''],
#  ['estádio',
#   'municipal',
#   'coaracy',
#   'da',
#   'mata',
#   'fonseca',
#   'name',
#   'ground',
#   'agremiação',
#   'sportiva',
#   'arapiraquense',
#   'arapiraca',
#   ''],
#  ['alvinegro',
#   '',
#   'nickname',
#   'agremiação',
#   'sportiva',
#   'arapiraquense',
#   '',
#   'play',
#   'campeonato',
#   'brasileiro',
#   'série',
#   'c',
#   'league',
#   'brazil',
#   ''],
#  ['nie',
#   'haisheng',
#   '',
#   'born',
#   'october',
#   '13',
#   '',
#   '1964',
#   '',
#   'worked',
#   'fighter',
#   'pilot',
#   ''],
#  ['nie',
#   'haisheng',
#   'former',
#   'fighter',
#   'pilot',
#   'born',
#   'october',
#   '13',
#   '',
#   '1964nie'],
#  ['haisheng', 'born', '10131964', 'fighter', 'pilot', ''],
#  ['motorsport', 'vision', 'located', 'city', 'fawkham', ''],
#  ['motorsport',
#   'vision',
#   'located',
#   'city',
#   'fawkham',
#   '',
#   'ukmotorsport',
#   'vision',
#   'located',
#   'fawkham185',
#   'centimetre',
#   'tall',
#   'aleksandr',
#   'prudnikov',
#   'played',
#   'otkrytiye',
#   'arena',
#   'based',
#   'fc',
#   'spartak',
#   '',
#   'moscow',
#   ''],
#  ['185',
#   'cm',
#   'tall',
#   'aleksandr',
#   'prudnikov',
#   'plays',
#   'fc',
#   'spartak',
#   'moscow',
#   'call',
#   'home',
#   'ground',
#   'otkrytiye',
#   'arena',
#   ''],
#  ['aleksandr',
#   'prudnikov',
#   '185',
#   'cm',
#   'tall',
#   '',
#   'plays',
#   'fc',
#   'spartak',
#   'moscow',
#   'whose',
#   'ground',
#   'otkrytiye',
#   'arena',
#   ''],
#  ['ciudad',
#   'ayala',
#   'city',
#   'population',
#   'density',
#   'population',
#   '1604',
#   '1777539',
#   'respectively',
#   '',
#   'leader',
#   'called',
#   'city',
#   'manager',
#   ''],
#  ['government',
#   'type',
#   'city',
#   'ciudad',
#   'ayala',
#   'council',
#   '',
#   'manager',
#   ''],
#  ['city',
#   'ciudad',
#   'ayala',
#   '',
#   'population',
#   '1777539',
#   '',
#   'led',
#   'city',
#   'manager',
#   'council',
#   '',
#   'manager',
#   'government',
#   'system',
#   ''],
#  ['population',
#   'density',
#   '1604ciudad',
#   'ayala',
#   '',
#   'city',
#   'population',
#   'density',
#   'population',
#   '16040',
#   '1777539',
#   'respectively',
#   '',
#   'uses',
#   'type',
#   'government',
#   'called',
#   'council',
#   '',
#   'manager',
#   'government',
#   ''],
#  ['one', 'leaders', 'ciudad', 'ayala', 'city', 'manager', ''],
#  ['album',
#   '1969',
#   '',
#   'velvet',
#   'underground',
#   'live',
#   'preceded',
#   'velvet',
#   'underground',
#   'album',
#   'squeeze',
#   '',
#   'followed',
#   'quine',
#   'tapes',
#   ''],
#  ['velvet',
#   'underground',
#   'album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'quine',
#   'tapes',
#   'preceded',
#   'album',
#   'squeeze',
#   '',
#   'followed',
#   'live',
#   'album',
#   '1969',
#   '',
#   'velvet',
#   'underground',
#   'live',
#   ''],
#  ['bootleg',
#   'series',
#   'volume',
#   '',
#   'quine',
#   'tapes',
#   'preceded',
#   'velvet',
#   'underground',
#   'album',
#   'squeeze',
#   'followed',
#   'album',
#   '1969',
#   ''],
#  ['velvet', 'underground', 'live', ''],
#  ['ciudad',
#   'ayala',
#   'mexico',
#   'population',
#   'density',
#   '16040',
#   'elevated',
#   '11470',
#   'sea',
#   'level',
#   'pdt',
#   'time',
#   'zone',
#   ''],
#  ['leader', 'called', 'governator', ''],
#  ['ciudad',
#   'ayala',
#   'country',
#   'mexico',
#   'located',
#   '1147',
#   'sea',
#   'level',
#   'pacific',
#   'daylight',
#   'time',
#   'zone',
#   ''],
#  ['population',
#   'density',
#   '1604',
#   'leader',
#   'ciudad',
#   'ayala',
#   'called',
#   'governator',
#   ''],
#  ['ciudad', 'ayala', 'located', 'mexico', 'population', 'density', '1604', ''],
#  ['city', 'stands', '1147', 'sea', 'level', ''],
#  ['governator',
#   'leader',
#   'ciudad',
#   'ayala',
#   'located',
#   'pacific',
#   'daylight',
#   'time',
#   'zone',
#   ''],
#  ['olga',
#   'bondareva',
#   'died',
#   'december',
#   '9',
#   '',
#   '1991olga',
#   'bondareva',
#   'died',
#   '9th',
#   'december',
#   '',
#   '1991the',
#   'date',
#   'olga',
#   'bondareva',
#   'death',
#   'ninth',
#   'december',
#   '1991saint',
#   'petersburg',
#   'founded',
#   'may',
#   '27',
#   '',
#   '1703',
#   'total',
#   'area',
#   '14390',
#   '',
#   'olga',
#   'bondareva',
#   'passed',
#   'away',
#   'saint',
#   'petersburg',
#   ''],
#  ['saint',
#   'petersburg',
#   '',
#   'olga',
#   'bondareva',
#   'died',
#   '',
#   'founded',
#   '27th',
#   'may',
#   '',
#   '1703',
#   'total',
#   'area',
#   'approximately',
#   '1439',
#   'km2saint',
#   'petersburg',
#   '',
#   'olga',
#   'bondareva',
#   'died',
#   '',
#   'founded',
#   'may',
#   '27',
#   '',
#   '1703',
#   'consists',
#   'total',
#   'area',
#   '14390',
#   'sq',
#   '',
#   'km',
#   ''],
#  ['population',
#   'density',
#   'ciudad',
#   'ayala',
#   '16040ciudad',
#   'ayala',
#   'city',
#   'population',
#   'density',
#   '16040the',
#   'population',
#   'density',
#   'ciudad',
#   'ayala',
#   '1604piotr',
#   'hallmann',
#   'born',
#   'august',
#   '25',
#   '',
#   '1987piotr',
#   'hallmann',
#   'birthday',
#   'august',
#   '25th'],
#  ['1987piotr', 'hallmann', 'born', '25th', 'august', '1987the'],
#  ['darlington',
#   'town',
#   'area',
#   'code',
#   '01325the',
#   'telephone',
#   'area',
#   'code',
#   'darlington',
#   '01325the',
#   'area',
#   'code',
#   'darlington',
#   '01325pennsylvania',
#   'franklin',
#   'county',
#   'found',
#   'west',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'pennsylvania',
#   'cumberland',
#   'county',
#   'north',
#   ''],
#  ['monument',
#   '11th',
#   'mississippi',
#   'infantry',
#   'erected',
#   'adams',
#   'county',
#   'year',
#   '2000',
#   'municipality',
#   'gettysburg',
#   'monument',
#   'categorised',
#   'contributing',
#   'property',
#   ''],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   '',
#   'contributing',
#   'property',
#   'established',
#   'year',
#   '2000',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'falls',
#   'municipality',
#   'gettysburg',
#   '',
#   'pennsylvania',
#   ''],
#  ['adams',
#   'county',
#   'pennsylvania',
#   'east',
#   'franklin',
#   'county',
#   '',
#   'pennsylvania',
#   'cumberland',
#   'county',
#   '',
#   'pennsylvania',
#   'north',
#   ''],
#  ['official', 'language', 'israel', 'modern', 'hebrew', ''],
#  ['israel', '’s', 'official', 'language', 'modern', 'hebrew', ''],
#  ['modern', 'hebrew', 'official', 'language', 'israel', ''],
#  ['enaire',
#   'operating',
#   'organisation',
#   'adolfo',
#   'suarez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   ''],
#  ['airport', 'situated', '610', 'meters', 'sea', 'level', 'alcobendas', ''],
#  ['gma',
#   'new',
#   'media',
#   '',
#   'company',
#   'founded',
#   '01',
#   '',
#   '01',
#   '',
#   '2000',
#   'manufacturers',
#   'mobile',
#   'applications',
#   ''],
#  ['gma',
#   'new',
#   'media',
#   '',
#   'founded',
#   'january',
#   '1',
#   '',
#   '2000',
#   '',
#   'company',
#   'offers',
#   'products',
#   'mobile',
#   'applications',
#   ''],
#  ['gma',
#   'new',
#   'media',
#   'makes',
#   'mobile',
#   'apps',
#   'founded',
#   '01012000hypermarcas',
#   'pharmaceutical',
#   'company',
#   'located',
#   'sao',
#   'paulo',
#   '',
#   'brazil',
#   ''],
#  ['brazil', '851483714', 'square', 'kilometers', 'size', ''],
#  ['hypermarcas',
#   '',
#   'pharmaceutical',
#   'company',
#   '',
#   'located',
#   'sao',
#   'paulo',
#   'within',
#   '851483714',
#   'square',
#   'kilometres',
#   'make',
#   'country',
#   'brazil',
#   ''],
#  ['hypermarcas',
#   '',
#   'company',
#   'pharmaceuticals',
#   'industry',
#   '',
#   'located',
#   'sao',
#   'paulo',
#   '',
#   'brazil',
#   '',
#   'country',
#   'total',
#   'area',
#   '851483714',
#   'square',
#   'kilometres',
#   ''],
#  ['quine',
#   'tapes',
#   'rock',
#   'music',
#   'genre',
#   'preceded',
#   'album',
#   'squeeze',
#   '',
#   'squeeze',
#   'preceded',
#   'album',
#   'andy',
#   'warhol',
#   'velvet',
#   'underground',
#   'featuring',
#   'nico',
#   ''],
#  ['bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'quine',
#   'tapes',
#   'genre',
#   'rock',
#   '',
#   'preceded',
#   'velvet',
#   'underground',
#   'album',
#   'squeeze',
#   '',
#   'preceded',
#   'compilation',
#   'album',
#   'andy',
#   'warhol',
#   'velvet',
#   'underground',
#   'featuring',
#   'nico',
#   ''],
#  ['album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'quine',
#   'tapes',
#   'fits',
#   'rock',
#   'music',
#   'genre',
#   'preceded',
#   'squeeze',
#   'velvet',
#   'underground',
#   '',
#   'turn',
#   'preceded',
#   'andy',
#   'warhol',
#   'velvet',
#   'underground',
#   'featuring',
#   'nico',
#   ''],
#  ['dr',
#   'g',
#   'p',
#   'prabhukumar',
#   'director',
#   'acharya',
#   'institute',
#   'technology',
#   'located',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '',
#   '560090',
#   'india',
#   'affiliated',
#   'visvesvaraya',
#   'technological',
#   'university',
#   ''],
#  ['acharya',
#   'institute',
#   'technology',
#   'campus',
#   'located',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '–',
#   '560090',
#   '',
#   'india',
#   ''],
#  ['director',
#   'dr',
#   'gp',
#   'prabhukumar',
#   'affiliated',
#   'visvesvaraya',
#   'technological',
#   'university',
#   ''],
#  ['campus',
#   'acharya',
#   'institute',
#   'technology',
#   'located',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '–',
#   '560090',
#   '',
#   'india',
#   'affiliated',
#   'visvesvaraya',
#   'technological',
#   'university',
#   ''],
#  ['director', 'dr', 'gpprabhukumar', ''],
#  ['abraham',
#   'ribicoff',
#   'born',
#   'died',
#   'united',
#   'states',
#   'african',
#   'americans',
#   'ethnic',
#   'group',
#   ''],
#  ['abraham', 'aribicoff', 'died', 'united', 'states', ''],
#  ['also', 'birthplace', ''],
#  ['african',
#   'americans',
#   'ethnic',
#   'group',
#   'usaabraham',
#   'ribicoff',
#   'born',
#   'died',
#   'united',
#   'states',
#   'african',
#   'americans',
#   'ethnic',
#   'group',
#   ''],
#  ['music',
#   'group',
#   'velvet',
#   'underground',
#   'produced',
#   'released',
#   'rock',
#   'music',
#   'album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'quine',
#   'tapes',
#   'polydor',
#   'records',
#   'record',
#   'label',
#   ''],
#  ['album',
#   'recorded',
#   'st',
#   'louis',
#   '',
#   'missouri',
#   '',
#   'usa',
#   'run',
#   'time',
#   '23005bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'quine',
#   'tapes',
#   'created',
#   'produced',
#   'velvet',
#   'underground',
#   'runtime',
#   '23005',
#   'minutes',
#   'recorded',
#   'st',
#   'louis',
#   'missouri',
#   '',
#   'united',
#   'states',
#   ''],
#  ['rock', 'genre', 'album', 'recorded', 'polydor', 'records', ''],
#  ['bootleg',
#   'series',
#   'volume',
#   '',
#   'quine',
#   'tapes',
#   'created',
#   'produced',
#   'velvet',
#   'underground',
#   'runtime',
#   '23005',
#   'minutes',
#   'recorded',
#   'st',
#   'louis',
#   '',
#   'missouri',
#   '',
#   'united',
#   'states',
#   ''],
#  ['rock',
#   'music',
#   'genre',
#   'album',
#   'released',
#   'record',
#   'label',
#   'polydor',
#   'records',
#   ''],
#  ['fellowship', 'ring', 'belongs', 'fantasy', 'genre', ''],
#  ['george', 'allen', '', 'amp', '', 'unwin', 'published', ''],
#  ['fellowship',
#   'ring',
#   'published',
#   'fantasy',
#   'genre',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['fellowship',
#   'ring',
#   '',
#   'fantasy',
#   'genre',
#   '',
#   'published',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['distinguished',
#   'service',
#   'medal',
#   '',
#   'us',
#   'navy',
#   '',
#   'recipient',
#   'alan',
#   'shepard',
#   'born',
#   'new',
#   'hampshire',
#   'died',
#   'california',
#   ''],
#  ['awarded',
#   'distinguished',
#   'service',
#   'medal',
#   'united',
#   'states',
#   'navy',
#   '',
#   'alan',
#   'shepard',
#   '',
#   'born',
#   'new',
#   'hampshire',
#   '',
#   'died',
#   'california',
#   ''],
#  ['alan',
#   'shepard',
#   '',
#   'born',
#   'new',
#   'hampshire',
#   'died',
#   'california',
#   '',
#   'awarded',
#   'distinguished',
#   'service',
#   'medal',
#   'united',
#   'states',
#   'navy',
#   ''],
#  ['imagine',
#   'song',
#   'train',
#   'followed',
#   'mermaid',
#   '',
#   'song',
#   'produced',
#   'production',
#   'team',
#   'espionage',
#   '',
#   'album',
#   'california',
#   '37train',
#   'followed',
#   'song',
#   'mermaid',
#   '',
#   'california',
#   '37',
#   'album',
#   '',
#   'produced',
#   'production',
#   'team',
#   'espionage',
#   '',
#   'song',
#   'titled',
#   'imagine',
#   ''],
#  ['production',
#   'team',
#   'espionage',
#   '',
#   'train',
#   'song',
#   'mermaid',
#   '',
#   'california',
#   '37',
#   'album',
#   '',
#   'followed',
#   'train',
#   'performance',
#   'imagine',
#   'john',
#   'lennon',
#   ''],
#  ['train',
#   'song',
#   'mermaid',
#   '',
#   'belongs',
#   'california',
#   '37',
#   'train',
#   'album',
#   'produced',
#   'espionage',
#   '',
#   'followed',
#   'john',
#   'lennon',
#   'song',
#   'imagine',
#   ''],
#  ['train',
#   'song',
#   'imagine',
#   'came',
#   'song',
#   'california',
#   '37',
#   'album',
#   '',
#   'titled',
#   'mermaid',
#   '',
#   'produced',
#   'production',
#   'team',
#   'espionage',
#   ''],
#  ['fellowship',
#   'ring',
#   'written',
#   'jrr',
#   'tolkien',
#   'released',
#   'july',
#   '29',
#   '',
#   '1954',
#   ''],
#  ['fellowship',
#   'ring',
#   'considered',
#   'fantasy',
#   'published',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['sequel', 'fellowship', 'ring', 'two', 'towers', ''],
#  ['jrr',
#   'tolkien',
#   'author',
#   'fellowship',
#   'ring',
#   'released',
#   'july',
#   '29',
#   '',
#   '1954',
#   ''],
#  ['fantasy',
#   'book',
#   'published',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['novel', 'followed', 'two', 'towers', ''],
#  ['fellowship', 'ring', 'belongs', 'fantasy', 'genre', ''],
#  ['author', 'jrr', 'tolkien', ''],
#  ['published',
#   'july',
#   '29',
#   '',
#   '1954',
#   'george',
#   'allen',
#   '',
#   'amp',
#   '',
#   'unwin',
#   ''],
#  ['followed', 'two', 'towers', ''],
#  ['gma'],
#  ['new',
#   'media',
#   'lies',
#   'philippines',
#   'applications',
#   'offered',
#   'entertainment',
#   'industry',
#   ''],
#  ['located',
#   'philippines',
#   '',
#   'gma',
#   'new',
#   'media',
#   'entertainment',
#   'industry',
#   ''],
#  ['gma'],
#  ['new', 'media', 'entertainment', 'company', 'located', 'philippines', ''],
#  ['english',
#   'without',
#   'tears',
#   '',
#   'written',
#   'terence',
#   'rattigan',
#   '',
#   'runs',
#   '89',
#   'minutes',
#   ''],
#  ['cinematography', 'film', 'done', 'bernard', 'knowles', ''],
#  ['english',
#   'without',
#   'tears',
#   '',
#   '89',
#   'minute',
#   'film',
#   'written',
#   'terence',
#   'rattigan',
#   '',
#   'features',
#   'cinematography',
#   'bernard',
#   'knowles',
#   ''],
#  ['terence',
#   'rattigan',
#   'writer',
#   '89',
#   'minute',
#   'movie',
#   '´',
#   'english',
#   'without',
#   'tears',
#   '´',
#   'bernard',
#   'knowles',
#   'cinematographer',
#   ''],
#  ['george',
#   'monson',
#   'married',
#   'lady',
#   'anne',
#   'monson',
#   '',
#   'botanist',
#   '',
#   'died',
#   'february',
#   '18',
#   '',
#   '1776lady',
#   'anne',
#   'monson',
#   '',
#   'professional',
#   'botanist',
#   'married',
#   'george',
#   'monson',
#   '',
#   'died',
#   'february',
#   '18th',
#   ''],
#  ['1776lady', 'anne', 'monson', 'spouse', 'george', 'monson', ''],
#  ['professional',
#   'field',
#   'study',
#   'botany',
#   '',
#   'died',
#   '18',
#   'february',
#   '1776abdul',
#   'taib',
#   'mahmud',
#   '',
#   'member',
#   'parti',
#   'pesaka',
#   'bumiputera',
#   'bersatu',
#   'party',
#   '',
#   'resides',
#   'demak',
#   'jaya',
#   '',
#   'jalan',
#   'bako',
#   '',
#   'kuching',
#   '',
#   'sarawak',
#   ''],
#  ['abdul',
#   'taib',
#   'mahmud',
#   '',
#   'member',
#   'parti',
#   'pesaka',
#   'bumiputera',
#   'bersatu',
#   'party',
#   '',
#   'resides',
#   'demak',
#   'jaya',
#   '',
#   'jalan',
#   'bako',
#   '',
#   'kuching',
#   '',
#   'sarawak',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'israeli',
#   'attended',
#   'school',
#   'applied',
#   'arts',
#   'stuttgart',
#   ''],
#  ['born', 'karlsruhe', '', 'germany', ''],
#  ['israel', 'national', 'language', 'modern', 'hebrew', ''],
#  ['liselotte',
#   'grschebina',
#   'israeli',
#   'national',
#   'studies',
#   'school',
#   'applied',
#   'arts',
#   'stuttgart',
#   'born',
#   'karlsruhe',
#   '',
#   'germany',
#   'unlike',
#   'israel',
#   'whose',
#   'language',
#   'modern',
#   'hebrew',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'born',
#   'karlsruhe',
#   'located',
#   'germany',
#   '',
#   'israeli',
#   'nationality',
#   '',
#   'language',
#   'israel',
#   'modern',
#   'hebrew',
#   '',
#   '',
#   'studied',
#   'school',
#   'applied',
#   'arts',
#   'stuttgart',
#   ''],
#  ['chinabank', 'location', 'philippines', ''],
#  ['chinabank', 'located', 'philippines', ''],
#  ['train',
#   'song',
#   'mermaid',
#   '',
#   'example',
#   'reggae',
#   'genre',
#   '',
#   'released',
#   'record',
#   'labels',
#   'columbia',
#   'records',
#   'sony',
#   'music',
#   'entertainment',
#   ''],
#  ['written',
#   'espen',
#   'lind',
#   'amund',
#   'bjørklund',
#   'total',
#   'runtime',
#   '3',
#   'minutes',
#   '16',
#   'seconds',
#   ''],
#  ['amund',
#   'bjorklund',
#   'espen',
#   'lind',
#   'writers',
#   '316',
#   'minute',
#   'reggae',
#   'song',
#   'mermaid',
#   'train',
#   'released',
#   'sony',
#   'music',
#   'entertainment',
#   'columbia',
#   'records',
#   ''],
#  ['song',
#   'mermaid',
#   'written',
#   'reggae',
#   'music',
#   'genre',
#   'espen',
#   'lind',
#   'amund',
#   'bjorklund',
#   'song',
#   'performed',
#   'train',
#   'released',
#   'columbia',
#   'records',
#   'sony',
#   'music',
#   'entertainment',
#   'records',
#   ''],
#  ['total', 'runtime', 'three', 'minutes', 'sixteen', 'seconds', ''],
#  ['great',
#   'young',
#   '',
#   '1956',
#   'film',
#   'starring',
#   'cecil',
#   'parker',
#   'composed',
#   'louis',
#   'levy',
#   'written',
#   'ted',
#   'willis',
#   ''],
#  ['“it',
#   'great',
#   'young',
#   '”',
#   '',
#   '1956',
#   '',
#   'written',
#   'ted',
#   'willis',
#   'features',
#   'music',
#   'louis',
#   'levy',
#   ''],
#  ['main', 'role', 'movie', 'given', 'cecil', 'parker', ''],
#  ['louis',
#   'levy',
#   'composer',
#   '1956',
#   'film',
#   'great',
#   'young',
#   '',
#   'written',
#   'ted',
#   'willis',
#   'stars',
#   'cecil',
#   'parker',
#   ''],
#  ['aaron',
#   'turner',
#   'post',
#   '',
#   'metal',
#   'musician',
#   'massachusetts',
#   'plays',
#   'electric',
#   'guitar',
#   ''],
#  ['started', 'performing', '1995', 'musician', 'lotus', 'eaters', 'band', ''],
#  ['aaron',
#   'turner',
#   'post',
#   '',
#   'metal',
#   'musician',
#   'born',
#   'massachusetts',
#   'plays',
#   'electric',
#   'guitar',
#   '',
#   'started',
#   'performing',
#   '1995',
#   'lotus',
#   'eaters',
#   'band',
#   ''],
#  ['aaron',
#   'turner',
#   'post',
#   'metal',
#   'performer',
#   'massachusetts',
#   'plays',
#   'electric',
#   'guitar',
#   '',
#   'started',
#   'performing',
#   '1995',
#   'lotus',
#   'eaters',
#   'band',
#   ''],
#  ['pennsylvania',
#   'franklin',
#   'county',
#   'found',
#   'west',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   'southeast',
#   ''],
#  ['monument',
#   '11th',
#   'mississippi',
#   'infantry',
#   'erected',
#   '2000',
#   'adams',
#   'county',
#   'monument',
#   'classed',
#   'contributing',
#   'property',
#   ''],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'established',
#   '2000',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   'southeast',
#   'franklin',
#   'county',
#   '',
#   'pennsylvania',
#   'west',
#   ''],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'category',
#   'contributing',
#   'property',
#   ''],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   '',
#   'established',
#   '2000',
#   '',
#   'falls',
#   'category',
#   'contributing',
#   'property',
#   'located',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   '',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   'southeast',
#   'franklin',
#   'county',
#   '',
#   'pennsylvania',
#   'east',
#   ''],
#  ['band',
#   'nord',
#   'sludge',
#   'metal',
#   'band',
#   'releases',
#   'post',
#   '',
#   'metal',
#   ''],
#  ['album',
#   'called',
#   'year',
#   'light',
#   'released',
#   'june',
#   '9th',
#   '2006',
#   '',
#   'crucial',
#   'blast',
#   'label',
#   ''],
#  ['year', 'light', 'self', '', 'produced', 'album', 'nord', ''],
#  ['album',
#   'released',
#   'label',
#   'crucial',
#   'blast',
#   'september',
#   '6th',
#   '',
#   '2006',
#   ''],
#  ['nord', 'falls', 'sludge', 'metal', 'post', '', 'metal', 'genres', ''],
#  ['ciudad',
#   'ayala',
#   'metropolitan',
#   'city',
#   'population',
#   '1777539',
#   'population',
#   'density',
#   '16040',
#   'falls',
#   'utc',
#   'offset',
#   '6',
#   'time',
#   'zone',
#   ''],
#  ['one',
#   'leaders',
#   'ciudad',
#   'ayala',
#   'city',
#   'manager',
#   'uses',
#   'council',
#   '',
#   'manager',
#   'government',
#   ''],
#  ['city',
#   'ciudad',
#   'ayala',
#   'population',
#   '1777539',
#   'making',
#   'density',
#   '16040',
#   ''],
#  ['one',
#   'leaders',
#   'council',
#   '',
#   'manager',
#   'government',
#   'city',
#   'manager',
#   ''],
#  ['utc',
#   'offset',
#   '6the',
#   'city',
#   'ciudad',
#   'ayala',
#   'population',
#   '1777539',
#   'making',
#   'density',
#   '1604',
#   ''],
#  ['council', '', 'managed', 'government', 'led', 'city', 'manager', ''],
#  ['utc', 'offset', '6super'],
#  ['capers', '98', 'minute', 'film', '', '20000000', 'budget', ''],
#  ['stars',
#   'tom',
#   'sizemore',
#   'michael',
#   'rooker',
#   '',
#   'written',
#   'directed',
#   'ray',
#   'griggs',
#   ''],
#  ['super',
#   'capers',
#   '98',
#   'minute',
#   'movie',
#   'starring',
#   'michael',
#   'rooker',
#   'tom',
#   'sizemore',
#   ''],
#  ['written', 'directed', 'ray', 'griggs', ''],
#  ['budget',
#   '',
#   '2000000the',
#   '98',
#   'minute',
#   'film',
#   'super',
#   'capers',
#   'budget',
#   '2',
#   'million',
#   'dollars',
#   ''],
#  ['written', 'directed', 'ray', 'griggs', ''],
#  ['starred', 'tom', 'sizemore', 'also', 'featured', 'michael', 'rooker', ''],
#  ['darinka',
#   'dentcheva',
#   'developed',
#   'theory',
#   'influenced',
#   'andrzej',
#   'piotr',
#   'ruszczyński',
#   ''],
#  ['darinka', 'dentcheva', 'influenced', 'andrzej', 'piotr', 'ruszczyński', ''],
#  ['darinka', 'dentcheva', 'influenced', 'andrzej', 'piotr', 'ruszczynski', ''],
#  ['born',
#   '1878',
#   '',
#   'harry',
#   'carey',
#   'later',
#   'grew',
#   'write',
#   'star',
#   'movie',
#   'mcveagh',
#   'south',
#   'seas',
#   ''],
#  ['harry',
#   'carey',
#   '',
#   'born',
#   '1878',
#   '',
#   'wrote',
#   'appeared',
#   'movie',
#   'mcveagh',
#   'south',
#   'seas',
#   ''],
#  ['harry',
#   'carey',
#   '',
#   'born',
#   '1878',
#   '',
#   'wrote',
#   'starred',
#   'film',
#   'mcveagh',
#   'south',
#   'seas',
#   ''],
#  ['mexicans',
#   '',
#   'inhabitants',
#   'mexico',
#   '',
#   'use',
#   'peso',
#   'currency',
#   'purchase',
#   'dessert',
#   'called',
#   'bionico',
#   ''],
#  ['bionico',
#   'found',
#   'guadalajara',
#   '',
#   'mexico',
#   '',
#   'made',
#   'sour',
#   'cream',
#   '',
#   'chopped',
#   'fruits',
#   '',
#   'condensed',
#   'milk',
#   '',
#   'granola',
#   '',
#   'coconut',
#   'raisins',
#   ''],
#  ['also', 'buy', 'cookies', '', 'another', 'dessert', ''],
#  ['much',
#   'like',
#   'cookie',
#   '',
#   'bionico',
#   'dessert',
#   'food',
#   'whose',
#   'ingredients',
#   'include',
#   'chopped',
#   'fruits',
#   '',
#   'sour',
#   'cream',
#   '',
#   'condensed',
#   'milk',
#   '',
#   'granola',
#   '',
#   'shredded',
#   'coconut',
#   'raisins',
#   ''],
#  ['bionico',
#   'found',
#   'guadalajara',
#   'region',
#   'mexico',
#   '',
#   'uses',
#   'pesos',
#   'currency',
#   'home',
#   'mexican',
#   'people',
#   ''],
#  ['mexico', 'inhabited', 'mexicans', 'peso', 'currency', ''],
#  ['bionico',
#   '',
#   'dessert',
#   'food',
#   'found',
#   'guadalajara',
#   '',
#   'mexico',
#   '',
#   'sour',
#   'cream',
#   '',
#   'chopped',
#   'fruits',
#   '',
#   'condensed',
#   'milk',
#   '',
#   'granola',
#   '',
#   'raisins',
#   'shredded',
#   'coconut',
#   'main',
#   'ingredients',
#   ''],
#  ['cookie', 'type', 'dessert', ''],
#  ['one',
#   'leader',
#   'ciudad',
#   'ayala',
#   '',
#   'city',
#   '',
#   'called',
#   'city',
#   'manager',
#   ''],
#  ['population',
#   'density',
#   '16040ciudad',
#   'ayala',
#   'city',
#   'population',
#   'density',
#   '1604',
#   ''],
#  ['one', 'leaders', 'called', 'city', 'manager', ''],
#  ['one',
#   'leaders',
#   'ciudad',
#   'ayala',
#   '',
#   'city',
#   'population',
#   'density',
#   '16040',
#   '',
#   'city',
#   'manager',
#   ''],
#  ['enaire',
#   '',
#   'based',
#   'madrid',
#   '',
#   'spain',
#   '',
#   'operating',
#   'organisation',
#   'adolfo',
#   'suarez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   'alcobendas',
#   ''],
#  ['runway',
#   'length',
#   'airport',
#   '3500located',
#   'madrid',
#   '',
#   'spain',
#   '',
#   'enaire',
#   'operates',
#   'adolfo',
#   'suarez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   'alcobendas',
#   'reports',
#   'runway',
#   'length',
#   '3500adolfo',
#   'suarez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   '',
#   'operated',
#   'enaire',
#   '',
#   'located',
#   'alcobendas',
#   'enaire',
#   'located',
#   'madrid',
#   '',
#   'spain',
#   ''],
#  ['airport',
#   'runway',
#   'length',
#   '3500bionico',
#   'dish',
#   'served',
#   'dessert',
#   'mexico',
#   '',
#   'currency',
#   'peso',
#   '',
#   'dish',
#   'contains',
#   'granola',
#   ''],
#  ['bionico',
#   '',
#   'food',
#   'requires',
#   'granola',
#   'one',
#   'ingredients',
#   'served',
#   'dessert',
#   'found',
#   'mexico',
#   ''],
#  ['currency', 'peso', ''],
#  ['bionico', 'food', 'found', 'mexico', '', 'currency', '', 'peso', '', ''],
#  ['bionico',
#   '',
#   'dessert',
#   '',
#   'requires',
#   'granola',
#   'one',
#   'ingredients',
#   ''],
#  ['periapsis',
#   '2608550000000',
#   '',
#   '1147',
#   'stavropolis',
#   'epoch',
#   '31',
#   'july',
#   '2016',
#   '',
#   'jd245760051147',
#   'stavropolis',
#   'epoch',
#   '31',
#   'july',
#   '2016',
#   '',
#   'julian',
#   'day',
#   '24576005',
#   '',
#   'periapsis',
#   '1147',
#   'stavropolis',
#   '2608550000001147'],
#  ['stavropolis',
#   'epoch',
#   '31',
#   'july',
#   '2016',
#   'periapsis',
#   '2608550000000ciudad',
#   'ayala',
#   'pacific',
#   'daylight',
#   'time',
#   'zone',
#   'population',
#   'density',
#   '1604ciudad',
#   'ayala',
#   'city',
#   'pdt',
#   'time',
#   'zone',
#   'population',
#   'density',
#   '16040ciudad',
#   'ayala',
#   'time',
#   'zone',
#   'pacific',
#   'daylight',
#   'time',
#   'population',
#   'density',
#   '16040the',
#   'net',
#   'income',
#   'chinabank',
#   '15100000000',
#   '',
#   '5594',
#   'workers',
#   'total',
#   ''],
#  ['chinabank',
#   'currently',
#   'brings',
#   'net',
#   'income',
#   '15100000000',
#   'thanks',
#   'efforts',
#   '5594',
#   'employees',
#   ''],
#  ['chinabank',
#   'brings',
#   'net',
#   'income',
#   '15100000000',
#   '5594',
#   'employees',
#   ''],
#  ['steve',
#   'bright',
#   'creator',
#   'bananaman',
#   'last',
#   'broadcast',
#   'april',
#   '15th',
#   '1986',
#   'bbcbananaman',
#   'created',
#   'steve',
#   'bright',
#   'last',
#   'aired',
#   'april',
#   '15th',
#   '1986',
#   ''],
#  ['broadcast',
#   'bbcbananaman',
#   '',
#   'tv',
#   'show',
#   '',
#   'created',
#   'steve',
#   'bright',
#   'last',
#   'aired',
#   '15th',
#   'april',
#   '1986',
#   ''],
#  ['bananaman',
#   'broadcast',
#   'bbcbionico',
#   '',
#   'dish',
#   'served',
#   'dessert',
#   '',
#   'food',
#   'found',
#   'guadalajara',
#   'mexico',
#   ''],
#  ['currency', 'mexico', 'mexican', 'peso', 'inhabited', 'mexicans', ''],
#  ['bionico', '', 'dessert', '', 'food', 'found', 'guadalajara', 'mexico', ''],
#  ['currency', 'mexico', 'mexican', 'peso', 'inhabited', 'mexicans', ''],
#  ['bionico', 'food', 'found', 'mexico', 'served', 'dessert', 'course', ''],
#  ['dessert', 'found', 'guadalajara', ''],
#  ['currency', 'mexico', '', 'inhabited', 'mexicans', '', 'peso', ''],
#  ['year',
#   'light',
#   'album',
#   'live',
#   'roadburn',
#   '2008',
#   'followed',
#   'album',
#   'nord',
#   ''],
#  ['live',
#   'roadburn',
#   '2008',
#   'preceded',
#   'album',
#   'nord',
#   'played',
#   'year',
#   'light',
#   ''],
#  ['year',
#   'light',
#   '',
#   'released',
#   'album',
#   'nord',
#   '',
#   'followed',
#   'album',
#   'live',
#   'roadburn',
#   '2008alan'],
#  ['shepard',
#   'crew',
#   'member',
#   'apollo',
#   '14',
#   'born',
#   'november',
#   '18th',
#   '',
#   '1923',
#   '',
#   'new',
#   'hampshire',
#   'died',
#   'california',
#   ''],
#  ['alan',
#   'shepard',
#   'born',
#   'new',
#   'hampshire',
#   'november',
#   '18',
#   '',
#   '1923',
#   ''],
#  ['crew', 'member', 'apollo', '14', '', 'died', 'later', 'california', ''],
#  ['alan',
#   'shepard',
#   'born',
#   'nov',
#   '18',
#   '',
#   '1923',
#   'new',
#   'hampshire',
#   '',
#   'member',
#   'apollo',
#   '14',
#   'crew',
#   'died',
#   'california',
#   ''],
#  ['alco',
#   'rs3',
#   '',
#   'four',
#   '',
#   'stroke',
#   'engine',
#   '12',
#   'cylinders',
#   '',
#   'length',
#   '170688',
#   'millimetres',
#   ''],
#  ['four',
#   '',
#   'stroke',
#   '12',
#   'cylinder',
#   'alco',
#   'rs3',
#   '170688',
#   'millimetres',
#   'long',
#   ''],
#  ['alco',
#   'rs3',
#   'four',
#   '',
#   'stroke',
#   'engine',
#   'cylinder',
#   'count',
#   '12',
#   '170688',
#   'mm',
#   'length',
#   ''],
#  ['olga',
#   'nikolaevna',
#   'bondareva',
#   '',
#   '',
#   'born',
#   'april',
#   '27',
#   '',
#   '1937',
#   '',
#   'died',
#   'saint',
#   'petersburg',
#   ''],
#  ['best', 'known', '', 'bondareva', '', 'shapley', 'theorem', ''],
#  ['olga',
#   'nikolaevna',
#   'bondareva',
#   '',
#   'known',
#   'bondareva',
#   '',
#   'shapley',
#   'theorem',
#   '',
#   'born',
#   'april',
#   '27',
#   '',
#   '1937',
#   'died',
#   'saint',
#   'petersburg',
#   ''],
#  ['olga',
#   'bondareva',
#   '',
#   'born',
#   '',
#   'olga',
#   'nikolaevna',
#   'bondareva',
#   '',
#   'april',
#   '27th',
#   '',
#   '1937',
#   'known',
#   'bondareva',
#   '',
#   'shapley',
#   'theorem',
#   '',
#   'died',
#   'saint',
#   'petersburg',
#   ''],
#  ['fellowship',
#   'ring',
#   '',
#   'fantasy',
#   'novel',
#   'created',
#   'jrr',
#   'tolkien',
#   'released',
#   'july',
#   '29',
#   '',
#   '1954',
#   '',
#   'hobbit',
#   'came',
#   'fellowship',
#   'ring',
#   ''],
#  ['jrr',
#   'tolkien',
#   'author',
#   'fellowship',
#   'ring',
#   'published',
#   'july',
#   '29',
#   '',
#   '1954',
#   ''],
#  ['book', 'belongs', 'fantasy', 'genre', 'came', 'hobbit', ''],
#  ['fantasy',
#   'fellowship',
#   'ring',
#   'genre',
#   '',
#   'released',
#   'july',
#   '29',
#   '',
#   '1954',
#   ''],
#  ['fellowship', 'ring', 'written', 'jrr', 'tolkien', 'preceded', 'hobbit', ''],
#  ['train',
#   'hit',
#   'mermaid',
#   'put',
#   'sony',
#   'music',
#   'entertainment',
#   'record',
#   'label',
#   '',
#   'written',
#   'amund',
#   'bjørklund',
#   'producer',
#   'stargate',
#   ''],
#  ['train',
#   'followed',
#   'mermaid',
#   'imagine',
#   '',
#   'song',
#   'john',
#   'lennon',
#   'mermaid',
#   'produced',
#   'espionage',
#   'production',
#   'team',
#   ''],
#  ['song',
#   'mermaid',
#   '',
#   'train',
#   '',
#   'sony',
#   'music',
#   'entertainment',
#   'release',
#   'produced',
#   'stargate',
#   'along',
#   'production',
#   'team',
#   'espionage',
#   ''],
#  ['mermaid',
#   '',
#   'written',
#   'amund',
#   'bjorklund',
#   '',
#   'followed',
#   'john',
#   'lennon',
#   'imagine',
#   ''],
#  ['train',
#   'song',
#   'mermaid',
#   'written',
#   'amund',
#   'bjørklund',
#   'production',
#   'team',
#   'stargate',
#   'produced',
#   'production',
#   'team',
#   'espionage',
#   'released',
#   'record',
#   'label',
#   'sony',
#   'music',
#   'entertainment',
#   ''],
#  ['followed',
#   'release',
#   'imagine',
#   'john',
#   'lennon',
#   'performed',
#   'train',
#   ''],
#  ['year',
#   'light',
#   'produced',
#   'album',
#   'called',
#   'nord',
#   '692006',
#   '5841',
#   'minutes',
#   'long',
#   ''],
#  ['came',
#   'demo',
#   '2004',
#   'album',
#   'first',
#   '',
#   'followed',
#   'nord',
#   '',
#   'album',
#   'live',
#   'roadburn',
#   '2008the',
#   'year',
#   'light',
#   'album',
#   'nord',
#   'runtime',
#   '5841',
#   'minutes',
#   'released',
#   'artist',
#   'date',
#   '2006',
#   '',
#   '09',
#   '',
#   '06',
#   ''],
#  ['preceded',
#   'year',
#   'light',
#   'album',
#   'demo',
#   '2004',
#   'followed',
#   'year',
#   'light',
#   'album',
#   'live',
#   'roadburn',
#   '2008the',
#   'album',
#   'nord',
#   'year',
#   'light',
#   'runtime',
#   '58',
#   'minutes',
#   '41',
#   'seconds',
#   'released',
#   'september',
#   '6',
#   '',
#   '2006the',
#   'album',
#   'nord',
#   'preceded',
#   'album',
#   'demo',
#   '2004',
#   'followed',
#   'live',
#   'roadburn',
#   '2008'],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'placed',
#   'municipality',
#   'gettysburg',
#   'pennsylvania',
#   '',
#   'adams',
#   'county',
#   '',
#   'usa',
#   ''],
#  ['adams',
#   'county',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   'southeast',
#   '11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'categorized',
#   'contributing',
#   'property',
#   ''],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'categorised',
#   'contributing',
#   'property',
#   'stands',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'municipality',
#   'gettysburg',
#   'usa',
#   ''],
#  ['carroll', 'county', 'maryland', 'southeast', 'adams', 'county', ''],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'location',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   '',
#   'usa',
#   '',
#   'municipality',
#   'gettysburg',
#   ''],
#  ['southeast',
#   'adams',
#   'county',
#   '',
#   'lies',
#   'carroll',
#   'county',
#   '',
#   'maryland',
#   ''],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'contributing',
#   'property',
#   ''],
#  ['israeli',
#   'national',
#   'liselotte',
#   'grschebina',
#   'born',
#   'german',
#   'empire',
#   'died',
#   'israel',
#   'june',
#   '14',
#   '',
#   '1994liselotte',
#   'grschebina',
#   'died',
#   'israel',
#   'june',
#   '14',
#   '',
#   '1994',
#   ''],
#  ['though', 'israeli', 'nationality', '', 'born', 'german', 'empire', ''],
#  ['liselotte',
#   'grschebina',
#   'israeli',
#   'national',
#   'born',
#   'german',
#   'empire',
#   ''],
#  ['died', 'june', '14', '', '1994', 'israel', ''],
#  ['located',
#   'king',
#   'prussia',
#   '',
#   'pennsylvania',
#   '',
#   'amerigas',
#   'energy',
#   'company',
#   'serves',
#   'united',
#   'states',
#   ''],
#  ['amerigas',
#   'operating',
#   'income',
#   '',
#   '380700000',
#   'net',
#   'income',
#   '',
#   '211200000currently',
#   'serving',
#   'regions',
#   'united',
#   'states',
#   '',
#   'amerigas',
#   'headquartered',
#   'king',
#   'prussia',
#   '',
#   'pennsylvania',
#   'united',
#   'states',
#   ''],
#  ['established',
#   'company',
#   'energy',
#   'industry',
#   '',
#   'amerigas',
#   'operating',
#   'income',
#   '',
#   '380700000',
#   'net',
#   'income',
#   '',
#   '211200000a',
#   'us',
#   'provider',
#   'energy',
#   'industry',
#   '',
#   'amerigas',
#   'located',
#   'king',
#   'prussia',
#   '',
#   'pennsylvania',
#   'united',
#   'states',
#   '',
#   'operating',
#   'income',
#   '',
#   '380700000',
#   'net',
#   'income',
#   '',
#   '211200000discovered',
#   '1927',
#   'grigory',
#   'neujmin',
#   '',
#   '1147',
#   'stavropolis',
#   'apoapsis',
#   '418476000000',
#   'orbital',
#   'period',
#   '12496',
#   'days',
#   ''],
#  ['asteroid',
#   '1147',
#   'stavropolis',
#   'discovered',
#   'grigory',
#   'neujmin',
#   '11th',
#   'june',
#   '1929',
#   ''],
#  ['orbital',
#   'period',
#   '12496',
#   'days',
#   'apoapsis',
#   '41847600000001147',
#   'stavropolis',
#   'asteroid',
#   '',
#   'discovered',
#   '11',
#   'june',
#   '1929',
#   'grigory',
#   'neujmin',
#   ''],
#  ['apoapsis', '4184760000000', 'au', 'orbital', 'period'],
#  ['12496ciudad',
#   'ayala',
#   'city',
#   'located',
#   '1147',
#   'sea',
#   'level',
#   'utc',
#   'offset',
#   '6',
#   ''],
#  ['ciudad',
#   'ayala',
#   'located',
#   'mexico',
#   'leader',
#   'called',
#   'governator',
#   ''],
#  ['ciudad',
#   'ayala',
#   'ruled',
#   'governator',
#   'country',
#   'mexico',
#   'offset',
#   '6',
#   'well',
#   'sea',
#   'level',
#   '11470ciudad',
#   'ayala',
#   'located',
#   'mexico',
#   '',
#   'utc',
#   'offset'],
#  ['6', ''],
#  ['city',
#   'elevation',
#   '11470',
#   'sea',
#   'level',
#   'leader',
#   'called',
#   'governator',
#   ''],
#  ['morelos', '', 'ciudad', 'ayala', '', 'utc', 'offset', '6', 'timezone', ''],
#  ['ciudad', 'ayala', '', 'utc', 'offset', '6', '', 'part', 'morelos', ''],
#  ['utc', 'offset', 'ciudad', 'ayala', 'part', 'morelos', '6lady'],
#  ['anne', 'monson', 'spouse', 'george', 'monson', ''],
#  ['spouse', 'george', 'monson', 'lady', 'anne', 'monson', ''],
#  ['lady', 'anne', 'monson', 'spouse', 'george', 'monson', ''],
#  ['17000',
#   'members',
#   '',
#   'agremiação',
#   'sportiva',
#   'arapiraquense',
#   'play',
#   'campeonato',
#   'brasileiro',
#   'série',
#   'c',
#   'league',
#   '',
#   'vila',
#   'nova',
#   'futebol',
#   'clube',
#   'champions',
#   ''],
#  ['agremiação',
#   'sportiva',
#   'arapiraquense',
#   'club',
#   '17000',
#   'members',
#   'campeonato',
#   'brasileiro',
#   'série',
#   'c',
#   'league',
#   'along',
#   'vila',
#   'nova',
#   'futebol',
#   'clube',
#   ''],
#  ['agremiação',
#   'sportiva',
#   'arapiraquense',
#   'play',
#   'campeonato',
#   'brasileiro',
#   'série',
#   'c',
#   'league',
#   ''],
#  ['club', 'currently', '17000', 'members', ''],
#  ['vila', 'nova', 'futebol', 'clube', 'champions', 'league', ''],
#  ['region',
#   'jalisco',
#   '',
#   'mexico',
#   '',
#   'food',
#   'dish',
#   'served',
#   'dessert',
#   'called',
#   'bionico',
#   ''],
#  ['bionico',
#   '',
#   'food',
#   'found',
#   'jalisco',
#   'region',
#   'mexico',
#   '',
#   'served',
#   'dessert',
#   'course',
#   ''],
#  ['bionico',
#   '',
#   'dessert',
#   '',
#   'food',
#   'found',
#   'region',
#   'jalisco',
#   'mexico',
#   ''],
#  ['quine',
#   'tapes',
#   'produced',
#   'velvet',
#   'underground',
#   'st',
#   'louis',
#   '',
#   'missouri',
#   '',
#   'united',
#   'states',
#   '',
#   'genre',
#   'rock',
#   ''],
#  ['rock',
#   'album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'quine',
#   'tapes',
#   'produced',
#   'recorded',
#   'velvet',
#   'underground',
#   'st',
#   'louis',
#   '',
#   'missouri',
#   '',
#   'usathe',
#   'velvet',
#   'underground',
#   'recorded',
#   'rock',
#   'album',
#   'bootleg',
#   'series',
#   'volume'],
#  ['',
#   'quine',
#   'tapes',
#   'st',
#   'louis',
#   '',
#   'missouri',
#   '',
#   'usagdynia',
#   'city',
#   'poland',
#   'time',
#   'zone',
#   'utc',
#   '2',
#   'gdynia'],
#  ['poland',
#   'utc',
#   '',
#   'coordinate',
#   'universal',
#   'time',
#   '',
#   'offset',
#   '2gdynia',
#   '',
#   'poland',
#   'utc',
#   '0200year',
#   'light',
#   'band',
#   'whose',
#   'members',
#   'include',
#   'former',
#   'guitarist',
#   'monarch',
#   'created',
#   'album',
#   'called',
#   'nord',
#   ''],
#  ['nord', 'album', 'year', 'light', '', 'associated', 'band', 'monarch', ''],
#  ['born',
#   'zaoyang',
#   'city',
#   '',
#   'hubei',
#   '',
#   'nie',
#   'haisheng',
#   'participated',
#   'shenzhou',
#   '6',
#   'mission',
#   ''],
#  ['shenzhou',
#   '6',
#   'crew',
#   'member',
#   'nie',
#   'haisheng',
#   'born',
#   'zaoyang',
#   'hubei',
#   'province',
#   ''],
#  ['born',
#   'zaoyang',
#   '',
#   'hubei',
#   '',
#   'nie',
#   'haisheng',
#   'participated',
#   'shenzhou',
#   '6aleksandr',
#   'prudnikov',
#   '',
#   '185',
#   'cm',
#   'tall',
#   'played',
#   'fc',
#   'spartak',
#   'moscow',
#   'youth',
#   'team',
#   ''],
#  ['fc', 'spartak', 'moscow', 'based', 'otkrytiye', 'arena', ''],
#  ['aleksandr',
#   'prudnikov',
#   '185',
#   'cm',
#   'tall',
#   'member',
#   'youth',
#   'side',
#   'fc',
#   'spartak',
#   'moscow',
#   ''],
#  ['home', 'ground', 'fc', 'spartak', 'moscow', 'otkrytiye', 'arena', ''],
#  ['aleksandr',
#   'prudnikov',
#   '1850',
#   'cm',
#   'tall',
#   'played',
#   'fc',
#   'spartak',
#   'moscow',
#   'otkrytiye',
#   'arena',
#   ''],
#  ['pontiac',
#   'rageous',
#   'assembled',
#   'michigan',
#   'assembly',
#   'line',
#   'detroit',
#   'last',
#   'produced',
#   '1997ending',
#   'production',
#   '1997',
#   '',
#   'pontiac',
#   'rageous',
#   'assembled',
#   'detroit',
#   '',
#   'michigan',
#   ''],
#  ['ending',
#   '1997',
#   '',
#   'pontiac',
#   'rageous',
#   'assembled',
#   'detroit',
#   '',
#   'michigan',
#   ''],
#  ['total', 'area', 'city', 'detroit', '37003', 'square', 'kilometers', ''],
#  ['detroit', 'total', 'area', '37003', 'square', 'kilometers', ''],
#  ['english',
#   'without',
#   'tears',
#   '',
#   'film',
#   'directed',
#   'harold',
#   'french',
#   'composed',
#   'nicholas',
#   'brodszky',
#   '',
#   'released',
#   '07',
#   '',
#   '28',
#   '',
#   '1944',
#   ''],
#  ['film', 'length', '89', 'minutes', ''],
#  ['89',
#   'minute',
#   'movie',
#   '´',
#   'english',
#   'without',
#   'tears',
#   '´',
#   'directed',
#   'harold',
#   'french',
#   '',
#   'released',
#   '7',
#   '',
#   '28',
#   '',
#   '1944',
#   ''],
#  ['songs',
#   'used',
#   'throughout',
#   'movie',
#   'composed',
#   'nicholas',
#   'brodszky',
#   ''],
#  ['english',
#   'without',
#   'tears',
#   'movie',
#   'directed',
#   'harold',
#   'french',
#   'musically',
#   'composed',
#   'nicholas',
#   'brodszky',
#   ''],
#  ['runs',
#   '89',
#   'minutes',
#   'released',
#   'july',
#   '7th',
#   '',
#   '1944gma',
#   'new',
#   'media',
#   'located',
#   'gma',
#   'network',
#   'center',
#   ''],
#  ['gma',
#   'new',
#   'media',
#   'headquarters',
#   'located',
#   'gma',
#   'network',
#   'center',
#   ''],
#  ['gma'],
#  ['new', 'media', 'located', 'inside', 'gma', 'network', 'center', ''],
#  ['olga', 'bondareva', 'professional', 'field', 'economics', ''],
#  ['olga', 'bondareva', 'economist', ''],
#  ['olga', 'bondareva', 'currently', 'works', 'field', 'economics', ''],
#  ['music',
#   'film',
#   'english',
#   'without',
#   'tears',
#   'composed',
#   'nicholas',
#   'brodszky',
#   ''],
#  ['nicholas',
#   'brodszky',
#   'composed',
#   'music',
#   'movie',
#   'english',
#   'without',
#   'tears',
#   ''],
#  ['nicholas',
#   'brodszky',
#   'composer',
#   'songs',
#   'used',
#   'english',
#   'without',
#   'tears',
#   ''],
#  ['bbc',
#   '',
#   'located',
#   'broadcasting',
#   'house',
#   'london',
#   '',
#   'last',
#   'aired',
#   'creator',
#   'steve',
#   'bright',
#   'bananaman',
#   '',
#   'starring',
#   'bill',
#   'oddie',
#   '',
#   'april',
#   '15th',
#   '',
#   '1986the',
#   'bbc',
#   '',
#   'broadcasting',
#   'house',
#   '',
#   'based',
#   'london',
#   ''],
#  ['show',
#   'bananaman',
#   'starred',
#   'bill',
#   'oddie',
#   'broadcasted',
#   'bbc',
#   'last',
#   'aired',
#   'april',
#   '15th',
#   '',
#   '1986',
#   ''],
#  ['creator', 'bananaman', 'steve', 'bright', ''],
#  ['broadcasting', 'house', 'also', 'known', 'headquarters', 'bbc', ''],
#  ['one',
#   'bbc',
#   'television',
#   'shows',
#   '',
#   'bananaman',
#   'created',
#   'steve',
#   'bright',
#   'starred',
#   'bill',
#   'oddie',
#   ''],
#  ['bananaman',
#   'last',
#   'episode',
#   'broadcast',
#   'april',
#   '15',
#   '',
#   '1986montreal',
#   'locomotive',
#   'works',
#   'built',
#   'alco',
#   'rs3',
#   'may',
#   '1950',
#   'august',
#   '1956the'],
#  ['alco',
#   'rs3',
#   '',
#   'built',
#   'montreal',
#   'locomotive',
#   'works',
#   '',
#   'produced',
#   'may',
#   '1950',
#   'august',
#   '1956the'],
#  ['alco',
#   'rs3',
#   'built',
#   'montreal',
#   'locomotive',
#   'works',
#   'produced',
#   'may',
#   '1950',
#   'august',
#   '1956agremiacao'],
#  ['sportiva',
#   'arapiraquense',
#   '17000',
#   'members',
#   'play',
#   'campeonato',
#   'brasileiro',
#   'serie',
#   'c',
#   'league',
#   ''],
#  ['champions', 'league', 'vila', 'nova', 'futebol', 'clube', ''],
#  ['agremiação',
#   'sportiva',
#   'arapiraquense',
#   '17000',
#   'members',
#   'play',
#   'campeonato',
#   'brasileiro',
#   'série',
#   'c',
#   'league',
#   '',
#   'vila',
#   'nova',
#   'futebol',
#   'clube',
#   'champions',
#   ''],
#  ['agremiacao',
#   'sportiva',
#   'arapiraquense',
#   '17000',
#   'members',
#   'plays',
#   'campeonato',
#   'brasileiro',
#   'serie',
#   'c',
#   'league',
#   'vila',
#   'nova',
#   'futebol',
#   'clube',
#   'champions',
#   ''],
#  ['cecil', 'parker', 'main', 'role', 'great', 'young', ''],
#  ['cecil', 'parker', 'starred', '1956', 'movie', 'great', 'young', ''],
#  ['great', 'young', '1956', 'film', 'starring', 'cecil', 'parker', ''],
#  ['movie', '', 'super', 'capers', '', 'directed', 'ray', 'griggs', ''],
#  ['super', 'capers', 'directed', 'ray', 'griggs', ''],
#  ['ray', 'griggs', 'director', 'super', 'capers', ''],
#  ['sludge',
#   'metal',
#   'post',
#   'metal',
#   'album',
#   'nord',
#   'produced',
#   'created',
#   'artist',
#   'year',
#   'light',
#   'released',
#   'record',
#   'label',
#   'crucial',
#   'blast',
#   '06',
#   '',
#   '09',
#   '',
#   '2006',
#   ''],
#  ['followed',
#   'album',
#   'live',
#   'roadburn',
#   '2008the',
#   'year',
#   'light',
#   'self',
#   'produced',
#   'album',
#   'nord',
#   '',
#   'sludge',
#   'post',
#   '',
#   'metal',
#   'genre',
#   'released',
#   'september',
#   '6',
#   '',
#   '2006',
#   ''],
#  ['record',
#   'label',
#   'crucial',
#   'blast',
#   'followed',
#   'live',
#   'roadburn',
#   '2008the',
#   'self',
#   '',
#   'produced',
#   'year',
#   'light',
#   'post',
#   'metal',
#   'sludge',
#   'metal',
#   'album',
#   'nord',
#   'released',
#   '2006',
#   '',
#   '09',
#   '',
#   '06',
#   'followed',
#   'album',
#   'live',
#   'roadburn',
#   '2008',
#   ''],
#  ['nord', 'released', 'crucial', 'blast', 'record', 'label', ''],
#  ['train',
#   'followed',
#   'mermaid',
#   'imagine',
#   'song',
#   'musical',
#   'artist',
#   'john',
#   'lennon',
#   '',
#   'fimi',
#   'certification',
#   ''],
#  ['produced', 'production', 'team', 'espionage', ''],
#  ['train',
#   'released',
#   'mermaid',
#   '',
#   'produced',
#   'espionage',
#   'team',
#   '',
#   'shortly',
#   'covering',
#   'john',
#   'lennon',
#   'imagine',
#   ''],
#  ['imagine', 'john', 'lennon', 'earned', 'fimi', 'certification', ''],
#  ['train',
#   'song',
#   'mermaid',
#   '',
#   'produced',
#   'espionage',
#   'production',
#   'team',
#   '',
#   'followed',
#   'band',
#   '’s',
#   'cover',
#   'john',
#   'lennon',
#   'song',
#   'imagine',
#   ''],
#  ['musician',
#   'john',
#   'lennon',
#   'wrote',
#   'also',
#   'originally',
#   'performed',
#   'song',
#   'imagine',
#   'certified',
#   'fimithe'],
#  ['adolfo',
#   'suárez',
#   'madrid',
#   '–',
#   'barajas',
#   'airport',
#   'located',
#   '610',
#   'metres',
#   'sea',
#   'level',
#   ''],
#  ['airport',
#   'operated',
#   'enaire',
#   'runway',
#   'named',
#   '14l32r',
#   '',
#   'length',
#   '3500adolfo',
#   'suárez',
#   'madrid',
#   '–',
#   'barajas',
#   'airport',
#   '',
#   'operated',
#   'enaire',
#   'organisation',
#   '',
#   'elevated',
#   '610',
#   'metres',
#   'sea',
#   'level',
#   'runway',
#   'length',
#   '35000',
#   ''],
#  ['adolfo',
#   'suárez',
#   'madrid',
#   '–',
#   'barajas',
#   'airport',
#   'runway',
#   'name',
#   '14l32rexpect',
#   'miracle',
#   'genre',
#   'easy',
#   'listening',
#   ''],
#  ['expect', 'miracle', 'easy', 'listening', 'album', ''],
#  ['expect', 'miracle', 'easy', 'listening', 'genre', ''],
#  ['liselotte',
#   'grschebina',
#   'nationality',
#   'israeli',
#   'one',
#   'ethnic',
#   'groups',
#   'arab',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'nationality',
#   'israel',
#   'one',
#   'ethnicities',
#   'arab',
#   'people',
#   ''],
#  ['israel',
#   'different',
#   'ethnic',
#   'groups',
#   'like',
#   'arabs',
#   '',
#   'israeli',
#   'nationals',
#   'liselotte',
#   'grschebina',
#   ''],
#  ['squeeze', 'followed', 'album', '1969', ''],
#  ['velvet', 'underground', 'live', ''],
#  ['velvet',
#   'underground',
#   'album',
#   'squeeze',
#   'followed',
#   'live',
#   'album',
#   '1969',
#   ''],
#  ['velvet', 'underground', 'live', ''],
#  ['velvet',
#   'underground',
#   'album',
#   'squeeze',
#   'followed',
#   'album',
#   '1969',
#   ''],
#  ['velvet', 'underground', 'live', ''],
#  ['alan',
#   'b',
#   'miller',
#   'hall',
#   'owned',
#   'college',
#   'william',
#   'mary',
#   'completed',
#   '1st',
#   'june',
#   '2009completed',
#   'june',
#   '1st',
#   '',
#   '2009',
#   '',
#   'alan',
#   'b',
#   'miller',
#   'hall',
#   'owned',
#   'college',
#   'william',
#   'mary',
#   ''],
#  ['alan',
#   'b',
#   'miller',
#   'hall',
#   '',
#   'owned',
#   'college',
#   'william',
#   'mary',
#   '',
#   'completed',
#   '1st',
#   'june',
#   '2009the',
#   'bootleg',
#   'series',
#   'volume',
#   '',
#   'quine',
#   'tapes',
#   '',
#   'rock',
#   'music',
#   'genre',
#   '',
#   'runtime',
#   '23005',
#   'produced',
#   'released',
#   'velvet',
#   'underground',
#   ''],
#  ['recorded', 'united', 'states', ''],
#  ['bootleg',
#   'series',
#   'volume',
#   '',
#   'quine',
#   'tapes',
#   '',
#   'produced',
#   'created',
#   'velvet',
#   'underground',
#   'run',
#   'time',
#   '23005',
#   'minutes',
#   'recorded',
#   'united',
#   'states',
#   ''],
#  ['belongs', 'rock', 'genre', ''],
#  ['album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'quine',
#   'tapes',
#   'velvet',
#   'underground',
#   'rock',
#   'music',
#   'genre',
#   '',
#   'produced',
#   'velvet',
#   'underground',
#   'recorded',
#   'united',
#   'states',
#   ''],
#  ['lasts', '23005', 'minutes', ''],
#  ['bionico',
#   '',
#   'served',
#   'dessert',
#   'course',
#   '',
#   'food',
#   'found',
#   'mexico',
#   ''],
#  ['currency', 'mexico', 'mexican', 'peso', 'inhabited', 'mexicans', ''],
#  ['honey', 'added', 'bionico', ''],
#  ['bionico', 'dessert', 'food', 'made', 'honey', 'found', 'mexico', ''],
#  ['mexico', 'inhabited', 'mexicans', 'currency', 'peso', ''],
#  ['bionico',
#   '',
#   'served',
#   'dessert',
#   'course',
#   '',
#   'food',
#   'found',
#   'mexico',
#   ''],
#  ['honey',
#   'used',
#   'variation',
#   'dish',
#   'bionico',
#   '',
#   'currency',
#   'mexico',
#   'peso',
#   'inhabited',
#   'mexicans',
#   ''],
#  ['gdynia',
#   '',
#   'poland',
#   'follows',
#   'central',
#   'european',
#   'summer',
#   'time',
#   'timezone',
#   ''],
#  ['gdynia', '', 'poland', 'central', 'european', 'summer', 'time', 'zone', ''],
#  ['time',
#   'zone',
#   'gdynia',
#   '',
#   'poland',
#   'central',
#   'european',
#   'summer',
#   'time',
#   ''],
#  ['super', 'capers', 'distributed', 'public', 'company', 'lionsgate', ''],
#  ['also', 'distributed', 'roadside', 'attractions', ''],
#  ['roadside',
#   'attractions',
#   'distributed',
#   'super',
#   'capers',
#   'also',
#   'distributed',
#   'public',
#   'company',
#   'lionsgate',
#   ''],
#  ['movie',
#   'super',
#   'capers',
#   'distributed',
#   'roadside',
#   'attractions',
#   'lionsgate',
#   '',
#   'public',
#   'company',
#   ''],
#  ['terms', 'nationality', '', 'nurhan', 'atasoy', 'turkish', 'person', ''],
#  ['nurhan', 'atasoy', 'turkish', 'nationality', ''],
#  ['nurhan', 'atasoy', 'nationality', 'turkish', 'people', ''],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   'established',
#   '2000',
#   'categorized',
#   'contributing',
#   'property',
#   ''],
#  ['monument',
#   'situated',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'frederick',
#   'county',
#   '',
#   'maryland',
#   'southwest',
#   ''],
#  ['11th',
#   'mississippi',
#   'infantry',
#   'monument',
#   '',
#   'built',
#   'year',
#   '2000',
#   '',
#   'falls',
#   'category',
#   'contributing',
#   'property',
#   ''],
#  ['monument',
#   'located',
#   'adams',
#   'county',
#   '',
#   'pennsylvania',
#   'frederick',
#   'county',
#   '',
#   'maryland',
#   'southwest',
# ...
#   'leader',
#   'title',
#   'city',
#   'manager',
#   ''],
#  ['population',
#   'ciudad',
#   'ayala',
#   'metropolitan',
#   'area',
#   '1777539',
#   '',
#   'population',
#   'density',
#   '1604',
#   ''],
#  ['1147', 'sea', 'level', 'utc', 'offset', '6ciudad', 'ayala', 'city', ''],
#  ['population', 'metropolitan', 'area', '1777539', 'density', '16040', ''],
#  ['government',
#   'type',
#   'council',
#   '',
#   'manager',
#   'government',
#   'one',
#   'leaders',
#   'city',
#   'manager',
#   ''],
#  ['utc', 'offset', 'city', '6'],
#  ['elevation',
#   'sea',
#   'level',
#   '11470adolfo',
#   'suárez',
#   'madrid',
#   '–',
#   'barajas',
#   'airport',
#   'alcobendas',
#   'operated',
#   'enaire',
#   'madrid',
#   ''],
#  ['runway',
#   'length',
#   'adolfo',
#   'suárez',
#   'madrid',
#   '–',
#   'barajas',
#   'airport',
#   '4349',
#   'named',
#   '14r32l',
#   '',
#   'adolfo',
#   'suárez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   'also',
#   'elevation',
#   '6100',
#   'metres',
#   'sea',
#   'level',
#   'runway',
#   'length',
#   '4349adolfo',
#   'suárez',
#   'madrid',
#   '–',
#   'barajas',
#   'airport',
#   'alcobendas',
#   '',
#   'operated',
#   'enaire',
#   'madrid',
#   '',
#   '',
#   'located',
#   '610',
#   'metres',
#   'sea',
#   'level',
#   'runway',
#   'called',
#   '14r32l',
#   '4349',
#   'metres',
#   'long',
#   ''],
#  ['adolfo',
#   'suárez',
#   'madrid',
#   '–',
#   'barajas',
#   'airport',
#   'located',
#   'alcobendas',
#   '',
#   '610',
#   'meters',
#   'sea',
#   'level',
#   ''],
#  ['airport', 'operated', 'enaire', '', 'located', 'madrid', ''],
#  ['runway', 'named', '14r32l', 'length', '4349', 'meters', ''],
#  ['aleksandr',
#   'prudnikov',
#   'plays',
#   'fc',
#   'amkar',
#   'perm',
#   '',
#   'managed',
#   'gadzhi',
#   'gadzhiyev',
#   ''],
#  ['prudnikov',
#   'also',
#   'played',
#   'fc',
#   'spartak',
#   'moscow',
#   'youth',
#   'team',
#   ''],
#  ['185', 'cm', ''],
#  ['tall', ''],
#  ['aleksandr',
#   'prudnikov',
#   '',
#   '185',
#   'cm',
#   '',
#   'plays',
#   'fc',
#   'amkar',
#   'perm',
#   '',
#   'managed',
#   'gadzhi',
#   'gadzhiyev',
#   ''],
#  ['aleksandr',
#   'prudnikov',
#   'also',
#   'member',
#   'youth',
#   'side',
#   'fc',
#   'spartak',
#   'moscow',
#   ''],
#  ['adolfo',
#   'suárez',
#   'madrid',
#   '–',
#   'barajas',
#   'airport',
#   'alcobendas',
#   '',
#   'madrid',
#   '',
#   'spain',
#   'operated',
#   'enaire',
#   'runway',
#   'called',
#   '14r32l',
#   'length',
#   '4349adolfo',
#   'suárez',
#   'madrid',
#   '–',
#   'barajas',
#   'airport',
#   'located',
#   'alcobendas',
#   ''],
#  ['airport', 'operated', 'enaire', '', 'located', 'madrid', '', 'spain', ''],
#  ['runway', 'named', '14r32l', 'length', '4349', 'meters', ''],
#  ['adolfo',
#   'suarez',
#   'madrid',
#   '',
#   'barajas',
#   'airport',
#   'operated',
#   'enaire',
#   'located',
#   'alcobendas',
#   'madrid',
#   '',
#   'spain',
#   ''],
#  ['runway', 'length', 'name', 'runway', 'airport', '43490', ''],
#  ['14r32lthe',
#   'drum',
#   'kit',
#   'instrument',
#   'used',
#   'punk',
#   'blues',
#   'genre',
#   ''],
#  ['drum', 'kit', 'instrument', 'punk', 'blues', ''],
#  ['punk', 'blues', 'usually', 'uses', 'drum', 'kit', ''],
#  ['liselotte',
#   'grschebina',
#   'born',
#   'karlsruhe',
#   'died',
#   'israel',
#   'june',
#   '14th',
#   '',
#   '1994liselotte',
#   'grschebina',
#   'born',
#   'karlsruhe',
#   'died',
#   'june',
#   '14th',
#   '',
#   '1994',
#   'israel',
#   ''],
#  ['one',
#   'official',
#   'languages',
#   'israel',
#   'modern',
#   'standard',
#   'arabic',
#   ''],
#  ['official', 'language', 'israel', 'modern', 'standard', 'arabic', ''],
#  ['liselotte',
#   'grschebina',
#   'born',
#   'karlsruhe',
#   'known',
#   'oberbürgermeister',
#   'leader',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'born',
#   'karlsruhe',
#   '',
#   'oberbürgermeister',
#   'leader',
#   ''],
#  ['karlsruhe',
#   '',
#   'birthplace',
#   'liselotte',
#   'grschebina',
#   '',
#   'leader',
#   'named',
#   'oberburgermeister',
#   ''],
#  ['acharya',
#   'institute',
#   'technology',
#   'affiliated',
#   'visvesvaraya',
#   'technological',
#   'university',
#   '',
#   'offers',
#   'tennis',
#   'sport',
#   ''],
#  ['india',
#   'council',
#   'technical',
#   'education',
#   'located',
#   'mumbai',
#   'gave',
#   'institute',
#   'technical',
#   'campus',
#   'status',
#   ''],
#  ['address',
#   'campus',
#   '',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '',
#   '560090tennis',
#   'one',
#   'sports',
#   'offered',
#   'acharya',
#   'institute',
#   'technology',
#   'affiliated',
#   'visvesvaraya',
#   'technological',
#   'university',
#   ''],
#  ['india',
#   'council',
#   'technical',
#   'education',
#   'located',
#   'mumbai',
#   'gave',
#   'institute',
#   'technical',
#   'campus',
#   'status',
#   ''],
#  ['address',
#   'campus',
#   '',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '',
#   '560090acharya',
#   'institute',
#   'technology',
#   'given',
#   '',
#   'technical',
#   'campus',
#   '',
#   'status',
#   'india',
#   'council',
#   'technical',
#   'education',
#   '',
#   'tennis',
#   'one',
#   'sports',
#   'offered',
#   'affiliated',
#   'visvesvaraya',
#   'technological',
#   'university',
#   ''],
#  ['india',
#   'council',
#   'technical',
#   'education',
#   'located',
#   'mumbai',
#   'campus',
#   'acharya',
#   'institute',
#   'technology',
#   'located',
#   'soldevanahalli',
#   '',
#   'acharya',
#   'dr',
#   'sarvapalli',
#   'radhakrishnan',
#   'road',
#   '',
#   'hessarghatta',
#   'main',
#   'road',
#   '',
#   'bangalore',
#   '–',
#   '560090tom',
#   'sizemore',
#   'stars',
#   'super',
#   'capers',
#   'starred',
#   'michael',
#   'rooker',
#   ''],
#  ['film',
#   'super',
#   'capers',
#   'stars',
#   'michael',
#   'rooker',
#   'tom',
#   'sizemore',
#   ''],
#  ['tom',
#   'sizemore',
#   'stars',
#   'super',
#   'capers',
#   '',
#   'film',
#   'michael',
#   'rooker',
#   'also',
#   'plays',
#   ''],
#  ['super',
#   'capers',
#   'starred',
#   'michael',
#   'rooker',
#   '',
#   'born',
#   'jasper',
#   '',
#   'alabama',
#   ''],
#  ['super',
#   'capers',
#   'film',
#   'starring',
#   'michael',
#   'rooker',
#   '',
#   'born',
#   'jasper',
#   '',
#   'alabama',
#   ''],
#  ['michael',
#   'rooker',
#   '',
#   'played',
#   'super',
#   'capers',
#   '',
#   'born',
#   'jasper',
#   '',
#   'alabama',
#   ''],
#  ['grigory',
#   'neujmin',
#   'discovered',
#   '1147',
#   'stavropolis',
#   'june',
#   '11th',
#   '',
#   '1929',
#   ''],
#  ['apoapsis',
#   '4184760000000',
#   'absolute',
#   'magnitude',
#   '115on',
#   'june',
#   '11',
#   '',
#   '1929',
#   '',
#   'grigory',
#   'neujmin',
#   'discovered',
#   'asteroid',
#   '1147',
#   'stavropolis',
#   ''],
#  ['apoapsis',
#   '4184760000000',
#   'absolute',
#   'magnitude',
#   '115grigory',
#   'neujmin',
#   'discovered',
#   'asteroid',
#   '1147',
#   'stavropolis',
#   'june',
#   '11',
#   '',
#   '1929',
#   ''],
#  ['absolute',
#   'magnitude',
#   '115',
#   '4184760000000',
#   'auafter',
#   'releasing',
#   'album',
#   'squeeze',
#   '',
#   'music',
#   'group',
#   'velvet',
#   'underground',
#   'produced',
#   'released',
#   'rock',
#   'music',
#   'album',
#   'bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'quine',
#   'tapes',
#   '',
#   'recorded',
#   'st',
#   'louis',
#   'missouri',
#   '',
#   'usa'],
#  ['album',
#   'released',
#   '2001',
#   '',
#   '10',
#   '',
#   '16',
#   'polydor',
#   'universal',
#   'music',
#   'group',
#   'record',
#   'labels',
#   'total',
#   'run',
#   'time',
#   '23005',
#   'minutes',
#   ''],
#  ['bootleg',
#   'series',
#   'volume',
#   '1',
#   '',
#   'quine',
#   'tapes',
#   'run',
#   'time',
#   '23005',
#   'recorded',
#   'polydor',
#   'records',
#   'universal',
#   'music',
#   'group',
#   'record',
#   'label',
#   'st',
#   'louis',
#   '',
#   'missouri',
#   '',
#   'united',
#   'states',
#   'released',
#   'october',
#   '',
#   '16',
#   '',
#   '2001',
#   ''],
#  ['preceded', 'squeeze', 'velvet', 'underground', ''],
#  ['bootleg',
#   'series',
#   'volume',
#   '',
#   'quine',
#   'tapes',
#   'runtime',
#   '23005',
#   'minutes',
#   'recorded',
#   'st',
#   'louis',
#   'missouri',
#   '',
#   'united',
#   'states',
#   'released',
#   '10',
#   '',
#   '16',
#   '',
#   '2001',
#   ''],
#  ['recorded',
#   'polydor',
#   'records',
#   'universal',
#   'music',
#   'group',
#   'record',
#   'label',
#   'album',
#   'preceded',
#   'album',
#   'squeeze1147',
#   'stavropolis',
#   'discovered',
#   'june',
#   '11',
#   '',
#   '1929',
#   'rotation',
#   'period',
#   '203785',
#   'periapsis',
#   '2608550000000',
#   'apoapsis',
#   '4184760000000',
#   ''],
#  ['orbital',
#   'period',
#   'asteroid',
#   '12496',
#   'days1147',
#   'stavropolis',
#   'asteroid',
#   '',
#   'discovered',
#   'june',
#   '1929',
#   ''],
#  ['rotation', 'period', '203785', ''],
#  ['periapsis',
#   '2608550000000',
#   '',
#   'apoapsis',
#   'asteroid',
#   '418476000000',
#   'au',
#   'orbital',
#   'period',
#   '12496the',
#   'asteroid',
#   '1147',
#   'stavropolis',
#   'discovered',
#   '11th',
#   'june',
#   '1929',
#   'rotation',
#   'period',
#   '203785',
#   'periapsis',
#   '260855000000',
#   'apoapsis',
#   '4184760000000',
#   ''],
#  ['orbital', 'period', 'asteroid', '12496', 'days', ''],
#  ['john',
#   'mills',
#   'died',
#   '2005nurhan',
#   'atasoy',
#   'born',
#   'reşadiye',
#   '',
#   'residence',
#   'istanbul',
#   ''],
#  ['istanbul',
#   'metro',
#   'area',
#   '5343',
#   'square',
#   'kilometers',
#   'time',
#   'zone',
#   'eastern',
#   'european',
#   'summer',
#   'time',
#   ''],
#  ['nurhan',
#   'atasoy',
#   'whose',
#   'birth',
#   'place',
#   'resadiye',
#   '',
#   'also',
#   'residence',
#   'istanbul',
#   'metropolitan',
#   'area',
#   '5343',
#   'km²',
#   ''],
#  ['istanbul', 'eastern', 'european', 'summer', 'time', 'zone', ''],
#  ['nurhan', 'atasoy', 'born', 'reşadiye', 'lives', 'istanbul', ''],
#  ['istanbul',
#   'metropolitan',
#   'area',
#   '53430000000',
#   'uses',
#   'eastern',
#   'european',
#   'summer',
#   'time',
#   'time',
#   'zone',
#   ''],
#  ['year',
#   'light',
#   'sludge',
#   'metal',
#   'album',
#   'nord',
#   '',
#   '2006',
#   '',
#   '09',
#   '',
#   '06',
#   '',
#   'followed',
#   'live',
#   'roadburn',
#   '2008the',
#   'release',
#   'date',
#   'nord',
#   '',
#   'year',
#   'light',
#   'album',
#   'sludge',
#   'metal',
#   'genre',
#   '',
#   '06',
#   '',
#   '09',
#   '',
#   '2006',
#   'album',
#   'live',
#   'roadburn',
#   '2008the',
#   'year',
#   'light',
#   'album',
#   'nord',
#   'sludge',
#   'metal',
#   'genre',
#   '',
#   'released',
#   'september',
#   '6',
#   '',
#   '2006',
#   'followed',
#   'year',
#   'light',
#   'album',
#   'live',
#   'roadburn',
#   '2008nurhan',
#   'atasoy',
#   'born',
#   'turkey',
#   ''],
#  ['binali',
#   'yıldırım',
#   'former',
#   'prime',
#   'minister',
#   'turkey',
#   'current',
#   'president',
#   'recep',
#   'tayyip',
#   'erdoğan',
#   ''],
#  ['turkey',
#   '',
#   'led',
#   'recep',
#   'tayyip',
#   'erdoğan',
#   'binali',
#   'yildirim',
#   '',
#   'nurhan',
#   'atasoy',
#   'born',
#   'nurhan'],
#  ['atasoy',
#   'born',
#   'turkey',
#   'current',
#   'leaders',
#   'include',
#   'recep',
#   'tayyip',
#   'erdoğan',
#   'binali',
#   'yildirim',
#   ''],
#  ['turn',
#   'honeymoon',
#   'killers',
#   '',
#   'noise',
#   'rock',
#   'punk',
#   'blues',
#   'genre',
#   '',
#   'runtime',
#   '351',
#   'minutes',
#   ''],
#  ['producers', 'honeymoon', 'killers', 'wharton', 'tiers', ''],
#  ['genre',
#   'punk',
#   'blues',
#   '',
#   'honeymoon',
#   'killers',
#   '',
#   '',
#   'turn',
#   '',
#   '35',
#   'minutes',
#   '10',
#   'seconds',
#   'example',
#   'noise',
#   'rock',
#   'produced',
#   'wharton',
#   'tiers',
#   'american',
#   'band',
#   ''],
#  ['band', 'also', 'participated', 'production', ''],
#  ['american',
#   'noise',
#   'rock',
#   'band',
#   'honeymoon',
#   'killers',
#   '',
#   'self',
#   '',
#   'produced',
#   'punk',
#   'blues',
#   'album',
#   'turn',
#   ''],
#  ['wharton', 'tiers', 'producer', 'album', 'runs', '351', 'minutes', ''],
#  ['baroque',
#   'pop',
#   'fusion',
#   'genre',
#   'includes',
#   'elements',
#   'pop',
#   'rock',
#   '',
#   'example',
#   'train',
#   'song',
#   'mermaid',
#   'mermaid',
#   '',
#   'released',
#   'band',
#   'train',
#   '',
#   'song',
#   'pop',
#   'rock',
#   'genre',
#   'also',
#   'includes',
#   'fusion',
#   'genre',
#   'baroque',
#   'pop',
#   ''],
#  ['mermaid',
#   '',
#   'song',
#   'band',
#   'train',
#   '',
#   'belongs',
#   'genre',
#   'pop',
#   'rock',
#   ''],
#  ['offshoot', 'pop', 'rock', 'fusion', 'genre', 'baroque', 'pop', ''],
#  ['parent',
#   'company',
#   'polydor',
#   'records',
#   'universal',
#   'music',
#   'group',
#   ''],
#  ['universal',
#   'music',
#   'group',
#   'parent',
#   'company',
#   'polydor',
#   'records',
#   ''],
#  ['polydor',
#   'records',
#   '',
#   'parent',
#   'company',
#   'universal',
#   'music',
#   'group',
#   ''],
#  ['liselotte', 'grschebina', 'photographer', 'born', 'german', 'empire', ''],
#  ['liselotte',
#   'grschebina',
#   'professional',
#   'photographer',
#   'born',
#   'german',
#   'empire',
#   ''],
#  ['liselotte',
#   'grschebina',
#   'professional',
#   'photographer',
#   'born',
#   'german',
#   'empire',
#   ''],
#  ['pontiac',
#   'rageous',
#   '',
#   'coupe',
#   'assembled',
#   'michigan',
#   '',
#   'first',
#   'last',
#   'produced',
#   '1997',
#   ''],
#  ['assembly', 'line', 'detroit', ''],
#  ['pontiac',
#   'rageous',
#   '',
#   'car',
#   'coupe',
#   'body',
#   'style',
#   '',
#   'assembled',
#   'detroit',
#   'michigan',
#   '',
#   'first',
#   'last',
#   'produced',
#   '1997in',
#   '1997',
#   '',
#   'pontiac',
#   'rageous',
#   'coupe',
#   '',
#   'assembled',
#   'detroit',
#   '',
#   'michigan',
#   '',
#   'went',
#   'ended',
#   'production',
#   ''],
#  ['gma'],
#  ['new',
#   'media',
#   'company',
#   'mass',
#   'media',
#   'industry',
#   'whose',
#   'headquarters',
#   'located',
#   'gma',
#   'network',
#   'center',
#   ''],
#  ['inside',
#   'gma',
#   'network',
#   'center',
#   'lies',
#   'mass',
#   'media',
#   'industry',
#   'gma',
#   'new',
#   'media',
#   ''],
#  ['gma'],
#  ['new', 'media', 'mass', 'media', 'company', 'gma', 'network', 'center', ''],
#  ['alan',
#   'shepard',
#   'born',
#   'nov',
#   '18',
#   '',
#   '1923',
#   'new',
#   'hampshire',
#   '',
#   'went',
#   'school',
#   'nwc',
#   'graduated',
#   '1957',
#   'member',
#   'apollo',
#   '14',
#   'crew',
#   ''],
#  ['alan',
#   'shepard',
#   'born',
#   'november',
#   '18',
#   '',
#   '1923',
#   'new',
#   'hampshire',
#   ''],
#  ['shepard',
#   'graduated',
#   'nwc',
#   '1957',
#   'served',
#   'crew',
#   'member',
#   'apollo',
#   '14alan'],
#  ['shepard', 'born', 'new', 'hampshire', 'november', '18th', '', '1923', ''],
#  ['graduated',
#   'nwc',
#   '1957',
#   'went',
#   'crew',
#   'member',
#   'apollo',
#   '14it',
#   'great',
#   'young',
#   'movie',
#   '1956',
#   'runs',
#   '94',
#   'minutes',
#   ''],
#  ['stars', 'cecil', 'parker', '’s', 'edited', 'max', 'benedict', ''],
#  ['louis', 'levy', 'composed', 'music', ''],
#  ['1956', 'film', '', 'great', 'young', '', 'stars', 'cecil', 'parker', ''],
#  ['movie', '94', 'minutes', 'edited', 'max', 'benedict', ''],
#  ['louis', 'levy', 'composed', 'music', 'film', ''],
#  ['great', 'young', '94', 'minute', 'movie', 'released', '1956', ''],
#  ['starred', 'cecil', 'parker', 'edited', 'max', 'benedict', ''],
#  ['louis', 'levy', 'musical', 'composer', ''],
#  ['israeli',
#   'national',
#   'liselotte',
#   'grschebina',
#   'born',
#   'karlsruhe',
#   'may',
#   '2',
#   '',
#   '1908',
#   '',
#   'died',
#   'june',
#   '14',
#   '',
#   '1994israeli',
#   'liselotte',
#   'grschebina',
#   'born',
#   'karlsruhe',
#   'may',
#   '2',
#   '',
#   '1908',
#   'died',
#   'june',
#   '14',
#   '',
#   '1994liselotte',
#   'grschebina',
#   'israeli',
#   'national',
#   'born',
#   'karlsruhe',
#   'may',
#   '2',
#   '',
#   '1908',
#   'died',
#   'june',
#   '14',
#   '',
#   '1994the',
#   'construction',
#   'alan',
#   'b',
#   'miller',
#   'hall',
#   'lasted',
#   'march',
#   '30th',
#   '',
#   '2007',
#   'june',
#   '1st',
#   '',
#   '2009',
#   ''],
#  ['robert', 'stern', 'architect', 'building', ''],
#  ['alan',
#   'b',
#   'miller',
#   'hall',
#   'located',
#   '101',
#   'ukrop',
#   'way',
#   '',
#   'virginia',
#   '',
#   'current',
#   'tenant',
#   'mason',
#   'school',
#   'business',
#   ''],
#  ['robert',
#   'stern',
#   'architect',
#   'responsible',
#   'designing',
#   'alan',
#   'b',
#   'miller',
#   'hall',
#   '101',
#   'ukrop',
#   'way',
#   'virginia',
#   ''],
#  ['construction',
#   'started',
#   'building',
#   '30th',
#   'march',
#   '',
#   '2007',
#   'completed',
#   '1st',
#   'june',
#   '',
#   '2009',
#   ''],
#  ['mason', 'school', 'business', 'current', 'occupants', 'hall', ''],
#  ['stargate', 'produced', 'song', 'mermaid', ''],
#  ['train', 'song', 'mermaid', 'written', 'production', 'team', 'stargate', ''],
#  ['person',
#   'named',
#   'jamie',
#   'lawrence',
#   'member',
#   'brentford',
#   'fc',
#   'someone',
#   'name',
#   'composer',
#   '',
#   'death',
#   'factory',
#   'farm',
#   '',
#   'music',
#   ''],
#  ['jamie',
#   'lawrence',
#   '',
#   'played',
#   'brentford',
#   'fc',
#   '',
#   'wrote',
#   'music',
#   'film',
#   '',
#   'death',
#   'factory',
#   'farm',
#   ''],
#  ['jamie',
#   'lawrence',
#   '',
#   'composed',
#   'death',
#   'factory',
#   'farm',
#   'also',
#   'played',
#   'club',
#   'brentford',
#   'fclet'],
#  ...]

# %% [markdown]
# ## Part-of-speech (POS) tagging
#
# **Exercise 7 (OPTIONAL):** Use POS tagging to find all verbs and nouns.
# - Define a function which takes a spaCy document as input and returns a list of nouns for tokens with POS tag "NOUN" and a list of verbs for tokens with POS tag "VERB"

# %% [markdown]
# ## Named Entity Recognition
#
# **Exercise 8 (OPTIONAL):** Extract all Person names from the file and print them out using spaCy Named Entity Recogniser
# - Define a function which takes a spaCy document as input and returns the list of named entities of type PERSON contained in that document.

# %%
def extract_person_entities(doc):
    """
    Extracts named entities of type 'PERSON' from a spaCy document.

    Parameters:
        doc (spacy.tokens.Doc): The input spaCy document.

    Returns:
        list: A list of named entities of type 'PERSON'.
    """
    return [ent.text for ent in doc.ents if ent.label_ == "PERSON"]

# Example usage:
res_1 = extract_person_entities(sp_tok)
print(set(res_1))  # Output: ['Barack Obama', 'Elon Musk']
# Out:
# {'Unwin', 'Brooke-Taylor', 'T.S. Thakur', 'Bionicos', 'Grigory Neujmin', "Anatole de Grunwald's", 'Hobbit', 'Pat Monahan', 'Tom Lister Jr.', 'the Brian Kelly', '560090.Nie Haisheng', '1953.Wharton Tiers', 'Adam West', 'Paul Ryan', 'Billie Oddie', '0004319.Harry Carey', '1249.6.Ciudad Ayala', 'Graco Ramírez', 'Johnny Colt', 'The Alan B. Miller Hall', 'Jonathan Palmer', 'Nord genre', '1878.Harry Carey', 'Penrose', 'Sarah Teale', 'Leni Robredo', 'J. R. R. Tolkien', "Mary Hayley Bell's", '260855000000.0.Ciudad Ayala', 'Juliet Mills', 'Grigory Neujmin.1147 Stavropolis', 'John N Dempsey', 'Alexandra Badoi', 'John Lennon', 'Eric Flint', 'Louis Levy', 'Estádio Municipal Coaracy da Mata Fonseca', 'Roadburn', 'Joe Biden', 'G.P. Prabhukumar,', 'Espionage', 'Liselotte Grschebina', 'Kempe Gowda I.', 'Benny Blanco', 'Xmas', "Andy Warhol's", 'John Lennon).Approximately', 'Binignit', 'B.M. Reddy', 'Rhein', 'Cyril Bruce', 'Crucial Blast.1147 Stavropolis', 'Graco Ramirez', "Brain Kelly's", '282,838.Abraham A. Ribicoff’s', 'Abdul Taib Mahmud', 'Robert Gates).The Mason School of Business', 'Aquilino Pimentel III', "Phil Spector's", 'Cecil Parker', "Gilbert Taylor's", 'Robert A. Heinlein.1634', "Nicholas Brodszky's", 'Swords Dublin', 'Velvet Underground', 'Espen Lind', 'Airport', 'Andrzej Piotr Ruszczynski', 'Squeeze.1147 Stavropolis', 'Dennis William Sciama', 'Graeme Garden', 'Steve Bright', 'Recep Tayyip Erdoğan', 'Paracuellos de Jarama', 'John Lennon’s', 'Demo 2004.1147', 'USA.Lady Anne Monson', 'Nolasco', 'mobile apps', 'Gadzhi Gadzhiyev,', 'B. Miller Hall', 'Without Tears', "Alan Shepard's", 'Miller Hall', 'Bill Oddie', 'relativity,', '1946.Grigory Neujmin', 'Jon Feltheimer', 'Anatole De Grunwald', 'Turn Me', '418476000000.0.Ciudad Ayala', 'Astronaut Alan Shepard', 'HBO.Sarah Teale', 'Alan B Miller', 'Leszek Borysiewicz', 'Olga Nikolaevna', 'Geof Bartz', 'Dijon', "Sarah Teale's", 'G.P. Prabhukumar', 'cm tall Piotr Hallmann', 'John F. Kennedy', "Lady Anne Monson's", 'Justin Whalin', 'Ciudad Ayala', 'Lira Yin', 'Ted Willis', 'Kent', 'Asa Gigante', "Liselotte Grschebina's", 'Lancashire', 'Mary', 'Roberto Gil Zuarth', 'Robert A.M.', 'Brian Kelly', 'Amkar Perm', 'Felipe Gozon', 'Stacy Katzman', 'La Crosse', "Bedford Aerodrome's", 'Ray Griggs', 'Pools', 'Bobina', 'Buzz Aldrin', '11.5.1147 Stavropolis', 'Jano', 'Rashid Rakhimov', 'Sylvia Tosun', 'Zaoyang', 'George Allen &amp', 'Phil Spector', 'Justin Whalin’s', 'Atasoy', 'Kempe Gowda', "J.R.R. Tolkien's", 'Cyril Frankel', 'Mary Hayley Bell', 'Agremiacao Sportiva Arapiraquense', 'Universal Time', 'Anthony J. Celebrezze', "Andrew Rayel's", 'Alexandre Bergheau', 'Jonathan Mendelsohn', '1955.Justin Whalin', 'Andrzej Piotr Ruszczyński', 'Polydor', 'Brandon Carter', 'Olga Nikolaevna Bondareva', 'Abraham Ribicoff', 'Andy Warhol', 'Tokat', 'Michigan.1147 Stavropolis', 'Botany', 'Huseyin Butuner', 'Prudnikov', 'Lennon', 'Die Wacht', 'Benedict', 'Born 20.11.1894', 'Nova Futebol Clube', 'Carter', '1983.Harry Carey', 'Oberburgermeister', 'Turk', '1878.Gregory Allen', 'Hilmi Guner', 'Maeve Quinlan', 'Abraham A. Ribicoff', 'Dennis William Sciama .English-', 'Demo', 'Dianne Feinstein', 'Fantasy', "Kempe Gowda I.It's", 'Binali Yıldırım', "Casey Ribicoff's", '230:05.Sarah Teale', 'km.1147 Stavropolis', 'David Sainsbury', 'Anne Monson', 'G.P.Prabhukumar', 'John Roberts', 'San Sebastian de los Reyes', 'Piotr Hallmann', 'Bedford Aerodrome', 'Aileen Raymond', "Alan B Miller Hall's", 'Alcobendas', 'HBO.Tom Simon', '418476000000.0.1147 Stavropolis', "Brian Kelly's", '260855000000.0.1147 Stavropolis', '08/26.The Bedford Aerodrome', 'Trane', "de Grunwald's", 'Punk Blues', 'William', 'G. P. Prabhukumar', '3287590000000.0.Nie Haisheng', 'Itzik Braverman', 'Harry Carey', '1604.Ciudad Ayala', 'Abraham A Ribicoff', '1964.Nie Haisheng', 'Robert Gates).Justin Whalin', 'Frank Giustra', 'Spartak Moscow', 'Composer', '1970.Jamie Lawrence', 'Whalin', 'Alan B. Miller Hall’s', 'Nurhan Atasoy', 'Andrew Rayel', '1908.Nurhan Atasoy', 'Aaro ...

# %%
doc = nlp(' '.join(list(map(lambda x: ' '.join(x), sp_tokenl))))

# %%
res = extract_person_entities(doc)
print(set(res))
# Out:
# {'mary hayley bell', 'hobbit genre juvenile fantasy', 'guadalajara granola', 'alan b miller hall  college william mary', 'bangalore ’s', 'dijon  postal', 'william mary mason school business', 'nord e  vinyl', 'tolkien  jrrtolkien', 'michael rooker  ', 'jd245760051147', 'karlsruhe german', 'reith 1st', 'brian kelly  alco', 'karlsruhe', 'steve bright  bananaman', 'tom simon  geof bartz', 'adams county  usa', 'cyril bruce  carey', 'mexico', 'spouse abraham', 'louis levy  gilbert taylor', 'sarah teale  death factory farm', 'college william mary  building', 'preceded brian kelly', 'armin van buuren  andrew rayel', 'der deutschen', 'asa gigante  ground estadio municipal', 'alan b miller hall  college william mary owner', 'john mills cecil parker  ', 'tolkien  agremiacao', 'alan jaggs harold', 'mexico silvano', 'john mills  ', '18l36radolfo suarez', 'headquarters bbc', 'joe biden', 'rd  hessarghatta', 'dr gp prabhukumar  institute', 'bionico dessert', 'de grunwald', 'spouse ruth ribicoff', 'robert gatesthe mason school business', 'sarah teale  running', 'longfield  kent  motorsport vision location', 'way1147', 'juan nolasco  ', 'william mary  building', 'mary alan b miller hall', 'louis missouri', 'birthplace abraham', 'birthplace nie haisheng hubei  olga bondareva', 'hall  alan b miller hall', 'haisheng zaoyang', 'tom simon   death factory', 'india indian  indian', 'college william mary', 'william mary  hall', 'john f kennedy', 'alan bmiller', 'college william mary home mason school business  alan b miller hall', 'zaoyang', 'train song', 'city zaoyang', 'peter ogden  bedford', 'john mills  died denham', 'guadalajara mexico  currency', 'william mary  ', 'pontiac buick', 'reith  ', 'harry carey  movie', 'metro manila  metro', '029anie haisheng', 'ruszczyński  acharya', 'zaoyang hubei', 'philippines  ', 'guadalajara  leader', 'sarah teale  film', 'dijon  campus', 'producer wharton', 'leningrad ussr', 'juan nolasco', 'ruth ribicoff', 'miller hall', 'suarez madrid', 'alumna olga bondareva', 'taylor', 'simon sarah', 'peter ogden  ', 'phil spector', 'dessert', 'language eng  bananaman', 'hbo', 'dennis william sciama  ', 'anne monson  hypermarcas', 'tom simon', 'karnataka soldevanahalli  acharya dr sarvapalli', 'usalady anne monson', 'william mary  completed', 'demonym person', 'pdtjuan nolasco', 'sarah teale  ', 'sarah teale tom simon', 'reith', 'mexico  currency', 'sarah teale death factory farm', 'buzz aldrin  ', 'louis levy  bootleg', 'usa  southeast adams county', 'cyril bruce harry carey  ’s', 'peter ogden  liselotte', 'karnataka', 'part xiangyang  participated shenzhou', 'st louis  ', 'robert stern  building', 'der deutschen die', 'suarez madrid  barajas', 'xiangyang  zaoyang xiangyang', 'john lennonapproximately', 'tom simon sarah', 'part xiangyang  part mission shenzhou', 'nicholas', 'kempe gowda  home acharya institute technology  technical campus', 'reuven rivlin', 'danielle harris', 'peter ogden  peter', 'honeymoon', 'gil zuarth  ', 'dennis william sciama', 'tom simon sarah teale  film', 'adam west  lionsgate', 'hypermarcas  sa corporation', 'mm', 'william mary  located', 'michael r burns', 'jamie lawrence sarah teale', 'michael rooker  film', 'katzman  language', 'john n', 'dennis william', 'robert stern  location', 'zaoyang utc', 'mexico  bionico', 'michael rooker  darinka', 'longfield  kent', 'bananaman starring', 'tittle ciudad', 'adams county', 'nord record label', 'nord  also', 'oberburgermeister  acharya institute technology', 'denham', 'cyril bruce  mcveagh', 'dr gp prabhukumar', 'nicholas brodszky  genre honeymoon', 'nord  year', 'john reith  baron', 'turville  david sainsbury', 'kempe gowda dr g p prabhukumar director', 'dessert guadalajara  mexico', 'justin whalin ’s', 'anne monson  englishwoman', 'shenzhou 10', 'tom simon geof bartz', 'hbotom simon sarah teale directed', 'guadalajara  mexico  inhabited', 'robert stern building completion', 'nz289147darlington', 'haisheng', 'nord  hardcore', 'guadalajara mexico  sande ...

# %%
tokens = [token for token in doc if not (token.is_stop or token.is_punct)]
spacy.tokens.Doc(doc.vocab, words=[token.text for token in tokens])
# Out:
# estádio municipal coaracy da mata fonseca ground agremiação sportiva arapiraquense arapiraca agremiação sportiva arapiraquense   nicknamed   alvinegro    lay campeonato brasileiro série c league brazil estádio municipal coaracy da mata fonseca ground agremiação sportiva arapiraquense arapiraca alvinegro   nickname agremiação sportiva arapiraquense   play campeonato brasileiro série c league brazil nie haisheng   born october 13   1964   worked fighter pilot nie haisheng fighter pilot born october 13   1964niehaisheng born 10131964 fighter pilot motorsport vision located city fawkham motorsport vision located city fawkham   ukmotorsport vision located fawkham185 centimetre tall aleksandr prudnikov played otkrytiye arena based fc spartak   moscow 185 cm tall aleksandr prudnikov plays fc spartak moscow home ground otkrytiye arena aleksandr prudnikov 185 cm tall   plays fc spartak moscow ground otkrytiye arena ciudad ayala city population density population 1604 1777539 respectively   leader called city manager government type city ciudad ayala council   manager city ciudad ayala   population 1777539   led city manager council   manager government system population density 1604ciudad ayala   city population density population 16040 1777539 respectively   uses type government called council   manager government leaders ciudad ayala city manager album 1969   velvet underground live preceded velvet underground album squeeze   followed quine tapes velvet underground album bootleg series volume 1   quine tapes preceded album squeeze   followed live album 1969   velvet underground live bootleg series volume   quine tapes preceded velvet underground album squeeze followed album 1969 velvet underground live ciudad ayala mexico population density 16040 elevated 11470 sea level pdt time zone leader called governator ciudad ayala country mexico located 1147 sea level pacific daylight time zone population density 1604 leader ciudad ayala called governator ciudad ayala located mexico population density 1604 city stands 1147 sea level governator leader ciudad ayala located pacific daylight time zone olga bondareva died december 9   1991olga bondareva died 9th december   1991the date olga bondareva death ninth december 1991saint petersburg founded 27   1703 total area 14390   olga bondareva passed away saint petersburg saint petersburg   olga bondareva died   founded 27th   1703 total area approximately 1439 km2saint petersburg   olga bondareva died   founded 27   1703 consists total area 14390 sq   km population density ciudad ayala 16040ciudad ayala city population density 16040the population density ciudad ayala 1604piotr hallmann born august 25   1987piotr hallmann birthday august 25th1987piotr hallmann born 25th august 1987thedarlington town area code 01325the telephone area code darlington 01325the area code darlington 01325pennsylvania franklin county found west adams county   pennsylvania pennsylvania cumberland county north monument 11th mississippi infantry erected adams county year 2000 municipality gettysburg monument categorised contributing property 11th mississippi infantry monument   contributing property established year 2000 adams county   pennsylvania falls municipality gettysburg   pennsylvania adams county pennsylvania east franklin county   pennsylvania cumberland county   pennsylvania north official language israel modern hebrew israel official language modern hebrew modern hebrew official language israel enaire operating organisation adolfo suarez madrid   barajas airport airport situated 610 meters sea level alcobendas gma new media   company founded 01   01   2000 manufacturers mobile applications gma new media   founded january 1   2000   company offers products mobile applications gma new media makes mobile apps founded 01012000hypermarcas pharmaceutical company located sao paulo   brazil brazil 851483714 square kilometers size hypermarcas   pharmaceutical company   located sao paulo 851483714 square kilometres countr ...

# %%
set(extract_person_entities(doc))
# Out:
# {'029anie haisheng',
#  '040anie haisheng',
#  '10131964nie haisheng',
#  '14l32radolfo suarez madrid',
#  '18l36radolfo suarez',
#  '1964nie haisheng',
#  '1994adolfo suarez',
#  '8nie haisheng',
#  'aaron',
#  'aaron turner',
#  'abraham',
#  'abraham aribicoff',
#  'abraham ribicoff',
#  'abraham ribicoff  ',
#  'abraham ribicoff  abraham',
#  'abraham ribicoff  birthplace  ',
#  'abraham ribicoff ’s birthplace usa',
#  'adam west',
#  'adam west  lionsgate',
#  'adams county',
#  'adams county  usa',
#  'al anbar province  ',
#  'alan',
#  'alan b',
#  'alan b miller',
#  'alan b miller hall',
#  'alan b miller hall  ',
#  'alan b miller hall  college william mary',
#  'alan b miller hall  college william mary owner',
#  'alan b miller hall  mason',
#  'alan b miller hall building',
#  'alan b miller hall mason school business  ',
#  'alan bmiller',
#  'alan jaggs',
#  'alan jaggs  ',
#  'alan jaggs  anatole de grunwald  harold',
#  'alan jaggs  film',
#  'alan jaggs  filmed bernard',
#  'alan jaggs  movie',
#  'alan jaggs bernard',
#  'alan jaggs harold',
#  'alan jaggs1147',
#  'alan shepard',
#  'alan shepard  ',
#  'album nord',
#  'alco rs3',
#  'alexander popov',
#  'alexandre bergheau',
#  'alumna olga bondareva',
#  'anatole de grunwald',
#  'andrew rayel',
#  'andrew rayel  andrew rayel',
#  'andrew rayel trance',
#  'andy warhol',
#  'anne monson',
#  'anne monson  ',
#  'anne monson  englishwoman',
#  'anne monson  hypermarcas',
#  'anne monson  town',
#  'anne monson ’s',
#  'anthony j',
#  'apoapsis1147',
#  'apollo 11he',
#  'apollo 11it',
#  'armin van buuren',
#  'armin van buuren  andrew rayel',
#  'armin van buuren  bobina',
#  'asa gigante',
#  'asa gigante  ground estadio municipal',
#  'asa gigante  play',
#  'au1147',
#  'bananaman  ',
#  'bananaman starring',
#  'bananaman steve',
#  'bangalore ’s',
#  'bedford',
#  'bedford autodrome',
#  'benny blanco',
#  'benny blanco michael jackson  fellowship',
#  'bernard knowles',
#  'bernard knowles  bernard knowles',
#  'bill oddie',
#  'bionico dessert',
#  'bionicos  bionicos',
#  'birth place',
#  'birthplace abraham',
#  'birthplace leningrad',
#  'birthplace liselotte',
#  'birthplace nie haisheng hubei  olga bondareva',
#  'blast1147',
#  'brandon carter',
#  'brian kelly',
#  'brian kelly  ',
#  'brian kelly  alco',
#  'brian kelly  brian',
#  'brian kelly  brian kelly',
#  'brian kelly  composer',
#  'brian kelly  preceded brian',
#  'brian kelly  silmarillion',
#  'burgundy dijon  ',
#  'business1147',
#  'buzz aldrin',
#  'buzz aldrin  ',
#  'carey',
#  'carter',
#  'centimetre tall',
#  'charlie colin',
#  'china1147',
#  'city zaoyang',
#  'cm tall  standing',
#  'cm tall aleksandr',
#  'college william',
#  'college william mary',
#  'college william mary  bootleg',
#  'college william mary  building',
#  'college william mary  ted',
#  'college william mary home mason school business  alan b miller hall',
#  'composer harold',
#  'construction alan',
#  'cyril',
#  'cyril bruce',
#  'cyril bruce  ',
#  'cyril bruce  carey',
#  'cyril bruce  cyril bruce',
#  'cyril bruce  film',
#  'cyril bruce  harry carey',
#  'cyril bruce  imdb',
#  'cyril bruce  located',
#  'cyril bruce  mcveagh',
#  'cyril bruce  piotr',
#  'cyril bruce  starring',
#  'cyril bruce harry carey  actor',
#  'cyril bruce harry carey  born',
#  'cyril bruce harry carey  carey  ',
#  'cyril bruce harry carey  ’s',
#  'danielle harris',
#  'danielle harris  ',
#  'danielle harris  film',
#  'darinka dentcheva',
#  'david sainsbury',
#  'days1147',
#  'de grunwald',
#  'de grunwald  harold',
#  'demarce eric flint',
#  'demonym person',
#  'denham',
#  'dennis william',
#  'dennis william sciama',
#  'dennis william sciama  ',
#  'dennis william sciama  brandon carter',
#  'dennis william sciama  chancellor',
#  'dennis william sciama  doctoral',
#  'dennis william sciama  mermaid',
#  'dentcheva',
#  'der deutschen',
#  'der deutschen die',
#  'dessert',
#  'dessert cookie',
#  'dessert guadalajara  mexico',
#  'dessert mexico',
#  'dijon  ',
#  'dijon  campus',
#  'dijon  postal',
#  'dijon elevation',
#  'dijon france',
#  'dissolution 1707brandon carter',
#  'dr g',
#  'dr g p prabhukumar',
#  'dr g prabhukumar  institute',
#  'dr gp',
#  'dr gp prabhukumar',
#  'dr gp prabhukumar  ',
#  'dr gp prabhukumar  affiliation visvesvaraya',
#  'dr gp prabhukumar  darinka dentcheva',
#  'dr gp prabhukumar  institute',
#  'dr gpprabhukumar  abraham',
#  'dr sarvapalli',
#  'dr sarvapalli radhakrishnan',
#  'dublin  part leinster',
#  'ed lee',
#  'ed lee  ',
#  'ed lee  ed lee  politician',
#  'ed lee resides  bootleg',
#  'england',
#  'england  brandon carter',
#  'england  david sainsbury',
#  'england  dennis william sciama',
#  'england1147',
#  'eric flint',
#  'eric flint  ',
#  'eric flint1634',
#  'eric flint1634  ',
#  'fantasy genre',
#  'frederick county',
#  'genre  ',
#  'genre aaron',
#  'genre high fantasy  aaron',
#  'genre hobbit juvenile fantasy  hobbit genre juvenile fantasy  hobbit',
#  'genre honeymoon',
#  'genre performer',
#  'genre song',
#  'genre trance',
#  'geof bartz',
#  'geof bartz  liselotte',
#  'george allen',
#  'george allen  amp',
#  'george allen  ampunwin',
#  'george death',
#  'george monson',
#  'george monson  ',
#  'george monson  17000',
#  'george monson  professional',
#  'george monson  resided',
#  'george monson  spouse',
#  'georgy poltavchenko',
#  'gil zuarth',
#  'gil zuarth  ',
#  'gilbert taylor',
#  'glen ridge',
#  'glen ridge  ',
#  'government1147',
#  'guadalajara  ',
#  'guadalajara  bionico',
#  'guadalajara  bionico dessert',
#  'guadalajara  chinabank',
#  'guadalajara  ciudad',
#  'guadalajara  currency',
#  'guadalajara  leader',
#  'guadalajara  mexico',
#  'guadalajara  mexico  ',
#  'guadalajara  mexico  bionico',
#  'guadalajara  mexico  inhabitants',
#  'guadalajara  mexico  inhabited',
#  'guadalajara  mexico  mexico',
#  'guadalajara  served',
#  'guadalajara area',
#  'guadalajara granola',
#  'guadalajara mexico  currency',
#  'guadalajara mexico  sandesh  confectionery',
#  'guadalajara region',
#  'gulden',
#  'haisheng',
#  'haisheng apart',
#  'haisheng crew',
#  'haisheng hubei  zaoyang',
#  'haisheng part',
#  'haisheng people',
#  'haisheng people republic',
#  'haisheng zaoyang',
#  'haisheng zaoyang  ',
#  'haisheng zaoyang  xiangyang',
#  'hall  address',
#  'hall  alan b miller hall',
#  'harold french',
#  'harry carey',
#  'harry carey  born',
#  'harry carey  harry carey',
#  'harry carey  imdb',
#  'harry carey  movie',
#  'harry carey cyril bruce  carey',
#  'harry carey cyril bruce  mcveagh',
#  'hayley bell',
#  'hbo',
#  'hbolady anne monson',
#  'hbosarah teale tom simon',
#  'hbotom simon',
#  'hbotom simon sarah teale directed',
#  'headquarters  broadcasting',
#  'headquarters bbc',
#  'hobbit genre',
#  'hobbit genre juvenile fantasy',
#  'honeymoon',
#  'honeymoon killers',
#  'honeymoon killers  ',
#  'honeymoon killers  producer',
#  'hubei  ',
#  'hubei  zaoyang  ',
#  'hubei province  tokat',
#  'hypermarcas  sa corporation',
#  'india  liselotte',
#  'india indian  indian',
#  'india kempe gowda',
#  'india pranab mukherjee',
#  'institute dr g p prabhukumar  institute',
#  'institute dr g p prabhukumar bangalore',
#  'israel reuven rivlin  ',
#  'jalan bako',
#  'jamie lawrence',
#  'jamie lawrence sarah teale',
#  'jano  ',
#  'jd245760051147',
#  'joe biden',
#  'john f kennedy',
#  'john f kennedy presidency  abraham',
#  'john geering',
#  'john geering  ',
#  'john geering starring',
#  'john lennon',
#  'john lennon  acharya institute',
#  'john lennon  musician',
#  'john lennon song',
#  'john lennon ’s',
#  'john lennonapproximately',
#  'john mills',
#  'john mills  ',
#  'john mills  died denham',
#  'john mills  film',
#  'john mills  great',
#  'john mills  runs',
#  'john mills cecil',
#  'john mills cecil parker',
#  'john mills cecil parker  ',
#  'john mills denham',
#  'john n',
#  'john n dempsey husband',
#  'john reith',
#  'john reith  ',
#  'john reith  baron',
#  'john roberts',
#  'johnny colt',
#  'jonathan mendelsohn  ',
#  'jonathan palmer  founded',
#  'jonathan palmer  motorsport vision',
#  'jonathan palmer  operates',
#  'juan nolasco',
#  'juan nolasco  ',
#  'juliet mills  ',
#  'justin whalin  98 minutes',
#  'justin whalin  box office  ',
#  'justin whalin  film',
#  'justin whalin  grossed',
#  'justin whalin  song train',
#  'justin whalin ’s',
#  'jwaydan',
#  'karlsruhe',
#  'karlsruhe  ',
#  'karlsruhe  liselotte',
#  'karlsruhe 17346karlsruhe',
#  'karlsruhe 76131  76229liselotte',
#  'karlsruhe german',
#  'karlsruhe israeli',
#  'karlsruhe may 2  ',
#  'karlsruhe within',
#  'karnataka',
#  'karnataka  george allen  amp',
#  'karnataka soldevanahalli  acharya dr sarvapalli',
#  'katzman',
#  'katzman  language',
#  'kelly',
#  'kelly ’s',
#  'kempe gowda',
#  'kempe gowda  home acharya institute',
#  'kempe gowda  home acharya institute technology  technical campus',
#  'kempe gowda  soldevanahalli  acharya dr sarvapalli radhakrishnan',
#  'kempe gowda dr g p prabhukumar director',
#  'km²  istanbul eastern',
#  'knowles cinematographer',
#  'knowles cinematographer  ',
#  'la crosse',
#  'lady anne monson',
#  'language eng  bananaman',
#  'leader saint',
#  'leader turkey',
#  'leader1147',
#  'leningrad ussr',
#  'london1147',
#  'longfield  bootleg series',
#  'longfield  kent',
#  'longfield  kent  motorsport vision location',
#  'longfield  motorsport vision city',
#  'louis levy',
#  'louis levy  ',
#  'louis levy  aaron',
#  'louis levy  bootleg',
#  'louis levy  cecil',
#  'louis levy  cinematography',
#  'louis levy  college william mary',
#  'louis levy  film',
#  'louis levy  gilbert taylor',
#  'louis levy  great',
#  'louis levy  length',
#  'louis levy  louis levy',
#  'louis levy  native',
#  'louis levy composer',
#  'louis levy running',
#  'louis missouri',
#  'louis missouri  bootleg',
#  'louis missouri  usa',
#  'manager1147',
#  'mark sixma  ',
#  'mary alan b miller hall',
#  'mary hayley bell',
#  'max',
#  'metro manila  metro',
#  'metropolis morelos  part',
#  'mexico',
#  'mexico  anatole de grunwald',
#  'mexico  bionico',
#  'mexico  currency',
#  'mexico silvano',
#  'michael',
#  'michael jackson',
#  'michael r burns',
#  'michael rooker',
#  'michael rooker  ',
#  'michael rooker  darinka',
#  'michael rooker  dijon  ',
#  'michael rooker  film',
#  'michael rooker  language',
#  'michael rooker  ’s',
#  'michael rooker budget  ',
#  'michael rooker tom',
#  'michigan1147',
#  'miller hall',
#  'mk44  icao',
#  'mm',
#  'morelos  ',
#  'motorsport vision',
#  'musician lotus',
#  'nicholas',
#  'nicholas brodszky',
#  'nicholas brodszky  ',
#  'nicholas brodszky  adams county',
#  'nicholas brodszky  bernard',
#  'nicholas brodszky  film',
#  'nicholas brodszky  genre honeymoon',
#  'nicholas brodszky  harold french',
#  'nicholas brodszky  hypermarcas sa corporation',
#  'nicholas brodszky  runs',
#  'nicholas brodszky harold',
#  'nie haisheng',
#  'nord',
#  'nord  ',
#  'nord  2006',
#  'nord  5841',
#  'nord  also',
#  'nord  hardcore',
#  'nord  nord',
#  'nord  released',
#  'nord  year',
#  'nord e  vinyl',
#  'nord record label',
#  'nz289147',
#  'nz289147darlington',
#  'oberburgermeister  acharya institute technology',
#  'olga',
#  'olga bondareva',
#  'olga bondareva alma',
#  'olga bondareva alma mater leningrad state',
#  'olga bondareva full',
#  'olga nikolaevna',
#  'olga nikolaevna bondareva',
#  'olga nikolaevna bondareva leningrad state',
#  'part michigan',
#  'part xiangyang  part mission shenzhou',
#  'part xiangyang  participated shenzhou',
#  'part xiangyang hubei province  ',
#  'pat monahan  nord',
#  'paul ryan',
#  'paul ryan  ',
#  'paul ryan  lady',
#  'pdtjuan nolasco',
#  'peter ogden',
#  'peter ogden  ',
#  'peter ogden  bedford',
#  'peter ogden  liselotte',
#  'peter ogden  peter',
#  'peter ogden  wharton',
#  'phil spector',
#  'philippines  ',
#  'pontiac buick',
#  'pontiac buick  pontiac',
#  'prabhukumar soldevanahalli  acharya dr sarvapalli radhakrishnan',
#  'preceded brian',
#  'preceded brian kelly',
#  'producer wharton',
#  'property1147',
#  'quinlan',
#  'quinlan  ’s',
#  'rattigan  rattigan',
#  'ray griggs',
#  'raymond  john mills',
#  'raymond  liselotte',
#  'rd  hessarghatta',
#  'reith',
#  'reith  ',
#  'reith  founded',
#  'reith 1st',
#  'reuven rivlin',
#  'reuven rivlin  ',
#  'reuven rivlin  liselotte',
#  'rhein  grschebina',
#  'rhein  liselotte',
#  'robert gates  building',
#  'robert gatesjustin whalin',
#  'robert gatesthe mason school business',
#  'robert heinlein  ',
#  'robert heinlein1634  bavarian',
#  'robert stern',
#  'robert stern  ',
#  'robert stern   ',
#  'robert stern  address',
#  'robert stern  address hall',
#  'robert stern  began',
#  'robert stern  building',
#  'robert stern  building hall',
#  'robert stern  college william mary',
#  'robert stern  construction',
#  'robert stern  hall',
#  'robert stern  hall  ',
#  'robert stern  honey',
#  'robert stern  located',
#  'robert stern  location',
#  'robert stern  owner building college',
#  'robert stern building began',
#  'robert stern building completion',
#  'robert stern georgian',
#  'robert stern project',
#  'ruszczyński  ',
#  'ruszczyński  acharya',
#  'ruszczyński  dentcheva',
#  'ruszczyński  pat',
#  'ruth',
#  'ruth ribicoff',
#  'ruth ribicoff  ',
#  'ruth ribicoff  abraham',
#  'ruth ribicoff  bedford',
#  'ruth ribicoff  citizen usa',
#  'ruth ribicoff abraham office',
#  'sandesh dessert',
#  'sarah',
#  'sarah teale',
#  'sarah teale  ',
#  'sarah teale  death factory farm',
#  'sarah teale  film',
#  'sarah teale  geof bartz',
#  'sarah teale  jamie lawrence',
#  'sarah teale  movie',
#  'sarah teale  running',
#  'sarah teale death factory farm',
#  'sarah teale producer',
#  'sarah teale running',
#  'sarah teale tom simon',
#  'sarvapalli radhakrishnan',
#  'shenzhou',
#  'shenzhou 10',
#  'shenzhou 6nie haisheng',
#  'simon sarah',
#  'soldevanahalli  acharya dr sarvapalli radhakrishnan',
#  'southeast  wharton',
#  'spouse abraham',
#  'spouse ruth ribicoff',
#  'spouse woman',
#  'squeeze1147',
#  'st louis  ',
#  'stacy katzman',
#  'stacy katzman  budget',
#  'stacy katzman  motorsport vision',
#  'stars michael rooker',
#  'steve',
#  'steve bright',
#  'steve bright  ',
#  'steve bright  bananaman',
#  'steve bright bananaman',
#  'suarez madrid',
#  'suarez madrid  barajas',
#  'suárez madrid',
#  'swords  dublin',
#  'sylvia tosun  lira yin  alexandra badoi  andrew rayel',
#  'sylvia tosun  lira yin alexandra badoi',
#  'sylvia tosun  lira yin alexandra badoi  andrew rayel',
#  'taylor',
#  'tim brooke  taylor',
#  'tittle ciudad',
#  'tolkien',
#  'tolkien  ',
#  'tolkien  agremiacao',
#  'tolkien  brandon carter',
#  'tolkien  george allen  amp',
#  'tolkien  jrr tolkien',
#  'tolkien  jrrtolkien',
#  'tolkien  published',
#  'tolkien  two',
#  'tolkien silmarillion  silmarillion',
#  'tom lister',
#  'tom lister jr',
#  'tom lister jr  ',
#  'tom lister jr film',
#  'tom lister jr movie',
#  'tom simon',
#  'tom simon  ',
#  'tom simon   death factory',
#  'tom simon  83 minute',
#  'tom simon  83 minutes',
#  'tom simon  acharya institute',
#  'tom simon  geof bartz',
#  'tom simon  jamie lawrence',
#  'tom simon geof bartz',
#  'tom simon sarah',
#  'tom simon sarah teale  film',
#  'train song',
#  'turkey binali',
#  'turville  david sainsbury',
#  'turville  dennis william sciama',
#  'turville1147',
#  'uklady anne monson',
#  'united states',
#  'unwin  george allen  amp',
#  'unwin  jrrtolkien  belongs fantasy',
#  'usa  african',
#  'usa  carroll county',
#  'usa  robert stern',
#  'usa  robert stern  ',
#  'usa  southeast adams county',
#  'usa african',
#  'usabrandon carter',
#  'usalady anne monson',
#  'way1147',
#  'whalin michael rooker  whalin',
#  'wharton',
#  'william mary',
#  'william mary  ',
#  'william mary  address',
#  'william mary  alan',
#  'william mary  american',
#  'william mary  architect',
#  'william mary  building',
#  'william mary  chancellor',
#  'william mary  college william',
#  'william mary  completed',
#  'william mary  construction',
#  'william mary  currently',
#  'william mary  hall',
#  'william mary  liselotte',
#  'william mary  located',
#  'william mary  michael',
#  'william mary  robert stern',
#  'william mary  started',
#  'william mary alan b',
#  'william mary building',
#  'william mary campus',
#  'william mary located',
#  'william mary mason school business',
#  'xiangyang',
#  'xiangyang  zaoyang xiangyang',
#  'zaoyang',
#  'zaoyang  ',
#  'zaoyang  xiangyang  hubei province  crew',
#  'zaoyang citizen',
#  'zaoyang city',
#  'zaoyang hubei',
#  'zaoyang part',
#  'zaoyang utc'}

# %% [markdown]
# ### Putting it all together
#
# **Exercise 9**
# Now we are going to use the code and functions defined in the preceding exercises to pre-process the webnlg.txt file in one go and extract from it:
# - a list of sentences (cf. Exercise 3)
# - a list of tokens (cf. Exercise 4)
# - a list of lowercased tokens excluding punctuation signs and function words (cf. Exercise 6)
# - a list of nouns and verbs (cf. Exercise 7)
# - a list of named entities (cf. Exercise 8)
#
# Define a function which takes a file as input and stores the 5 lists above into a file. Apply this function to the webnlg.txt file. This should yield a new file containing the 5 lists above.
#
# **N.B.** To be able to save SpaCy objects to a file, you'll need to use the `__repr__()` method which represents SpaCy objects as strings (cf. spacy CS)

# %%
def EveryProc(txt_file):
    rawtext=open(txt_file).read()
    doc = nlp(rawtext)
    sent_l = SentSpilt(doc)
    tok_l = [SpacyTokSeq(s) for s in sent_l]
    proc_l = StopWordsRem([Processing(s, ) for s in tok_l])
    ner_l = list(set(extract_person_entities(doc)))
    return sent_l, tok_l,  proc_l, ner_l

# %%
sent_l, tok_l,  proc_l, ner_l = EveryProc('webnlg-test.txt')

# %%
len(sent_l)
# Out:
# 6429

# %%
sum(map(len, proc_l))
# Out:
# 83951

# %%
sum(map(len, tok_l))
# Out:
# 128191

# %%
ner_l
# Out:
# ['Unwin',
#  'Brooke-Taylor',
#  'T.S. Thakur',
#  'Bionicos',
#  'Grigory Neujmin',
#  "Anatole de Grunwald's",
#  'Hobbit',
#  'Pat Monahan',
#  'Tom Lister Jr.',
#  'the Brian Kelly',
#  '560090.Nie Haisheng',
#  '1953.Wharton Tiers',
#  'Adam West',
#  'Paul Ryan',
#  'Billie Oddie',
#  '0004319.Harry Carey',
#  '1249.6.Ciudad Ayala',
#  'Graco Ramírez',
#  'Johnny Colt',
#  'The Alan B. Miller Hall',
#  'Jonathan Palmer',
#  'Nord genre',
#  '1878.Harry Carey',
#  'Penrose',
#  'Sarah Teale',
#  'Leni Robredo',
#  'J. R. R. Tolkien',
#  "Mary Hayley Bell's",
#  '260855000000.0.Ciudad Ayala',
#  'Juliet Mills',
#  'Grigory Neujmin.1147 Stavropolis',
#  'John N Dempsey',
#  'Alexandra Badoi',
#  'John Lennon',
#  'Eric Flint',
#  'Louis Levy',
#  'Estádio Municipal Coaracy da Mata Fonseca',
#  'Roadburn',
#  'Joe Biden',
#  'G.P. Prabhukumar,',
#  'Espionage',
#  'Liselotte Grschebina',
#  'Kempe Gowda I.',
#  'Benny Blanco',
#  'Xmas',
#  "Andy Warhol's",
#  'John Lennon).Approximately',
#  'Binignit',
#  'B.M. Reddy',
#  'Rhein',
#  'Cyril Bruce',
#  'Crucial Blast.1147 Stavropolis',
#  'Graco Ramirez',
#  "Brain Kelly's",
#  '282,838.Abraham A. Ribicoff’s',
#  'Abdul Taib Mahmud',
#  'Robert Gates).The Mason School of Business',
#  'Aquilino Pimentel III',
#  "Phil Spector's",
#  'Cecil Parker',
#  "Gilbert Taylor's",
#  'Robert A. Heinlein.1634',
#  "Nicholas Brodszky's",
#  'Swords Dublin',
#  'Velvet Underground',
#  'Espen Lind',
#  'Airport',
#  'Andrzej Piotr Ruszczynski',
#  'Squeeze.1147 Stavropolis',
#  'Dennis William Sciama',
#  'Graeme Garden',
#  'Steve Bright',
#  'Recep Tayyip Erdoğan',
#  'Paracuellos de Jarama',
#  'John Lennon’s',
#  'Demo 2004.1147',
#  'USA.Lady Anne Monson',
#  'Nolasco',
#  'mobile apps',
#  'Gadzhi Gadzhiyev,',
#  'B. Miller Hall',
#  'Without Tears',
#  "Alan Shepard's",
#  'Miller Hall',
#  'Bill Oddie',
#  'relativity,',
#  '1946.Grigory Neujmin',
#  'Jon Feltheimer',
#  'Anatole De Grunwald',
#  'Turn Me',
#  '418476000000.0.Ciudad Ayala',
#  'Astronaut Alan Shepard',
#  'HBO.Sarah Teale',
#  'Alan B Miller',
#  'Leszek Borysiewicz',
#  'Olga Nikolaevna',
#  'Geof Bartz',
#  'Dijon',
#  "Sarah Teale's",
#  'G.P. Prabhukumar',
#  'cm tall Piotr Hallmann',
#  'John F. Kennedy',
#  "Lady Anne Monson's",
#  'Justin Whalin',
#  'Ciudad Ayala',
#  'Lira Yin',
#  'Ted Willis',
#  'Kent',
#  'Asa Gigante',
#  "Liselotte Grschebina's",
#  'Lancashire',
#  'Mary',
#  'Roberto Gil Zuarth',
#  'Robert A.M.',
#  'Brian Kelly',
#  'Amkar Perm',
#  'Felipe Gozon',
#  'Stacy Katzman',
#  'La Crosse',
#  "Bedford Aerodrome's",
#  'Ray Griggs',
#  'Pools',
#  'Bobina',
#  'Buzz Aldrin',
#  '11.5.1147 Stavropolis',
#  'Jano',
#  'Rashid Rakhimov',
#  'Sylvia Tosun',
#  'Zaoyang',
#  'George Allen &amp',
#  'Phil Spector',
#  'Justin Whalin’s',
#  'Atasoy',
#  'Kempe Gowda',
#  "J.R.R. Tolkien's",
#  'Cyril Frankel',
#  'Mary Hayley Bell',
#  'Agremiacao Sportiva Arapiraquense',
#  'Universal Time',
#  'Anthony J. Celebrezze',
#  "Andrew Rayel's",
#  'Alexandre Bergheau',
#  'Jonathan Mendelsohn',
#  '1955.Justin Whalin',
#  'Andrzej Piotr Ruszczyński',
#  'Polydor',
#  'Brandon Carter',
#  'Olga Nikolaevna Bondareva',
#  'Abraham Ribicoff',
#  'Andy Warhol',
#  'Tokat',
#  'Michigan.1147 Stavropolis',
#  'Botany',
#  'Huseyin Butuner',
#  'Prudnikov',
#  'Lennon',
#  'Die Wacht',
#  'Benedict',
#  'Born 20.11.1894',
#  'Nova Futebol Clube',
#  'Carter',
#  '1983.Harry Carey',
#  'Oberburgermeister',
#  'Turk',
#  '1878.Gregory Allen',
#  'Hilmi Guner',
#  'Maeve Quinlan',
#  'Abraham A. Ribicoff',
#  'Dennis William Sciama .English-',
#  'Demo',
#  'Dianne Feinstein',
#  'Fantasy',
#  "Kempe Gowda I.It's",
#  'Binali Yıldırım',
#  "Casey Ribicoff's",
#  '230:05.Sarah Teale',
#  'km.1147 Stavropolis',
#  'David Sainsbury',
#  'Anne Monson',
#  'G.P.Prabhukumar',
#  'John Roberts',
#  'San Sebastian de los Reyes',
#  'Piotr Hallmann',
#  'Bedford Aerodrome',
#  'Aileen Raymond',
#  "Alan B Miller Hall's",
#  'Alcobendas',
#  'HBO.Tom Simon',
#  '418476000000.0.1147 Stavropolis',
#  "Brian Kelly's",
#  '260855000000.0.1147 Stavropolis',
#  '08/26.The Bedford Aerodrome',
#  'Trane',
#  "de Grunwald's",
#  'Punk Blues',
#  'William',
#  'G. P. Prabhukumar',
#  '3287590000000.0.Nie Haisheng',
#  'Itzik Braverman',
#  'Harry Carey',
#  '1604.Ciudad Ayala',
#  'Abraham A Ribicoff',
#  '1964.Nie Haisheng',
#  'Robert Gates).Justin Whalin',
#  'Frank Giustra',
#  'Spartak Moscow',
#  'Composer',
#  '1970.Jamie Lawrence',
#  'Whalin',
#  'Alan B. Miller Hall’s',
#  'Nurhan Atasoy',
#  'Andrew Rayel',
#  '1908.Nurhan Atasoy',
#  'Aaron Turner',
#  'Stavropolis.1147 Stavropolis',
#  'Max Benedict',
#  'Roberts',
#  "Spartak Moscow's",
#  'Grschebina',
#  'Abraham A. Ribs',
#  'J.R.R. Tolkien’s',
#  'CEO.Aleksandr Prudnikov',
#  'Michael Jackson',
#  'Jwaydan',
#  'Robert A. M. Stern',
#  'Gadzhi Gadzhiyev',
#  'Gilbert Taylor’s',
#  'Robert Gates',
#  'JD2457600.5).1147 Stavropolis',
#  'Grozny',
#  'Dentcheva',
#  'km²',
#  'Reşadiye',
#  'Haisheng',
#  'Aldrin',
#  'Simon',
#  'Alan B. Miller Hall',
#  "Aaron Turner's",
#  'Karlsruhe',
#  'Charlie Colin',
#  'The Velvet Underground',
#  'Abraham',
#  'EGBF.Casey Ribicoff',
#  'John Lennon’s Imagine',
#  'Arapiraca',
#  'Darinka Dentcheva',
#  'Rattigan',
#  'Doomsday',
#  'Demo 2004.Following',
#  'native Bill Oddie',
#  'Aerodrome',
#  'Taib Mahmud',
#  'Gregory Allen',
#  'Tapes',
#  'Eric',
#  'Terence Rattigan',
#  'Robert A.M. Stern',
#  'Armin van Buuren',
#  'Michael Rooker',
#  'J.R.R. Tolkien',
#  'McVeagh',
#  'St Petersburg',
#  'Sarvapalli Radhakrishnan Road',
#  'E-Vinyl',
#  'Digify',
#  'Christian Burns',
#  'Polydor Records',
#  'Noise Rock',
#  'Sehitleri Aniti',
#  'John Reith',
#  '21000.Ciudad Ayala',
#  'Oberbürgermeister',
#  'Abraham A.Ribicoff',
#  'Trance',
#  'Reith',
#  'days.1147 Stavropolis',
#  'Tom Sizemore',
#  'Suarez Madrid',
#  'A. Ribicoff',
#  'genre performer',
#  'Bedford Autodrome',
#  'B. M. Reddy',
#  '76229.Liselotte Grschebina',
#  'Parker',
#  'Tim Brooke-Taylor',
#  'Robert Stern',
#  'The Bedford Aerodrome',
#  'Ring',
#  'Otkrytiye Arena',
#  'Noise',
#  'England.1147 Stavropolis',
#  'Tom Lister Jr. Directed',
#  'Suárez Madrid',
#  'Cuernavaca',
#  'Peso',
#  'Buick',
#  "Terek Grozny's",
#  'Hüseyin Bütüner',
#  'Suarez Madrid-Barajas Airport',
#  'Mukherjee',
#  'Alan Shepard’s',
#  'Andrzej Piotr Ruszczynski -',
#  'Artist Brian Kelly',
#  'Demo 2004.Nurhan Atasoy',
#  'Vila Nova',
#  'Wharton Tiers',
#  'Jalan Bako',
#  'DeMarce',
#  'A.M. Stern',
#  'John Geering',
#  'Jwaydan Moyine',
#  'Lady Anne Monson’s',
#  '1972550.0.Ciudad Ayala',
#  'Vica',
#  'Chopped Fruits',
#  'George Allen',
#  '03/08/1970.Jamie Lawrence',
#  'government.1147 Stavropolis',
#  'Recep Tayyip Erdogan',
#  'English Without Tears',
#  'Vila Nova Futebol Clube',
#  'AU.1147 Stavropolis',
#  'FC Spartak',
#  'Nicholas Brodszky',
#  "Olga Bondareva's",
#  '83.0.Sarah Teale',
#  'Casey Ribicoff',
#  'Soldevanahalli',
#  'Baron Reith',
#  'Leningrad',
#  'Bangalore',
#  'de Grunwald',
#  'Hakeem Ayers',
#  'Kempe Gowda I. Dr.',
#  'Deutschen',
#  'Ribicoff',
#  'Hilmi Güner',
#  'Olga Bondareva',
#  "km^2.Nurhan Atasoy's",
#  'Hayley Mills',
#  'Brentford',
#  'Economics',
#  "Nurhan Atasoy's",
#  'Alexander Popov',
#  'Akeem Ayers',
#  'Binali Yildirim',
#  'Locomotive Works',
#  'Carey',
#  '2691.0.1147 Stavropolis',
#  "Ciudad Ayala's",
#  'Cookie',
#  'Mark Sixma',
#  'the Carter Constant',
#  'Robert A.M Stern',
#  "Aleksandr Prudnikov's",
#  'Bananaman',
#  '1954.Abraham A. Ribicoff',
#  'Bernard Knowles',
#  'Olga',
#  'Harold French',
#  'Georgy Poltavchenko',
#  'Stavropolis',
#  'Dennis William Sciama .Brandon',
#  'The Brian Kelly',
#  "Anne Monson's",
#  'Reuven Rivlin',
#  '356.Nie Haisheng',
#  'Tikva',
#  '1998.Ciudad Ayala',
#  'Pussy Galore',
#  'Nie Haisheng',
#  'Astronaut',
#  'Peter Ogden',
#  'Darinka Dentcheva’s alma mater',
#  'Alan Shepard',
#  'Armin Van Buuren',
#  'Aleksandr Prudnikov',
#  'music.1147 Stavropolis',
#  'NZ289147.Lady Anne Monson',
#  'Die Wacht Am Rhein',
#  'Robert AM Stern',
#  'George',
#  'Louis levy',
#  'Michael R. Burns',
#  '2001.1147 Stavropolis',
#  'Ed Lee',
#  'Jamie Lawrence',
#  'Ruth Ribicoff',
#  '2000.Liselotte Grschebina',
#  'Abraham A. Ribicoff’s',
#  'Kelly',
#  'Leinster',
#  'John Mills',
#  'George Allen &',
#  "Grigory Neujmin's",
#  'Hessarghatta Main Road',
#  'Petah Tikva',
#  'Juan Nolasco',
#  'Claude Bartolone',
#  'Philippines,',
#  'Lady Anne Monson',
#  '54.56).Geof Bartz',
#  'Amund Bjørklund',
#  'Michael R Burns',
#  'Brandon',
#  'R. R. Tolkien',
#  'Xiangyang',
#  'John N. Dempsey',
#  'Lucian Grainge',
#  'John F. Kennedy’s',
#  'Danielle Harris',
#  'Lou Reed',
#  'J.R.R.Tolkien',
#  'Demo 2004',
#  'J.R.R Tolkien',
#  'Stargate',
#  'Happy Xmas',
#  'George Allen &amp;Unwin',
#  'Breed',
#  'Anatole de Grunwald',
#  'Tom Simon',
#  'F. Kennedy',
#  'Alan Jaggs',
#  'Robert A. Heinlein',
#  'Turville.1147 Stavropolis',
#  'Jonny Rose',
#  '20378.5.1147 Stavropolis',
#  'Olga Bondareva’s',
#  'Mermaid',
#  "Darinka Dentcheva's",
#  'Carter Constant',
#  'Anatole Grunwald',
#  'Hypermarcas',
#  'alma mater',
#  'leader.1147 Stavropolis',
#  '14L/32R.Alan Shepard',
#  'George Monson',
#  'Sarvapalli Radhakrishnan',
#  'Gilbert Taylor',
#  'Alan Jaggs.1147 Stavropolis',
#  'Lawrence',
#  'Agremiação Sportiva Arapiraquense',
#  "Brandon Carter's",
#  'Virginia DeMarce',
#  'Alan B Miller Hall',
#  'G. Prabhukumar',
#  'Business.1147 Stavropolis',
#  "John Lennon's",
#  'Robert A M Stern',
#  "Polydor Records'",
#  'Honeymoon Killers',
#  'Nord',
#  "Steve Bright's"]
