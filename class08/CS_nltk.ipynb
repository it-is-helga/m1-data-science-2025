# %% [markdown]
# # NLTK

# %%
import nltk
nltk.download('punkt')  # Downloads the Punkt tokenizer models
nltk.download('punkt_tab')# Downloads additional tokenizer models
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /home/tacit/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/tacit/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/tacit/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
#  Summary for segmentation, POS tagging and tokenization
rawtext=open("webnlg-test.txt").read()
sentences = nltk.sent_tokenize(rawtext) # NLTK default sentence  segmenter
tokens = [nltk.word_tokenize(sent) for sent in sentences] # NLTK word tokenizer
postags = [nltk.pos_tag(sent) for sent in sentences] # NLTK POS tagger
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 sentences = nltk.sent_tokenize(rawtext) # NLTK default sentence  segmenter
#       4 tokens = [nltk.word_tokenize(sent) for sent in sentences] # NLTK word tokenizer
# ----> 5 postags = [nltk.pos_tag(sent) for sent in sentences] # NLTK POS tagger
#
# Cell In[9], line 5, in <listcomp>(.0)
#       3 sentences = nltk.sent_tokenize(rawtext) # NLTK default sentence  segmenter
#       4 tokens = [nltk.word_tokenize(sent) for sent in sentences] # NLTK word tokenizer
# ----> 5 postags = [nltk.pos_tag(sent) for sent in sentences] # NLTK POS tagger
#
# File ~/.local/lib/python3.10/site-packages/nltk/tag/__init__.py:169, in pos_tag(tokens, tagset, lang)
#     144 """
#     145 Use NLTK's currently recommended part of speech tagger to
#     146 tag the given list of tokens.
#    (...)
#     166 :rtype: list(tuple(str, str))
#     167 """
#     168 tagger = _get_tagger(lang)
# --> 169 return _pos_tag(tokens, tagset, tagger, lang)
#
# File ~/.local/lib/python3.10/site-packages/nltk/tag/__init__.py:123, in _pos_tag(tokens, tagset, tagger, lang)
#     121 # Throws Error if tokens is of string type
#     122 elif isinstance(tokens, str):
# --> 123     raise TypeError("tokens: expected a list of strings, got a string")
#     125 else:
#     126     tagged_tokens = tagger.tag(tokens)
#
# TypeError: tokens: expected a list of strings, got a string

# %% [markdown]
# #### Segmenting a string into sentences

# %%
import nltk
text = "John loves apples. He does'nt like pears."

# text must be a string
sentences = nltk.sent_tokenize(text)
print(sentences)

# %% [markdown]
# #### Segmenting a string into tokens

# %%
import nltk
text = "John loves apples"

# text must be a string 
tokens = nltk.word_tokenize(text)
print(tokens)

# %% [markdown]
# #### Retrieving NLTK Stop Words list

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
en_stopwords = stopwords.words('english')
print(en_stopwords)

# %% [markdown]
# #### POS Tagging

# %%
import nltk

sentence = "Amélie is a story about a girl named Amélie whose childhood was suppressed by her Father's mistaken concerns of a heart defect."

# Tokenize and Pos-tag the sentence
tokens = nltk.word_tokenize(sentence)
tagged_tokens = nltk.pos_tag(tokens) 
tagged_tokens

# %% [markdown]
# #### Lemmatizing
#
# Given a token and its POS tag, NLTK WordNet lemmatizer (nltk.stem.wordnet.WordNetLemmatizer) will return its lemma i.e., the word form which is usually found in dictionary entries.

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/tacit/nltk_data...
# True

# %%
# Instantiate a lemmatizer object
lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
      
word_form = "suppressed"

# For this lemmatizer, we need to indicate the POS of the word 
# (in this case, v for verb)
lemma = lemmatizer.lemmatize(word_form, "v") 
print(word_form, lemma)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/nltk/corpus/util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~/.local/lib/python3.10/site-packages/nltk/data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - '/home/tacit/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[10], line 8
#       4 word_form = "suppressed"
#       6 # For this lemmatizer, we need to indicate the POS of the word
#       7 # (in this case, v for verb)
# ----> 8 lemma = lemmatizer.lemmatize(word_form, "v")
#       9 print(word_form, lemma)
#
# File ~/.local/lib/python3.10/site-packages/nltk/stem/wordnet.py:85, in WordNetLemmatizer.lemmatize(self, word, pos)
#      60 def lemmatize(self, word: str, pos: str = "n") -> str:
#      61     """Lemmatize `word` by picking the shortest of the possible lemmas,
#      62     using the wordnet corpus reader's built-in _morphy function.
#      63     Returns the input word unchanged if it cannot be found in WordNet.
#    (...)
#      83     :return: The shortest lemma of `word`, for the given `pos`.
#      84     """
# ---> 85     lemmas = self._morphy(word, pos)
#      86     return min(lemmas, key=len) if lemmas else word
#
# File ~/.local/lib/python3.10/site-packages/nltk/stem/wordnet.py:41, in WordNetLemmatizer._morphy(self, form, pos, check_exceptions)
#      31 """
#      32 _morphy() is WordNet's _morphy lemmatizer.
#      33 It returns a list of all lemmas found in WordNet.
#    (...)
#      37 ['us', 'u']
#      38 """
#      39 from nltk.corpus import wordnet as wn
# ---> 41 return wn._morphy(form, pos, check_exceptions)
#
# File ~/.local/lib/python3.10/site-packages/nltk/corpus/util.py:120, in LazyCorpusLoader.__getattr__(self, attr)
#     117 if attr == "__bases__":
#     118     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 120 self.__load()
#     121 # This looks circular, but its not, since __load() changes our
#     122 # __class__ to something new:
#     123 return getattr(self, attr)
#
# File ~/.local/lib/python3.10/site-packages/nltk/corpus/util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~/.local/lib/python3.10/site-packages/nltk/corpus/util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~/.local/lib/python3.10/site-packages/nltk/data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - '/home/tacit/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# #### Stemming

# %%
from nltk.stem.porter import PorterStemmer
# Create a stemmer instance
porter = PorterStemmer()
sentence = "Mr. and Mrs. Dursley, of number four, Privet Drive in Stansted, were proud to say that they were perfectly normal, thank you very much."
# Tokenize
tokens = nltk.word_tokenize(sentence)
# Apply the stemmer and collect the stems
porterlemmas = []
for word in tokens:
    porterlemmas.append(porter.stem(word))
print(porterlemmas)
